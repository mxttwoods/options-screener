# %% [markdown]
# # 🎯 LEAPS Screener — May 2026+ Expirations
#
# **Conviction picks (bold):** GEV, AMAT, AVGO
# **Full watchlist:** WDC, GEV, STX, LRCX, AMAT, TSM, GE, CMI, KLAC, SNPS, META, UBER, ISRG, MSFT, AMZN, AVGO
#
# Screens for deep-ITM to ATM call LEAPS with ≥90 DTE (May 2026+).
# Evaluates: IV, liquidity, breakeven, leverage ratio, and cost efficiency.

# %%
import time
import warnings
import math
from datetime import datetime
from typing import Optional

import numpy as np
import pandas as pd
import yfinance as yf

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

from IPython.display import display, Markdown

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 60)
pd.set_option("display.width", 200)
pd.set_option("display.max_rows", 200)

# ── Config ──────────────────────────────────────────────────────
CONVICTION = ["GEV", "AMAT", "AVGO"]

ALL_TICKERS = [
    "WDC",
    "GEV",
    "STX",
    "LRCX",
    "AMAT",
    "TSM",
    "GE",
    "CMI",
    "KLAC",
    "SNPS",
    "META",
    "UBER",
    "ISRG",
    "MSFT",
    "AMZN",
    "AVGO",
]

MIN_DTE = 90  # May 2026+ from today
MONEYNESS_RANGE = (0.80, 1.05)  # 80% to 105% of spot (deep-ITM to slightly OTM)
RATE_LIMIT_SLEEP = 0.35
MIN_OPEN_INTEREST = 20
DELTA_TARGETS = [0.80, 0.70, 0.60]  # typical LEAPS deltas
RISK_FREE_RATE = 0.045  # ~4.5% annualised (T-bill proxy) — used everywhere

# Plot style
pio.renderers.default = "notebook_connected"

print(f"Tickers: {len(ALL_TICKERS)}")
print(f"Conviction: {', '.join(CONVICTION)}")
print(f"Min DTE: {MIN_DTE} days  (targets May 2026+)")
# Out:
# Tickers: 16
# Conviction: GEV, AMAT, AVGO
# Min DTE: 90 days  (targets May 2026+)

# %% [markdown]
# ## 1. Fetch Spot Prices & Available LEAPS Expirations

# %%
def get_spot(ticker: str) -> Optional[float]:
    """Get current spot price."""
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        hist = t.history(period="5d")
        if not hist.empty and "Close" in hist.columns:
            return float(hist["Close"].iloc[-1])
        return None
    except Exception:
        return None


def get_leap_expirations(ticker: str, min_dte: int = MIN_DTE) -> list[tuple[str, int]]:
    """Return expirations with DTE >= min_dte."""
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        today = datetime.now().date()
        result = []
        for exp_str in t.options or []:
            try:
                exp_date = datetime.strptime(exp_str, "%Y-%m-%d").date()
                dte = (exp_date - today).days
                if dte >= min_dte:
                    result.append((exp_str, dte))
            except ValueError:
                continue
        return sorted(result, key=lambda x: x[1])
    except Exception:
        return []


# Fetch spots and expirations
spot_map = {}
exp_map = {}
ticker_info = []

for ticker in ALL_TICKERS:
    spot = get_spot(ticker)
    spot_map[ticker] = spot
    exps = get_leap_expirations(ticker) if spot else []
    exp_map[ticker] = exps

    ticker_info.append(
        {
            "Ticker": ticker,
            "Conviction": "⭐" if ticker in CONVICTION else "",
            "Spot": spot,
            "LEAPS Expirations": len(exps),
            "Nearest LEAPS": exps[0][0] if exps else "—",
            "Nearest DTE": exps[0][1] if exps else None,
            "Farthest LEAPS": exps[-1][0] if exps else "—",
            "Farthest DTE": exps[-1][1] if exps else None,
        }
    )

info_df = pd.DataFrame(ticker_info)
display(Markdown("### Spot Prices & LEAPS Availability"))
display(
    info_df.style.format(
        {
            "Spot": "${:,.2f}",
            "Nearest DTE": "{:.0f}",
            "Farthest DTE": "{:.0f}",
        },
        na_rep="—",
    ).set_caption("All tickers — ⭐ = conviction pick")
)
# Out:
# ### Spot Prices & LEAPS Availability
# <style type="text/css">
# </style>
# <table id="T_b39d1">
#   <caption>All tickers — ⭐ = conviction pick</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b39d1_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_b39d1_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_b39d1_level0_col2" class="col_heading level0 col2" >Spot</th>
#       <th id="T_b39d1_level0_col3" class="col_heading level0 col3" >LEAPS Expirations</th>
#       <th id="T_b39d1_level0_col4" class="col_heading level0 col4" >Nearest LEAPS</th>
#       <th id="T_b39d1_level0_col5" class="col_heading level0 col5" >Nearest DTE</th>
#       <th id="T_b39d1_level0_col6" class="col_heading level0 col6" >Farthest LEAPS</th>
#       <th id="T_b39d1_level0_col7" class="col_heading level0 col7" >Farthest DTE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b39d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b39d1_row0_col0" class="data row0 col0" >WDC</td>
#       <td id="T_b39d1_row0_col1" class="data row0 col1" ></td>
#       <td id="T_b39d1_row0_col2" class="data row0 col2" >$282.58</td>
#       <td id="T_b39d1_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_b39d1_row0_col4" class="data row0 col4" >2026-06-18</td>
#       <td id="T_b39d1_row0_col5" class="data row0 col5" >130</td>
#       <td id="T_b39d1_row0_col6" class="data row0 col6" >2028-01-21</td>
#       <td id="T_b39d1_row0_col7" class="data row0 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b39d1_row1_col0" class="data row1 col0" >GEV</td>
#       <td id="T_b39d1_row1_col1" class="data row1 col1" >⭐</td>
#       <td id="T_b39d1_row1_col2" class="data row1 col2" >$779.35</td>
#       <td id="T_b39d1_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_b39d1_row1_col4" class="data row1 col4" >2026-05-15</td>
#       <td id="T_b39d1_row1_col5" class="data row1 col5" >96</td>
#       <td id="T_b39d1_row1_col6" class="data row1 col6" >2028-12-15</td>
#       <td id="T_b39d1_row1_col7" class="data row1 col7" >1041</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b39d1_row2_col0" class="data row2 col0" >STX</td>
#       <td id="T_b39d1_row2_col1" class="data row2 col1" ></td>
#       <td id="T_b39d1_row2_col2" class="data row2 col2" >$429.32</td>
#       <td id="T_b39d1_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_b39d1_row2_col4" class="data row2 col4" >2026-06-18</td>
#       <td id="T_b39d1_row2_col5" class="data row2 col5" >130</td>
#       <td id="T_b39d1_row2_col6" class="data row2 col6" >2028-01-21</td>
#       <td id="T_b39d1_row2_col7" class="data row2 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b39d1_row3_col0" class="data row3 col0" >LRCX</td>
#       <td id="T_b39d1_row3_col1" class="data row3 col1" ></td>
#       <td id="T_b39d1_row3_col2" class="data row3 col2" >$231.01</td>
#       <td id="T_b39d1_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_b39d1_row3_col4" class="data row3 col4" >2026-06-18</td>
#       <td id="T_b39d1_row3_col5" class="data row3 col5" >130</td>
#       <td id="T_b39d1_row3_col6" class="data row3 col6" >2028-01-21</td>
#       <td id="T_b39d1_row3_col7" class="data row3 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b39d1_row4_col0" class="data row4 col0" >AMAT</td>
#       <td id="T_b39d1_row4_col1" class="data row4 col1" >⭐</td>
#       <td id="T_b39d1_row4_col2" class="data row4 col2" >$322.51</td>
#       <td id="T_b39d1_row4_col3" class="data row4 col3" >10</td>
#       <td id="T_b39d1_row4_col4" class="data row4 col4" >2026-05-15</td>
#       <td id="T_b39d1_row4_col5" class="data row4 col5" >96</td>
#       <td id="T_b39d1_row4_col6" class="data row4 col6" >2028-01-21</td>
#       <td id="T_b39d1_row4_col7" class="data row4 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b39d1_row5_col0" class="data row5 col0" >TSM</td>
#       <td id="T_b39d1_row5_col1" class="data row5 col1" ></td>
#       <td id="T_b39d1_row5_col2" class="data row5 col2" >$348.85</td>
#       <td id="T_b39d1_row5_col3" class="data row5 col3" >10</td>
#       <td id="T_b39d1_row5_col4" class="data row5 col4" >2026-05-15</td>
#       <td id="T_b39d1_row5_col5" class="data row5 col5" >96</td>
#       <td id="T_b39d1_row5_col6" class="data row5 col6" >2028-12-15</td>
#       <td id="T_b39d1_row5_col7" class="data row5 col7" >1041</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b39d1_row6_col0" class="data row6 col0" >GE</td>
#       <td id="T_b39d1_row6_col1" class="data row6 col1" ></td>
#       <td id="T_b39d1_row6_col2" class="data row6 col2" >$321.00</td>
#       <td id="T_b39d1_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_b39d1_row6_col4" class="data row6 col4" >2026-05-15</td>
#       <td id="T_b39d1_row6_col5" class="data row6 col5" >96</td>
#       <td id="T_b39d1_row6_col6" class="data row6 col6" >2028-01-21</td>
#       <td id="T_b39d1_row6_col7" class="data row6 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b39d1_row7_col0" class="data row7 col0" >CMI</td>
#       <td id="T_b39d1_row7_col1" class="data row7 col1" ></td>
#       <td id="T_b39d1_row7_col2" class="data row7 col2" >$577.73</td>
#       <td id="T_b39d1_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_b39d1_row7_col4" class="data row7 col4" >2026-06-18</td>
#       <td id="T_b39d1_row7_col5" class="data row7 col5" >130</td>
#       <td id="T_b39d1_row7_col6" class="data row7 col6" >2026-09-18</td>
#       <td id="T_b39d1_row7_col7" class="data row7 col7" >222</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b39d1_row8_col0" class="data row8 col0" >KLAC</td>
#       <td id="T_b39d1_row8_col1" class="data row8 col1" ></td>
#       <td id="T_b39d1_row8_col2" class="data row8 col2" >$1,442.95</td>
#       <td id="T_b39d1_row8_col3" class="data row8 col3" >7</td>
#       <td id="T_b39d1_row8_col4" class="data row8 col4" >2026-05-15</td>
#       <td id="T_b39d1_row8_col5" class="data row8 col5" >96</td>
#       <td id="T_b39d1_row8_col6" class="data row8 col6" >2028-01-21</td>
#       <td id="T_b39d1_row8_col7" class="data row8 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b39d1_row9_col0" class="data row9 col0" >SNPS</td>
#       <td id="T_b39d1_row9_col1" class="data row9 col1" ></td>
#       <td id="T_b39d1_row9_col2" class="data row9 col2" >$426.88</td>
#       <td id="T_b39d1_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_b39d1_row9_col4" class="data row9 col4" >2026-06-18</td>
#       <td id="T_b39d1_row9_col5" class="data row9 col5" >130</td>
#       <td id="T_b39d1_row9_col6" class="data row9 col6" >2028-01-21</td>
#       <td id="T_b39d1_row9_col7" class="data row9 col7" >712</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b39d1_row10_col0" class="data row10 col0" >META</td>
#       <td id="T_b39d1_row10_col1" class="data row10 col1" ></td>
#       <td id="T_b39d1_row10_col2" class="data row10 col2" >$661.46</td>
#       <td id="T_b39d1_row10_col3" class="data row10 col3" >14</td>
#       <td id="T_b39d1_row10_col4" class="data row10 col4" >2026-05-15</td>
#       <td id="T_b39d1_row10_col5" class="data row10 col5" >96</td>
#       <td id="T_b39d1_row10_col6" class="data row10 col6" >2028-12-15</td>
#       <td id="T_b39d1_row10_col7" class="data row10 col7" >1041</td>
#     </tr>
#     <tr>
#       <th id="T_b39d1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b39

# %% [markdown]
# ## 2. Fetch LEAPS Chains & Build Comparison Table
#
# For each ticker, pull call chains at available LEAPS expirations.
# Filter to strikes between 80–105% of spot (deep-ITM to slightly OTM).
# Compute breakeven, leverage ratio, and extrinsic value %.

# %%
def safe_float(v):
    try:
        return float(v) if v is not None else np.nan
    except Exception:
        return np.nan


def fetch_leaps_calls(ticker: str, exp_date: str, spot: float) -> pd.DataFrame:
    """Fetch call chain and enrich with LEAPS metrics."""
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        chain = t.option_chain(exp_date)
        df = chain.calls.copy()
        if df.empty:
            return df

        exp_dt = datetime.strptime(exp_date, "%Y-%m-%d").date()
        dte = (exp_dt - datetime.now().date()).days

        df["ticker"] = ticker
        df["expiration"] = exp_date
        df["dte"] = dte
        df["spot"] = spot
        df["mid"] = (df["bid"] + df["ask"]) / 2
        df.loc[df["mid"] <= 0, "mid"] = df["lastPrice"]
        df["moneyness"] = df["strike"] / spot
        df["spread"] = df["ask"] - df["bid"]
        df["spread_pct"] = np.where(df["mid"] > 0, df["spread"] / df["mid"], np.nan)

        # LEAPS-specific metrics
        df["intrinsic"] = np.maximum(spot - df["strike"], 0)
        df["extrinsic"] = df["mid"] - df["intrinsic"]
        df["extrinsic_pct"] = np.where(
            df["mid"] > 0, df["extrinsic"] / df["mid"], np.nan
        )
        df["breakeven"] = df["strike"] + df["mid"]
        df["breakeven_pct"] = (df["breakeven"] - spot) / spot
        df["leverage"] = np.where(df["mid"] > 0, spot / df["mid"], np.nan)
        df["cost_per_contract"] = df["mid"] * 100
        df["iv"] = df["impliedVolatility"]

        # Filter to LEAPS-relevant range
        mask = (
            (df["moneyness"] >= MONEYNESS_RANGE[0])
            & (df["moneyness"] <= MONEYNESS_RANGE[1])
            & (df["mid"] > 0)
        )
        return df[mask].copy()
    except Exception as e:
        print(f"  ⚠ {ticker} {exp_date}: {e}")
        return pd.DataFrame()


# Pull chains for ALL tickers — pick the 2 nearest LEAPS expirations per ticker
all_leaps = []
skipped = []

for ticker in ALL_TICKERS:
    spot = spot_map.get(ticker)
    exps = exp_map.get(ticker, [])
    if not spot or not exps:
        skipped.append(ticker)
        continue

    # Take up to 3 expirations to give options across time horizons
    selected_exps = exps[:3]
    print(f"📊 {ticker} (${spot:.2f}) — pulling {len(selected_exps)} expirations...")

    for exp_date, dte in selected_exps:
        df = fetch_leaps_calls(ticker, exp_date, spot)
        if not df.empty:
            all_leaps.append(df)

if skipped:
    print(f"\n⚠ Skipped (no spot/expirations): {skipped}")

leaps_df = pd.concat(all_leaps, ignore_index=True) if all_leaps else pd.DataFrame()
print(f"\n✅ Total LEAPS options fetched: {len(leaps_df)}")
print(
    f"   Tickers with data: {leaps_df['ticker'].nunique() if not leaps_df.empty else 0}"
)
# Out:
# 📊 WDC ($282.58) — pulling 3 expirations...
# 📊 GEV ($779.35) — pulling 3 expirations...
# 📊 STX ($429.32) — pulling 3 expirations...
# 📊 LRCX ($231.01) — pulling 3 expirations...
# 📊 AMAT ($322.51) — pulling 3 expirations...
# 📊 TSM ($348.85) — pulling 3 expirations...
# 📊 GE ($321.00) — pulling 3 expirations...
# 📊 CMI ($577.73) — pulling 2 expirations...
# 📊 KLAC ($1442.95) — pulling 3 expirations...
# 📊 SNPS ($426.88) — pulling 3 expirations...
# 📊 META ($661.46) — pulling 3 expirations...
# 📊 UBER ($74.77) — pulling 3 expirations...
# 📊 ISRG ($488.15) — pulling 3 expirations...
# 📊 MSFT ($401.14) — pulling 3 expirations...
# 📊 AMZN ($210.32) — pulling 3 expirations...
# 📊 AVGO ($332.92) — pulling 3 expirations...
#
# ✅ Total LEAPS options fetched: 536
#    Tickers with data: 16

# %% [markdown]
# ## 3. Best LEAPS Picks per Ticker
#
# For each ticker, find the "sweet spot" LEAPS: ~80–90% moneyness (10–20% ITM) with reasonable liquidity.
# These give stock-like delta exposure at a fraction of the cost.

# %%
if leaps_df.empty:
    display(Markdown("❌ No LEAPS data available."))
else:
    # For each ticker × expiration, pick the best option at ~0.85 moneyness (15% ITM)
    # and also show ATM for comparison
    pick_rows = []

    for ticker in ALL_TICKERS:
        tdf = leaps_df[leaps_df["ticker"] == ticker]
        if tdf.empty:
            continue
        spot = spot_map[ticker]

        for exp_date in tdf["expiration"].unique():
            edf = tdf[tdf["expiration"] == exp_date].copy()
            dte = edf["dte"].iloc[0]

            # Deep ITM pick (~80-85% moneyness for high delta)
            deep_itm = edf[(edf["moneyness"] >= 0.78) & (edf["moneyness"] <= 0.87)]
            if not deep_itm.empty:
                best = deep_itm.loc[(deep_itm["moneyness"] - 0.82).abs().idxmin()]
                pick_rows.append(
                    {
                        "Ticker": ticker,
                        "Conviction": "⭐" if ticker in CONVICTION else "",
                        "Type": "Deep ITM",
                        "Expiration": exp_date,
                        "DTE": dte,
                        "Strike": best["strike"],
                        "Moneyness": best["moneyness"],
                        "Bid": best["bid"],
                        "Ask": best["ask"],
                        "Mid": best["mid"],
                        "IV": best["iv"],
                        "Intrinsic": best["intrinsic"],
                        "Extrinsic": best["extrinsic"],
                        "Extrinsic %": best["extrinsic_pct"],
                        "Breakeven": best["breakeven"],
                        "Breakeven %": best["breakeven_pct"],
                        "Leverage": best["leverage"],
                        "Cost/Contract": best["cost_per_contract"],
                        "OI": safe_float(best.get("openInterest")),
                        "Volume": safe_float(best.get("volume")),
                        "Spread %": best["spread_pct"],
                        "Spot": spot,
                    }
                )

            # Moderate ITM pick (~90% moneyness)
            mod_itm = edf[(edf["moneyness"] >= 0.87) & (edf["moneyness"] <= 0.93)]
            if not mod_itm.empty:
                best = mod_itm.loc[(mod_itm["moneyness"] - 0.90).abs().idxmin()]
                pick_rows.append(
                    {
                        "Ticker": ticker,
                        "Conviction": "⭐" if ticker in CONVICTION else "",
                        "Type": "ITM ~90%",
                        "Expiration": exp_date,
                        "DTE": dte,
                        "Strike": best["strike"],
                        "Moneyness": best["moneyness"],
                        "Bid": best["bid"],
                        "Ask": best["ask"],
                        "Mid": best["mid"],
                        "IV": best["iv"],
                        "Intrinsic": best["intrinsic"],
                        "Extrinsic": best["extrinsic"],
                        "Extrinsic %": best["extrinsic_pct"],
                        "Breakeven": best["breakeven"],
                        "Breakeven %": best["breakeven_pct"],
                        "Leverage": best["leverage"],
                        "Cost/Contract": best["cost_per_contract"],
                        "OI": safe_float(best.get("openInterest")),
                        "Volume": safe_float(best.get("volume")),
                        "Spread %": best["spread_pct"],
                        "Spot": spot,
                    }
                )

            # ATM pick (~100% moneyness)
            atm = edf[(edf["moneyness"] >= 0.97) & (edf["moneyness"] <= 1.03)]
            if not atm.empty:
                best = atm.loc[(atm["moneyness"] - 1.0).abs().idxmin()]
                pick_rows.append(
                    {
                        "Ticker": ticker,
                        "Conviction": "⭐" if ticker in CONVICTION else "",
                        "Type": "ATM",
                        "Expiration": exp_date,
                        "DTE": dte,
                        "Strike": best["strike"],
                        "Moneyness": best["moneyness"],
                        "Bid": best["bid"],
                        "Ask": best["ask"],
                        "Mid": best["mid"],
                        "IV": best["iv"],
                        "Intrinsic": best["intrinsic"],
                        "Extrinsic": best["extrinsic"],
                        "Extrinsic %": best["extrinsic_pct"],
                        "Breakeven": best["breakeven"],
                        "Breakeven %": best["breakeven_pct"],
                        "Leverage": best["leverage"],
                        "Cost/Contract": best["cost_per_contract"],
                        "OI": safe_float(best.get("openInterest")),
                        "Volume": safe_float(best.get("volume")),
                        "Spread %": best["spread_pct"],
                        "Spot": spot,
                    }
                )

    picks_df = pd.DataFrame(pick_rows)

    display(Markdown("### 🏆 LEAPS Picks — All Tickers"))
    display(
        Markdown(
            "*Deep ITM = highest delta / stock replacement | ITM ~90% = balance of delta + leverage | ATM = max leverage*"
        )
    )

    fmt = {
        "Strike": "${:,.0f}",
        "Bid": "${:,.2f}",
        "Ask": "${:,.2f}",
        "Mid": "${:,.2f}",
        "IV": "{:.1%}",
        "Intrinsic": "${:,.2f}",
        "Extrinsic": "${:,.2f}",
        "Extrinsic %": "{:.1%}",
        "Breakeven": "${:,.2f}",
        "Breakeven %": "{:+.1%}",
        "Leverage": "{:.1f}x",
        "Cost/Contract": "${:,.0f}",
        "OI": "{:,.0f}",
        "Volume": "{:,.0f}",
        "Spread %": "{:.1%}",
        "Spot": "${:,.2f}",
        "Moneyness": "{:.1%}",
    }
    display(
        picks_df.style.format(fmt, na_rep="—").set_caption(
            "LEAPS Call Options — May 2026+ Expirations"
        )
    )
# Out:
# ### 🏆 LEAPS Picks — All Tickers
# *Deep ITM = highest delta / stock replacement | ITM ~90% = balance of delta + leverage | ATM = max leverage*
# <style type="text/css">
# </style>
# <table id="T_1348f">
#   <caption>LEAPS Call Options — May 2026+ Expirations</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1348f_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_1348f_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_1348f_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_1348f_level0_col3" class="col_heading level0 col3" >Expiration</th>
#       <th id="T_1348f_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_1348f_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_1348f_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_1348f_level0_col7" class="col_heading level0 col7" >Bid</th>
#       <th id="T_1348f_level0_col8" class="col_heading level0 col8" >Ask</th>
#       <th id="T_1348f_level0_col9" class="col_heading level0 col9" >Mid</th>
#       <th id="T_1348f_level0_col10" class="col_heading level0 col10" >IV</th>
#       <th id="T_1348f_level0_col11" class="col_heading level0 col11" >Intrinsic</th>
#       <th id="T_1348f_level0_col12" class="col_heading level0 col12" >Extrinsic</th>
#       <th id="T_1348f_level0_col13" class="col_heading level0 col13" >Extrinsic %</th>
#       <th id="T_1348f_level0_col14" class="col_heading level0 col14" >Breakeven</th>
#       <th id="T_1348f_level0_col15" class="col_heading level0 col15" >Breakeven %</th>
#       <th id="T_1348f_level0_col16" class="col_heading level0 col16" >Leverage</th>
#       <th id="T_1348f_level0_col17" class="col_heading level0 col17" >Cost/Contract</th>
#       <th id="T_1348f_level0_col18" class="col_heading level0 col18" >OI</th>
#       <th id="T_1348f_level0_col19" class="col_heading level0 col19" >Volume</th>
#       <th id="T_1348f_level0_col20" class="col_heading level0 col20" >Spread %</th>
#       <th id="T_1348f_level0_col21" class="col_heading level0 col21" >Spot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1348f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1348f_row0_col0" class="data row0 col0" >WDC</td>
#       <td id="T_1348f_row0_col1" class="data row0 col1" ></td>
#       <td id="T_1348f_row0_col2" class="data row0 col2" >Deep ITM</td>
#       <td id="T_1348f_row0_col3" class="data row0 col3" >2026-06-18</td>
#       <td id="T_1348f_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_1348f_row0_col5" class="data row0 col5" >$230</td>
#       <td id="T_1348f_row0_col6" class="data row0 col6" >81.4%</td>
#       <td id="T_1348f_row0_col7" class="data row0 col7" >$79.55</td>
#       <td id="T_1348f_row0_col8" class="data row0 col8" >$85.50</td>
#       <td id="T_1348f_row0_col9" class="data row0 col9" >$82.53</td>
#       <td id="T_1348f_row0_col10" class="data row0 col10" >86.2%</td>
#       <td id="T_1348f_row0_col11" class="data row0 col11" >$52.58</td>
#       <td id="T_1348f_row0_col12" class="data row0 col12" >$29.95</td>
#       <td id="T_1348f_row0_col13" class="data row0 col13" >36.3%</td>
#       <td id="T_1348f_row0_col14" class="data row0 col14" >$312.52</td>
#       <td id="T_1348f_row0_col15" class="data row0 col15" >+10.6%</td>
#       <td id="T_1348f_row0_col16" class="data row0 col16" >3.4x</td>
#       <td id="T_1348f_row0_col17" class="data row0 col17" >$8,252</td>
#       <td id="T_1348f_row0_col18" class="data row0 col18" >430</td>
#       <td id="T_1348f_row0_col19" class="data row0 col19" >3</td>
#       <td id="T_1348f_row0_col20" class="data row0 col20" >7.2%</td>
#       <td id="T_1348f_row0_col21" class="data row0 col21" >$282.58</td>
#     </tr>
#     <tr>
#       <th id="T_1348f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1348f_row1_col0" class="data row1 col0" >WDC</td>
#       <td id="T_1348f_row1_col1" class="data row1 col1" ></td>
#       <td id="T_1348f_row1_col2" class="data row1 col2" >ITM ~90%</td>
#       <td id="T_1348f_row1_col3" class="data row1 col3" >2026-06-18</td>
#       <td id="T_1348f_row1_col4" class="data row1 col4" >130</td>
#       <td id="T_1348f_row1_col5" class="data row1 col5" >$250</td>
#       <td id="T_1348f_row1_col6" class="data row1 col6" >88.5%</td>
#       <td id="T_1348f_row1_col7" class="data row1 col7" >$68.00</td>
#       <td id="T_1348f_row1_col8" class="data row1 col8" >$74.85</td>
#       <td id="T_1348f_row1_col9" class="data row1 col9" >$71.42</td>
#       <td id="T_1348f_row1_col10" class="data row1 col10" >85.2%</td>
#       <td id="T_1348f_row1_col11" class="data row1 col11" >$32.58</td>
#       <td id="T_1348f_row1_col12" class="data row1 col12" >$38.85</td>
#       <td id="T_1348f_row1_col13" class="data row1 col13" >54.4%</td>
#       <td id="T_1348f_row1_col14" class="data row1 col14" >$321.43</td>
#       <td id="T_1348f_row1_col15" class="data row1 col15" >+13.7%</td>
#       <td id="T_1348f_row1_col16" class="data row1 col16" >4.0x</td>
#       <td id="T_1348f_row1_col17" class="data row1 col17" >$7,142</td>
#       <td id="T_1348f_row1_col18" class="data row1 col18" >545</td>
#       <td id="T_1348f_row1_col19" class="data row1 col19" >12</td>
#       <td id="T_1348f_row1_col20" class="data row1 col20" >9.6%</td>
#       <td id="T_1348f_row1_col21" class="data row1 col21" >$282.58</td>
#     </tr>
#     <tr>
#       <th id="T_1348f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1348f_row2_col0" class="data row2 col0" >WDC</td>
#       <td id="T_1348f_row2_col1" class="data row2 col1" ></td>
#       <td id="T_1348f_row2_col2" class="data row2 col2" >ATM</td>
#       <td id="T_1348f_row2_col3" class="data row2 col3" >2026-06-18</td>
#       <td id="T_1348f_row2_col4" class="data row2 col4" >130</td>
#       <td id="T_1348f_row2_col5" class="data row2 col5" >$280</td>
#       <td id="T_1348f_row2_col6" class="data row2 col6" >99.1%</td>
#       <td id="T_1348f_row2_col7" class="data row2 col7" >$55.10</td>
#       <td id="T_1348f_row2_col8" class="data row2 col8" >$60.30</td>
#       <td id="T_1348f_row2_col9" class="data row2 col9" >$57.70</td>
#       <td id="T_1348f_row2_col10" class="data row2 col10" >84.8%</td>
#       <td id="T_1348f_row2_col11" class="data row2 col11" >$2.58</td>
#       <td id="T_1348f_row2_col12" class="data row2 col12" >$55.12</td>
#       <td id="T_1348f_row2_col13" class="data row2 col13" >95.5%</td>
#       <td id="T_1348f_row2_col14" class="data row2 col14" >$337.70</td>
#       <td id="T_1348f_row2_col15" class="data row2 col15" >+19.5%</td>
#       <td id="T_1348f_row2_col16" class="data row2 col16" >4.9x</td>
#       <td id="T_1348f_row2_col17" class="data row2 col17" >$5,770</td>
#       <td id="T_1348f_row2_col18" class="data row2 col18" >326</td>
#       <td id="T_1348f_row2_col19" class="data row2 col19" >23</td>
#       <td id="T_1348f_row2_col20" class="data row2 col20" >9.0%</td>
#       <td id="T_1348f_row2_col21" class="data row2 col21" >$282.58</td>
#     </tr>
#     <tr>
#       <th id="T_1348f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1348f_row3_col0" class="data row3 col0" >WDC</td>
#       <td id="T_1348f_row3_col1" class="data row3 col1" ></td>
#       <td id="T_1348f_row3_col2" class="data row3 col2" >Deep ITM</td>
#       <td id="T_1348f_row3_col3" class="data row3 col3" >2026-07-17</td>
#       <td id="T_1348f_row3_col4" class="data row3 col4" >159</td>
#       <td id="T_1348f_row3_col5" class="data row3 col5" >$230</td>
#       <td id="T_1348f_row3_col6" class="data row3 col6" >81.4%</td>
#       <td id="T_1348f_row3_col7" class="data row3 col7" >$84.00</td>
#       <td id="T_1348f_row3_col8" class="data row3 col8" >$89.50</td>
#       <td id="T_1348f_row3_col9" class="data row3 col9" >$86.75</td>
#       <td id="T_1348f_row3_col10" class="data row3 col10" >85.0%</td>
#       <td id="T_1348f_row3_col11" class="data row3 col11" >$52.58</td>
#       <td id="T_1348f_row3_col12" class="data row3 col12" >$34.17</td>
#       <td id="T_1348f_row3_col13" class="data row3 col13" >39.4%</td>
#       <td id="T_1348f_row3_col14" class="data row3 col14" >$316.75</td>
#       <td id="T_1348f_row3_

# %% [markdown]
# ## 4. Conviction Picks Deep Dive — GEV, AMAT, AVGO
#
# Detailed comparison of your three conviction names across strike levels and expirations.
# Key question: **what's the cheapest way to get long-dated exposure?**

# %%
if leaps_df.empty:
    display(Markdown("❌ No data."))
else:
    for ticker in CONVICTION:
        tdf = leaps_df[leaps_df["ticker"] == ticker].copy()
        spot = spot_map.get(ticker)
        if tdf.empty or spot is None:
            display(Markdown(f"### ⚠ {ticker} — no LEAPS data"))
            continue

        display(Markdown(f"---\n### ⭐ {ticker}  —  Spot: ${spot:,.2f}"))

        # Show full chain filtered to interesting range for nearest LEAPS expiration
        nearest_exp = tdf["expiration"].min()
        nearest_dte = tdf[tdf["expiration"] == nearest_exp]["dte"].iloc[0]

        chain = tdf[tdf["expiration"] == nearest_exp].sort_values("strike")

        display(Markdown(f"**Nearest LEAPS:** {nearest_exp} ({nearest_dte} DTE)"))

        show_cols = [
            "strike",
            "moneyness",
            "bid",
            "ask",
            "mid",
            "iv",
            "intrinsic",
            "extrinsic",
            "extrinsic_pct",
            "breakeven",
            "breakeven_pct",
            "leverage",
            "cost_per_contract",
            "openInterest",
            "volume",
            "spread_pct",
        ]
        available_cols = [c for c in show_cols if c in chain.columns]
        display(
            chain[available_cols]
            .style.format(
                {
                    "strike": "${:,.0f}",
                    "moneyness": "{:.1%}",
                    "bid": "${:,.2f}",
                    "ask": "${:,.2f}",
                    "mid": "${:,.2f}",
                    "iv": "{:.1%}",
                    "intrinsic": "${:,.2f}",
                    "extrinsic": "${:,.2f}",
                    "extrinsic_pct": "{:.1%}",
                    "breakeven": "${:,.2f}",
                    "breakeven_pct": "{:+.1%}",
                    "leverage": "{:.1f}x",
                    "cost_per_contract": "${:,.0f}",
                    "openInterest": "{:,.0f}",
                    "volume": "{:,.0f}",
                    "spread_pct": "{:.1%}",
                },
                na_rep="—",
            )
            .set_caption(f"{ticker} — {nearest_exp} LEAPS Calls")
        )

        # Scenario analysis: what happens if stock moves ±10%, ±20%
        display(Markdown(f"\n**Scenario P&L (at expiration) — {ticker}**"))
        scenarios = [-0.20, -0.10, 0.0, +0.10, +0.20, +0.30]
        scenario_rows = []
        # Pick 3 representative strikes
        for moneyness_target in [0.85, 0.90, 1.00]:
            candidates = chain[(chain["moneyness"] - moneyness_target).abs() < 0.05]
            if candidates.empty:
                continue
            opt = candidates.loc[
                (candidates["moneyness"] - moneyness_target).abs().idxmin()
            ]
            strike = opt["strike"]
            cost = opt["mid"]
            for move in scenarios:
                future_spot = spot * (1 + move)
                payout = max(future_spot - strike, 0)
                pnl = payout - cost
                pnl_pct = pnl / cost if cost > 0 else np.nan
                scenario_rows.append(
                    {
                        "Strike": strike,
                        "Moneyness": opt["moneyness"],
                        "Cost": cost,
                        "Stock Move": move,
                        "Future Spot": future_spot,
                        "Payout": payout,
                        "P&L": pnl,
                        "P&L %": pnl_pct,
                    }
                )

        if scenario_rows:
            sdf = pd.DataFrame(scenario_rows)
            pivot = sdf.pivot_table(
                index=["Strike", "Moneyness", "Cost"],
                columns="Stock Move",
                values="P&L %",
            )
            pivot.columns = [f"{c:+.0%}" for c in pivot.columns]
            display(
                pivot.style.format("{:+.0%}", na_rep="—")
                .background_gradient(cmap="RdYlGn", axis=None, vmin=-1, vmax=2)
                .set_caption(f"{ticker} — LEAPS P&L % at Expiration by Stock Move")
            )
# Out:
# ---
# ### ⭐ GEV  —  Spot: $779.35
# **Nearest LEAPS:** 2026-05-15 (96 DTE)
# <style type="text/css">
# </style>
# <table id="T_b293d">
#   <caption>GEV — 2026-05-15 LEAPS Calls</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b293d_level0_col0" class="col_heading level0 col0" >strike</th>
#       <th id="T_b293d_level0_col1" class="col_heading level0 col1" >moneyness</th>
#       <th id="T_b293d_level0_col2" class="col_heading level0 col2" >bid</th>
#       <th id="T_b293d_level0_col3" class="col_heading level0 col3" >ask</th>
#       <th id="T_b293d_level0_col4" class="col_heading level0 col4" >mid</th>
#       <th id="T_b293d_level0_col5" class="col_heading level0 col5" >iv</th>
#       <th id="T_b293d_level0_col6" class="col_heading level0 col6" >intrinsic</th>
#       <th id="T_b293d_level0_col7" class="col_heading level0 col7" >extrinsic</th>
#       <th id="T_b293d_level0_col8" class="col_heading level0 col8" >extrinsic_pct</th>
#       <th id="T_b293d_level0_col9" class="col_heading level0 col9" >breakeven</th>
#       <th id="T_b293d_level0_col10" class="col_heading level0 col10" >breakeven_pct</th>
#       <th id="T_b293d_level0_col11" class="col_heading level0 col11" >leverage</th>
#       <th id="T_b293d_level0_col12" class="col_heading level0 col12" >cost_per_contract</th>
#       <th id="T_b293d_level0_col13" class="col_heading level0 col13" >openInterest</th>
#       <th id="T_b293d_level0_col14" class="col_heading level0 col14" >volume</th>
#       <th id="T_b293d_level0_col15" class="col_heading level0 col15" >spread_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b293d_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_b293d_row0_col0" class="data row0 col0" >$630</td>
#       <td id="T_b293d_row0_col1" class="data row0 col1" >80.8%</td>
#       <td id="T_b293d_row0_col2" class="data row0 col2" >$177.80</td>
#       <td id="T_b293d_row0_col3" class="data row0 col3" >$181.60</td>
#       <td id="T_b293d_row0_col4" class="data row0 col4" >$179.70</td>
#       <td id="T_b293d_row0_col5" class="data row0 col5" >59.1%</td>
#       <td id="T_b293d_row0_col6" class="data row0 col6" >$149.35</td>
#       <td id="T_b293d_row0_col7" class="data row0 col7" >$30.35</td>
#       <td id="T_b293d_row0_col8" class="data row0 col8" >16.9%</td>
#       <td id="T_b293d_row0_col9" class="data row0 col9" >$809.70</td>
#       <td id="T_b293d_row0_col10" class="data row0 col10" >+3.9%</td>
#       <td id="T_b293d_row0_col11" class="data row0 col11" >4.3x</td>
#       <td id="T_b293d_row0_col12" class="data row0 col12" >$17,970</td>
#       <td id="T_b293d_row0_col13" class="data row0 col13" >26</td>
#       <td id="T_b293d_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_b293d_row0_col15" class="data row0 col15" >2.1%</td>
#     </tr>
#     <tr>
#       <th id="T_b293d_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_b293d_row1_col0" class="data row1 col0" >$640</td>
#       <td id="T_b293d_row1_col1" class="data row1 col1" >82.1%</td>
#       <td id="T_b293d_row1_col2" class="data row1 col2" >$169.70</td>
#       <td id="T_b293d_row1_col3" class="data row1 col3" >$174.00</td>
#       <td id="T_b293d_row1_col4" class="data row1 col4" >$171.85</td>
#       <td id="T_b293d_row1_col5" class="data row1 col5" >58.3%</td>
#       <td id="T_b293d_row1_col6" class="data row1 col6" >$139.35</td>
#       <td id="T_b293d_row1_col7" class="data row1 col7" >$32.50</td>
#       <td id="T_b293d_row1_col8" class="data row1 col8" >18.9%</td>
#       <td id="T_b293d_row1_col9" class="data row1 col9" >$811.85</td>
#       <td id="T_b293d_row1_col10" class="data row1 col10" >+4.2%</td>
#       <td id="T_b293d_row1_col11" class="data row1 col11" >4.5x</td>
#       <td id="T_b293d_row1_col12" class="data row1 col12" >$17,185</td>
#       <td id="T_b293d_row1_col13" class="data row1 col13" >60</td>
#       <td id="T_b293d_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_b293d_row1_col15" class="data row1 col15" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_b293d_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_b293d_row2_col0" class="data row2 col0" >$650</td>
#       <td id="T_b293d_row2_col1" class="data row2 col1" >83.4%</td>
#       <td id="T_b293d_row2_col2" class="data row2 col2" >$162.10</td>
#       <td id="T_b293d_row2_col3" class="data row2 col3" >$167.00</td>
#       <td id="T_b293d_row2_col4" class="data row2 col4" >$164.55</td>
#       <td id="T_b293d_row2_col5" class="data row2 col5" >57.9%</td>
#       <td id="T_b293d_row2_col6" class="data row2 col6" >$129.35</td>
#       <td id="T_b293d_row2_col7" class="data row2 col7" >$35.20</td>
#       <td id="T_b293d_row2_col8" class="data row2 col8" >21.4%</td>
#       <td id="T_b293d_row2_col9" class="data row2 col9" >$814.55</td>
#       <td id="T_b293d_row2_col10" class="data row2 col10" >+4.5%</td>
#       <td id="T_b293d_row2_col11" class="data row2 col11" >4.7x</td>
#       <td id="T_b293d_row2_col12" class="data row2 col12" >$16,455</td>
#       <td id="T_b293d_row2_col13" class="data row2 col13" >81</td>
#       <td id="T_b293d_row2_col14" class="data row2 col14" >3</td>
#       <td id="T_b293d_row2_col15" class="data row2 col15" >3.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b293d_level0_row3" class="row_heading level0 row3" >17</th>
#       <td id="T_b293d_row3_col0" class="data row3 col0" >$660</td>
#       <td id="T_b293d_row3_col1" class="data row3 col1" >84.7%</td>
#       <td id="T_b293d_row3_col2" class="data row3 col2" >$154.00</td>
#       <td id="T_b293d_row3_col3" class="data row3 col3" >$159.20</td>
#       <td id="T_b293d_row3_col4" class="data row3 col4" >$156.60</td>
#       <td id="T_b293d_row3_col5" class="data row3 col5" >56.9%</td>
#       <td id="T_b293d_row3_col6" class="data row3 col6" >$119.35</td>
#       <td id="T_b293d_row3_col7" class="data row3 col7" >$37.25</td>
#       <td id="T_b293d_row3_col8" class="data row3 col8" >23.8%</td>
#       <td id="T_b293d_row3_col9" class="data row3 col9" >$816.60</td>
#       <td id="T_b293d_row3_col10" class="data row3 col10" >+4.8%</td>
#       <td id="T_b293d_row3_col11" class="data row3 col11" >5.0x</td>
#       <td id="T_b293d_row3_col12" class="data row3 col12" >$15,660</td>
#       <td id="T_b293d_row3_col13" class="data row3 col13" >47</td>
#       <td id="T_b293d_row3_col14" class="data row3 col14" >1</td>
#       <td id="T_b293d_row3_col15" class="data row3 col15" >3.3%</td>
#     </tr>
#     <tr>
#       <th id="T_b293d_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_b293d_row4_col0" class="data row4 col0" >$670</td>
#       <td id="T_b293d_row4_col1" class="data row4 col1" >86.0%</td>
#       <td id="T_b293d_row4_col2" class="data row4 col2" >$147.30</td>
#       <td id="T_b293d_row4_col3" class="data row4 col3" >$152.00</td>
#       <td id="T_b293d_row4_col4" class="data row4 col4" >$149.65</td>
#       <td id="T_b293d_row4_col5" class="data row4 col5" >56.6%</td>
#       <td id="T_b293d_row4_col6" class="data row4 col6" >$109.35</td>
#       <td id="T_b293d_row4_col7" class="data row4 col7" >$40.30</td>
#       <td id="T_b293d_row4_col8" class="data row4 col8" >26.9%</td>
#       <td id="T_b293d_row4_col9" class="data row4 col9" >$819.65</td>
#       <td id="T_b293d_row4_col10" class="data row4 col10" >+5.2%</td>
#       <td id="T_b293d_row4_col11" class="data row4 col11" >5.2x</td>
#       <td id="T_b293d_row4_col12" class="data row4 col12" >$14,965</td>
#       <td id="T_b293d_row4_col13" class="data row4 col13" >53</td>
#       <td id="T_b293d_row4_col14" class="data row4 col14" >6</td>
#       <td id="T_b293d_row4_col15" class="data row4 col15" >3.1%</td>
#     </tr>
#     <tr>
#       <th id="T_b293d_level0_row5" class="row_heading level0 row5" >19</th>
#       <td id="T_b293d_row5_col0" class="data row5 col0" >$680</td>
#       <td id="T_b293d_row5_col1" class="data row5 col1" >87.3%</td>
#       <td id="T_b293d_row5_col2" class="data row5 col2" >$141.10</td>
#       <td id="T_b293d_row5_col3" class="data row5 col3" >$145.80</td>
#       <td id="T_b293d_row5_col4" class="data row5 col4" >$143.45</td>
#       <td id="T_b293d_row5_col5" class="data row5 col5
# **Scenario P&L (at expiration) — GEV**
# <style type="text/css">
# #T_4620f_row0_col0, #T_4620f_row1_col0, #T_4620f_row1_col1, #T_4620f_row2_col0, #T_4620f_row2_col1, #T_4620f_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4620f_row0_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_4620f_row0_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_4620f_row0_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_4620f_row0_col4 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_4620f_row0_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_4620f_row1_col2 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_4620f_row1_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_4620f_row1_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_4620f_row1_col5 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_4620f_row2_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_4620f_row2_col4 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_4620f_row2_col5 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4620f">
#   <caption>GEV — LEAPS P&L % at Expiration by Stock Move</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4620f_level0_col0" class="col_heading level0 col0" >-20%</th>
#       <th id="T_4620f_level0_col1" class="col_heading level0 col1" >-10%</th>
#       <th id="T_4620f_level0_col2" class="col_heading level0 col2" >+0%</th>
#       <th id="T_4620f_level0_col3" class="col_heading level0 col3" >+10%</th>
#       <th id="T_4620f_level0_col4" class="col_heading level0 col4" >+20%</th>
#       <th id="T_4620f_level0_col5" class="col_heading level0 col5" >+30%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Strike</th>
#       <th class="index_name level1" >Moneyness</th>
#       <th class="index_name level2" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4620f_level0_row0" class="row_heading level0 row0" >660.000000</th>
#       <th id="T_4620f_level1_row0" class="row_heading level1 row0" >0.846860</th>
#       <th id="T_4620f_level2_row0" class="row_heading level2 row0" >156.600000</th>
#       <td id="T_4620f_row0_col0" class="data row0 col0" >-100%</td>
#       <td id="T_4620f_row0_col1" class="data row0 col1" >-74%</td>
#       <td id="T_4620f_row0_col2" class="data row0 col2" >-24%</td>
#       <td id="T_4620f_row0_col3" class="data row0 col3" >+26%</td>
#       <td id="T_4620f_row0_col4" class="data row0 col4" >+76%</td>
#       <td id="T_4620f_row0_col5" class="data row0 col5" >+126%</td>
#     </tr>
#     <tr>
#       <th id="T_4620f_level0_row1" class="row_heading level0 row1" >700.000000</th>
#       <th id="T_4620f_level1_row1" class="row_heading level1 row1" >0.898184</th>
#       <th id="T_4620f_level2_row1" class="row_heading level2 row1" >129.100000</th>
#       <td id="T_4620f_row1_col0" class="data row1 col0" >-100%</td>
#       <td id="T_4620f_row1_col1" class="data row1 col1" >-99%</td>
#       <td id="T_4620f_row1_col2" class="data row1 col2" >-39%</td>
#       <td id="T_4620f_row1_col3" class="data row1 col3" >+22%</td>
#       <td id="T_4620f_row1_col4" class="data row1 col4" >+82%</td>
#       <td id="T_4620f_row1_col5" class="data row1 col5" >+143%</td>
#     </tr>
#     <tr>
#       <th id="T_4620f_level0_row2" class="row_heading level0 row2" >780.000000</th>
#       <th id="T_4620f_level1_row2" class="row_heading level1 row2" >1.000834</th>
#       <th id="T_4620f_level2_row2" class="row_heading level2 row2" >84.550000</th>
#       <td id="T_4620f_row2_col0" class="data row2 col0" >-100%</td>
#       <td id="T_4620f_row2_col1" class="data row2 col1" >-100%</td>
#       <td id="T_4620f_row2_col2" class="data row2 col2" >-100%</td>
#       <td id="T_4620f_row2_col3" class="data row2 col3" >-9%</td>
#       <td id="T_4620f_row2_col4" class="data row2 col4" >+84%</td>
#       <td id="T_4620f_row2_col5" class="data row2 col5" >+176%</td>
#     </tr>
#   </tbody>
# </table>
# ---
# ### ⭐ AMAT  —  Spot: $322.51
# **Nearest LEAPS:** 2026-05-15 (96 DTE)
# <style type="text/css">
# </style>
# <table id="T_769e5">
#   <caption>AMAT — 2026-05-15 LEAPS Calls</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_769e5_level0_col0" class="col_heading level0 col0" >strike</th>
#       <th id="T_769e5_level0_col1" class="col_heading level0 col1" >moneyness</th>
#       <th id="T_769e5_level0_col2" class="col_heading level0 col2" >bid</th>
#       <th id="T_769e5_level0_col3" class="col_heading level0 col3" >ask</th>
#       <th id="T_769e5_level0_col4" class="col_heading level0 col4" >mid</th>
#       <th id="T_769e5_level0_col5" class="col_heading level0 col5" >iv</th>
#       <th id="T_769e5_level0_col6" class="col_heading level0 col6" >intrinsic</th>
#       <th id="T_769e5_level0_col7" class="col_heading level0 col7" >extrinsic</th>
#       <th id="T_769e5_level0_col8" class="col_heading level0 col8" >extrinsic_pct</th>
#       <th id="T_769e5_level0_col9" class="col_heading level0 col9" >breakeven</th>
#       <th id="T_769e5_level0_col10" class="col_heading level0 col10" >breakeven_pct</th>
#       <th id="T_769e5_level0_col11" class="col_heading level0 col11" >leverage</th>
#       <th id="T_769e5_level0_col12" class="col_heading level0 col12" >cost_per_contract</th>
#       <th id="T_769e5_level0_col13" class="col_heading level0 col13" >openInterest</th>
#       <th id="T_769e5_level0_col14" class="col_heading level0 col14" >volume</th>
#       <th id="T_769e5_level0_col15" class="col_heading level0 col15" >spread_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_769e5_level0_row0" class="row_heading level0 row0" >123</th>
#       <td id="T_769e5_row0_col0" class="data row0 col0" >$260</td>
#       <td id="T_769e5_row0_col1" class="data row0 col1" >80.6%</td>
#       <td id="T_769e5_row0_col2" class="data row0 col2" >$75.60</td>
#       <td id="T_769e5_row0_col3" class="data row0 col3" >$78.55</td>
#       <td id="T_769e5_row0_col4" class="data row0 col4" >$77.07</td>
#       <td id="T_769e5_row0_col5" class="data row0 col5" >63.8%</td>
#       <td id="T_769e5_row0_col6" class="data row0 col6" >$62.51</td>
#       <td id="T_769e5_row0_col7" class="data row0 col7" >$14.56</td>
#       <td id="T_769e5_row0_col8" class="data row0 col8" >18.9%</td>
#       <td id="T_769e5_row0_col9" class="data row0 col9" >$337.07</td>
#       <td id="T_769e5_row0_col10" class="data row0 col10" >+4.5%</td>
#       <td id="T_769e5_row0_col11" class="data row0 col11" >4.2x</td>
#       <td id="T_769e5_row0_col12" class="data row0 col12" >$7,707</td>
#       <td id="T_769e5_row0_col13" class="data row0 col13" >127</td>
#       <td id="T_769e5_row0_col14" class="data row0 col14" >5</td>
#       <td id="T_769e5_row0_col15" class="data row0 col15" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_769e5_level0_row1" class="row_heading level0 row1" >124</th>
#       <td id="T_769e5_row1_col0" class="data row1 col0" >$270</td>
#       <td id="T_769e5_row1_col1" class="data row1 col1" >83.7%</td>
#       <td id="T_769e5_row1_col2" class="data row1 col2" >$68.40</td>
#       <td id="T_769e5_row1_col3" class="data row1 col3" >$71.10</td>
#       <td id="T_769e5_row1_col4" class="data row1 col4" >$69.75</td>
#       <td id="T_769e5_row1_col5" class="data row1 col5" >62.5%</td>
#       <td id="T_769e5_row1_col6" class="data row1 col6" >$52.51</td>
#       <td id="T_769e5_row1_col7" class="data row1 col7" >$17.24</td>
#       <td id="T_769e5_row1_col8" class="data row1 col8" >24.7%</td>
#       <td id="T_769e5_row1_col9" class="data row1 col9" >$339.75</td>
#       <td id="T_769e5_row1_col10" class="data row1 col10" >+5.3%</td>
#       <td id="T_769e5_row1_col11" class="data row1 col11" >4.6x</td>
#       <td id="T_769e5_row1_col12" class="data row1 col12" >$6,975</td>
#       <td id="T_769e5_row1_col13" class="data row1 col13" >326</td>
#       <td id="T_769e5_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_769e5_row1_col15" class="data row1 col15" >3.9%</td>
#     </tr>
#     <tr>
#       <th id="T_769e5_level0_row2" class="row_heading level0 row2" >125</th>
#       <td id="T_769e5_row2_col0" class="data row2 col0" >$280</td>
#       <td id="T_769e5_row2_col1" class="data row2 col1" >86.8%</td>
#       <td id="T_769e5_row2_col2" class="data row2 col2" >$61.85</td>
#       <td id="T_769e5_row2_col3" class="data row2 col3" >$64.65</td>
#       <td id="T_769e5_row2_col4" class="data row2 col4" >$63.25</td>
#       <td id="T_769e5_row2_col5" class="data row2 col5" >62.2%</td>
#       <td id="T_769e5_row2_col6" class="data row2 col6" >$42.51</td>
#       <td id="T_769e5_row2_col7" class="data row2 col7" >$20.74</td>
#       <td id="T_769e5_row2_col8" class="data row2 col8" >32.8%</td>
#       <td id="T_769e5_row2_col9" class="data row2 col9" >$343.25</td>
#       <td id="T_769e5_row2_col10" class="data row2 col10" >+6.4%</td>
#       <td id="T_769e5_row2_col11" class="data row2 col11" >5.1x</td>
#       <td id="T_769e5_row2_col12" class="data row2 col12" >$6,325</td>
#       <td id="T_769e5_row2_col13" class="data row2 col13" >424</td>
#       <td id="T_769e5_row2_col14" class="data row2 col14" >14</td>
#       <td id="T_769e5_row2_col15" class="data row2 col15" >4.4%</td>
#     </tr>
#     <tr>
#       <th id="T_769e5_level0_row3" class="row_heading level0 row3" >126</th>
#       <td id="T_769e5_row3_col0" class="data row3 col0" >$290</td>
#       <td id="T_769e5_row3_col1" class="data row3 col1" >89.9%</td>
#       <td id="T_769e5_row3_col2" class="data row3 col2" >$55.75</td>
#       <td id="T_769e5_row3_col3" class="data row3 col3" >$58.10</td>
#       <td id="T_769e5_row3_col4" class="data row3 col4" >$56.92</td>
#       <td id="T_769e5_row3_col5" class="data row3 col5" >61.4%</td>
#       <td id="T_769e5_row3_col6" class="data row3 col6" >$32.51</td>
#       <td id="T_769e5_row3_col7" class="data row3 col7" >$24.41</td>
#       <td id="T_769e5_row3_col8" class="data row3 col8" >42.9%</td>
#       <td id="T_769e5_row3_col9" class="data row3 col9" >$346.93</td>
#       <td id="T_769e5_row3_col10" class="data row3 col10" >+7.6%</td>
#       <td id="T_769e5_row3_col11" class="data row3 col11" >5.7x</td>
#       <td id="T_769e5_row3_col12" class="data row3 col12" >$5,692</td>
#       <td id="T_769e5_row3_col13" class="data row3 col13" >333</td>
#       <td id="T_769e5_row3_col14" class="data row3 col14" >8</td>
#       <td id="T_769e5_row3_col15" class="data row3 col15" >4.1%</td>
#     </tr>
#     <tr>
#       <th id="T_769e5_level0_row4" class="row_heading level0 row4" >127</th>
#       <td id="T_769e5_row4_col0" class="data row4 col0" >$300</td>
#       <td id="T_769e5_row4_col1" class="data row4 col1" >93.0%</td>
#       <td id="T_769e5_row4_col2" class="data row4 col2" >$49.10</td>
#       <td id="T_769e5_row4_col3" class="data row4 col3" >$51.95</td>
#       <td id="T_769e5_row4_col4" class="data row4 col4" >$50.53</td>
#       <td id="T_769e5_row4_col5" class="data row4 col5" >60.0%</td>
#       <td id="T_769e5_row4_col6" class="data row4 col6" >$22.51</td>
#       <td id="T_769e5_row4_col7" class="data row4 col7" >$28.01</td>
#       <td id="T_769e5_row4_col8" class="data row4 col8" >55.4%</td>
#       <td id="T_769e5_row4_col9" class="data row4 col9" >$350.52</td>
#       <td id="T_769e5_row4_col10" class="data row4 col10" >+8.7%</td>
#       <td id="T_769e5_row4_col11" class="data row4 col11" >6.4x</td>
#       <td id="T_769e5_row4_col12" class="data row4 col12" >$5,053</td>
#       <td id="T_769e5_row4_col13" class="data row4 col13" >497</td>
#       <td id="T_769e5_row4_col14" class="data row4 col14" >7</td>
#       <td id="T_769e5_row4_col15" class="data row4 col15" >5.6%</td>
#     </tr>
#     <tr>
#       <th id="T_769e5_level0_row5" class="row_heading level0 row5" >128</th>
#       <td id="T_769e5_row5_col0" class="data row5 col0" >$310</td>
#       <td id="T_769e5_row5_col1" class="data row5 col1" >96.1%</td>
#       <td id="T_769e5_row5_col2" class="data row5 col2" >$44.00</td>
#       <td id="T_769e5_row5_col3" class="data row5 col3" >$46.15</td>
#       <td id="T_769e5_row5_col4" class="data row5 col4" >$45.08</td>
#       <td id="T_769e5_row5_col5" class="data row5 col5" >59.4%</td>
# **Scenario P&L (at expiration) — AMAT**
# <style type="text/css">
# #T_80f81_row0_col0, #T_80f81_row1_col0, #T_80f81_row1_col1, #T_80f81_row2_col0, #T_80f81_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_80f81_row0_col1 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_80f81_row0_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_80f81_row0_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_80f81_row0_col4 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_80f81_row0_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_80f81_row1_col2 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_80f81_row1_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_80f81_row1_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_80f81_row1_col5 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_80f81_row2_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_80f81_row2_col3 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_80f81_row2_col4 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_80f81_row2_col5 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80f81">
#   <caption>AMAT — LEAPS P&L % at Expiration by Stock Move</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80f81_level0_col0" class="col_heading level0 col0" >-20%</th>
#       <th id="T_80f81_level0_col1" class="col_heading level0 col1" >-10%</th>
#       <th id="T_80f81_level0_col2" class="col_heading level0 col2" >+0%</th>
#       <th id="T_80f81_level0_col3" class="col_heading level0 col3" >+10%</th>
#       <th id="T_80f81_level0_col4" class="col_heading level0 col4" >+20%</th>
#       <th id="T_80f81_level0_col5" class="col_heading level0 col5" >+30%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Strike</th>
#       <th class="index_name level1" >Moneyness</th>
#       <th class="index_name level2" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f81_level0_row0" class="row_heading level0 row0" >270.000000</th>
#       <th id="T_80f81_level1_row0" class="row_heading level1 row0" >0.837183</th>
#       <th id="T_80f81_level2_row0" class="row_heading level2 row0" >69.750000</th>
#       <td id="T_80f81_row0_col0" class="data row0 col0" >-100%</td>
#       <td id="T_80f81_row0_col1" class="data row0 col1" >-71%</td>
#       <td id="T_80f81_row0_col2" class="data row0 col2" >-25%</td>
#       <td id="T_80f81_row0_col3" class="data row0 col3" >+22%</td>
#       <td id="T_80f81_row0_col4" class="data row0 col4" >+68%</td>
#       <td id="T_80f81_row0_col5" class="data row0 col5" >+114%</td>
#     </tr>
#     <tr>
#       <th id="T_80f81_level0_row1" class="row_heading level0 row1" >290.000000</th>
#       <th id="T_80f81_level1_row1" class="row_heading level1 row1" >0.899197</th>
#       <th id="T_80f81_level2_row1" class="row_heading level2 row1" >56.925000</th>
#       <td id="T_80f81_row1_col0" class="data row1 col0" >-100%</td>
#       <td id="T_80f81_row1_col1" class="data row1 col1" >-100%</td>
#       <td id="T_80f81_row1_col2" class="data row1 col2" >-43%</td>
#       <td id="T_80f81_row1_col3" class="data row1 col3" >+14%</td>
#       <td id="T_80f81_row1_col4" class="data row1 col4" >+70%</td>
#       <td id="T_80f81_row1_col5" class="data row1 col5" >+127%</td>
#     </tr>
#     <tr>
#       <th id="T_80f81_level0_row2" class="row_heading level0 row2" >320.000000</th>
#       <th id="T_80f81_level1_row2" class="row_heading level1 row2" >0.992217</th>
#       <th id="T_80f81_level2_row2" class="row_heading level2 row2" >39.550000</th>
#       <td id="T_80f81_row2_col0" class="data row2 col0" >-100%</td>
#       <td id="T_80f81_row2_col1" class="data row2 col1" >-100%</td>
#       <td id="T_80f81_row2_col2" class="data row2 col2" >-94%</td>
#       <td id="T_80f81_row2_col3" class="data row2 col3" >-12%</td>
#       <td id="T_80f81_row2_col4" class="data row2 col4" >+69%</td>
#       <td id="T_80f81_row2_col5" class="data row2 col5" >+151%</td>
#     </tr>
#   </tbody>
# </table>
# ---
# ### ⭐ AVGO  —  Spot: $332.92
# **Nearest LEAPS:** 2026-05-15 (96 DTE)
# <style type="text/css">
# </style>
# <table id="T_d289a">
#   <caption>AVGO — 2026-05-15 LEAPS Calls</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d289a_level0_col0" class="col_heading level0 col0" >strike</th>
#       <th id="T_d289a_level0_col1" class="col_heading level0 col1" >moneyness</th>
#       <th id="T_d289a_level0_col2" class="col_heading level0 col2" >bid</th>
#       <th id="T_d289a_level0_col3" class="col_heading level0 col3" >ask</th>
#       <th id="T_d289a_level0_col4" class="col_heading level0 col4" >mid</th>
#       <th id="T_d289a_level0_col5" class="col_heading level0 col5" >iv</th>
#       <th id="T_d289a_level0_col6" class="col_heading level0 col6" >intrinsic</th>
#       <th id="T_d289a_level0_col7" class="col_heading level0 col7" >extrinsic</th>
#       <th id="T_d289a_level0_col8" class="col_heading level0 col8" >extrinsic_pct</th>
#       <th id="T_d289a_level0_col9" class="col_heading level0 col9" >breakeven</th>
#       <th id="T_d289a_level0_col10" class="col_heading level0 col10" >breakeven_pct</th>
#       <th id="T_d289a_level0_col11" class="col_heading level0 col11" >leverage</th>
#       <th id="T_d289a_level0_col12" class="col_heading level0 col12" >cost_per_contract</th>
#       <th id="T_d289a_level0_col13" class="col_heading level0 col13" >openInterest</th>
#       <th id="T_d289a_level0_col14" class="col_heading level0 col14" >volume</th>
#       <th id="T_d289a_level0_col15" class="col_heading level0 col15" >spread_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d289a_level0_row0" class="row_heading level0 row0" >512</th>
#       <td id="T_d289a_row0_col0" class="data row0 col0" >$270</td>
#       <td id="T_d289a_row0_col1" class="data row0 col1" >81.1%</td>
#       <td id="T_d289a_row0_col2" class="data row0 col2" >$76.15</td>
#       <td id="T_d289a_row0_col3" class="data row0 col3" >$78.70</td>
#       <td id="T_d289a_row0_col4" class="data row0 col4" >$77.43</td>
#       <td id="T_d289a_row0_col5" class="data row0 col5" >61.7%</td>
#       <td id="T_d289a_row0_col6" class="data row0 col6" >$62.92</td>
#       <td id="T_d289a_row0_col7" class="data row0 col7" >$14.50</td>
#       <td id="T_d289a_row0_col8" class="data row0 col8" >18.7%</td>
#       <td id="T_d289a_row0_col9" class="data row0 col9" >$347.43</td>
#       <td id="T_d289a_row0_col10" class="data row0 col10" >+4.4%</td>
#       <td id="T_d289a_row0_col11" class="data row0 col11" >4.3x</td>
#       <td id="T_d289a_row0_col12" class="data row0 col12" >$7,743</td>
#       <td id="T_d289a_row0_col13" class="data row0 col13" >109</td>
#       <td id="T_d289a_row0_col14" class="data row0 col14" >21</td>
#       <td id="T_d289a_row0_col15" class="data row0 col15" >3.3%</td>
#     </tr>
#     <tr>
#       <th id="T_d289a_level0_row1" class="row_heading level0 row1" >513</th>
#       <td id="T_d289a_row1_col0" class="data row1 col0" >$280</td>
#       <td id="T_d289a_row1_col1" class="data row1 col1" >84.1%</td>
#       <td id="T_d289a_row1_col2" class="data row1 col2" >$69.05</td>
#       <td id="T_d289a_row1_col3" class="data row1 col3" >$71.10</td>
#       <td id="T_d289a_row1_col4" class="data row1 col4" >$70.07</td>
#       <td id="T_d289a_row1_col5" class="data row1 col5" >60.5%</td>
#       <td id="T_d289a_row1_col6" class="data row1 col6" >$52.92</td>
#       <td id="T_d289a_row1_col7" class="data row1 col7" >$17.15</td>
#       <td id="T_d289a_row1_col8" class="data row1 col8" >24.5%</td>
#       <td id="T_d289a_row1_col9" class="data row1 col9" >$350.07</td>
#       <td id="T_d289a_row1_col10" class="data row1 col10" >+5.2%</td>
#       <td id="T_d289a_row1_col11" class="data row1 col11" >4.8x</td>
#       <td id="T_d289a_row1_col12" class="data row1 col12" >$7,007</td>
#       <td id="T_d289a_row1_col13" class="data row1 col13" >858</td>
#       <td id="T_d289a_row1_col14" class="data row1 col14" >5</td>
#       <td id="T_d289a_row1_col15" class="data row1 col15" >2.9%</td>
#     </tr>
#     <tr>
#       <th id="T_d289a_level0_row2" class="row_heading level0 row2" >514</th>
#       <td id="T_d289a_row2_col0" class="data row2 col0" >$290</td>
#       <td id="T_d289a_row2_col1" class="data row2 col1" >87.1%</td>
#       <td id="T_d289a_row2_col2" class="data row2 col2" >$61.70</td>
#       <td id="T_d289a_row2_col3" class="data row2 col3" >$64.10</td>
#       <td id="T_d289a_row2_col4" class="data row2 col4" >$62.90</td>
#       <td id="T_d289a_row2_col5" class="data row2 col5" >59.0%</td>
#       <td id="T_d289a_row2_col6" class="data row2 col6" >$42.92</td>
#       <td id="T_d289a_row2_col7" class="data row2 col7" >$19.98</td>
#       <td id="T_d289a_row2_col8" class="data row2 col8" >31.8%</td>
#       <td id="T_d289a_row2_col9" class="data row2 col9" >$352.90</td>
#       <td id="T_d289a_row2_col10" class="data row2 col10" >+6.0%</td>
#       <td id="T_d289a_row2_col11" class="data row2 col11" >5.3x</td>
#       <td id="T_d289a_row2_col12" class="data row2 col12" >$6,290</td>
#       <td id="T_d289a_row2_col13" class="data row2 col13" >546</td>
#       <td id="T_d289a_row2_col14" class="data row2 col14" >9</td>
#       <td id="T_d289a_row2_col15" class="data row2 col15" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d289a_level0_row3" class="row_heading level0 row3" >515</th>
#       <td id="T_d289a_row3_col0" class="data row3 col0" >$300</td>
#       <td id="T_d289a_row3_col1" class="data row3 col1" >90.1%</td>
#       <td id="T_d289a_row3_col2" class="data row3 col2" >$55.60</td>
#       <td id="T_d289a_row3_col3" class="data row3 col3" >$57.50</td>
#       <td id="T_d289a_row3_col4" class="data row3 col4" >$56.55</td>
#       <td id="T_d289a_row3_col5" class="data row3 col5" >58.4%</td>
#       <td id="T_d289a_row3_col6" class="data row3 col6" >$32.92</td>
#       <td id="T_d289a_row3_col7" class="data row3 col7" >$23.63</td>
#       <td id="T_d289a_row3_col8" class="data row3 col8" >41.8%</td>
#       <td id="T_d289a_row3_col9" class="data row3 col9" >$356.55</td>
#       <td id="T_d289a_row3_col10" class="data row3 col10" >+7.1%</td>
#       <td id="T_d289a_row3_col11" class="data row3 col11" >5.9x</td>
#       <td id="T_d289a_row3_col12" class="data row3 col12" >$5,655</td>
#       <td id="T_d289a_row3_col13" class="data row3 col13" >798</td>
#       <td id="T_d289a_row3_col14" class="data row3 col14" >94</td>
#       <td id="T_d289a_row3_col15" class="data row3 col15" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d289a_level0_row4" class="row_heading level0 row4" >516</th>
#       <td id="T_d289a_row4_col0" class="data row4 col0" >$310</td>
#       <td id="T_d289a_row4_col1" class="data row4 col1" >93.1%</td>
#       <td id="T_d289a_row4_col2" class="data row4 col2" >$48.90</td>
#       <td id="T_d289a_row4_col3" class="data row4 col3" >$51.30</td>
#       <td id="T_d289a_row4_col4" class="data row4 col4" >$50.10</td>
#       <td id="T_d289a_row4_col5" class="data row4 col5" >57.0%</td>
#       <td id="T_d289a_row4_col6" class="data row4 col6" >$22.92</td>
#       <td id="T_d289a_row4_col7" class="data row4 col7" >$27.18</td>
#       <td id="T_d289a_row4_col8" class="data row4 col8" >54.3%</td>
#       <td id="T_d289a_row4_col9" class="data row4 col9" >$360.10</td>
#       <td id="T_d289a_row4_col10" class="data row4 col10" >+8.2%</td>
#       <td id="T_d289a_row4_col11" class="data row4 col11" >6.6x</td>
#       <td id="T_d289a_row4_col12" class="data row4 col12" >$5,010</td>
#       <td id="T_d289a_row4_col13" class="data row4 col13" >1,162</td>
#       <td id="T_d289a_row4_col14" class="data row4 col14" >99</td>
#       <td id="T_d289a_row4_col15" class="data row4 col15" >4.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d289a_level0_row5" class="row_heading level0 row5" >517</th>
#       <td id="T_d289a_row5_col0" class="data row5 col0" >$320</td>
#       <td id="T_d289a_row5_col1" class="data row5 col1" >96.1%</td>
#       <td id="T_d289a_row5_col2" class="data row5 col2" >$43.85</td>
#       <td id="T_d289a_row5_col3" class="data row5 col3" >$44.95</td>
#       <td id="T_d289a_row5_col4" class="data row5 col4" >$44.40</td>
#       <td id="T_d289a_row5_col5" class="data row5 col5" >56.2%</t
# **Scenario P&L (at expiration) — AVGO**
# <style type="text/css">
# #T_a2a2a_row0_col0, #T_a2a2a_row1_col0, #T_a2a2a_row1_col1, #T_a2a2a_row2_col0, #T_a2a2a_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a2a2a_row0_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_a2a2a_row0_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_a2a2a_row0_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_a2a2a_row0_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_a2a2a_row0_col5 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_a2a2a_row1_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_a2a2a_row1_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_a2a2a_row1_col4 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_a2a2a_row1_col5 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_a2a2a_row2_col2 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_a2a2a_row2_col3 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_a2a2a_row2_col4 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_a2a2a_row2_col5 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2a2a">
#   <caption>AVGO — LEAPS P&L % at Expiration by Stock Move</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2a2a_level0_col0" class="col_heading level0 col0" >-20%</th>
#       <th id="T_a2a2a_level0_col1" class="col_heading level0 col1" >-10%</th>
#       <th id="T_a2a2a_level0_col2" class="col_heading level0 col2" >+0%</th>
#       <th id="T_a2a2a_level0_col3" class="col_heading level0 col3" >+10%</th>
#       <th id="T_a2a2a_level0_col4" class="col_heading level0 col4" >+20%</th>
#       <th id="T_a2a2a_level0_col5" class="col_heading level0 col5" >+30%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Strike</th>
#       <th class="index_name level1" >Moneyness</th>
#       <th class="index_name level2" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2a2a_level0_row0" class="row_heading level0 row0" >280.000000</th>
#       <th id="T_a2a2a_level1_row0" class="row_heading level1 row0" >0.841043</th>
#       <th id="T_a2a2a_level2_row0" class="row_heading level2 row0" >70.075000</th>
#       <td id="T_a2a2a_row0_col0" class="data row0 col0" >-100%</td>
#       <td id="T_a2a2a_row0_col1" class="data row0 col1" >-72%</td>
#       <td id="T_a2a2a_row0_col2" class="data row0 col2" >-24%</td>
#       <td id="T_a2a2a_row0_col3" class="data row0 col3" >+23%</td>
#       <td id="T_a2a2a_row0_col4" class="data row0 col4" >+71%</td>
#       <td id="T_a2a2a_row0_col5" class="data row0 col5" >+118%</td>
#     </tr>
#     <tr>
#       <th id="T_a2a2a_level0_row1" class="row_heading level0 row1" >300.000000</th>
#       <th id="T_a2a2a_level1_row1" class="row_heading level1 row1" >0.901117</th>
#       <th id="T_a2a2a_level2_row1" class="row_heading level2 row1" >56.550000</th>
#       <td id="T_a2a2a_row1_col0" class="data row1 col0" >-100%</td>
#       <td id="T_a2a2a_row1_col1" class="data row1 col1" >-100%</td>
#       <td id="T_a2a2a_row1_col2" class="data row1 col2" >-42%</td>
#       <td id="T_a2a2a_row1_col3" class="data row1 col3" >+17%</td>
#       <td id="T_a2a2a_row1_col4" class="data row1 col4" >+76%</td>
#       <td id="T_a2a2a_row1_col5" class="data row1 col5" >+135%</td>
#     </tr>
#     <tr>
#       <th id="T_a2a2a_level0_row2" class="row_heading level0 row2" >330.000000</th>
#       <th id="T_a2a2a_level1_row2" class="row_heading level1 row2" >0.991229</th>
#       <th id="T_a2a2a_level2_row2" class="row_heading level2 row2" >38.775000</th>
#       <td id="T_a2a2a_row2_col0" class="data row2 col0" >-100%</td>
#       <td id="T_a2a2a_row2_col1" class="data row2 col1" >-100%</td>
#       <td id="T_a2a2a_row2_col2" class="data row2 col2" >-92%</td>
#       <td id="T_a2a2a_row2_col3" class="data row2 col3" >-7%</td>
#       <td id="T_a2a2a_row2_col4" class="data row2 col4" >+79%</td>
#       <td id="T_a2a2a_row2_col5" class="data row2 col5" >+165%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Visualizations — IV Smiles & Cost Comparison

# %%
if leaps_df.empty:
    display(Markdown("❌ No data."))
else:
    # ── IV Smile for conviction picks ──
    conv_df = leaps_df[leaps_df["ticker"].isin(CONVICTION)].copy()
    if not conv_df.empty:
        # Use nearest expiration per ticker
        nearest = conv_df.groupby("ticker")["expiration"].min().reset_index()
        nearest.columns = ["ticker", "nearest_exp"]
        conv_nearest = conv_df.merge(nearest, on="ticker")
        conv_nearest = conv_nearest[
            conv_nearest["expiration"] == conv_nearest["nearest_exp"]
        ]

        fig = px.line(
            conv_nearest,
            x="moneyness",
            y="iv",
            color="ticker",
            title="LEAPS IV Smile — Conviction Picks (Nearest Expiration)",
            labels={
                "moneyness": "Moneyness (Strike / Spot)",
                "iv": "Implied Volatility",
            },
            markers=True,
        )
        fig.add_vline(x=1.0, line_dash="dash", line_color="gray", annotation_text="ATM")
        fig.update_layout(yaxis_tickformat=".0%", xaxis_tickformat=".0%")
        fig.show()

    # ── Cost per contract comparison (ITM ~90%) ──
    if not picks_df.empty:
        itm_picks = picks_df[picks_df["Type"] == "ITM ~90%"].copy()
        if not itm_picks.empty:
            # Take nearest expiration per ticker
            itm_nearest = (
                itm_picks.sort_values("DTE").groupby("Ticker").first().reset_index()
            )
            itm_nearest["is_conviction"] = itm_nearest["Ticker"].isin(CONVICTION)
            itm_nearest = itm_nearest.sort_values("Cost/Contract")

            fig2 = px.bar(
                itm_nearest,
                x="Ticker",
                y="Cost/Contract",
                color="is_conviction",
                color_discrete_map={True: "#1a7431", False: "#4C6E91"},
                title="LEAPS Cost per Contract — ITM ~90% Strike (Nearest Expiration)",
                labels={
                    "Cost/Contract": "Cost per Contract ($)",
                    "is_conviction": "Conviction",
                },
                text="Cost/Contract",
            )
            fig2.update_traces(texttemplate="$%{text:,.0f}", textposition="outside")
            fig2.update_layout(
                showlegend=True, yaxis_tickprefix="$", yaxis_tickformat=","
            )
            fig2.show()

    # ── Breakeven % comparison ──
    if not picks_df.empty:
        itm_picks = picks_df[picks_df["Type"] == "ITM ~90%"].copy()
        if not itm_picks.empty:
            itm_nearest = (
                itm_picks.sort_values("DTE").groupby("Ticker").first().reset_index()
            )
            itm_nearest["is_conviction"] = itm_nearest["Ticker"].isin(CONVICTION)
            itm_nearest = itm_nearest.sort_values("Breakeven %")

            fig3 = px.bar(
                itm_nearest,
                x="Ticker",
                y="Breakeven %",
                color="is_conviction",
                color_discrete_map={True: "#1a7431", False: "#4C6E91"},
                title="LEAPS Breakeven % Above Spot — ITM ~90% (Nearest Expiration)",
                labels={"Breakeven %": "Breakeven Above Spot (%)"},
                text="Breakeven %",
            )
            fig3.update_traces(texttemplate="%{text:+.1%}", textposition="outside")
            fig3.update_layout(showlegend=True, yaxis_tickformat="+.1%")
            fig3.show()

    # ── Leverage ratio comparison ──
    if not picks_df.empty:
        for opt_type in ["Deep ITM", "ITM ~90%", "ATM"]:
            type_picks = picks_df[picks_df["Type"] == opt_type].copy()
            if type_picks.empty:
                continue
            type_nearest = (
                type_picks.sort_values("DTE").groupby("Ticker").first().reset_index()
            )
            type_nearest["is_conviction"] = type_nearest["Ticker"].isin(CONVICTION)
            type_nearest = type_nearest.sort_values("Leverage", ascending=False)

            fig4 = px.bar(
                type_nearest,
                x="Ticker",
                y="Leverage",
                color="is_conviction",
                color_discrete_map={True: "#1a7431", False: "#4C6E91"},
                title=f"LEAPS Leverage Ratio — {opt_type} (Nearest Expiration)",
                labels={"Leverage": "Leverage (Spot / Premium)"},
                text="Leverage",
            )
            fig4.update_traces(texttemplate="%{text:.1f}x", textposition="outside")
            fig4.update_layout(showlegend=True)
            fig4.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b1b2d61a-ad88-4dcc-bb9d-df553876d964" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b1b2d61a-ad88-4dcc-bb9d-df553876d964")) {                    Plotly.newPlot(                        "b1b2d61a-ad88-4dcc-bb9d-df553876d964",                        [{"hovertemplate":"ticker=GEV\u003cbr\u003eMoneyness (Strike \u002f Spot)=%{x}\u003cbr\u003eImplied Volatility=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GEV","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"GEV","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"nFk+UCLe6T9FKnRNP0fqP+76qUpcsOo\u002fl8vfR3kZ6z9AnBVFloLrP+lsS0Kz6+s\u002fkz2BP9BU7D88Drc87b3sP+Xe7DkKJ+0\u002fjq8iNyeQ7T83gFg0RPntP+BQjjFhYu4\u002fiSHELn7L7j8y8vkrmzTvP9vCLym4ne8\u002fwskyk2oD8D8Xss0R+TfwP2uaaJCHbPA\u002fwIIDDxah8D8="},"xaxis":"x","y":{"dtype":"f8","bdata":"8rVnlojl4j9I10y+qKjiP5K4x9JoieI\u002fYpy\u002fCYk14j+4kh0bCRviPx7EzhSpJOI\u002fkKUPXWm24T\u002fEQq1pKaPhP6fydoRJeuE\u002ftJjYfOmF4T\u002fFlEiiyUzhP8RHxJRpYeE\u002fHkKVmolY4T8sDmf+OcDgP8wQx7ppJ+E\u002fIPRs1jn94D\u002fzyB8MSqvgP9S3zOmp3+A\u002fndLB+snF4D8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"ticker=AMAT\u003cbr\u003eMoneyness (Strike \u002f Spot)=%{x}\u003cbr\u003eImplied Volatility=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AMAT","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AMAT","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"3en0tzLM6T\u002fb8larNMrqP9r7uJ42yOs\u002f2QQbkjjG7D\u002fXDX2FOsTtP9YW33g8wu4\u002f1B9BbD7A7z9qlNEvIF\u002fwPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"ayv2l8dp5D8opaDbhwLkP6wJou6H5eM\u002fd08eFkip4z\u002flvWplSDDjP1ealILIA+M\u002f6PaSxgic4j+g\u002fUgRCSriPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"ticker=AVGO\u003cbr\u003eMoneyness (Strike \u002f Spot)=%{x}\u003cbr\u003eImplied Volatility=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AVGO","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AVGO","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"Fy\u002fIC8Lz6T+mj+K20unqPzXw\u002fGHj3+s\u002fxFAXDfTV7D9TsTG4BMztP+MRTGMVwu4\u002fcnJmDia47z+AacBcG1fwPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"K\u002fuuCMi94z9ge2ZJCFvjP7cy4ZdI4+I\u002f3Xahuciv4j9BQ\u002f8EyTziP4MclDBJ+uE\u002fbgTidYmQ4T8730+NyWzhPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="53b47597-d7b2-417d-a121-63fb65885694" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("53b47597-d7b2-417d-a121-63fb65885694")) {                    Plotly.newPlot(                        "53b47597-d7b2-417d-a121-63fb65885694",                        [{"hovertemplate":"Conviction=False\u003cbr\u003eTicker=%{x}\u003cbr\u003eCost per Contract ($)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","pattern":{"shape":""}},"name":"False","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAADakUABAAAAAE2nQAAAAACAsLBA\u002f\u002f\u002f\u002f\u002f\u002f9+skAAAAAAADG1QAAAAAAAXrVAAAAAAACeu0AAAAAAgOa7QP\u002f\u002f\u002f\u002f\u002f\u002fML9A\u002f\u002f\u002f\u002f\u002f\u002f+tv0AAAAAAANDBQAAAAAAAJMNAAAAAAABI10A="},"textposition":"outside","x":["UBER","AMZN","GE","LRCX","MSFT","TSM","ISRG","WDC","CMI","SNPS","META","STX","KLAC"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADakUABAAAAAE2nQAAAAACAsLBA\u002f\u002f\u002f\u002f\u002f\u002f9+skAAAAAAADG1QAAAAAAAXrVAAAAAAACeu0AAAAAAgOa7QP\u002f\u002f\u002f\u002f\u002f\u002fML9A\u002f\u002f\u002f\u002f\u002f\u002f+tv0AAAAAAANDBQAAAAAAAJMNAAAAAAABI10A="},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"},{"hovertemplate":"Conviction=True\u003cbr\u003eTicker=%{x}\u003cbr\u003eCost per Contract ($)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","pattern":{"shape":""}},"name":"True","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAXtkAAAAAAgDy2QAAAAAAAN8lA"},"textposition":"outside","x":["AVGO","AMAT","GEV"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAXtkAAAAAAgDy2QAAAAAAAN8lA"},"yaxis":"y","type":"bar","texttemplate":"$%{text:,.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e0c775bb-e9e4-4581-a455-0ebe3dd73f6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e0c775bb-e9e4-4581-a455-0ebe3dd73f6b")) {                    Plotly.newPlot(                        "e0c775bb-e9e4-4581-a455-0ebe3dd73f6b",                        [{"hovertemplate":"is_conviction=False\u003cbr\u003eTicker=%{x}\u003cbr\u003eBreakeven Above Spot (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","pattern":{"shape":""}},"name":"False","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"0SmK36u7oD94ae9HmbOiPzixL\u002fB1mqM\u002fQm3pkSQFpz9OXuaJiSOnP79+OQdBQ6c\u002fyDNRStmmpz+uK0lVu3OsP33t6Cgo77A\u002f\u002fHQFfZCFtD\u002fzrEEHfDC9P088e2DFfsE\u002fJo72nXiYwT8="},"textposition":"outside","x":["MSFT","GE","CMI","META","AMZN","TSM","ISRG","UBER","KLAC","SNPS","LRCX","STX","WDC"],"xaxis":"x","y":{"dtype":"f8","bdata":"0SmK36u7oD94ae9HmbOiPzixL\u002fB1mqM\u002fQm3pkSQFpz9OXuaJiSOnP79+OQdBQ6c\u002fyDNRStmmpz+uK0lVu3OsP33t6Cgo77A\u002f\u002fHQFfZCFtD\u002fzrEEHfDC9P088e2DFfsE\u002fJo72nXiYwT8="},"yaxis":"y","type":"bar","texttemplate":"%{text:+.1%}"},{"hovertemplate":"is_conviction=True\u003cbr\u003eTicker=%{x}\u003cbr\u003eBreakeven Above Spot (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","pattern":{"shape":""}},"name":"True","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ciW2SoJXsD+h8ui5nCuyP9X9gFxGYbM\u002f"},"textposition":"outside","x":["GEV","AVGO","AMAT"],"xaxis":"x","y":{"dtype":"f8","bdata":"ciW2SoJXsD+h8ui5nCuyP9X9gFxGYbM\u002f"},"yaxis":"y","type":"bar","texttemplate":"%{text:+.1%}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7a395cfb-4ca4-4b00-8667-2493de37f2e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7a395cfb-4ca4-4b00-8667-2493de37f2e2")) {                    Plotly.newPlot(                        "7a395cfb-4ca4-4b00-8667-2493de37f2e2",                        [{"hovertemplate":"is_conviction=False\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","pattern":{"shape":""}},"name":"False","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"hdTtVy1WFEBf8RVfLe8TQA7xNoVNaRNAoaCgoKQkE0BQ6P9psSATQNY3kgew\u002fBJA9AV9QS+MEkDOAmw+Y3ASQPv9ETgpfBFA9uvOoXLxDkA4X4AIsIMMQPal1IK1ZAtAPU5789PfBEA="},"textposition":"outside","x":["MSFT","TSM","CMI","ISRG","META","GE","UBER","AMZN","KLAC","LRCX","STX","WDC","SNPS"],"xaxis":"x","y":{"dtype":"f8","bdata":"hdTtVy1WFEBf8RVfLe8TQA7xNoVNaRNAoaCgoKQkE0BQ6P9psSATQNY3kgew\u002fBJA9AV9QS+MEkDOAmw+Y3ASQPv9ETgpfBFA9uvOoXLxDkA4X4AIsIMMQPal1IK1ZAtAPU5789PfBEA="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"},{"hovertemplate":"is_conviction=True\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","pattern":{"shape":""}},"name":"True","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"Jbxqo+YjEkCSNCTaGTMRQF5UGHHKvBBA"},"textposition":"outside","x":["GEV","AVGO","AMAT"],"xaxis":"x","y":{"dtype":"f8","bdata":"Jbxqo+YjEkCSNCTaGTMRQF5UGHHKvBBA"},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1c56fb48-932f-4f3b-bb2a-18c146d1a6b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1c56fb48-932f-4f3b-bb2a-18c146d1a6b8")) {                    Plotly.newPlot(                        "1c56fb48-932f-4f3b-bb2a-18c146d1a6b8",                        [{"hovertemplate":"is_conviction=False\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","pattern":{"shape":""}},"name":"False","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"li4NSHsNHkD\u002faH+0v5MdQNNZTGfrAh1AvZ1I19XwHECbGuSxCzUcQP\u002fAuRU8nhtA1N3UZHwtGkAOtsn7koIZQMKTguTnNRhAU+6nxPMNFUDFs32V3YMTQOHlFLz0hRFAHx1D24mmD0A="},"textposition":"outside","x":["GE","MSFT","META","CMI","AMZN","ISRG","UBER","TSM","KLAC","SNPS","LRCX","STX","WDC"],"xaxis":"x","y":{"dtype":"f8","bdata":"li4NSHsNHkD\u002faH+0v5MdQNNZTGfrAh1AvZ1I19XwHECbGuSxCzUcQP\u002fAuRU8nhtA1N3UZHwtGkAOtsn7koIZQMKTguTnNRhAU+6nxPMNFUDFs32V3YMTQOHlFLz0hRFAHx1D24mmD0A="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"},{"hovertemplate":"is_conviction=True\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","pattern":{"shape":""}},"name":"True","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"Gt0PEK0lGEAE0HvXeIwXQNxSs2F\u002fqRZA"},"textposition":"outside","x":["GEV","AVGO","AMAT"],"xaxis":"x","y":{"dtype":"f8","bdata":"Gt0PEK0lGEAE0HvXeIwXQNxSs2F\u002fqRZA"},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7d5e8e67-fe7d-438a-90d0-66a4f2ce8a53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7d5e8e67-fe7d-438a-90d0-66a4f2ce8a53")) {                    Plotly.newPlot(                        "7d5e8e67-fe7d-438a-90d0-66a4f2ce8a53",                        [{"hovertemplate":"is_conviction=False\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","pattern":{"shape":""}},"name":"False","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"5CZq0K+tLEDavE9xyRAsQHeTu8mdnypA2\u002fJ42lK0KEDDHXFHsHQoQFyhuBX6qidAckfcETsvJ0Cs5Cg0sr4mQDH0YFNGHCJAB7YlTLcfIEBw7QPJccYZQFF3OW5xxxVAMJQyDvCWE0A="},"textposition":"outside","x":["MSFT","GE","CMI","META","AMZN","ISRG","UBER","TSM","KLAC","SNPS","LRCX","STX","WDC"],"xaxis":"x","y":{"dtype":"f8","bdata":"5CZq0K+tLEDavE9xyRAsQHeTu8mdnypA2\u002fJ42lK0KEDDHXFHsHQoQFyhuBX6qidAckfcETsvJ0Cs5Cg0sr4mQDH0YFNGHCJAB7YlTLcfIEBw7QPJccYZQFF3OW5xxxVAMJQyDvCWE0A="},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"},{"hovertemplate":"is_conviction=True\u003cbr\u003eTicker=%{x}\u003cbr\u003eLeverage (Spot \u002f Premium)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","pattern":{"shape":""}},"name":"True","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"qgGvNGxvIkCEDz74ACwhQLZiCRUZTyBA"},"textposition":"outside","x":["GEV","AVGO","AMAT"],"xaxis":"x","y":{"dtype":"f8","bdata":"qgGvNGxvIkCEDz74ACwhQLZiCRUZTyBA"},"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}x"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...

# %% [markdown]
# ## 6. Summary & Recommendation
#
# Quick-reference table: best LEAPS pick per ticker at the ITM ~90% level, sorted by conviction then value.

# %%
if picks_df.empty:
    display(Markdown("❌ No picks to summarize."))
else:
    # Best ITM ~90% pick per ticker (nearest expiration)
    best = picks_df[picks_df["Type"] == "ITM ~90%"].copy()
    if best.empty:
        best = picks_df.copy()

    best = best.sort_values("DTE").groupby("Ticker").first().reset_index()

    # Sort: conviction first, then by breakeven %
    best["is_conviction"] = best["Ticker"].isin(CONVICTION)
    best = best.sort_values(["is_conviction", "Breakeven %"], ascending=[False, True])

    summary_cols = [
        "Ticker",
        "Conviction",
        "Expiration",
        "DTE",
        "Spot",
        "Strike",
        "Mid",
        "IV",
        "Breakeven",
        "Breakeven %",
        "Leverage",
        "Cost/Contract",
        "OI",
        "Spread %",
    ]
    available = [c for c in summary_cols if c in best.columns]

    display(Markdown("### 🎯 Top LEAPS Picks — One per Ticker"))
    display(
        best[available]
        .style.format(
            {
                "Spot": "${:,.2f}",
                "Strike": "${:,.0f}",
                "Mid": "${:,.2f}",
                "IV": "{:.1%}",
                "Breakeven": "${:,.2f}",
                "Breakeven %": "{:+.1%}",
                "Leverage": "{:.1f}x",
                "Cost/Contract": "${:,.0f}",
                "OI": "{:,.0f}",
                "Spread %": "{:.1%}",
            },
            na_rep="—",
        )
        .set_caption("ITM ~90% LEAPS Calls — Sorted by Conviction then Breakeven")
    )

    # Quick conviction summary
    conv_best = best[best["is_conviction"]].copy()
    if not conv_best.empty:
        display(Markdown("\n### ⭐ Your Conviction Picks at a Glance"))
        for _, row in conv_best.iterrows():
            ticker = row["Ticker"]
            display(
                Markdown(
                    f"**{ticker}** — ${row['Spot']:,.2f} spot → "
                    f"${row['Strike']:,.0f} strike LEAPS @ ${row['Mid']:,.2f} "
                    f"(${row['Cost/Contract']:,.0f}/contract) | "
                    f"Breakeven: ${row['Breakeven']:,.2f} ({row['Breakeven %']:+.1%}) | "
                    f"Leverage: {row['Leverage']:.1f}x | "
                    f"IV: {row['IV']:.1%} | "
                    f"Expires: {row['Expiration']} ({row['DTE']:.0f} DTE)"
                )
            )
# Out:
# ### 🎯 Top LEAPS Picks — One per Ticker
# <style type="text/css">
# </style>
# <table id="T_2801a">
#   <caption>ITM ~90% LEAPS Calls — Sorted by Conviction then Breakeven</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2801a_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_2801a_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_2801a_level0_col2" class="col_heading level0 col2" >Expiration</th>
#       <th id="T_2801a_level0_col3" class="col_heading level0 col3" >DTE</th>
#       <th id="T_2801a_level0_col4" class="col_heading level0 col4" >Spot</th>
#       <th id="T_2801a_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_2801a_level0_col6" class="col_heading level0 col6" >Mid</th>
#       <th id="T_2801a_level0_col7" class="col_heading level0 col7" >IV</th>
#       <th id="T_2801a_level0_col8" class="col_heading level0 col8" >Breakeven</th>
#       <th id="T_2801a_level0_col9" class="col_heading level0 col9" >Breakeven %</th>
#       <th id="T_2801a_level0_col10" class="col_heading level0 col10" >Leverage</th>
#       <th id="T_2801a_level0_col11" class="col_heading level0 col11" >Cost/Contract</th>
#       <th id="T_2801a_level0_col12" class="col_heading level0 col12" >OI</th>
#       <th id="T_2801a_level0_col13" class="col_heading level0 col13" >Spread %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2801a_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_2801a_row0_col0" class="data row0 col0" >GEV</td>
#       <td id="T_2801a_row0_col1" class="data row0 col1" >⭐</td>
#       <td id="T_2801a_row0_col2" class="data row0 col2" >2026-05-15</td>
#       <td id="T_2801a_row0_col3" class="data row0 col3" >96</td>
#       <td id="T_2801a_row0_col4" class="data row0 col4" >$779.35</td>
#       <td id="T_2801a_row0_col5" class="data row0 col5" >$700</td>
#       <td id="T_2801a_row0_col6" class="data row0 col6" >$129.10</td>
#       <td id="T_2801a_row0_col7" class="data row0 col7" >55.1%</td>
#       <td id="T_2801a_row0_col8" class="data row0 col8" >$829.10</td>
#       <td id="T_2801a_row0_col9" class="data row0 col9" >+6.4%</td>
#       <td id="T_2801a_row0_col10" class="data row0 col10" >6.0x</td>
#       <td id="T_2801a_row0_col11" class="data row0 col11" >$12,910</td>
#       <td id="T_2801a_row0_col12" class="data row0 col12" >135</td>
#       <td id="T_2801a_row0_col13" class="data row0 col13" >4.3%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2801a_row1_col0" class="data row1 col0" >AVGO</td>
#       <td id="T_2801a_row1_col1" class="data row1 col1" >⭐</td>
#       <td id="T_2801a_row1_col2" class="data row1 col2" >2026-05-15</td>
#       <td id="T_2801a_row1_col3" class="data row1 col3" >96</td>
#       <td id="T_2801a_row1_col4" class="data row1 col4" >$332.92</td>
#       <td id="T_2801a_row1_col5" class="data row1 col5" >$300</td>
#       <td id="T_2801a_row1_col6" class="data row1 col6" >$56.55</td>
#       <td id="T_2801a_row1_col7" class="data row1 col7" >58.4%</td>
#       <td id="T_2801a_row1_col8" class="data row1 col8" >$356.55</td>
#       <td id="T_2801a_row1_col9" class="data row1 col9" >+7.1%</td>
#       <td id="T_2801a_row1_col10" class="data row1 col10" >5.9x</td>
#       <td id="T_2801a_row1_col11" class="data row1 col11" >$5,655</td>
#       <td id="T_2801a_row1_col12" class="data row1 col12" >798</td>
#       <td id="T_2801a_row1_col13" class="data row1 col13" >3.4%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_2801a_row2_col0" class="data row2 col0" >AMAT</td>
#       <td id="T_2801a_row2_col1" class="data row2 col1" >⭐</td>
#       <td id="T_2801a_row2_col2" class="data row2 col2" >2026-05-15</td>
#       <td id="T_2801a_row2_col3" class="data row2 col3" >96</td>
#       <td id="T_2801a_row2_col4" class="data row2 col4" >$322.51</td>
#       <td id="T_2801a_row2_col5" class="data row2 col5" >$290</td>
#       <td id="T_2801a_row2_col6" class="data row2 col6" >$56.92</td>
#       <td id="T_2801a_row2_col7" class="data row2 col7" >61.4%</td>
#       <td id="T_2801a_row2_col8" class="data row2 col8" >$346.93</td>
#       <td id="T_2801a_row2_col9" class="data row2 col9" >+7.6%</td>
#       <td id="T_2801a_row2_col10" class="data row2 col10" >5.7x</td>
#       <td id="T_2801a_row2_col11" class="data row2 col11" >$5,692</td>
#       <td id="T_2801a_row2_col12" class="data row2 col12" >333</td>
#       <td id="T_2801a_row2_col13" class="data row2 col13" >4.1%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_2801a_row3_col0" class="data row3 col0" >MSFT</td>
#       <td id="T_2801a_row3_col1" class="data row3 col1" ></td>
#       <td id="T_2801a_row3_col2" class="data row3 col2" >2026-05-15</td>
#       <td id="T_2801a_row3_col3" class="data row3 col3" >96</td>
#       <td id="T_2801a_row3_col4" class="data row3 col4" >$401.14</td>
#       <td id="T_2801a_row3_col5" class="data row3 col5" >$360</td>
#       <td id="T_2801a_row3_col6" class="data row3 col6" >$54.25</td>
#       <td id="T_2801a_row3_col7" class="data row3 col7" >38.9%</td>
#       <td id="T_2801a_row3_col8" class="data row3 col8" >$414.25</td>
#       <td id="T_2801a_row3_col9" class="data row3 col9" >+3.3%</td>
#       <td id="T_2801a_row3_col10" class="data row3 col10" >7.4x</td>
#       <td id="T_2801a_row3_col11" class="data row3 col11" >$5,425</td>
#       <td id="T_2801a_row3_col12" class="data row3 col12" >92</td>
#       <td id="T_2801a_row3_col13" class="data row3 col13" >3.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2801a_row4_col0" class="data row4 col0" >GE</td>
#       <td id="T_2801a_row4_col1" class="data row4 col1" ></td>
#       <td id="T_2801a_row4_col2" class="data row4 col2" >2026-05-15</td>
#       <td id="T_2801a_row4_col3" class="data row4 col3" >96</td>
#       <td id="T_2801a_row4_col4" class="data row4 col4" >$321.00</td>
#       <td id="T_2801a_row4_col5" class="data row4 col5" >$290</td>
#       <td id="T_2801a_row4_col6" class="data row4 col6" >$42.73</td>
#       <td id="T_2801a_row4_col7" class="data row4 col7" >40.5%</td>
#       <td id="T_2801a_row4_col8" class="data row4 col8" >$332.73</td>
#       <td id="T_2801a_row4_col9" class="data row4 col9" >+3.7%</td>
#       <td id="T_2801a_row4_col10" class="data row4 col10" >7.5x</td>
#       <td id="T_2801a_row4_col11" class="data row4 col11" >$4,272</td>
#       <td id="T_2801a_row4_col12" class="data row4 col12" >610</td>
#       <td id="T_2801a_row4_col13" class="data row4 col13" >5.3%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_2801a_row5_col0" class="data row5 col0" >CMI</td>
#       <td id="T_2801a_row5_col1" class="data row5 col1" ></td>
#       <td id="T_2801a_row5_col2" class="data row5 col2" >2026-06-18</td>
#       <td id="T_2801a_row5_col3" class="data row5 col3" >130</td>
#       <td id="T_2801a_row5_col4" class="data row5 col4" >$577.73</td>
#       <td id="T_2801a_row5_col5" class="data row5 col5" >$520</td>
#       <td id="T_2801a_row5_col6" class="data row5 col6" >$79.85</td>
#       <td id="T_2801a_row5_col7" class="data row5 col7" >35.6%</td>
#       <td id="T_2801a_row5_col8" class="data row5 col8" >$599.85</td>
#       <td id="T_2801a_row5_col9" class="data row5 col9" >+3.8%</td>
#       <td id="T_2801a_row5_col10" class="data row5 col10" >7.2x</td>
#       <td id="T_2801a_row5_col11" class="data row5 col11" >$7,985</td>
#       <td id="T_2801a_row5_col12" class="data row5 col12" >15</td>
#       <td id="T_2801a_row5_col13" class="data row5 col13" >2.9%</td>
#     </tr>
#     <tr>
#       <th id="T_2801a_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_2801a_row6_col0" class="data row6 col0" >META</td>
#       <td id="T_2801a_row6_col1" class="data row6 col1" ></td>
#       <td id="T_2801a_row6_col2" class="data row6 col2" >2026-05-15</td>
#       <td id="T_2801a_row6_col3" class=
# ### ⭐ Your Conviction Picks at a Glance
# **GEV** — $779.35 spot → $700 strike LEAPS @ $129.10 ($12,910/contract) | Breakeven: $829.10 (+6.4%) | Leverage: 6.0x | IV: 55.1% | Expires: 2026-05-15 (96 DTE)
# **AVGO** — $332.92 spot → $300 strike LEAPS @ $56.55 ($5,655/contract) | Breakeven: $356.55 (+7.1%) | Leverage: 5.9x | IV: 58.4% | Expires: 2026-05-15 (96 DTE)
# **AMAT** — $322.51 spot → $290 strike LEAPS @ $56.92 ($5,692/contract) | Breakeven: $346.93 (+7.6%) | Leverage: 5.7x | IV: 61.4% | Expires: 2026-05-15 (96 DTE)

# %% [markdown]
# ## 7. 🔍 Style Profile — Learning from Trades You Liked
#
# These are trades you spotted and liked (but missed). Reverse-engineering the pattern to understand what you look for, then use it to find fresh setups.

# %%
# ── Trades you liked (missed) — use as style reference ──
ref_trades = pd.DataFrame(
    [
        {
            "ticker": "GEV",
            "strike": 450,
            "expiry": "2026-12-18",
            "dte": 316,
            "premium": 306.20,
        },
        {
            "ticker": "KLAC",
            "strike": 1320,
            "expiry": "2026-02-20",
            "dte": 14,
            "premium": 51.30,
        },
        {
            "ticker": "KLAC",
            "strike": 1340,
            "expiry": "2026-02-20",
            "dte": 14,
            "premium": 51.30,
        },
        {
            "ticker": "AVGO",
            "strike": 330,
            "expiry": "2026-09-18",
            "dte": 224,
            "premium": 52.70,
        },
        {
            "ticker": "AVGO",
            "strike": 330,
            "expiry": "2026-12-18",
            "dte": 316,
            "premium": 55.45,
        },
        {
            "ticker": "WDC",
            "strike": 240,
            "expiry": "2026-02-20",
            "dte": 14,
            "premium": 22.50,
        },
    ]
)

# Compute style metrics for each reference trade
style_rows = []
for _, t in ref_trades.iterrows():
    spot = spot_map.get(t["ticker"])
    if not spot:
        continue
    moneyness = t["strike"] / spot
    intrinsic = max(spot - t["strike"], 0)
    extrinsic = t["premium"] - intrinsic
    extrinsic_pct = extrinsic / t["premium"] if t["premium"] > 0 else 0
    breakeven = t["strike"] + t["premium"]
    breakeven_pct = (breakeven - spot) / spot
    leverage = spot / t["premium"] if t["premium"] > 0 else 0
    value_at_risk = t["premium"] * 100

    style_rows.append(
        {
            "Ticker": t["ticker"],
            "Strike": t["strike"],
            "Expiry": t["expiry"],
            "DTE": t["dte"],
            "Spot": spot,
            "Premium": t["premium"],
            "Moneyness": moneyness,
            "Intrinsic": intrinsic,
            "Extrinsic": extrinsic,
            "Extrinsic %": extrinsic_pct,
            "Breakeven": breakeven,
            "Breakeven %": breakeven_pct,
            "Leverage": leverage,
            "Value at Risk": value_at_risk,
            "Category": "LEAPS" if t["dte"] > 90 else "Swing",
        }
    )

style_df = pd.DataFrame(style_rows)

display(Markdown("### 🧬 Your Style DNA — What You Like"))
display(
    style_df.style.format(
        {
            "Strike": "${:,.0f}",
            "Spot": "${:,.2f}",
            "Premium": "${:,.2f}",
            "Moneyness": "{:.1%}",
            "Intrinsic": "${:,.2f}",
            "Extrinsic": "${:,.2f}",
            "Extrinsic %": "{:.1%}",
            "Breakeven": "${:,.2f}",
            "Breakeven %": "{:+.1%}",
            "Leverage": "{:.1f}x",
            "Value at Risk": "${:,.0f}",
        },
        na_rep="—",
    ).set_caption("Reference trades — what caught your eye")
)

# Extract the pattern
leaps_trades = style_df[style_df["Category"] == "LEAPS"]
swing_trades = style_df[style_df["Category"] == "Swing"]

display(Markdown("\n### 📊 Pattern Summary"))

if not leaps_trades.empty:
    display(
        Markdown(
            f"**LEAPS pattern** (DTE > 90):\n"
            f"- Moneyness: {leaps_trades['Moneyness'].mean():.0%} avg "
            f"(range {leaps_trades['Moneyness'].min():.0%}–{leaps_trades['Moneyness'].max():.0%})\n"
            f"- Breakeven above spot: {leaps_trades['Breakeven %'].mean():+.1%} avg\n"
            f"- Leverage: {leaps_trades['Leverage'].mean():.1f}x avg\n"
            f"- Extrinsic %: {leaps_trades['Extrinsic %'].mean():.0%} avg (lower = more intrinsic value)\n"
            f"- Avg value at risk: ${leaps_trades['Value at Risk'].mean():,.0f}/contract\n"
            f"- **Style: Deep-to-moderate ITM, long-dated, stock replacement with leverage**"
        )
    )

if not swing_trades.empty:
    display(
        Markdown(
            f"\n**Swing pattern** (DTE ≤ 90):\n"
            f"- Moneyness: {swing_trades['Moneyness'].mean():.0%} avg\n"
            f"- Breakeven above spot: {swing_trades['Breakeven %'].mean():+.1%} avg\n"
            f"- Leverage: {swing_trades['Leverage'].mean():.1f}x avg\n"
            f"- Avg value at risk: ${swing_trades['Value at Risk'].mean():,.0f}/contract\n"
            f"- **Style: Near-ATM, short-duration momentum plays with high leverage**"
        )
    )

# Store style parameters for the scoring engine
STYLE_PREFS = {
    "preferred_moneyness_leaps": (0.55, 1.00),  # deep ITM to ATM
    "preferred_moneyness_swing": (0.85, 1.00),  # near ATM
    "ideal_moneyness_leaps": float(leaps_trades["Moneyness"].mean())
    if not leaps_trades.empty
    else 0.90,
    "ideal_breakeven_pct": float(style_df["Breakeven %"].mean()),
    "max_var_per_contract": float(style_df["Value at Risk"].max()),
    "ideal_leverage": float(style_df["Leverage"].mean()),
}
display(Markdown(f"\n*Style prefs saved → feeding into scoring engine below*"))
# Out:
# ### 🧬 Your Style DNA — What You Like
# <style type="text/css">
# </style>
# <table id="T_2a921">
#   <caption>Reference trades — what caught your eye</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a921_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_2a921_level0_col1" class="col_heading level0 col1" >Strike</th>
#       <th id="T_2a921_level0_col2" class="col_heading level0 col2" >Expiry</th>
#       <th id="T_2a921_level0_col3" class="col_heading level0 col3" >DTE</th>
#       <th id="T_2a921_level0_col4" class="col_heading level0 col4" >Spot</th>
#       <th id="T_2a921_level0_col5" class="col_heading level0 col5" >Premium</th>
#       <th id="T_2a921_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_2a921_level0_col7" class="col_heading level0 col7" >Intrinsic</th>
#       <th id="T_2a921_level0_col8" class="col_heading level0 col8" >Extrinsic</th>
#       <th id="T_2a921_level0_col9" class="col_heading level0 col9" >Extrinsic %</th>
#       <th id="T_2a921_level0_col10" class="col_heading level0 col10" >Breakeven</th>
#       <th id="T_2a921_level0_col11" class="col_heading level0 col11" >Breakeven %</th>
#       <th id="T_2a921_level0_col12" class="col_heading level0 col12" >Leverage</th>
#       <th id="T_2a921_level0_col13" class="col_heading level0 col13" >Value at Risk</th>
#       <th id="T_2a921_level0_col14" class="col_heading level0 col14" >Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a921_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a921_row0_col0" class="data row0 col0" >GEV</td>
#       <td id="T_2a921_row0_col1" class="data row0 col1" >$450</td>
#       <td id="T_2a921_row0_col2" class="data row0 col2" >2026-12-18</td>
#       <td id="T_2a921_row0_col3" class="data row0 col3" >316</td>
#       <td id="T_2a921_row0_col4" class="data row0 col4" >$779.35</td>
#       <td id="T_2a921_row0_col5" class="data row0 col5" >$306.20</td>
#       <td id="T_2a921_row0_col6" class="data row0 col6" >57.7%</td>
#       <td id="T_2a921_row0_col7" class="data row0 col7" >$329.35</td>
#       <td id="T_2a921_row0_col8" class="data row0 col8" >$-23.15</td>
#       <td id="T_2a921_row0_col9" class="data row0 col9" >-7.6%</td>
#       <td id="T_2a921_row0_col10" class="data row0 col10" >$756.20</td>
#       <td id="T_2a921_row0_col11" class="data row0 col11" >-3.0%</td>
#       <td id="T_2a921_row0_col12" class="data row0 col12" >2.5x</td>
#       <td id="T_2a921_row0_col13" class="data row0 col13" >$30,620</td>
#       <td id="T_2a921_row0_col14" class="data row0 col14" >LEAPS</td>
#     </tr>
#     <tr>
#       <th id="T_2a921_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a921_row1_col0" class="data row1 col0" >KLAC</td>
#       <td id="T_2a921_row1_col1" class="data row1 col1" >$1,320</td>
#       <td id="T_2a921_row1_col2" class="data row1 col2" >2026-02-20</td>
#       <td id="T_2a921_row1_col3" class="data row1 col3" >14</td>
#       <td id="T_2a921_row1_col4" class="data row1 col4" >$1,442.95</td>
#       <td id="T_2a921_row1_col5" class="data row1 col5" >$51.30</td>
#       <td id="T_2a921_row1_col6" class="data row1 col6" >91.5%</td>
#       <td id="T_2a921_row1_col7" class="data row1 col7" >$122.95</td>
#       <td id="T_2a921_row1_col8" class="data row1 col8" >$-71.65</td>
#       <td id="T_2a921_row1_col9" class="data row1 col9" >-139.7%</td>
#       <td id="T_2a921_row1_col10" class="data row1 col10" >$1,371.30</td>
#       <td id="T_2a921_row1_col11" class="data row1 col11" >-5.0%</td>
#       <td id="T_2a921_row1_col12" class="data row1 col12" >28.1x</td>
#       <td id="T_2a921_row1_col13" class="data row1 col13" >$5,130</td>
#       <td id="T_2a921_row1_col14" class="data row1 col14" >Swing</td>
#     </tr>
#     <tr>
#       <th id="T_2a921_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2a921_row2_col0" class="data row2 col0" >KLAC</td>
#       <td id="T_2a921_row2_col1" class="data row2 col1" >$1,340</td>
#       <td id="T_2a921_row2_col2" class="data row2 col2" >2026-02-20</td>
#       <td id="T_2a921_row2_col3" class="data row2 col3" >14</td>
#       <td id="T_2a921_row2_col4" class="data row2 col4" >$1,442.95</td>
#       <td id="T_2a921_row2_col5" class="data row2 col5" >$51.30</td>
#       <td id="T_2a921_row2_col6" class="data row2 col6" >92.9%</td>
#       <td id="T_2a921_row2_col7" class="data row2 col7" >$102.95</td>
#       <td id="T_2a921_row2_col8" class="data row2 col8" >$-51.65</td>
#       <td id="T_2a921_row2_col9" class="data row2 col9" >-100.7%</td>
#       <td id="T_2a921_row2_col10" class="data row2 col10" >$1,391.30</td>
#       <td id="T_2a921_row2_col11" class="data row2 col11" >-3.6%</td>
#       <td id="T_2a921_row2_col12" class="data row2 col12" >28.1x</td>
#       <td id="T_2a921_row2_col13" class="data row2 col13" >$5,130</td>
#       <td id="T_2a921_row2_col14" class="data row2 col14" >Swing</td>
#     </tr>
#     <tr>
#       <th id="T_2a921_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2a921_row3_col0" class="data row3 col0" >AVGO</td>
#       <td id="T_2a921_row3_col1" class="data row3 col1" >$330</td>
#       <td id="T_2a921_row3_col2" class="data row3 col2" >2026-09-18</td>
#       <td id="T_2a921_row3_col3" class="data row3 col3" >224</td>
#       <td id="T_2a921_row3_col4" class="data row3 col4" >$332.92</td>
#       <td id="T_2a921_row3_col5" class="data row3 col5" >$52.70</td>
#       <td id="T_2a921_row3_col6" class="data row3 col6" >99.1%</td>
#       <td id="T_2a921_row3_col7" class="data row3 col7" >$2.92</td>
#       <td id="T_2a921_row3_col8" class="data row3 col8" >$49.78</td>
#       <td id="T_2a921_row3_col9" class="data row3 col9" >94.5%</td>
#       <td id="T_2a921_row3_col10" class="data row3 col10" >$382.70</td>
#       <td id="T_2a921_row3_col11" class="data row3 col11" >+15.0%</td>
#       <td id="T_2a921_row3_col12" class="data row3 col12" >6.3x</td>
#       <td id="T_2a921_row3_col13" class="data row3 col13" >$5,270</td>
#       <td id="T_2a921_row3_col14" class="data row3 col14" >LEAPS</td>
#     </tr>
#     <tr>
#       <th id="T_2a921_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2a921_row4_col0" class="data row4 col0" >AVGO</td>
#       <td id="T_2a921_row4_col1" class="data row4 col1" >$330</td>
#       <td id="T_2a921_row4_col2" class="data row4 col2" >2026-12-18</td>
#       <td id="T_2a921_row4_col3" class="data row4 col3" >316</td>
#       <td id="T_2a921_row4_col4" class="data row4 col4" >$332.92</td>
#       <td id="T_2a921_row4_col5" class="data row4 col5" >$55.45</td>
#       <td id="T_2a921_row4_col6" class="data row4 col6" >99.1%</td>
#       <td id="T_2a921_row4_col7" class="data row4 col7" >$2.92</td>
#       <td id="T_2a921_row4_col8" class="data row4 col8" >$52.53</td>
#       <td id="T_2a921_row4_col9" class="data row4 col9" >94.7%</td>
#       <td id="T_2a921_row4_col10" class="data row4 col10" >$385.45</td>
#       <td id="T_2a921_row4_col11" class="data row4 col11" >+15.8%</td>
#       <td id="T_2a921_row4_col12" class="data row4 col12" >6.0x</td>
#       <td id="T_2a921_row4_col13" class="data row4 col13" >$5,545</td>
#       <td id="T_2a921_row4_col14" class="data row4 col14" >LEAPS</td>
#     </tr>
#     <tr>
#       <th id="T_2a921_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2a921_row5_col0" class="data row5 col0" >WDC</td>
#       <td id="T_2a921_row5_col1" class="data row5 col1" >$240</td>
#       <td id="T_2a921_row5_col2" class="data row5 col2" >2026-02-20</td>
#       <td id="T_2a921_row5_col3" class="data row5 col3" >14</td>
#       <td id="T_2a921_row5_col4" class="data row5 col4" >$282.58</td>
#       <td id="T_2a921_row5_col5" class="data row5 col5" >$22.50</td>
#       <td id="T_2a921_row5_col6" class="data row5 col6" >84.9%</td>
#       <td id="T_2a921_row5_col7" class="data row5 col7" >$42.58</td>
#       <td id="T_2a921_row5_col8" class="data row5 col8" >$-20.08</td>
#       <td id="T_2a921_row5_col9" class="data row5 col9" >-89.2%</td>
#       <td id="T_2a921_row5_col10" class="data row5 col10" >$262.50</td>
#       <td id="T_2a921_row5_
# ### 📊 Pattern Summary
# **LEAPS pattern** (DTE > 90):
# - Moneyness: 85% avg (range 58%–99%)
# - Breakeven above spot: +9.3% avg
# - Leverage: 5.0x avg
# - Extrinsic %: 61% avg (lower = more intrinsic value)
# - Avg value at risk: $13,812/contract
# - **Style: Deep-to-moderate ITM, long-dated, stock replacement with leverage**
# **Swing pattern** (DTE ≤ 90):
# - Moneyness: 90% avg
# - Breakeven above spot: -5.2% avg
# - Leverage: 22.9x avg
# - Avg value at risk: $4,170/contract
# - **Style: Near-ATM, short-duration momentum plays with high leverage**
# *Style prefs saved → feeding into scoring engine below*

# %% [markdown]
# ## 8. 🧠 Edge Scoring Engine — Find the Next Plays
#
# Using your style profile + market data to score **every LEAPS option** on edge & probability of profit.
#
# | Factor              | What it measures                                     | Weight |
# | ------------------- | ---------------------------------------------------- | ------ |
# | **P(Profit) — BSM** | Black-Scholes probability spot > breakeven at expiry | 25%    |
# | **IV vs HV edge**   | IV overpriced vs realized? Trend-adjusted            | 15%    |
# | **Breakeven %**     | How far stock must move — lower = better             | 15%    |
# | **Momentum**        | 1M + 3M returns — trend is your friend               | 20%    |
# | **Style match**     | How close to your preferred moneyness/leverage       | 15%    |
# | **Liquidity**       | Tight spreads + open interest                        | 10%    |

# %%
from scipy.stats import norm

# ══════════════════════════════════════════════════════════════════
# STEP 1: Fetch HV + Momentum for all tickers
# ══════════════════════════════════════════════════════════════════
hv_momentum = {}

for ticker in ALL_TICKERS:
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        hist = t.history(period="1y")
        if hist.empty or "Close" not in hist.columns:
            continue
        closes = hist["Close"].dropna()
        if len(closes) < 60:
            continue

        log_ret = np.log(closes / closes.shift(1)).dropna()
        hv_30 = float(log_ret.iloc[-30:].std() * math.sqrt(252))
        hv_60 = float(log_ret.iloc[-60:].std() * math.sqrt(252))

        price = float(closes.iloc[-1])
        ret_1m = (
            float(closes.iloc[-1] / closes.iloc[-21] - 1) if len(closes) > 21 else 0
        )
        ret_3m = (
            float(closes.iloc[-1] / closes.iloc[-63] - 1) if len(closes) > 63 else 0
        )
        ret_6m = (
            float(closes.iloc[-1] / closes.iloc[-126] - 1) if len(closes) > 126 else 0
        )

        # RSI (Wilder's smoothing — EWM with com=13)
        delta = closes.diff()
        gain = delta.clip(lower=0).ewm(com=13, adjust=False).mean()
        loss_s = (-delta.clip(upper=0)).ewm(com=13, adjust=False).mean()
        rs = gain.iloc[-1] / loss_s.iloc[-1] if loss_s.iloc[-1] > 0 else 100
        rsi = float(100 - (100 / (1 + rs)))

        # 50/200 MA trend
        ma50 = float(closes.rolling(50).mean().iloc[-1]) if len(closes) >= 50 else None
        ma200 = (
            float(closes.rolling(200).mean().iloc[-1]) if len(closes) >= 200 else None
        )
        above_50 = price > ma50 if ma50 else False
        above_200 = price > ma200 if ma200 else False
        golden_cross = (ma50 > ma200) if (ma50 and ma200) else False

        # 52-week high distance
        high_52w = (
            float(closes.iloc[-252:].max())
            if len(closes) >= 252
            else float(closes.max())
        )
        dist_52w = (price - high_52w) / high_52w

        hv_momentum[ticker] = {
            "hv_30": hv_30,
            "hv_60": hv_60,
            "ret_1m": ret_1m,
            "ret_3m": ret_3m,
            "ret_6m": ret_6m,
            "rsi": rsi,
            "dist_52w_high": dist_52w,
            "above_50ma": above_50,
            "above_200ma": above_200,
            "golden_cross": golden_cross,
        }
        trend_flags = []
        if above_50:
            trend_flags.append("▲50MA")
        if above_200:
            trend_flags.append("▲200MA")
        if golden_cross:
            trend_flags.append("🔥GC")
        print(
            f"  {ticker}: HV30={hv_30:.1%} 1M={ret_1m:+.1%} 3M={ret_3m:+.1%} RSI={rsi:.0f} {' '.join(trend_flags)}"
        )
    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

print(f"\n✅ HV/momentum for {len(hv_momentum)} tickers")
# Out:
#   WDC: HV30=94.8% 1M=+50.6% 3M=+72.9% RSI=64 ▲50MA ▲200MA 🔥GC
#   GEV: HV30=42.7% 1M=+24.0% 3M=+41.8% RSI=68 ▲50MA ▲200MA 🔥GC
#   STX: HV30=88.9% 1M=+50.9% 3M=+54.6% RSI=65 ▲50MA ▲200MA 🔥GC
#   LRCX: HV30=66.1% 1M=+15.0% 3M=+42.7% RSI=58 ▲50MA ▲200MA 🔥GC
#   AMAT: HV30=53.4% 1M=+14.5% 3M=+38.4% RSI=57 ▲50MA ▲200MA 🔥GC
#   TSM: HV30=36.5% 1M=+9.7% 3M=+20.9% RSI=62 ▲50MA ▲200MA 🔥GC
#   GE: HV30=37.8% 1M=+2.1% 3M=+5.3% RSI=59 ▲50MA ▲200MA 🔥GC
#   CMI: HV30=44.6% 1M=+6.1% 3M=+25.4% RSI=54 ▲50MA ▲200MA 🔥GC
#   KLAC: HV30=73.7% 1M=+8.9% 3M=+19.8% RSI=52 ▲50MA ▲200MA 🔥GC
#   SNPS: HV30=43.8% 1M=-17.0% 3M=+7.8% RSI=34
#   META: HV30=41.4% 1M=+2.4% 3M=+7.0% RSI=49 ▲50MA
#   UBER: HV30=32.2% 1M=-14.6% 3M=-18.8% RSI=32
#   ISRG: HV30=24.6% 1M=-16.6% 3M=-10.9% RSI=29 🔥GC
#   MSFT: HV30=39.9% 1M=-16.1% 3M=-19.2% RSI=29
#   AMZN: HV30=32.9% 1M=-14.6% 3M=-13.5% RSI=29 🔥GC
#   AVGO: HV30=39.3% 1M=+0.1% 3M=-6.2% RSI=49 ▲200MA 🔥GC
#
# ✅ HV/momentum for 16 tickers

# %% [markdown]
# ### Scoring & Ranking — LEAPS + Swing Opportunities

# %%
# ══════════════════════════════════════════════════════════════════
# STEP 2: Score every LEAPS option
# ══════════════════════════════════════════════════════════════════


def bsm_prob_profit(spot, breakeven, iv, dte, r=None):
    """P(spot > breakeven at expiry) under Black-Scholes lognormal model.

    NOTE: Uses risk-neutral drift (r), so this is the risk-neutral probability.
    Real-world probability would use expected return μ > r (equity risk premium),
    making this estimate conservative — actual P(profit) is likely higher.
    """
    if r is None:
        r = RISK_FREE_RATE
    if iv <= 0 or dte <= 0 or spot <= 0 or breakeven <= 0:
        return np.nan
    T = dte / 365.0
    d2 = (math.log(spot / breakeven) + (r - 0.5 * iv**2) * T) / (iv * math.sqrt(T))
    return float(norm.cdf(d2))


def score_option(row, hv_data, style_prefs):
    """Score a single option 0-100 based on edge factors."""
    scores = {}
    weights = {}
    ticker = row["ticker"]
    hv = hv_data.get(ticker, {})
    if not hv:
        return np.nan, np.nan, {}

    spot = row["spot"]
    iv = row.get("iv", np.nan)
    dte = row["dte"]
    breakeven = row["breakeven"]
    moneyness = row["moneyness"]

    # 1. P(Profit) from BSM — 25%
    p_profit = bsm_prob_profit(spot, breakeven, iv, dte) if not np.isnan(iv) else np.nan
    if not np.isnan(p_profit):
        scores["p_profit"] = min(p_profit * 100, 100)  # 0-100
        weights["p_profit"] = 0.25

    # 2. Momentum — 20% (combine 1M + 3M, RSI, trend flags)
    ret_1m = hv.get("ret_1m", 0)
    ret_3m = hv.get("ret_3m", 0)
    rsi = hv.get("rsi", 50)
    above_50 = hv.get("above_50ma", False)
    above_200 = hv.get("above_200ma", False)
    golden_cross = hv.get("golden_cross", False)

    # Momentum: positive returns = good, RSI 50-70 sweet spot (trending but not overbought)
    mom_score = 0
    mom_score += np.clip(ret_1m * 200, -30, 40)  # 1M return contribution
    mom_score += np.clip(ret_3m * 100, -20, 30)  # 3M return contribution
    if 45 < rsi < 72:
        mom_score += 15  # sweet spot — trending, not overbought
    elif rsi >= 72:
        mom_score += 5  # overbought risk, but still going
    if above_50:
        mom_score += 5
    if above_200:
        mom_score += 5
    if golden_cross:
        mom_score += 5
    scores["momentum"] = np.clip(mom_score, 0, 100)
    weights["momentum"] = 0.20

    # 3. Breakeven % — 15% (lower = easier to profit)
    be_pct = row.get("breakeven_pct", np.nan)
    if not np.isnan(be_pct):
        # Best case: breakeven below spot (already ITM beyond premium)
        # Worst: breakeven +20% above
        be_score = np.clip((0.15 - be_pct) / 0.20 * 100, 0, 100)
        scores["breakeven"] = be_score
        weights["breakeven"] = 0.15

    # 4. IV vs HV edge — 15%
    hv_30 = hv.get("hv_30", np.nan)
    if not np.isnan(iv) and not np.isnan(hv_30) and iv > 0:
        # For CALL buyers with momentum: HV > IV means realized moves exceed what IV prices in
        # Also reward: IV not wildly expensive vs HV (IV/HV < 1.3 is good)
        iv_hv_ratio = iv / hv_30 if hv_30 > 0 else 2.0
        if iv_hv_ratio < 0.9:
            iv_score = 90  # IV cheap vs realized — strong edge
        elif iv_hv_ratio < 1.1:
            iv_score = 70  # fair value
        elif iv_hv_ratio < 1.3:
            iv_score = 45  # slightly expensive
        else:
            iv_score = max(0, 30 - (iv_hv_ratio - 1.3) * 50)  # expensive
        scores["iv_edge"] = iv_score
        weights["iv_edge"] = 0.15

    # 5. Style match — 15% (how close to your pattern)
    ideal_mon = style_prefs.get("ideal_moneyness_leaps", 0.90)
    mon_dist = abs(moneyness - ideal_mon)
    style_score = max(0, 100 - mon_dist * 500)  # penalize distance from ideal
    # Bonus for deep ITM (more intrinsic, less risk)
    if moneyness < 0.90:
        style_score = min(100, style_score + 10)
    scores["style_match"] = style_score
    weights["style_match"] = 0.15

    # 6. Liquidity — 10%
    oi = safe_float(row.get("openInterest", 0))
    spread_pct = row.get("spread_pct", np.nan)
    liq_score = 0
    if oi > 500:
        liq_score += 40
    elif oi > 100:
        liq_score += 25
    elif oi > 20:
        liq_score += 10
    if not np.isnan(spread_pct):
        if spread_pct < 0.05:
            liq_score += 60
        elif spread_pct < 0.10:
            liq_score += 40
        elif spread_pct < 0.20:
            liq_score += 20
    scores["liquidity"] = min(liq_score, 100)
    weights["liquidity"] = 0.10

    # Weighted total
    total_w = sum(weights.values())
    if total_w == 0:
        return np.nan, p_profit, scores

    edge_score = sum(scores[k] * weights[k] for k in scores) / total_w
    return edge_score, p_profit, scores


# ── Score all LEAPS options ──
scored_rows = []

for _, row in leaps_df.iterrows():
    edge, p_profit, components = score_option(row, hv_momentum, STYLE_PREFS)
    if np.isnan(edge):
        continue

    scored_rows.append(
        {
            "Ticker": row["ticker"],
            "Conviction": "⭐" if row["ticker"] in CONVICTION else "",
            "Expiry": row["expiration"],
            "DTE": row["dte"],
            "Strike": row["strike"],
            "Moneyness": row["moneyness"],
            "Spot": row["spot"],
            "Mid": row["mid"],
            "IV": row.get("iv", np.nan),
            "HV30": hv_momentum.get(row["ticker"], {}).get("hv_30", np.nan),
            "Breakeven": row["breakeven"],
            "Breakeven %": row["breakeven_pct"],
            "Leverage": row["leverage"],
            "Cost/Contract": row["cost_per_contract"],
            "OI": safe_float(row.get("openInterest", 0)),
            "Spread %": row.get("spread_pct", np.nan),
            "P(Profit)": p_profit,
            "Edge Score": edge,
            "s_pprofit": components.get("p_profit", np.nan),
            "s_momentum": components.get("momentum", np.nan),
            "s_breakeven": components.get("breakeven", np.nan),
            "s_iv_edge": components.get("iv_edge", np.nan),
            "s_style": components.get("style_match", np.nan),
            "s_liquidity": components.get("liquidity", np.nan),
            "Ret 1M": hv_momentum.get(row["ticker"], {}).get("ret_1m", np.nan),
            "Ret 3M": hv_momentum.get(row["ticker"], {}).get("ret_3m", np.nan),
            "RSI": hv_momentum.get(row["ticker"], {}).get("rsi", np.nan),
        }
    )

scored_df = pd.DataFrame(scored_rows)
print(
    f"✅ Scored {len(scored_df)} options across {scored_df['Ticker'].nunique()} tickers"
)
# Out:
# ✅ Scored 536 options across 16 tickers

# %% [markdown]
# ## 9. 🏆 Top Ranked Opportunities — Best Edge Right Now

# %%
if scored_df.empty:
    display(Markdown("❌ No scored options."))
else:
    # ── Best LEAPS pick per ticker (highest edge score, prefer ITM ~85-95%) ──
    sweet_spot = scored_df[
        (scored_df["Moneyness"] >= 0.82) & (scored_df["Moneyness"] <= 0.98)
    ].copy()
    if sweet_spot.empty:
        sweet_spot = scored_df.copy()

    # Best single option per ticker (highest edge)
    top_per_ticker = (
        sweet_spot.sort_values("Edge Score", ascending=False)
        .groupby("Ticker")
        .first()
        .reset_index()
    )
    top_per_ticker = top_per_ticker.sort_values("Edge Score", ascending=False)

    display_cols = [
        "Ticker",
        "Conviction",
        "Expiry",
        "DTE",
        "Strike",
        "Moneyness",
        "Spot",
        "Mid",
        "IV",
        "HV30",
        "Breakeven",
        "Breakeven %",
        "Leverage",
        "Cost/Contract",
        "P(Profit)",
        "Edge Score",
        "Ret 1M",
        "Ret 3M",
        "RSI",
        "OI",
    ]
    avail = [c for c in display_cols if c in top_per_ticker.columns]

    display(Markdown("### 🎯 Best LEAPS Pick per Ticker — Ranked by Edge Score"))
    display(
        top_per_ticker[avail]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Spot": "${:,.2f}",
                "Mid": "${:,.2f}",
                "Moneyness": "{:.0%}",
                "IV": "{:.1%}",
                "HV30": "{:.1%}",
                "Breakeven": "${:,.2f}",
                "Breakeven %": "{:+.1%}",
                "Leverage": "{:.1f}x",
                "Cost/Contract": "${:,.0f}",
                "P(Profit)": "{:.0%}",
                "Edge Score": "{:.0f}",
                "Ret 1M": "{:+.1%}",
                "Ret 3M": "{:+.1%}",
                "RSI": "{:.0f}",
                "OI": "{:,.0f}",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Edge Score"], cmap="RdYlGn", vmin=30, vmax=80)
        .background_gradient(subset=["P(Profit)"], cmap="RdYlGn", vmin=0.3, vmax=0.8)
        .set_caption("Ranked by Edge Score — higher = stronger setup")
    )

    # ── Score component breakdown for top 8 ──
    top8 = top_per_ticker.head(8)
    component_cols = [
        "Ticker",
        "Edge Score",
        "s_pprofit",
        "s_momentum",
        "s_breakeven",
        "s_iv_edge",
        "s_style",
        "s_liquidity",
    ]
    comp_avail = [c for c in component_cols if c in top8.columns]
    display(Markdown("\n### 🔬 Score Breakdown — Top 8"))
    display(
        top8[comp_avail]
        .style.format(
            {
                "Edge Score": "{:.0f}",
                "s_pprofit": "{:.0f}",
                "s_momentum": "{:.0f}",
                "s_breakeven": "{:.0f}",
                "s_iv_edge": "{:.0f}",
                "s_style": "{:.0f}",
                "s_liquidity": "{:.0f}",
            },
            na_rep="—",
        )
        .background_gradient(
            cmap="RdYlGn",
            vmin=20,
            vmax=90,
            axis=None,
            subset=[
                "s_pprofit",
                "s_momentum",
                "s_breakeven",
                "s_iv_edge",
                "s_style",
                "s_liquidity",
            ],
        )
        .set_caption(
            "Component scores (0-100) | P(Profit)=25% Momentum=20% Breakeven=15% IV Edge=15% Style=15% Liquidity=10%"
        )
    )

    # ── Chart: Edge score vs P(Profit) scatter ──
    plot_df = top_per_ticker.copy()
    plot_df["is_conviction"] = plot_df["Ticker"].isin(CONVICTION)

    fig = px.scatter(
        plot_df,
        x="P(Profit)",
        y="Edge Score",
        color="is_conviction",
        text="Ticker",
        size="Leverage",
        size_max=25,
        color_discrete_map={True: "#1a7431", False: "#4C6E91"},
        title="Edge Score vs P(Profit) — Best LEAPS per Ticker",
        labels={"is_conviction": "Conviction"},
    )
    fig.update_traces(textposition="top center")
    fig.update_layout(
        xaxis_tickformat=".0%",
        xaxis_title="Probability of Profit (BSM)",
        yaxis_title="Edge Score (0-100)",
    )
    # Quadrant lines
    fig.add_hline(y=55, line_dash="dot", line_color="gray", opacity=0.5)
    fig.add_vline(x=0.50, line_dash="dot", line_color="gray", opacity=0.5)
    fig.add_annotation(
        x=0.7,
        y=75,
        text="🎯 Sweet Spot",
        showarrow=False,
        font=dict(size=14, color="green"),
    )
    fig.show()
# Out:
# ### 🎯 Best LEAPS Pick per Ticker — Ranked by Edge Score
# <style type="text/css">
# #T_40632_row0_col14 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_40632_row0_col15 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_40632_row1_col14 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_40632_row1_col15 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_40632_row2_col14 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_40632_row2_col15 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_40632_row3_col14 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_40632_row3_col15 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_40632_row4_col14 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_40632_row4_col15 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_40632_row5_col14 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_40632_row5_col15 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_40632_row6_col14 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_40632_row6_col15 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_40632_row7_col14 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_40632_row7_col15 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_40632_row8_col14 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_40632_row8_col15 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_40632_row9_col14, #T_40632_row14_col14 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_40632_row9_col15 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_40632_row10_col14 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_40632_row10_col15 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_40632_row11_col14 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_40632_row11_col15 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_40632_row12_col14 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_40632_row12_col15 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_40632_row13_col14 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_40632_row13_col15 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_40632_row14_col15 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_40632_row15_col14 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_40632_row15_col15 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40632">
#   <caption>Ranked by Edge Score — higher = stronger setup</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40632_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_40632_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_40632_level0_col2" class="col_heading level0 col2" >Expiry</th>
#       <th id="T_40632_level0_col3" class="col_heading level0 col3" >DTE</th>
#       <th id="T_40632_level0_col4" class="col_heading level0 col4" >Strike</th>
#       <th id="T_40632_level0_col5" class="col_heading level0 col5" >Moneyness</th>
#       <th id="T_40632_level0_col6" class="col_heading level0 col6" >Spot</th>
#       <th id="T_40632_level0_col7" class="col_heading level0 col7" >Mid</th>
#       <th id="T_40632_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_40632_level0_col9" class="col_heading level0 col9" >HV30</th>
#       <th id="T_40632_level0_col10" class="col_heading level0 col10" >Breakeven</th>
#       <th id="T_40632_level0_col11" class="col_heading level0 col11" >Breakeven %</th>
#       <th id="T_40632_level0_col12" class="col_heading level0 col12" >Leverage</th>
#       <th id="T_40632_level0_col13" class="col_heading level0 col13" >Cost/Contract</th>
#       <th id="T_40632_level0_col14" class="col_heading level0 col14" >P(Profit)</th>
#       <th id="T_40632_level0_col15" class="col_heading level0 col15" >Edge Score</th>
#       <th id="T_40632_level0_col16" class="col_heading level0 col16" >Ret 1M</th>
#       <th id="T_40632_level0_col17" class="col_heading level0 col17" >Ret 3M</th>
#       <th id="T_40632_level0_col18" class="col_heading level0 col18" >RSI</th>
#       <th id="T_40632_level0_col19" class="col_heading level0 col19" >OI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40632_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_40632_row0_col0" class="data row0 col0" >CMI</td>
#       <td id="T_40632_row0_col1" class="data row0 col1" ></td>
#       <td id="T_40632_row0_col2" class="data row0 col2" >2026-06-18</td>
#       <td id="T_40632_row0_col3" class="data row0 col3" >130</td>
#       <td id="T_40632_row0_col4" class="data row0 col4" >$480</td>
#       <td id="T_40632_row0_col5" class="data row0 col5" >83%</td>
#       <td id="T_40632_row0_col6" class="data row0 col6" >$577.73</td>
#       <td id="T_40632_row0_col7" class="data row0 col7" >$110.75</td>
#       <td id="T_40632_row0_col8" class="data row0 col8" >38.6%</td>
#       <td id="T_40632_row0_col9" class="data row0 col9" >44.6%</td>
#       <td id="T_40632_row0_col10" class="data row0 col10" >$590.75</td>
#       <td id="T_40632_row0_col11" class="data row0 col11" >+2.3%</td>
#       <td id="T_40632_row0_col12" class="data row0 col12" >5.2x</td>
#       <td id="T_40632_row0_col13" class="data row0 col13" >$11,075</td>
#       <td id="T_40632_row0_col14" class="data row0 col14" >44%</td>
#       <td id="T_40632_row0_col15" class="data row0 col15" >69</td>
#       <td id="T_40632_row0_col16" class="data row0 col16" >+6.1%</td>
#       <td id="T_40632_row0_col17" class="data row0 col17" >+25.4%</td>
#       <td id="T_40632_row0_col18" class="data row0 col18" >50</td>
#       <td id="T_40632_row0_col19" class="data row0 col19" >38</td>
#     </tr>
#     <tr>
#       <th id="T_40632_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_40632_row1_col0" class="data row1 col0" >STX</td>
#       <td id="T_40632_row1_col1" class="data row1 col1" ></td>
#       <td id="T_40632_row1_col2" class="data row1 col2" >2026-06-18</td>
#       <td id="T_40632_row1_col3" class="data row1 col3" >130</td>
#       <td id="T_40632_row1_col4" class="data row1 col4" >$370</td>
#       <td id="T_40632_row1_col5" class="data row1 col5" >86%</td>
#       <td id="T_40632_row1_col6" class="data row1 col6" >$429.32</td>
#       <td id="T_40632_row1_col7" class="data row1 col7" >$108.65</td>
#       <td id="T_40632_row1_col8" class="data row1 col8" >79.7%</td>
#       <td id="T_40632_row1_col9" class="data row1 col9" >88.9%</td>
#       <td id="T_40632_row1_col10" class="data row1 col10" >$478.65</td>
#       <td id="T_40632_row1_col11" class="data row1 col11" >+11.5%</td>
#       <td id="T_40632_row1_col12" class="data row1 col12" >4.0x</td>
#       <td id="T_40632_row1_col13" class="data row1 col13" >$10,865</td>
#       <td id="T_40632_row1_col14" class="data row1 col14" >33%</td>
#       <td id="T_40632_row1_col15" class="data row1 col15" >68</td>
#       <td id="T_40632_row1_col16" class="data row1 col16" >+50.9%</td>
#       <td id="T_40632_row1_col17" class="data row1 col17" >+54.6%</td>
#       <td id="T_40632_row1_col18" class="data row1 col18" >70</td>
#       <td id="T_40632_row1_col19" class="data row1 col19" >132</td>
#     </tr>
#     <tr>
#       <th id="T_40632_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_40632_row2_col0" class="data row2 col0" >LRCX</td>
#       <td id="T_40632_row2_col1" class="data row2 col1" ></td>
#       <td id="T_40632_row2_col2" class="data row2 col2" >2026-06-18</td>
#       <td id="T_40632_row2_col3" class="data row2 col3" >130</td>
#       <td id="T_40632_row2_col4" class="data row2 col4" >$190</td>
#       <td id="T_40632_row2_col5" class="data row2 col5" >82%</td>
#       <td id="T_40632_row2_col6" class="data row2 col6" >$231.01</td>
#       <td id="T_40632_row2_col7" class="data row2 col7" >$59.73</td>
#       <td id="T_40632_row2_col8" class="data row2 col8" >71.4%</td>
#       <td id="T_40632_row2_col9" class="data row2 col9" >66.1%</td>
#       <td id="T_40632_row2_col10" class="data row2 col10" >$249.72</td>
#       <td id="T_40632_row2_col11" class="data row2 col11" >+8.1%</td>
#       <td id="T_40632_row2_col12" class="data row2 col12" >3.9x</td>
#       <td id="T_
# ### 🔬 Score Breakdown — Top 8
# <style type="text/css">
# #T_28c6e_row0_col2 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_28c6e_row0_col3 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_28c6e_row0_col4 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_28c6e_row0_col5, #T_28c6e_row0_col6, #T_28c6e_row1_col3, #T_28c6e_row1_col5, #T_28c6e_row1_col6, #T_28c6e_row2_col3, #T_28c6e_row2_col6, #T_28c6e_row2_col7, #T_28c6e_row3_col3, #T_28c6e_row3_col6, #T_28c6e_row4_col6, #T_28c6e_row4_col7, #T_28c6e_row5_col3, #T_28c6e_row5_col5, #T_28c6e_row5_col6, #T_28c6e_row6_col5, #T_28c6e_row6_col6, #T_28c6e_row7_col6, #T_28c6e_row7_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_28c6e_row0_col7, #T_28c6e_row2_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_28c6e_row1_col2 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_28c6e_row1_col4, #T_28c6e_row5_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_28c6e_row1_col7, #T_28c6e_row3_col7, #T_28c6e_row6_col7 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_28c6e_row2_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_28c6e_row2_col4 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_28c6e_row3_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_28c6e_row3_col4 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_28c6e_row3_col5, #T_28c6e_row4_col5 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_28c6e_row4_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_28c6e_row4_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_28c6e_row4_col4 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_28c6e_row5_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_28c6e_row5_col7 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_28c6e_row6_col2 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_28c6e_row6_col3 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_28c6e_row6_col4 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_28c6e_row7_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_28c6e_row7_col3 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_28c6e_row7_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_28c6e_row7_col5 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_28c6e">
#   <caption>Component scores (0-100) | P(Profit)=25% Momentum=20% Breakeven=15% IV Edge=15% Style=15% Liquidity=10%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28c6e_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_28c6e_level0_col1" class="col_heading level0 col1" >Edge Score</th>
#       <th id="T_28c6e_level0_col2" class="col_heading level0 col2" >s_pprofit</th>
#       <th id="T_28c6e_level0_col3" class="col_heading level0 col3" >s_momentum</th>
#       <th id="T_28c6e_level0_col4" class="col_heading level0 col4" >s_breakeven</th>
#       <th id="T_28c6e_level0_col5" class="col_heading level0 col5" >s_iv_edge</th>
#       <th id="T_28c6e_level0_col6" class="col_heading level0 col6" >s_style</th>
#       <th id="T_28c6e_level0_col7" class="col_heading level0 col7" >s_liquidity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28c6e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_28c6e_row0_col0" class="data row0 col0" >CMI</td>
#       <td id="T_28c6e_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_28c6e_row0_col2" class="data row0 col2" >44</td>
#       <td id="T_28c6e_row0_col3" class="data row0 col3" >68</td>
#       <td id="T_28c6e_row0_col4" class="data row0 col4" >64</td>
#       <td id="T_28c6e_row0_col5" class="data row0 col5" >90</td>
#       <td id="T_28c6e_row0_col6" class="data row0 col6" >99</td>
#       <td id="T_28c6e_row0_col7" class="data row0 col7" >70</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_28c6e_row1_col0" class="data row1 col0" >STX</td>
#       <td id="T_28c6e_row1_col1" class="data row1 col1" >68</td>
#       <td id="T_28c6e_row1_col2" class="data row1 col2" >33</td>
#       <td id="T_28c6e_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_28c6e_row1_col4" class="data row1 col4" >18</td>
#       <td id="T_28c6e_row1_col5" class="data row1 col5" >90</td>
#       <td id="T_28c6e_row1_col6" class="data row1 col6" >100</td>
#       <td id="T_28c6e_row1_col7" class="data row1 col7" >85</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_28c6e_row2_col0" class="data row2 col0" >LRCX</td>
#       <td id="T_28c6e_row2_col1" class="data row2 col1" >67</td>
#       <td id="T_28c6e_row2_col2" class="data row2 col2" >36</td>
#       <td id="T_28c6e_row2_col3" class="data row2 col3" >90</td>
#       <td id="T_28c6e_row2_col4" class="data row2 col4" >34</td>
#       <td id="T_28c6e_row2_col5" class="data row2 col5" >70</td>
#       <td id="T_28c6e_row2_col6" class="data row2 col6" >95</td>
#       <td id="T_28c6e_row2_col7" class="data row2 col7" >100</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_28c6e_row3_col0" class="data row3 col0" >GEV</td>
#       <td id="T_28c6e_row3_col1" class="data row3 col1" >66</td>
#       <td id="T_28c6e_row3_col2" class="data row3 col2" >38</td>
#       <td id="T_28c6e_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_28c6e_row3_col4" class="data row3 col4" >45</td>
#       <td id="T_28c6e_row3_col5" class="data row3 col5" >45</td>
#       <td id="T_28c6e_row3_col6" class="data row3 col6" >94</td>
#       <td id="T_28c6e_row3_col7" class="data row3 col7" >85</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_28c6e_row4_col0" class="data row4 col0" >AMAT</td>
#       <td id="T_28c6e_row4_col1" class="data row4 col1" >65</td>
#       <td id="T_28c6e_row4_col2" class="data row4 col2" >38</td>
#       <td id="T_28c6e_row4_col3" class="data row4 col3" >89</td>
#       <td id="T_28c6e_row4_col4" class="data row4 col4" >42</td>
#       <td id="T_28c6e_row4_col5" class="data row4 col5" >45</td>
#       <td id="T_28c6e_row4_col6" class="data row4 col6" >100</td>
#       <td id="T_28c6e_row4_col7" class="data row4 col7" >100</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_28c6e_row5_col0" class="data row5 col0" >WDC</td>
#       <td id="T_28c6e_row5_col1" class="data row5 col1" >64</td>
#       <td id="T_28c6e_row5_col2" class="data row5 col2" >32</td>
#       <td id="T_28c6e_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_28c6e_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_28c6e_row5_col5" class="data row5 col5" >90</td>
#       <td id="T_28c6e_row5_col6" class="data row5 col6" >94</td>
#       <td id="T_28c6e_row5_col7" class="data row5 col7" >80</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_28c6e_row6_col0" class="data row6 col0" >KLAC</td>
#       <td id="T_28c6e_row6_col1" class="data row6 col1" >64</td>
#       <td id="T_28c6e_row6_col2" class="data row6 col2" >39</td>
#       <td id="T_28c6e_row6_col3" class="data row6 col3" >53</td>
#       <td id="T_28c6e_row6_col4" class="data row6 col4" >46</td>
#       <td id="T_28c6e_row6_col5" class="data row6 col5" >90</td>
#       <td id="T_28c6e_row6_col6" class="data row6 col6" >99</td>
#       <td id="T_28c6e_row6_col7" class="data row6 col7" >85</td>
#     </tr>
#     <tr>
#       <th id="T_28c6e_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_28c6e_row7_col0" class="data row7 col0" >TSM</td>
#       <td id="T_28c6e_row7_col1" class="data row7 col1" >62</td>
#       <td id="T_28c6e_row7_col2" class="data row7 col2" >41</td>
#       <td id="T_28c6e_row7_col3" class="data row7 col3" >70</td>
#       <td id="T_28c6e_row7_col4" class="data row7 col4" >56</td>
#       <td id="T_28c6e_row7_col5" class="data row7 col5" >28</td>
#       <td id="T_28c6e_row7_col6" class="data row7 col6" >100
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="efbc0689-4837-44fb-853f-d24dd5b7792a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("efbc0689-4837-44fb-853f-d24dd5b7792a")) {                    Plotly.newPlot(                        "efbc0689-4837-44fb-853f-d24dd5b7792a",                        [{"hovertemplate":"Conviction=False\u003cbr\u003eP(Profit)=%{x}\u003cbr\u003eEdge Score=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","size":{"dtype":"f8","bdata":"jWTWV7jdFEDpFT6FeZwPQPbrzqFy8Q5AHx1D24mmD0ClCwJJ0LwRQGuttdamgRZAJCz3NAL\u002fGEBmhGwfBwUcQAadPBdZyhhAV2a50SN\u002fE0DIJHQQniMQQPIBksZkvhZAzWU0l2HWFkA="},"sizemode":"area","sizeref":0.01120785597381342,"symbol":"circle"},"mode":"markers+text","name":"False","orientation":"v","showlegend":true,"text":["CMI","STX","LRCX","WDC","KLAC","TSM","META","GE","MSFT","AMZN","SNPS","UBER","ISRG"],"x":{"dtype":"f8","bdata":"GBtXBoAu3D\u002fkhcnkqTLVP9Bt68Al8tY\u002fFFcxQ8s11D\u002fYbv6qzKnYP34neNHrJ9o\u002fkOhZNKhC2j+dY2UdOrTZP68Vk1uH+9o\u002fViiHMkV22j8e6mSqpvfWP54H0mNLwdk\u002fQOxzd5q22j8="},"xaxis":"x","y":{"dtype":"f8","bdata":"D0+aH6lZUUAKtClBavpQQLqq7zavs1BAFBVDA50eUEAcyaYUogBQQB5kSDpJ+U5Axe611f9oTUAVkLEsTrpMQOOSGn4DYEtAgHXoXGa3R0ALqodqG5FGQBhD0LH\u002fG0ZAV7167SieQ0A="},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Conviction=True\u003cbr\u003eP(Profit)=%{x}\u003cbr\u003eEdge Score=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","size":{"dtype":"f8","bdata":"2dyj0t8DF0Byu5gw+H0RQB62cojuABNA"},"sizemode":"area","sizeref":0.01120785597381342,"symbol":"circle"},"mode":"markers+text","name":"True","orientation":"v","showlegend":true,"text":["GEV","AMAT","AVGO"],"x":{"dtype":"f8","bdata":"vMPYoXJG2D\u002f64V1ALQbYP2xH1Eye3dg\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"ztzh+whpUEA6bGO9+U9QQGlf7c\u002fVzkZA"},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %% [markdown]
# ## 10. ⚡ Short-Term Momentum Scanner — KLAC-Style Swing Plays
#
# Your KLAC trades were 14-DTE near-ATM calls with massive leverage (22x).
# Scanning for similar setups: **strong momentum + near-ATM + 14-45 DTE** across all tickers.

# %%
# ══════════════════════════════════════════════════════════════════
# Scan for short-term momentum plays (14-45 DTE, near ATM)
# Like your KLAC $1320/$1340 calls — high leverage swing trades
# ══════════════════════════════════════════════════════════════════

SWING_DTE_MIN = 7
SWING_DTE_MAX = 50
SWING_MONEYNESS = (0.93, 1.03)  # near ATM

swing_rows = []
swing_skipped = []

# Filter tickers by momentum first — only scan tickers with positive trend
momentum_tickers = []
for ticker in ALL_TICKERS:
    hv = hv_momentum.get(ticker, {})
    ret_1m = hv.get("ret_1m", 0)
    ret_3m = hv.get("ret_3m", 0)
    rsi = hv.get("rsi", 50)
    above_50 = hv.get("above_50ma", False)

    # Momentum filter: at least 2 of these
    checks = [ret_1m > 0.02, ret_3m > 0.05, rsi > 50, above_50]
    if sum(checks) >= 2:
        momentum_tickers.append(ticker)

print(f"Momentum tickers ({len(momentum_tickers)}): {', '.join(momentum_tickers)}\n")

for ticker in momentum_tickers:
    spot = spot_map.get(ticker)
    if not spot:
        continue

    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        all_exps = t.options or []

        today = datetime.now().date()
        swing_exps = []
        for exp_str in all_exps:
            try:
                exp_date = datetime.strptime(exp_str, "%Y-%m-%d").date()
                dte = (exp_date - today).days
                if SWING_DTE_MIN <= dte <= SWING_DTE_MAX:
                    swing_exps.append((exp_str, dte))
            except ValueError:
                continue

        if not swing_exps:
            swing_skipped.append((ticker, "no_swing_exps"))
            continue

        # Take nearest 2 expirations
        swing_exps.sort(key=lambda x: x[1])
        for exp_str, dte in swing_exps[:2]:
            time.sleep(RATE_LIMIT_SLEEP)
            chain = t.option_chain(exp_str)
            calls = chain.calls.copy()
            if calls.empty:
                continue

            calls["mid"] = (calls["bid"] + calls["ask"]) / 2
            calls.loc[calls["mid"] <= 0, "mid"] = calls["lastPrice"]
            calls["moneyness"] = calls["strike"] / spot
            calls["spread_pct"] = np.where(
                calls["mid"] > 0, (calls["ask"] - calls["bid"]) / calls["mid"], np.nan
            )

            # Filter to near ATM
            mask = (
                (calls["moneyness"] >= SWING_MONEYNESS[0])
                & (calls["moneyness"] <= SWING_MONEYNESS[1])
                & (calls["mid"] > 0.5)
            )
            near_atm = calls[mask].copy()
            if near_atm.empty:
                continue

            for _, opt in near_atm.iterrows():
                iv = safe_float(opt.get("impliedVolatility"))
                intrinsic = max(spot - opt["strike"], 0)
                extrinsic = opt["mid"] - intrinsic
                breakeven = opt["strike"] + opt["mid"]
                breakeven_pct = (breakeven - spot) / spot
                leverage = spot / opt["mid"] if opt["mid"] > 0 else 0

                p_profit = bsm_prob_profit(spot, breakeven, iv, dte)
                hv = hv_momentum.get(ticker, {})

                # Quick edge score for swing
                edge = 0
                n = 0
                if not np.isnan(p_profit):
                    edge += p_profit * 100 * 0.20
                    n += 0.20
                # Momentum (big weight for swings)
                ret_1m = hv.get("ret_1m", 0)
                ret_3m = hv.get("ret_3m", 0)
                mom = np.clip(ret_1m * 300, -30, 50) + np.clip(ret_3m * 150, -20, 30)
                if hv.get("above_50ma"):
                    mom += 5
                if hv.get("golden_cross"):
                    mom += 5
                edge += np.clip(mom, 0, 100) * 0.35
                n += 0.35
                # Breakeven closeness
                be_score = np.clip((0.08 - breakeven_pct) / 0.12 * 100, 0, 100)
                edge += be_score * 0.20
                n += 0.20
                # IV edge
                hv30 = hv.get("hv_30", np.nan)
                if not np.isnan(iv) and not np.isnan(hv30) and hv30 > 0:
                    ratio = iv / hv30
                    iv_s = 80 if ratio < 1.0 else max(0, 70 - (ratio - 1.0) * 80)
                    edge += iv_s * 0.15
                    n += 0.15
                # Liquidity
                oi = safe_float(opt.get("openInterest", 0))
                sp = opt["spread_pct"] if not np.isnan(opt["spread_pct"]) else 0.5
                liq = min(
                    100,
                    (30 if oi > 100 else 10)
                    + (60 if sp < 0.10 else 20 if sp < 0.20 else 0),
                )
                edge += liq * 0.10
                n += 0.10

                edge = edge / n if n > 0 else 0

                swing_rows.append(
                    {
                        "Ticker": ticker,
                        "Conviction": "⭐" if ticker in CONVICTION else "",
                        "Expiry": exp_str,
                        "DTE": dte,
                        "Strike": opt["strike"],
                        "Moneyness": opt["moneyness"],
                        "Spot": spot,
                        "Mid": opt["mid"],
                        "IV": iv,
                        "Breakeven": breakeven,
                        "Breakeven %": breakeven_pct,
                        "Leverage": leverage,
                        "Cost/Contract": opt["mid"] * 100,
                        "P(Profit)": p_profit,
                        "Edge Score": edge,
                        "OI": oi,
                        "Spread %": opt["spread_pct"],
                        "Ret 1M": hv.get("ret_1m", np.nan),
                        "Ret 3M": hv.get("ret_3m", np.nan),
                        "RSI": hv.get("rsi", np.nan),
                    }
                )

        print(
            f"  ✅ {ticker} — {len([r for r in swing_rows if r['Ticker'] == ticker])} swing options found"
        )
    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

swing_df = pd.DataFrame(swing_rows)
print(f"\n✅ Total swing candidates: {len(swing_df)}")

# ── Show top swing picks ──
if not swing_df.empty:
    # Best per ticker
    swing_top = (
        swing_df.sort_values("Edge Score", ascending=False)
        .groupby("Ticker")
        .head(2)
        .reset_index(drop=True)
    )
    swing_top = swing_top.sort_values("Edge Score", ascending=False).head(20)

    display(Markdown("### ⚡ Top Swing Plays — KLAC-Style Momentum Calls"))
    display(
        Markdown(
            "*Short DTE + near ATM + strong momentum = high leverage plays like your KLAC $1320/$1340 trades*"
        )
    )

    scols = [
        "Ticker",
        "Conviction",
        "Expiry",
        "DTE",
        "Strike",
        "Moneyness",
        "Spot",
        "Mid",
        "IV",
        "Breakeven",
        "Breakeven %",
        "Leverage",
        "Cost/Contract",
        "P(Profit)",
        "Edge Score",
        "Ret 1M",
        "Ret 3M",
        "RSI",
        "OI",
    ]
    sa = [c for c in scols if c in swing_top.columns]

    display(
        swing_top[sa]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Spot": "${:,.2f}",
                "Mid": "${:,.2f}",
                "Moneyness": "{:.0%}",
                "IV": "{:.1%}",
                "Breakeven": "${:,.2f}",
                "Breakeven %": "{:+.1%}",
                "Leverage": "{:.0f}x",
                "Cost/Contract": "${:,.0f}",
                "P(Profit)": "{:.0%}",
                "Edge Score": "{:.0f}",
                "Ret 1M": "{:+.1%}",
                "Ret 3M": "{:+.1%}",
                "RSI": "{:.0f}",
                "OI": "{:,.0f}",
                "Spread %": "{:.1%}",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Edge Score"], cmap="RdYlGn", vmin=30, vmax=75)
        .background_gradient(subset=["P(Profit)"], cmap="RdYlGn", vmin=0.2, vmax=0.6)
        .set_caption("Swing Calls — Ranked by Edge Score")
    )

    # Scenario: what if stock moves +5%, +10% before expiry?
    display(Markdown("\n### 💰 Quick Scenario — If Stock Pops"))
    best_swings = swing_top.groupby("Ticker").first().reset_index().head(8)
    scen_rows = []
    for _, r in best_swings.iterrows():
        for pct_move in [0.05, 0.10, 0.15]:
            new_spot = r["Spot"] * (1 + pct_move)
            payout = max(new_spot - r["Strike"], 0)
            gain = payout - r["Mid"]
            gain_pct = gain / r["Mid"] if r["Mid"] > 0 else 0
            scen_rows.append(
                {
                    "Ticker": r["Ticker"],
                    "Strike": r["Strike"],
                    "DTE": r["DTE"],
                    "Cost": r["Mid"],
                    "Stock Move": pct_move,
                    "New Spot": new_spot,
                    "Payout": payout,
                    "Gain/Loss": gain,
                    "Return %": gain_pct,
                }
            )
    scen_df = pd.DataFrame(scen_rows)
    pivot = scen_df.pivot_table(
        index=["Ticker", "Strike", "DTE", "Cost"],
        columns="Stock Move",
        values="Return %",
    )
    pivot.columns = [f"+{c:.0%}" for c in pivot.columns]
    display(
        pivot.style.format("{:+.0%}", na_rep="—")
        .background_gradient(cmap="RdYlGn", vmin=-0.5, vmax=3, axis=None)
        .set_caption("Return % if stock moves +5% / +10% / +15% before expiry")
    )
else:
    display(Markdown("No swing setups found meeting criteria."))
# Out:
# Momentum tickers (10): WDC, GEV, STX, LRCX, AMAT, TSM, GE, CMI, KLAC, META
#
#   ✅ WDC — 15 swing options found
#   ✅ GEV — 27 swing options found
#   ✅ STX — 14 swing options found
#   ✅ LRCX — 15 swing options found
#   ✅ AMAT — 20 swing options found
#   ✅ TSM — 21 swing options found
#   ✅ GE — 20 swing options found
#   ✅ CMI — 12 swing options found
#   ✅ KLAC — 21 swing options found
#   ✅ META — 33 swing options found
#
# ✅ Total swing candidates: 198
# ### ⚡ Top Swing Plays — KLAC-Style Momentum Calls
# *Short DTE + near ATM + strong momentum = high leverage plays like your KLAC $1320/$1340 trades*
# <style type="text/css">
# #T_6c678_row0_col13 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_6c678_row0_col14 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_6c678_row1_col13 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_6c678_row1_col14 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_6c678_row2_col13, #T_6c678_row10_col13, #T_6c678_row11_col13 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_6c678_row2_col14 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_6c678_row3_col13 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_6c678_row3_col14 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_6c678_row4_col13 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_6c678_row4_col14 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_6c678_row5_col13 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_6c678_row5_col14 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_6c678_row6_col13 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_6c678_row6_col14 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_6c678_row7_col13 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_6c678_row7_col14 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_6c678_row8_col13 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_6c678_row8_col14 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_6c678_row9_col13 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_6c678_row9_col14 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_6c678_row10_col14, #T_6c678_row11_col14, #T_6c678_row12_col14 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_6c678_row12_col13 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_6c678_row13_col13 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_6c678_row13_col14 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_6c678_row14_col13 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_6c678_row14_col14 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_6c678_row15_col13, #T_6c678_row16_col14 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_6c678_row15_col14 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_6c678_row16_col13 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_6c678_row17_col13 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_6c678_row17_col14 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_6c678_row18_col13 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_6c678_row18_col14 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_6c678_row19_col13 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_6c678_row19_col14 {
#   background-color: #fee18d;
#   color: #000000;
# }
# </style>
# <table id="T_6c678">
#   <caption>Swing Calls — Ranked by Edge Score</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c678_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_6c678_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_6c678_level0_col2" class="col_heading level0 col2" >Expiry</th>
#       <th id="T_6c678_level0_col3" class="col_heading level0 col3" >DTE</th>
#       <th id="T_6c678_level0_col4" class="col_heading level0 col4" >Strike</th>
#       <th id="T_6c678_level0_col5" class="col_heading level0 col5" >Moneyness</th>
#       <th id="T_6c678_level0_col6" class="col_heading level0 col6" >Spot</th>
#       <th id="T_6c678_level0_col7" class="col_heading level0 col7" >Mid</th>
#       <th id="T_6c678_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_6c678_level0_col9" class="col_heading level0 col9" >Breakeven</th>
#       <th id="T_6c678_level0_col10" class="col_heading level0 col10" >Breakeven %</th>
#       <th id="T_6c678_level0_col11" class="col_heading level0 col11" >Leverage</th>
#       <th id="T_6c678_level0_col12" class="col_heading level0 col12" >Cost/Contract</th>
#       <th id="T_6c678_level0_col13" class="col_heading level0 col13" >P(Profit)</th>
#       <th id="T_6c678_level0_col14" class="col_heading level0 col14" >Edge Score</th>
#       <th id="T_6c678_level0_col15" class="col_heading level0 col15" >Ret 1M</th>
#       <th id="T_6c678_level0_col16" class="col_heading level0 col16" >Ret 3M</th>
#       <th id="T_6c678_level0_col17" class="col_heading level0 col17" >RSI</th>
#       <th id="T_6c678_level0_col18" class="col_heading level0 col18" >OI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c678_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c678_row0_col0" class="data row0 col0" >STX</td>
#       <td id="T_6c678_row0_col1" class="data row0 col1" ></td>
#       <td id="T_6c678_row0_col2" class="data row0 col2" >2026-02-20</td>
#       <td id="T_6c678_row0_col3" class="data row0 col3" >12</td>
#       <td id="T_6c678_row0_col4" class="data row0 col4" >$400</td>
#       <td id="T_6c678_row0_col5" class="data row0 col5" >93%</td>
#       <td id="T_6c678_row0_col6" class="data row0 col6" >$429.32</td>
#       <td id="T_6c678_row0_col7" class="data row0 col7" >$42.60</td>
#       <td id="T_6c678_row0_col8" class="data row0 col8" >81.1%</td>
#       <td id="T_6c678_row0_col9" class="data row0 col9" >$442.60</td>
#       <td id="T_6c678_row0_col10" class="data row0 col10" >+3.1%</td>
#       <td id="T_6c678_row0_col11" class="data row0 col11" >10x</td>
#       <td id="T_6c678_row0_col12" class="data row0 col12" >$4,260</td>
#       <td id="T_6c678_row0_col13" class="data row0 col13" >39%</td>
#       <td id="T_6c678_row0_col14" class="data row0 col14" >69</td>
#       <td id="T_6c678_row0_col15" class="data row0 col15" >+50.9%</td>
#       <td id="T_6c678_row0_col16" class="data row0 col16" >+54.6%</td>
#       <td id="T_6c678_row0_col17" class="data row0 col17" >70</td>
#       <td id="T_6c678_row0_col18" class="data row0 col18" >486</td>
#     </tr>
#     <tr>
#       <th id="T_6c678_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c678_row1_col0" class="data row1 col0" >GEV</td>
#       <td id="T_6c678_row1_col1" class="data row1 col1" >⭐</td>
#       <td id="T_6c678_row1_col2" class="data row1 col2" >2026-02-20</td>
#       <td id="T_6c678_row1_col3" class="data row1 col3" >12</td>
#       <td id="T_6c678_row1_col4" class="data row1 col4" >$730</td>
#       <td id="T_6c678_row1_col5" class="data row1 col5" >94%</td>
#       <td id="T_6c678_row1_col6" class="data row1 col6" >$779.35</td>
#       <td id="T_6c678_row1_col7" class="data row1 col7" >$60.00</td>
#       <td id="T_6c678_row1_col8" class="data row1 col8" >50.8%</td>
#       <td id="T_6c678_row1_col9" class="data row1 col9" >$790.00</td>
#       <td id="T_6c678_row1_col10" class="data row1 col10" >+1.4%</td>
#       <td id="T_6c678_row1_col11" class="data row1 col11" >13x</td>
#       <td id="T_6c678_row1_col12" class="data row1 col12" >$6,000</td>
#       <td id="T_6c678_row1_col13" class="data row1 col13" >43%</td>
#       <td id="T_6c678_row1_col14" class="data row1 col14" >68</td>
#       <td id="T_6c678_row1_col15" class="data row1 col15" >+24.0%</td>
#       <td id="T_6c678_row1_col16" class="data row1 col16" >+41.8%</td>
#       <td id="T_6c678_row1_col17" class="data row1 col17" >71</td>
#       <td id="T_6c678_row1_col18" class="data row1 col18" >810</td>
#     </tr>
#     <tr>
#       <th id="T_6c678_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c678_row2_col0" class="data row2 col0" >GEV</td>
#       <td id="T_6c678_row2_col1" class="data row2 col1" >⭐</td>
#       <td id="T_6c678_row2_col2" class="data row2 col2" >2026-02-20</td>
#       <td id="T_6c678_row2_col3" class="data row2 col3" >12</td>
#       <td id="T_6c678_row2_col4" class="data row2 col4" >$735</td>
#       <td id="T_6c678_row2_col5" class="data row2 col5" >94%</td>
#       <td id="T_6c678_row2_col6" class="data row2 col6" >$779.35</td>
#       <td id="T_6c678_row2_col7" class="data row2 col7" >$55.85</td>
#       <td id="T_6c678_row2_col8" class="data row2 col8" >54.8%</td>
#       <td id="T_6c678_row2_col9" class="data row2 col9" >$790.85</td>
#       <td id="T_6c678_row2_col10" class="data row2 col10" >+1.5%</td>
#       <td id="T_6c6
# ### 💰 Quick Scenario — If Stock Pops
# <style type="text/css">
# #T_68861_row0_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_68861_row0_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_68861_row0_col2 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_68861_row1_col0 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_68861_row1_col1, #T_68861_row3_col2 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_68861_row1_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_68861_row2_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_68861_row2_col1 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_68861_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_68861_row3_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_68861_row3_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_68861_row4_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_68861_row4_col1, #T_68861_row7_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_68861_row4_col2 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_68861_row5_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_68861_row5_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_68861_row5_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_68861_row6_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_68861_row6_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_68861_row6_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_68861_row7_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_68861_row7_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# </style>
# <table id="T_68861">
#   <caption>Return % if stock moves +5% / +10% / +15% before expiry</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68861_level0_col0" class="col_heading level0 col0" >+5%</th>
#       <th id="T_68861_level0_col1" class="col_heading level0 col1" >+10%</th>
#       <th id="T_68861_level0_col2" class="col_heading level0 col2" >+15%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="index_name level1" >Strike</th>
#       <th class="index_name level2" >DTE</th>
#       <th class="index_name level3" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68861_level0_row0" class="row_heading level0 row0" >AMAT</th>
#       <th id="T_68861_level1_row0" class="row_heading level1 row0" >300.000000</th>
#       <th id="T_68861_level2_row0" class="row_heading level2 row0" >12</th>
#       <th id="T_68861_level3_row0" class="row_heading level3 row0" >30.075000</th>
#       <td id="T_68861_row0_col0" class="data row0 col0" >+28%</td>
#       <td id="T_68861_row0_col1" class="data row0 col1" >+82%</td>
#       <td id="T_68861_row0_col2" class="data row0 col2" >+136%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row1" class="row_heading level0 row1" >CMI</th>
#       <th id="T_68861_level1_row1" class="row_heading level1 row1" >550.000000</th>
#       <th id="T_68861_level2_row1" class="row_heading level2 row1" >12</th>
#       <th id="T_68861_level3_row1" class="row_heading level3 row1" >30.800000</th>
#       <td id="T_68861_row1_col0" class="data row1 col0" >+84%</td>
#       <td id="T_68861_row1_col1" class="data row1 col1" >+178%</td>
#       <td id="T_68861_row1_col2" class="data row1 col2" >+271%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row2" class="row_heading level0 row2" >GE</th>
#       <th id="T_68861_level1_row2" class="row_heading level1 row2" >312.500000</th>
#       <th id="T_68861_level2_row2" class="row_heading level2 row2" >12</th>
#       <th id="T_68861_level3_row2" class="row_heading level3 row2" >12.700000</th>
#       <td id="T_68861_row2_col0" class="data row2 col0" >+93%</td>
#       <td id="T_68861_row2_col1" class="data row2 col1" >+220%</td>
#       <td id="T_68861_row2_col2" class="data row2 col2" >+346%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row3" class="row_heading level0 row3" >GEV</th>
#       <th id="T_68861_level1_row3" class="row_heading level1 row3" >730.000000</th>
#       <th id="T_68861_level2_row3" class="row_heading level2 row3" >12</th>
#       <th id="T_68861_level3_row3" class="row_heading level3 row3" >60.000000</th>
#       <td id="T_68861_row3_col0" class="data row3 col0" >+47%</td>
#       <td id="T_68861_row3_col1" class="data row3 col1" >+112%</td>
#       <td id="T_68861_row3_col2" class="data row3 col2" >+177%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row4" class="row_heading level0 row4" >KLAC</th>
#       <th id="T_68861_level1_row4" class="row_heading level1 row4" >1360.000000</th>
#       <th id="T_68861_level2_row4" class="row_heading level2 row4" >12</th>
#       <th id="T_68861_level3_row4" class="row_heading level3 row4" >103.500000</th>
#       <td id="T_68861_row4_col0" class="data row4 col0" >+50%</td>
#       <td id="T_68861_row4_col1" class="data row4 col1" >+120%</td>
#       <td id="T_68861_row4_col2" class="data row4 col2" >+189%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row5" class="row_heading level0 row5" >LRCX</th>
#       <th id="T_68861_level1_row5" class="row_heading level1 row5" >220.000000</th>
#       <th id="T_68861_level2_row5" class="row_heading level2 row5" >19</th>
#       <th id="T_68861_level3_row5" class="row_heading level3 row5" >19.600000</th>
#       <td id="T_68861_row5_col0" class="data row5 col0" >+15%</td>
#       <td id="T_68861_row5_col1" class="data row5 col1" >+74%</td>
#       <td id="T_68861_row5_col2" class="data row5 col2" >+133%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row6" class="row_heading level0 row6" >META</th>
#       <th id="T_68861_level1_row6" class="row_heading level1 row6" >625.000000</th>
#       <th id="T_68861_level2_row6" class="row_heading level2 row6" >12</th>
#       <th id="T_68861_level3_row6" class="row_heading level3 row6" >42.500000</th>
#       <td id="T_68861_row6_col0" class="data row6 col0" >+64%</td>
#       <td id="T_68861_row6_col1" class="data row6 col1" >+141%</td>
#       <td id="T_68861_row6_col2" class="data row6 col2" >+219%</td>
#     </tr>
#     <tr>
#       <th id="T_68861_level0_row7" class="row_heading level0 row7" >STX</th>
#       <th id="T_68861_level1_row7" class="row_heading level1 row7" >400.000000</th>
#       <th id="T_68861_level2_row7" class="row_heading level2 row7" >12</th>
#       <th id="T_68861_level3_row7" class="row_heading level3 row7" >42.600000</th>
#       <td id="T_68861_row7_col0" class="data row7 col0" >+19%</td>
#       <td id="T_68861_row7_col1" class="data row7 col1" >+70%</td>
#       <td id="T_68861_row7_col2" class="data row7 col2" >+120%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 11. 🔄 Bounce Scanner — Which Pullbacks Are Ready to Reverse?
#
# Several names on your watchlist have sold off hard (SNPS, UBER, ISRG, MSFT, AMZN, AVGO).
# Using a stack of technical indicators to score **mean-reversion probability**:
#
# | Indicator                  | Signal                        | Logic                                       |
# | -------------------------- | ----------------------------- | ------------------------------------------- |
# | **RSI**                    | Oversold < 30                 | Snap-back due; < 25 = extreme               |
# | **Distance from 200MA**    | Near/above support            | Holding long-term trend = strong floor      |
# | **Bollinger Band %B**      | Below lower band              | Statistically stretched, reversion likely   |
# | **MACD Histogram**         | Turning up from negative      | Momentum shifting from sellers to buyers    |
# | **Volume spike**           | Above-avg volume on down days | Capitulation = near bottom                  |
# | **Stochastic %K**          | < 20 + crossing up            | Classic oversold reversal signal            |
# | **Distance from 52W High** | -15% to -25%                  | Pullback within healthy correction range    |
# | **Support proximity**      | Near key MA levels            | Bouncing off support = higher prob reversal |

# %%
# ══════════════════════════════════════════════════════════════════
# Technical Bounce Scanner — deep dive on all tickers
# ══════════════════════════════════════════════════════════════════

bounce_rows = []

for ticker in ALL_TICKERS:
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        hist = t.history(period="1y")
        if hist.empty or len(hist) < 60:
            continue

        closes = hist["Close"].dropna()
        highs = hist["High"].dropna()
        lows = hist["Low"].dropna()
        volumes = hist["Volume"].dropna()
        price = float(closes.iloc[-1])
        spot = spot_map.get(ticker, price)

        # ── RSI (14, Wilder's EWM) ──
        delta = closes.diff()
        gain = delta.clip(lower=0).ewm(com=13, adjust=False).mean()
        loss_s = (-delta.clip(upper=0)).ewm(com=13, adjust=False).mean()
        rs_val = gain.iloc[-1] / loss_s.iloc[-1] if loss_s.iloc[-1] > 0 else 100
        rsi = float(100 - (100 / (1 + rs_val)))

        # ── Stochastic %K / %D (14,3) ──
        low_14 = lows.rolling(14).min()
        high_14 = highs.rolling(14).max()
        stoch_k = (
            float(
                ((price - low_14.iloc[-1]) / (high_14.iloc[-1] - low_14.iloc[-1])) * 100
            )
            if (high_14.iloc[-1] - low_14.iloc[-1]) > 0
            else 50
        )
        stoch_k_series = ((closes - low_14) / (high_14 - low_14)) * 100
        stoch_d = float(stoch_k_series.rolling(3).mean().iloc[-1])
        stoch_cross_up = stoch_k > stoch_d and stoch_k < 30  # crossing up from oversold

        # ── Bollinger Bands (20, 2σ) ──
        bb_mid = closes.rolling(20).mean()
        bb_std = closes.rolling(20).std()
        bb_upper = bb_mid + 2 * bb_std
        bb_lower = bb_mid - 2 * bb_std
        bb_pct_b = (
            float((price - bb_lower.iloc[-1]) / (bb_upper.iloc[-1] - bb_lower.iloc[-1]))
            if (bb_upper.iloc[-1] - bb_lower.iloc[-1]) > 0
            else 0.5
        )
        below_lower_bb = price < bb_lower.iloc[-1]

        # ── MACD (12,26,9) ──
        ema12 = closes.ewm(span=12).mean()
        ema26 = closes.ewm(span=26).mean()
        macd_line = ema12 - ema26
        macd_signal = macd_line.ewm(span=9).mean()
        macd_hist = macd_line - macd_signal
        macd_hist_val = float(macd_hist.iloc[-1])
        macd_hist_prev = (
            float(macd_hist.iloc[-2]) if len(macd_hist) > 1 else macd_hist_val
        )
        macd_turning_up = (
            macd_hist_val > macd_hist_prev and macd_hist_val < 0
        )  # negative but improving

        # ── Moving Averages ──
        ma20 = float(bb_mid.iloc[-1]) if not pd.isna(bb_mid.iloc[-1]) else None
        ma50 = float(closes.rolling(50).mean().iloc[-1]) if len(closes) >= 50 else None
        ma200 = (
            float(closes.rolling(200).mean().iloc[-1]) if len(closes) >= 200 else None
        )
        dist_ma20 = (price - ma20) / ma20 if ma20 else np.nan
        dist_ma50 = (price - ma50) / ma50 if ma50 else np.nan
        dist_ma200 = (price - ma200) / ma200 if ma200 else np.nan

        # ── 52-week stats ──
        high_52w = float(closes.max())
        low_52w = float(closes.min())
        dist_high = (price - high_52w) / high_52w
        dist_low = (price - low_52w) / low_52w

        # ── Volume analysis ──
        avg_vol_20 = float(volumes.rolling(20).mean().iloc[-1])
        recent_vol = float(volumes.iloc[-5:].mean())  # last 5 days
        vol_ratio = recent_vol / avg_vol_20 if avg_vol_20 > 0 else 1.0

        # ── Returns ──
        ret_1w = float(price / closes.iloc[-5] - 1) if len(closes) > 5 else 0
        ret_1m = float(price / closes.iloc[-21] - 1) if len(closes) > 21 else 0
        ret_3m = float(price / closes.iloc[-63] - 1) if len(closes) > 63 else 0

        # ═══════════════════════════════════════════════════════
        # BOUNCE SCORE (0-100) — higher = more likely to reverse up
        # ═══════════════════════════════════════════════════════
        score = 0
        signals = []

        # RSI oversold (0-25 pts)
        if rsi < 20:
            score += 25
            signals.append(f"RSI extreme ({rsi:.0f})")
        elif rsi < 30:
            score += 20
            signals.append(f"RSI oversold ({rsi:.0f})")
        elif rsi < 40:
            score += 10
            signals.append(f"RSI weak ({rsi:.0f})")
        elif rsi > 65:
            score += 0  # already running, not a bounce play

        # Stochastic oversold + cross (0-15 pts)
        if stoch_cross_up:
            score += 15
            signals.append("Stoch cross up from oversold")
        elif stoch_k < 20:
            score += 10
            signals.append(f"Stoch oversold ({stoch_k:.0f})")

        # Bollinger Band position (0-15 pts)
        if below_lower_bb:
            score += 15
            signals.append("Below lower BB — stretched")
        elif bb_pct_b < 0.15:
            score += 10
            signals.append(f"Near lower BB (%B={bb_pct_b:.2f})")

        # MACD turning up from negative (0-12 pts)
        if macd_turning_up:
            score += 12
            signals.append("MACD histogram turning up")
        elif macd_hist_val > 0 and macd_hist_prev < 0:
            score += 10
            signals.append("MACD crossed positive")

        # Support proximity — near key MAs (0-12 pts)
        if ma200 and abs(dist_ma200) < 0.03:
            score += 12
            signals.append(f"At 200MA support ({dist_ma200:+.1%})")
        elif ma50 and abs(dist_ma50) < 0.03:
            score += 8
            signals.append(f"At 50MA ({dist_ma50:+.1%})")
        elif ma200 and dist_ma200 > 0:
            score += 5
            signals.append("Above 200MA")

        # 52W high distance — sweet spot is -10% to -25% (0-10 pts)
        if -0.25 < dist_high < -0.08:
            score += 10
            signals.append(f"Healthy pullback ({dist_high:.0%} from 52W high)")
        elif -0.35 < dist_high < -0.25:
            score += 6
            signals.append(f"Deep pullback ({dist_high:.0%} from 52W high)")

        # Volume capitulation signal (0-8 pts)
        if vol_ratio > 1.5 and ret_1w < -0.03:
            score += 8
            signals.append(f"Volume spike on sell-off ({vol_ratio:.1f}x avg)")
        elif vol_ratio > 1.2:
            score += 4
            signals.append(f"Elevated volume ({vol_ratio:.1f}x)")

        # Penalize if still in freefall (no stabilization)
        if ret_1w < -0.08:
            score -= 10
            signals.append("⚠ Still falling sharply this week")

        # Bonus: golden cross still intact despite pullback = strong base
        hv = hv_momentum.get(ticker, {})
        if hv.get("golden_cross") and rsi < 40:
            score += 5
            signals.append("Golden cross intact on pullback")

        score = max(0, min(100, score))

        bounce_rows.append(
            {
                "Ticker": ticker,
                "Conviction": "⭐" if ticker in CONVICTION else "",
                "Spot": spot,
                "RSI": rsi,
                "Stoch %K": stoch_k,
                "Stoch %D": stoch_d,
                "BB %B": bb_pct_b,
                "MACD Hist": macd_hist_val,
                "MACD Turning": "✅" if macd_turning_up else "—",
                "Dist 200MA": dist_ma200,
                "Dist 50MA": dist_ma50,
                "Dist 52W High": dist_high,
                "Dist 52W Low": dist_low,
                "Ret 1W": ret_1w,
                "Ret 1M": ret_1m,
                "Ret 3M": ret_3m,
                "Vol Ratio": vol_ratio,
                "Bounce Score": score,
                "Signals": " | ".join(signals) if signals else "No strong signals",
            }
        )

        status = "🟢" if score >= 50 else "🟡" if score >= 30 else "⚪"
        print(
            f"  {status} {ticker}: Bounce={score} RSI={rsi:.0f} Stoch={stoch_k:.0f} BB%B={bb_pct_b:.2f} 1M={ret_1m:+.1%}"
        )

    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

bounce_df = pd.DataFrame(bounce_rows)
bounce_df = bounce_df.sort_values("Bounce Score", ascending=False)

print(f"\n✅ Scanned {len(bounce_df)} tickers for bounce setups")
# Out:
#   ⚪ WDC: Bounce=9 RSI=64 Stoch=82 BB%B=0.85 1M=+50.6%
#   ⚪ GEV: Bounce=5 RSI=68 Stoch=89 BB%B=0.95 1M=+24.0%
#   ⚪ STX: Bounce=5 RSI=65 Stoch=78 BB%B=0.78 1M=+50.9%
#   ⚪ LRCX: Bounce=17 RSI=58 Stoch=56 BB%B=0.64 1M=+15.0%
#   ⚪ AMAT: Bounce=17 RSI=57 Stoch=61 BB%B=0.58 1M=+14.5%
#   ⚪ TSM: Bounce=17 RSI=62 Stoch=97 BB%B=1.03 1M=+9.7%
#   ⚪ GE: Bounce=15 RSI=59 Stoch=91 BB%B=0.74 1M=+2.1%
#   ⚪ CMI: Bounce=9 RSI=54 Stoch=56 BB%B=0.53 1M=+6.1%
#   ⚪ KLAC: Bounce=27 RSI=52 Stoch=39 BB%B=0.41 1M=+8.9%
#   🟢 SNPS: Bounce=61 RSI=34 Stoch=18 BB%B=0.12 1M=-17.0%
#   ⚪ META: Bounce=18 RSI=49 Stoch=43 BB%B=0.52 1M=+2.4%
#   🟡 UBER: Bounce=49 RSI=32 Stoch=21 BB%B=0.03 1M=-14.6%
#   🟢 ISRG: Bounce=51 RSI=29 Stoch=30 BB%B=0.22 1M=-16.6%
#   🟢 MSFT: Bounce=67 RSI=29 Stoch=10 BB%B=0.08 1M=-16.1%
#   🟢 AMZN: Bounce=63 RSI=29 Stoch=21 BB%B=-0.28 1M=-14.6%
#   🟡 AVGO: Bounce=31 RSI=49 Stoch=75 BB%B=0.51 1M=+0.1%
#
# ✅ Scanned 16 tickers for bounce setups

# %% [markdown]
# ### Bounce Rankings & LEAPS Entry Points

# %%
if bounce_df.empty:
    display(Markdown("❌ No bounce data."))
else:
    # ── Full ranking table ──
    display(Markdown("### 🔄 Bounce Score Rankings — All Tickers"))
    rank_cols = [
        "Ticker",
        "Conviction",
        "Spot",
        "Bounce Score",
        "RSI",
        "Stoch %K",
        "BB %B",
        "MACD Turning",
        "Dist 200MA",
        "Dist 52W High",
        "Ret 1W",
        "Ret 1M",
        "Ret 3M",
        "Vol Ratio",
        "Signals",
    ]
    ra = [c for c in rank_cols if c in bounce_df.columns]
    display(
        bounce_df[ra]
        .style.format(
            {
                "Spot": "${:,.2f}",
                "Bounce Score": "{:.0f}",
                "RSI": "{:.0f}",
                "Stoch %K": "{:.0f}",
                "BB %B": "{:.2f}",
                "Dist 200MA": "{:+.1%}",
                "Dist 52W High": "{:.0%}",
                "Ret 1W": "{:+.1%}",
                "Ret 1M": "{:+.1%}",
                "Ret 3M": "{:+.1%}",
                "Vol Ratio": "{:.1f}x",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Bounce Score"], cmap="RdYlGn", vmin=0, vmax=80)
        .background_gradient(
            subset=["RSI"],
            cmap="RdYlGn_r",
            vmin=20,
            vmax=70,  # low RSI = green (oversold = good for bounce)
        )
        .set_caption("Sorted by Bounce Score — higher = more reversal signals firing")
    )

    # ── Chart: Bounce Score vs RSI with Dist from 52W High as size ──
    plot_b = bounce_df.copy()
    plot_b["abs_dist_high"] = plot_b["Dist 52W High"].abs() * 100
    plot_b["is_conviction"] = plot_b["Ticker"].isin(CONVICTION)

    fig_b = px.scatter(
        plot_b,
        x="RSI",
        y="Bounce Score",
        text="Ticker",
        size="abs_dist_high",
        size_max=30,
        color="is_conviction",
        color_discrete_map={True: "#1a7431", False: "#4C6E91"},
        title="Bounce Score vs RSI — Bigger Bubble = Further from 52W High",
        labels={"is_conviction": "Conviction"},
    )
    fig_b.update_traces(textposition="top center")
    fig_b.add_vline(
        x=30,
        line_dash="dot",
        line_color="red",
        opacity=0.5,
        annotation_text="RSI Oversold",
    )
    fig_b.add_hline(y=40, line_dash="dot", line_color="gray", opacity=0.5)
    fig_b.add_annotation(
        x=22,
        y=65,
        text="🎯 Bounce Zone",
        showarrow=False,
        font=dict(size=14, color="green"),
    )
    fig_b.show()

    # ── Tier the bounce candidates ──
    high_bounce = bounce_df[bounce_df["Bounce Score"] >= 45].copy()
    mid_bounce = bounce_df[
        (bounce_df["Bounce Score"] >= 25) & (bounce_df["Bounce Score"] < 45)
    ].copy()
    low_bounce = bounce_df[bounce_df["Bounce Score"] < 25].copy()

    if not high_bounce.empty:
        display(Markdown("\n### 🟢 Strong Bounce Setups"))
        for _, r in high_bounce.iterrows():
            display(
                Markdown(
                    f"**{r['Ticker']}** {r['Conviction']} — Bounce Score: **{r['Bounce Score']:.0f}** | "
                    f"RSI: {r['RSI']:.0f} | Stoch: {r['Stoch %K']:.0f} | "
                    f"BB%B: {r['BB %B']:.2f} | MACD: {r['MACD Turning']} | "
                    f"1M: {r['Ret 1M']:+.1%} | From 52W High: {r['Dist 52W High']:.0%}\n"
                    f"> Signals: *{r['Signals']}*"
                )
            )

    if not mid_bounce.empty:
        display(Markdown("\n### 🟡 Developing — Watch for Confirmation"))
        for _, r in mid_bounce.iterrows():
            display(
                Markdown(
                    f"**{r['Ticker']}** {r['Conviction']} — Bounce Score: **{r['Bounce Score']:.0f}** | "
                    f"RSI: {r['RSI']:.0f} | 1M: {r['Ret 1M']:+.1%} | "
                    f"From 52W High: {r['Dist 52W High']:.0%}\n"
                    f"> Signals: *{r['Signals']}*"
                )
            )

    # ── Best LEAPS for the top bounce candidates ──
    bounce_tickers = bounce_df[bounce_df["Bounce Score"] >= 30]["Ticker"].tolist()
    if bounce_tickers and not leaps_df.empty:
        display(Markdown("\n---\n### 💰 LEAPS Entry Points for Top Bounce Candidates"))
        display(
            Markdown(
                "*If you believe the bounce is coming, these are the options to express that view:*"
            )
        )

        bounce_leaps = scored_df[scored_df["Ticker"].isin(bounce_tickers)].copy()
        if not bounce_leaps.empty:
            # Best option per ticker: balance of edge + P(profit)
            bounce_leaps["combined"] = (
                bounce_leaps["Edge Score"] * 0.6
                + bounce_leaps["P(Profit)"].fillna(0) * 100 * 0.4
            )
            bl_top = (
                bounce_leaps.sort_values("combined", ascending=False)
                .groupby("Ticker")
                .head(2)
                .reset_index(drop=True)
            )

            # Merge bounce score
            bl_top = bl_top.merge(
                bounce_df[["Ticker", "Bounce Score", "RSI"]].rename(
                    columns={"RSI": "RSI_bounce"}
                ),
                on="Ticker",
                how="left",
            )
            bl_top = bl_top.sort_values("Bounce Score", ascending=False)

            bl_cols = [
                "Ticker",
                "Conviction",
                "Bounce Score",
                "Expiry",
                "DTE",
                "Strike",
                "Moneyness",
                "Spot",
                "Mid",
                "IV",
                "Breakeven %",
                "Leverage",
                "Cost/Contract",
                "P(Profit)",
                "Edge Score",
            ]
            bla = [c for c in bl_cols if c in bl_top.columns]
            display(
                bl_top[bla]
                .style.format(
                    {
                        "Bounce Score": "{:.0f}",
                        "Strike": "${:,.0f}",
                        "Spot": "${:,.2f}",
                        "Mid": "${:,.2f}",
                        "Moneyness": "{:.0%}",
                        "IV": "{:.1%}",
                        "Breakeven %": "{:+.1%}",
                        "Leverage": "{:.1f}x",
                        "Cost/Contract": "${:,.0f}",
                        "P(Profit)": "{:.0%}",
                        "Edge Score": "{:.0f}",
                    },
                    na_rep="—",
                )
                .background_gradient(
                    subset=["Bounce Score"], cmap="RdYlGn", vmin=20, vmax=70
                )
                .set_caption(
                    "LEAPS calls for bounce candidates — sorted by Bounce Score"
                )
            )
# Out:
# ### 🔄 Bounce Score Rankings — All Tickers
# <style type="text/css">
# #T_b2177_row0_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_b2177_row0_col4 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_b2177_row1_col3 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_b2177_row1_col4 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_b2177_row2_col3 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_b2177_row2_col4 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_b2177_row3_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_b2177_row3_col4 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_b2177_row4_col3 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_b2177_row4_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_b2177_row5_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_b2177_row5_col4 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_b2177_row6_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_b2177_row6_col4 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_b2177_row7_col3 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_b2177_row7_col4 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_b2177_row8_col3, #T_b2177_row9_col3, #T_b2177_row10_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_b2177_row8_col4 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_b2177_row9_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_b2177_row10_col4 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_b2177_row11_col3 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_b2177_row11_col4 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_b2177_row12_col3, #T_b2177_row13_col3 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_b2177_row12_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_b2177_row13_col4 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_b2177_row14_col3, #T_b2177_row15_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_b2177_row14_col4, #T_b2177_row15_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2177">
#   <caption>Sorted by Bounce Score — higher = more reversal signals firing</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2177_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_b2177_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_b2177_level0_col2" class="col_heading level0 col2" >Spot</th>
#       <th id="T_b2177_level0_col3" class="col_heading level0 col3" >Bounce Score</th>
#       <th id="T_b2177_level0_col4" class="col_heading level0 col4" >RSI</th>
#       <th id="T_b2177_level0_col5" class="col_heading level0 col5" >Stoch %K</th>
#       <th id="T_b2177_level0_col6" class="col_heading level0 col6" >BB %B</th>
#       <th id="T_b2177_level0_col7" class="col_heading level0 col7" >MACD Turning</th>
#       <th id="T_b2177_level0_col8" class="col_heading level0 col8" >Dist 200MA</th>
#       <th id="T_b2177_level0_col9" class="col_heading level0 col9" >Dist 52W High</th>
#       <th id="T_b2177_level0_col10" class="col_heading level0 col10" >Ret 1W</th>
#       <th id="T_b2177_level0_col11" class="col_heading level0 col11" >Ret 1M</th>
#       <th id="T_b2177_level0_col12" class="col_heading level0 col12" >Ret 3M</th>
#       <th id="T_b2177_level0_col13" class="col_heading level0 col13" >Vol Ratio</th>
#       <th id="T_b2177_level0_col14" class="col_heading level0 col14" >Signals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2177_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_b2177_row0_col0" class="data row0 col0" >SNPS</td>
#       <td id="T_b2177_row0_col1" class="data row0 col1" ></td>
#       <td id="T_b2177_row0_col2" class="data row0 col2" >$426.88</td>
#       <td id="T_b2177_row0_col3" class="data row0 col3" >71</td>
#       <td id="T_b2177_row0_col4" class="data row0 col4" >23</td>
#       <td id="T_b2177_row0_col5" class="data row0 col5" >18</td>
#       <td id="T_b2177_row0_col6" class="data row0 col6" >0.12</td>
#       <td id="T_b2177_row0_col7" class="data row0 col7" >✅</td>
#       <td id="T_b2177_row0_col8" class="data row0 col8" >-14.2%</td>
#       <td id="T_b2177_row0_col9" class="data row0 col9" >-34%</td>
#       <td id="T_b2177_row0_col10" class="data row0 col10" >-6.8%</td>
#       <td id="T_b2177_row0_col11" class="data row0 col11" >-17.0%</td>
#       <td id="T_b2177_row0_col12" class="data row0 col12" >+7.8%</td>
#       <td id="T_b2177_row0_col13" class="data row0 col13" >1.6x</td>
#       <td id="T_b2177_row0_col14" class="data row0 col14" >RSI oversold (23) | Stoch cross up from oversold | Near lower BB (%B=0.12) | MACD histogram turning up | Deep pullback (-34% from 52W high) | Volume spike on sell-off (1.6x avg)</td>
#     </tr>
#     <tr>
#       <th id="T_b2177_level0_row1" class="row_heading level0 row1" >14</th>
#       <td id="T_b2177_row1_col0" class="data row1 col0" >AMZN</td>
#       <td id="T_b2177_row1_col1" class="data row1 col1" ></td>
#       <td id="T_b2177_row1_col2" class="data row1 col2" >$210.32</td>
#       <td id="T_b2177_row1_col3" class="data row1 col3" >63</td>
#       <td id="T_b2177_row1_col4" class="data row1 col4" >28</td>
#       <td id="T_b2177_row1_col5" class="data row1 col5" >21</td>
#       <td id="T_b2177_row1_col6" class="data row1 col6" >-0.28</td>
#       <td id="T_b2177_row1_col7" class="data row1 col7" >—</td>
#       <td id="T_b2177_row1_col8" class="data row1 col8" >-5.8%</td>
#       <td id="T_b2177_row1_col9" class="data row1 col9" >-17%</td>
#       <td id="T_b2177_row1_col10" class="data row1 col10" >-13.4%</td>
#       <td id="T_b2177_row1_col11" class="data row1 col11" >-14.6%</td>
#       <td id="T_b2177_row1_col12" class="data row1 col12" >-13.5%</td>
#       <td id="T_b2177_row1_col13" class="data row1 col13" >1.7x</td>
#       <td id="T_b2177_row1_col14" class="data row1 col14" >RSI oversold (28) | Stoch cross up from oversold | Below lower BB — stretched | Healthy pullback (-17% from 52W high) | Volume spike on sell-off (1.7x avg) | ⚠ Still falling sharply this week | Golden cross intact on pullback</td>
#     </tr>
#     <tr>
#       <th id="T_b2177_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_b2177_row2_col0" class="data row2 col0" >UBER</td>
#       <td id="T_b2177_row2_col1" class="data row2 col1" ></td>
#       <td id="T_b2177_row2_col2" class="data row2 col2" >$74.77</td>
#       <td id="T_b2177_row2_col3" class="data row2 col3" >59</td>
#       <td id="T_b2177_row2_col4" class="data row2 col4" >24</td>
#       <td id="T_b2177_row2_col5" class="data row2 col5" >21</td>
#       <td id="T_b2177_row2_col6" class="data row2 col6" >0.03</td>
#       <td id="T_b2177_row2_col7" class="data row2 col7" >—</td>
#       <td id="T_b2177_row2_col8" class="data row2 col8" >-16.1%</td>
#       <td id="T_b2177_row2_col9" class="data row2 col9" >-25%</td>
#       <td id="T_b2177_row2_col10" class="data row2 col10" >-7.5%</td>
#       <td id="T_b2177_row2_col11" class="data row2 col11" >-14.6%</td>
#       <td id="T_b2177_row2_col12" class="data row2 col12" >-18.8%</td>
#       <td id="T_b2177_row2_col13" class="data row2 col13" >1.5x</td>
#       <td id="T_b2177_row2_col14" class="data row2 col14" >RSI oversold (24) | Stoch cross up from oversold | Near lower BB (%B=0.03) | Deep pullback (-25% from 52W high) | Volume spike on sell-off (1.5x avg)</td>
#     </tr>
#     <tr>
#       <th id="T_b2177_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_b2177_row3_col0" class="data row3 col0" >MSFT</td>
#       <td id="T_b2177_row3_col1" class="data row3 col1" ></td>
#       <td id="T_b2177_row3_col2" class="data row3 col2" >$401.14</td>
#       <td id="T_b2177_row3_col3" class="data row3 col3" >57</td>
#       <td id="T_b2177_row3_col4" class="data row3 col4" >31</td>
#       <td id="T_b2177_row3_col5" class="data row3 col5" >10</td>
#       <td id="T_b2177_row3_col6" class="data row3 col6" >0.08</td>
#       <td id="T_b2177_row3_col7" class="data row3 col7" >✅</td>
#       <td id="T_b2177_row3_col8" class="data row3 col8" >-17
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e7e52f5f-d243-46e1-b30a-6bc79345e59b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7e52f5f-d243-46e1-b30a-6bc79345e59b")) {                    Plotly.newPlot(                        "e7e52f5f-d243-46e1-b30a-6bc79345e59b",                        [{"hovertemplate":"Conviction=False\u003cbr\u003eRSI=%{x}\u003cbr\u003eBounce Score=%{y}\u003cbr\u003eabs_dist_high=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#4C6E91","size":{"dtype":"f8","bdata":"8TcvSy3tQEDKZDKZZDIxQCkWGqgATjlAXOANAyjcOUDmXk54h8YzQGv8rFVTsyxAgUxjlWIlMEAAAAAAAAAAAPad3jqRqBtAzpsnNIHy\u002fz\u002f7wE76Vm0SQDPy5A0THQVAVZyPNvfmDkA="},"sizemode":"area","sizeref":0.03761438305966686,"symbol":"circle"},"mode":"markers+text","name":"False","orientation":"v","showlegend":true,"text":["SNPS","AMZN","UBER","MSFT","ISRG","KLAC","META","TSM","LRCX","GE","CMI","WDC","STX"],"x":{"dtype":"f8","bdata":"KJ6LCmfeNkBYbKbzH9U7QDCGQyn3sTdAxK+MMzUEP0AY2N5I8T02QL+JvjkQQUVAvfQn6L9TTUDZl6CyAqVKQE9lzK1ZwEpA39y5cK7TR0AL5qH5jtdIQAYqzcPOb1BAbGm3jt9zUUA="},"xaxis":"x","y":{"dtype":"i1","bdata":"Rz87OTMbEhERDwkJBQ=="},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Conviction=True\u003cbr\u003eRSI=%{x}\u003cbr\u003eBounce Score=%{y}\u003cbr\u003eabs_dist_high=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#1a7431","size":{"dtype":"f8","bdata":"uim5A886M0C07mW94hAWQLa+29mgh70\u002f"},"sizemode":"area","sizeref":0.03761438305966686,"symbol":"circle"},"mode":"markers+text","name":"True","orientation":"v","showlegend":true,"text":["AVGO","AMAT","GEV"],"x":{"dtype":"f8","bdata":"UURJmvwbREDeyBd24yRIQAUxmDdIplFA"},"xaxis":"x","y":{"dtype":"i1","bdata":"HxEF"},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"t ...
# ### 🟢 Strong Bounce Setups
# **SNPS**  — Bounce Score: **71** | RSI: 23 | Stoch: 18 | BB%B: 0.12 | MACD: ✅ | 1M: -17.0% | From 52W High: -34%
# > Signals: *RSI oversold (23) | Stoch cross up from oversold | Near lower BB (%B=0.12) | MACD histogram turning up | Deep pullback (-34% from 52W high) | Volume spike on sell-off (1.6x avg)*
# **AMZN**  — Bounce Score: **63** | RSI: 28 | Stoch: 21 | BB%B: -0.28 | MACD: — | 1M: -14.6% | From 52W High: -17%
# > Signals: *RSI oversold (28) | Stoch cross up from oversold | Below lower BB — stretched | Healthy pullback (-17% from 52W high) | Volume spike on sell-off (1.7x avg) | ⚠ Still falling sharply this week | Golden cross intact on pullback*
# **UBER**  — Bounce Score: **59** | RSI: 24 | Stoch: 21 | BB%B: 0.03 | MACD: — | 1M: -14.6% | From 52W High: -25%
# > Signals: *RSI oversold (24) | Stoch cross up from oversold | Near lower BB (%B=0.03) | Deep pullback (-25% from 52W high) | Volume spike on sell-off (1.5x avg)*
# **MSFT**  — Bounce Score: **57** | RSI: 31 | Stoch: 10 | BB%B: 0.08 | MACD: ✅ | 1M: -16.1% | From 52W High: -26%
# > Signals: *RSI weak (31) | Stoch cross up from oversold | Near lower BB (%B=0.08) | MACD histogram turning up | Deep pullback (-26% from 52W high) | Elevated volume (1.3x)*
# **ISRG**  — Bounce Score: **51** | RSI: 22 | Stoch: 30 | BB%B: 0.22 | MACD: ✅ | 1M: -16.6% | From 52W High: -20%
# > Signals: *RSI oversold (22) | MACD histogram turning up | Healthy pullback (-20% from 52W high) | Elevated volume (1.2x) | Golden cross intact on pullback*
# ### 🟡 Developing — Watch for Confirmation
# **AVGO** ⭐ — Bounce Score: **31** | RSI: 40 | 1M: +0.1% | From 52W High: -19%
# > Signals: *MACD histogram turning up | Above 200MA | Healthy pullback (-19% from 52W high) | Elevated volume (1.2x)*
# **KLAC**  — Bounce Score: **27** | RSI: 43 | 1M: +8.9% | From 52W High: -14%
# > Signals: *MACD histogram turning up | Above 200MA | Healthy pullback (-14% from 52W high)*
# ---
# ### 💰 LEAPS Entry Points for Top Bounce Candidates
# *If you believe the bounce is coming, these are the options to express that view:*
# <style type="text/css">
# #T_d25cc_row0_col2, #T_d25cc_row1_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d25cc_row2_col2, #T_d25cc_row3_col2 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_d25cc_row4_col2, #T_d25cc_row5_col2 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_d25cc_row6_col2, #T_d25cc_row7_col2 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_d25cc_row8_col2, #T_d25cc_row9_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_d25cc_row10_col2, #T_d25cc_row11_col2 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d25cc">
#   <caption>LEAPS calls for bounce candidates — sorted by Bounce Score</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d25cc_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_d25cc_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_d25cc_level0_col2" class="col_heading level0 col2" >Bounce Score</th>
#       <th id="T_d25cc_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_d25cc_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_d25cc_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_d25cc_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_d25cc_level0_col7" class="col_heading level0 col7" >Spot</th>
#       <th id="T_d25cc_level0_col8" class="col_heading level0 col8" >Mid</th>
#       <th id="T_d25cc_level0_col9" class="col_heading level0 col9" >IV</th>
#       <th id="T_d25cc_level0_col10" class="col_heading level0 col10" >Breakeven %</th>
#       <th id="T_d25cc_level0_col11" class="col_heading level0 col11" >Leverage</th>
#       <th id="T_d25cc_level0_col12" class="col_heading level0 col12" >Cost/Contract</th>
#       <th id="T_d25cc_level0_col13" class="col_heading level0 col13" >P(Profit)</th>
#       <th id="T_d25cc_level0_col14" class="col_heading level0 col14" >Edge Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d25cc_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_d25cc_row0_col0" class="data row0 col0" >SNPS</td>
#       <td id="T_d25cc_row0_col1" class="data row0 col1" ></td>
#       <td id="T_d25cc_row0_col2" class="data row0 col2" >71</td>
#       <td id="T_d25cc_row0_col3" class="data row0 col3" >2026-09-18</td>
#       <td id="T_d25cc_row0_col4" class="data row0 col4" >222</td>
#       <td id="T_d25cc_row0_col5" class="data row0 col5" >$350</td>
#       <td id="T_d25cc_row0_col6" class="data row0 col6" >82%</td>
#       <td id="T_d25cc_row0_col7" class="data row0 col7" >$426.88</td>
#       <td id="T_d25cc_row0_col8" class="data row0 col8" >$112.30</td>
#       <td id="T_d25cc_row0_col9" class="data row0 col9" >55.9%</td>
#       <td id="T_d25cc_row0_col10" class="data row0 col10" >+8.3%</td>
#       <td id="T_d25cc_row0_col11" class="data row0 col11" >3.8x</td>
#       <td id="T_d25cc_row0_col12" class="data row0 col12" >$11,230</td>
#       <td id="T_d25cc_row0_col13" class="data row0 col13" >37%</td>
#       <td id="T_d25cc_row0_col14" class="data row0 col14" >45</td>
#     </tr>
#     <tr>
#       <th id="T_d25cc_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_d25cc_row1_col0" class="data row1 col0" >SNPS</td>
#       <td id="T_d25cc_row1_col1" class="data row1 col1" ></td>
#       <td id="T_d25cc_row1_col2" class="data row1 col2" >71</td>
#       <td id="T_d25cc_row1_col3" class="data row1 col3" >2026-09-18</td>
#       <td id="T_d25cc_row1_col4" class="data row1 col4" >222</td>
#       <td id="T_d25cc_row1_col5" class="data row1 col5" >$360</td>
#       <td id="T_d25cc_row1_col6" class="data row1 col6" >84%</td>
#       <td id="T_d25cc_row1_col7" class="data row1 col7" >$426.88</td>
#       <td id="T_d25cc_row1_col8" class="data row1 col8" >$105.80</td>
#       <td id="T_d25cc_row1_col9" class="data row1 col9" >55.3%</td>
#       <td id="T_d25cc_row1_col10" class="data row1 col10" >+9.1%</td>
#       <td id="T_d25cc_row1_col11" class="data row1 col11" >4.0x</td>
#       <td id="T_d25cc_row1_col12" class="data row1 col12" >$10,580</td>
#       <td id="T_d25cc_row1_col13" class="data row1 col13" >36%</td>
#       <td id="T_d25cc_row1_col14" class="data row1 col14" >45</td>
#     </tr>
#     <tr>
#       <th id="T_d25cc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d25cc_row2_col0" class="data row2 col0" >AMZN</td>
#       <td id="T_d25cc_row2_col1" class="data row2 col1" ></td>
#       <td id="T_d25cc_row2_col2" class="data row2 col2" >63</td>
#       <td id="T_d25cc_row2_col3" class="data row2 col3" >2026-05-15</td>
#       <td id="T_d25cc_row2_col4" class="data row2 col4" >96</td>
#       <td id="T_d25cc_row2_col5" class="data row2 col5" >$175</td>
#       <td id="T_d25cc_row2_col6" class="data row2 col6" >83%</td>
#       <td id="T_d25cc_row2_col7" class="data row2 col7" >$210.32</td>
#       <td id="T_d25cc_row2_col8" class="data row2 col8" >$41.38</td>
#       <td id="T_d25cc_row2_col9" class="data row2 col9" >48.8%</td>
#       <td id="T_d25cc_row2_col10" class="data row2 col10" >+2.9%</td>
#       <td id="T_d25cc_row2_col11" class="data row2 col11" >5.1x</td>
#       <td id="T_d25cc_row2_col12" class="data row2 col12" >$4,138</td>
#       <td id="T_d25cc_row2_col13" class="data row2 col13" >42%</td>
#       <td id="T_d25cc_row2_col14" class="data row2 col14" >46</td>
#     </tr>
#     <tr>
#       <th id="T_d25cc_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_d25cc_row3_col0" class="data row3 col0" >AMZN</td>
#       <td id="T_d25cc_row3_col1" class="data row3 col1" ></td>
#       <td id="T_d25cc_row3_col2" class="data row3 col2" >63</td>
#       <td id="T_d25cc_row3_col3" class="data row3 col3" >2026-06-18</td>
#       <td id="T_d25cc_row3_col4" class="data row3 col4" >130</td>
#       <td id="T_d25cc_row3_col5" class="data row3 col5" >$175</td>
#       <td id="T_d25cc_row3_col6" class="data row3 col6" >83%</td>
#       <td id="T_d25cc_row3_col7" class="data row3 col7" >$210.32</td>
#       <td id="T_d25cc_row3_col8" class="data row3 col8" >$43.15</td>
#       <td id="T_d25cc_row3_col9" class="data row3 col9" >46.1%</td>
#       <td id="T_d25cc_row3_col10" class="data row3 col10" >+3.7%</td>
#       <td id="T_d25cc_row3_col11" class="data row3 col11" >4.9x</td>
#       <td id="T_d25cc_row3_col12" class="data row3 col12" >$4,315</td>
#       <td id="T_d25cc_row3_col13" class="data row3 col13" >41%</td>
#       <td id="T_d25cc_row3_col14" class="data row3 col14" >47</td>
#     </tr>
#     <tr>
#       <th id="T_d25cc_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_d25cc_row4_col0" class="data row4 col0" >UBER</td>
#       <td id="T_d25cc_row4_col1" class="data row4 col1" ></td>
#       <td id="T_d25cc_row4_col2" class="data row4 col2" >59</td>
#       <td id="T_d25cc_row4_col3" class="data row4 col3" >2026-06-18</td>
#       <td id="T_d25cc_row4_col4" class="data row4 col4" >130</td>
#       <td id="T_d25cc_row4_col5" class="data row4 col5" >$60</td>
#       <td id="T_d25cc_row4_col6" class="data row4 col6" >80%</td>
#       <td id="T_d25cc_row4_col7" class="data row4 col7" >$74.77</td>
#       <td id="T_d25cc_row4_col8" class="data row4 col8" >$17.27</td>
#       <td id="T_d25cc_row4_col9" class="data row4 col9" >50.8%</td>
#       <td id="T_d25cc_row4_col10" class="data row4 col10" >+3.4%</td>
#       <td id="T_d25cc_row4_col11" class="data row4 col11" >4.3x</td>
#       <td id="T_d25cc_row4_col12" class="data row4 col12" >$1,727</td>
#       <td id="T_d25cc_row4_col13" class="data row4 col13" >42%</td>
#       <td id="T_d25cc_row4_col14" class="data row4 col14" >43</td>
#     </tr>
#     <tr>
#       <th id="T_d25cc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d25cc_row5_col0" class="data row5 col0" >UBER</td>
#       <td id="T_d25cc_row5_col1" class="data row5 col1" ></td>
#       <td id="T_d25cc_row5_col2" class="data row5 col2" >59</td>
#       <td id="T_d25cc_row5_col3" class="data row5 col3" >2026-06-18</td>
#       <td id="T_d25cc_row5_col4" class="data row5 col4" >130</td>
#       <td id=

# %% [markdown]
# ## 📋 Final Call Picks — Unified by DTE Bucket
#
# All signals combined: **Edge Score** (BSM probability, IV vs HV, momentum, style) + **Bounce Score** (RSI, Stochastic, Bollinger, MACD, support levels).
#
# | Bucket             | DTE   | Strategy                         | Thesis                            |
# | ------------------ | ----- | -------------------------------- | --------------------------------- |
# | ⚡ **Short-Term**  | <30   | Momentum swings, bounce snaps    | High leverage, ride a quick move  |
# | 🔄 **Medium-Term** | 30–90 | Bounce recovery, earnings setups | Time for oversold names to revert |
# | 🏗️ **LEAPS**       | 300+  | Conviction holds, deep-ITM       | Stock replacement, long runway    |

# %%
# ══════════════════════════════════════════════════════════════════
# STEP 1 — Fetch medium-term (30-90 DTE) options to fill the gap
#          Also fetch <30 DTE for bounce tickers we didn't swing-scan
# ══════════════════════════════════════════════════════════════════

MED_DTE_MIN, MED_DTE_MAX = 30, 90
SHORT_DTE_MAX = 30
MED_MONEYNESS = (0.88, 1.05)

med_rows = []
short_extra_rows = []  # <30 DTE for non-momentum (bounce) tickers

# Which tickers are missing from swing_df's <30 DTE?
swing_tickers_set = set(swing_df["Ticker"].unique()) if not swing_df.empty else set()
bounce_only = [t for t in ALL_TICKERS if t not in swing_tickers_set]

print("Fetching medium-term (30-90 DTE) + short-term gap fills...\n")

for ticker in ALL_TICKERS:
    spot = spot_map.get(ticker)
    if not spot:
        continue
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        all_exps = t.options or []
        today = datetime.now().date()

        target_exps = []
        for exp_str in all_exps:
            try:
                exp_date = datetime.strptime(exp_str, "%Y-%m-%d").date()
                dte = (exp_date - today).days
                # Medium-term for ALL tickers
                if MED_DTE_MIN <= dte <= MED_DTE_MAX:
                    target_exps.append((exp_str, dte, "med"))
                # Short-term for bounce-only tickers (not already in swing_df)
                elif dte < SHORT_DTE_MAX and dte >= 7 and ticker in bounce_only:
                    target_exps.append((exp_str, dte, "short"))
            except ValueError:
                continue

        if not target_exps:
            print(f"  ⚪ {ticker}: no exps in target range")
            continue

        # Take up to 2 per bucket
        med_exps = sorted(
            [e for e in target_exps if e[2] == "med"], key=lambda x: x[1]
        )[:2]
        short_exps = sorted(
            [e for e in target_exps if e[2] == "short"], key=lambda x: x[1]
        )[:1]

        for exp_str, dte, bucket in med_exps + short_exps:
            time.sleep(RATE_LIMIT_SLEEP)
            chain = t.option_chain(exp_str)
            calls = chain.calls.copy()
            if calls.empty:
                continue

            calls["mid"] = (calls["bid"] + calls["ask"]) / 2
            calls.loc[calls["mid"] <= 0, "mid"] = calls["lastPrice"]
            calls["moneyness"] = calls["strike"] / spot
            calls["spread_pct"] = np.where(
                calls["mid"] > 0, (calls["ask"] - calls["bid"]) / calls["mid"], np.nan
            )

            mask = (
                (calls["moneyness"] >= MED_MONEYNESS[0])
                & (calls["moneyness"] <= MED_MONEYNESS[1])
                & (calls["mid"] > 0.5)
            )
            filtered = calls[mask].copy()
            if filtered.empty:
                continue

            for _, opt in filtered.iterrows():
                iv = safe_float(opt.get("impliedVolatility"))
                intrinsic = max(spot - opt["strike"], 0)
                breakeven = opt["strike"] + opt["mid"]
                breakeven_pct = (breakeven - spot) / spot
                leverage = spot / opt["mid"] if opt["mid"] > 0 else 0
                p_profit = bsm_prob_profit(spot, breakeven, iv, dte)
                oi = safe_float(opt.get("openInterest", 0))

                # Edge score — aligned with score_option() weights
                hv = hv_momentum.get(ticker, {})
                edge = 0
                n = 0
                if not np.isnan(p_profit):
                    edge += p_profit * 100 * 0.25
                    n += 0.25
                ret_1m = hv.get("ret_1m", 0)
                ret_3m = hv.get("ret_3m", 0)
                mom = np.clip(ret_1m * 200, -30, 40) + np.clip(ret_3m * 100, -20, 30)
                rsi_val = hv.get("rsi", 50)
                if 45 < rsi_val < 72:
                    mom += 15
                elif rsi_val >= 72:
                    mom += 5
                if hv.get("above_50ma"):
                    mom += 5
                if hv.get("above_200ma"):
                    mom += 5
                if hv.get("golden_cross"):
                    mom += 5
                edge += np.clip(mom, 0, 100) * 0.20
                n += 0.20
                be_score = np.clip((0.15 - breakeven_pct) / 0.20 * 100, 0, 100)
                edge += be_score * 0.15
                n += 0.15
                hv30 = hv.get("hv_30", np.nan)
                if not np.isnan(iv) and not np.isnan(hv30) and hv30 > 0:
                    ratio = iv / hv30
                    if ratio < 0.9:
                        iv_s = 90
                    elif ratio < 1.1:
                        iv_s = 70
                    elif ratio < 1.3:
                        iv_s = 45
                    else:
                        iv_s = max(0, 30 - (ratio - 1.3) * 50)
                    edge += iv_s * 0.15
                    n += 0.15
                # Style match (moneyness proximity) — 15%
                ideal_mon = STYLE_PREFS.get("ideal_moneyness_leaps", 0.90)
                mon_dist = abs(opt["moneyness"] - ideal_mon)
                style_s = max(0, 100 - mon_dist * 500)
                if opt["moneyness"] < 0.90:
                    style_s = min(100, style_s + 10)
                edge += style_s * 0.15
                n += 0.15
                sp = opt["spread_pct"] if not np.isnan(opt["spread_pct"]) else 0.5
                liq = min(
                    100,
                    (40 if oi > 500 else 25 if oi > 100 else 10 if oi > 20 else 0)
                    + (
                        60 if sp < 0.05 else 40 if sp < 0.10 else 20 if sp < 0.20 else 0
                    ),
                )
                edge += liq * 0.10
                n += 0.10
                edge = edge / n if n > 0 else 0

                row_data = {
                    "Ticker": ticker,
                    "Conviction": "⭐" if ticker in CONVICTION else "",
                    "Expiry": exp_str,
                    "DTE": dte,
                    "Strike": opt["strike"],
                    "Moneyness": opt["moneyness"],
                    "Spot": spot,
                    "Mid": opt["mid"],
                    "IV": iv,
                    "Breakeven": breakeven,
                    "Breakeven %": breakeven_pct,
                    "Leverage": leverage,
                    "Cost/Contract": opt["mid"] * 100,
                    "P(Profit)": p_profit,
                    "Edge Score": edge,
                    "OI": oi,
                    "Spread %": opt["spread_pct"],
                    "Ret 1M": hv.get("ret_1m", np.nan),
                    "Ret 3M": hv.get("ret_3m", np.nan),
                    "RSI": hv.get("rsi", np.nan),
                }
                if bucket == "med":
                    med_rows.append(row_data)
                else:
                    short_extra_rows.append(row_data)

        n_med = len([r for r in med_rows if r["Ticker"] == ticker])
        n_short = len([r for r in short_extra_rows if r["Ticker"] == ticker])
        print(f"  ✅ {ticker}: {n_med} med-term + {n_short} short-term")

    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

med_df = pd.DataFrame(med_rows)
short_extra_df = pd.DataFrame(short_extra_rows)
print(
    f"\n✅ Medium-term (30-90 DTE): {len(med_df)} options across {med_df['Ticker'].nunique() if not med_df.empty else 0} tickers"
)
print(f"✅ Short-term gap fills: {len(short_extra_df)} options")


# ══════════════════════════════════════════════════════════════════
# STEP 2 — Combine ALL options into unified DataFrame
# ══════════════════════════════════════════════════════════════════

common_cols = [
    "Ticker",
    "Conviction",
    "Expiry",
    "DTE",
    "Strike",
    "Moneyness",
    "Spot",
    "Mid",
    "IV",
    "Breakeven",
    "Breakeven %",
    "Leverage",
    "Cost/Contract",
    "P(Profit)",
    "Edge Score",
    "OI",
    "Spread %",
    "Ret 1M",
    "Ret 3M",
    "RSI",
]

frames = []

# Short-term from swing_df
if not swing_df.empty:
    sw = swing_df.copy()
    for c in common_cols:
        if c not in sw.columns:
            sw[c] = np.nan
    frames.append(sw[common_cols])

# Short-term gap fills (bounce tickers)
if not short_extra_df.empty:
    for c in common_cols:
        if c not in short_extra_df.columns:
            short_extra_df[c] = np.nan
    frames.append(short_extra_df[common_cols])

# Medium-term
if not med_df.empty:
    for c in common_cols:
        if c not in med_df.columns:
            med_df[c] = np.nan
    frames.append(med_df[common_cols])

# LEAPS from scored_df
if not scored_df.empty:
    sc = scored_df.copy()
    for c in common_cols:
        if c not in sc.columns:
            sc[c] = np.nan
    frames.append(sc[common_cols])

unified_df = pd.concat(frames, ignore_index=True)


# DTE bucket labels
def dte_bucket(d):
    if d < 30:
        return "⚡ <30 DTE"
    elif d <= 90:
        return "🔄 30-90 DTE"
    else:
        return "🏗️ 300+ DTE"


unified_df["Bucket"] = unified_df["DTE"].apply(dte_bucket)

# Merge bounce scores
if not bounce_df.empty:
    bounce_merge = bounce_df[["Ticker", "Bounce Score", "Signals"]].copy()
    unified_df = unified_df.merge(bounce_merge, on="Ticker", how="left")
    unified_df["Bounce Score"] = unified_df["Bounce Score"].fillna(0)
else:
    unified_df["Bounce Score"] = 0
    unified_df["Signals"] = ""


# Combined rank score: Edge + Bounce bonus
# For short/med term, bounce matters more. For LEAPS, edge matters more.
def combined_score(row):
    edge = row["Edge Score"] if not np.isnan(row["Edge Score"]) else 0
    bounce = row["Bounce Score"]
    if row["Bucket"] == "⚡ <30 DTE":
        return edge * 0.55 + bounce * 0.45
    elif row["Bucket"] == "🔄 30-90 DTE":
        return edge * 0.50 + bounce * 0.50
    else:
        return edge * 0.70 + bounce * 0.30


unified_df["Combo Score"] = unified_df.apply(combined_score, axis=1)

# Drop exact duplicates (same ticker/strike/expiry)
unified_df = unified_df.drop_duplicates(
    subset=["Ticker", "Strike", "Expiry"], keep="first"
)

print(f"\n📊 Unified universe: {len(unified_df)} options")
for b in ["⚡ <30 DTE", "🔄 30-90 DTE", "🏗️ 300+ DTE"]:
    sub = unified_df[unified_df["Bucket"] == b]
    print(f"  {b}: {len(sub)} options across {sub['Ticker'].nunique()} tickers")
# Out:
# Fetching medium-term (30-90 DTE) + short-term gap fills...
#
#   ✅ WDC: 14 med-term + 0 short-term
#   ✅ GEV: 29 med-term + 0 short-term
#   ✅ STX: 17 med-term + 0 short-term
#   ✅ LRCX: 9 med-term + 0 short-term
#   ✅ AMAT: 7 med-term + 0 short-term
#   ✅ TSM: 16 med-term + 0 short-term
#   ✅ GE: 10 med-term + 0 short-term
#   ✅ CMI: 17 med-term + 0 short-term
#   ✅ KLAC: 36 med-term + 0 short-term
#   ✅ SNPS: 7 med-term + 7 short-term
#   ✅ META: 34 med-term + 0 short-term
#   ✅ UBER: 6 med-term + 10 short-term
#   ✅ ISRG: 21 med-term + 17 short-term
#   ✅ MSFT: 21 med-term + 14 short-term
#   ✅ AMZN: 9 med-term + 8 short-term
#   ✅ AVGO: 15 med-term + 16 short-term
#
# ✅ Medium-term (30-90 DTE): 268 options across 16 tickers
# ✅ Short-term gap fills: 72 options
#
# 📊 Unified universe: 1061 options
#   ⚡ <30 DTE: 257 options across 16 tickers
#   🔄 30-90 DTE: 268 options across 16 tickers
#   🏗️ 300+ DTE: 536 options across 16 tickers

# %%
# ══════════════════════════════════════════════════════════════════
# FINAL PICKS — Best calls per DTE bucket
# ══════════════════════════════════════════════════════════════════

display(Markdown("---\n# 🎯 Final Call Picks\n"))

pick_cols = [
    "Ticker",
    "Conviction",
    "Bucket",
    "Expiry",
    "DTE",
    "Strike",
    "Moneyness",
    "Spot",
    "Mid",
    "IV",
    "Breakeven %",
    "Leverage",
    "Cost/Contract",
    "P(Profit)",
    "Edge Score",
    "Bounce Score",
    "Combo Score",
]

buckets = [
    (
        "⚡ <30 DTE",
        "⚡ Short-Term Swings — Momentum & Snap-Back Plays",
        "Quick directional bets. High leverage, tight risk. Look for RSI reversals + momentum continuation.",
    ),
    (
        "🔄 30-90 DTE",
        "🔄 Medium-Term — Bounce Recovery & Earnings Setups",
        "Give oversold names 1-3 months to revert. Best risk/reward for bounce thesis.",
    ),
    (
        "🏗️ 300+ DTE",
        "🏗️ LEAPS — Conviction Holds & Stock Replacement",
        "Deep ITM for delta exposure, ATM for leverage. Long runway = time to be right.",
    ),
]

all_picks = []  # collect for summary

for bucket_key, title, description in buckets:
    sub = unified_df[unified_df["Bucket"] == bucket_key].copy()
    if sub.empty:
        display(Markdown(f"\n### {title}\n*No options in this bucket.*"))
        continue

    # Pick top 2 per ticker, then top 15 overall
    top = (
        sub.sort_values("Combo Score", ascending=False)
        .groupby("Ticker")
        .head(2)
        .sort_values("Combo Score", ascending=False)
        .head(15)
        .reset_index(drop=True)
    )

    display(Markdown(f"\n### {title}"))
    display(Markdown(f"*{description}*"))

    avail = [c for c in pick_cols if c in top.columns]
    styled = (
        top[avail]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Spot": "${:,.2f}",
                "Mid": "${:,.2f}",
                "Moneyness": "{:.0%}",
                "IV": "{:.1%}",
                "Breakeven %": "{:+.1%}",
                "Leverage": "{:.0f}x",
                "Cost/Contract": "${:,.0f}",
                "P(Profit)": "{:.0%}",
                "Edge Score": "{:.0f}",
                "Bounce Score": "{:.0f}",
                "Combo Score": "{:.0f}",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Combo Score"], cmap="RdYlGn", vmin=20, vmax=70)
    )
    if "P(Profit)" in avail:
        styled = styled.background_gradient(
            subset=["P(Profit)"], cmap="RdYlGn", vmin=0.15, vmax=0.65
        )
    if "Bounce Score" in avail:
        styled = styled.background_gradient(
            subset=["Bounce Score"], cmap="Blues", vmin=0, vmax=70
        )

    display(styled.set_caption(f"Top picks — {bucket_key} | Sorted by Combo Score"))

    # Scenario P&L for this bucket
    best_per_ticker = top.groupby("Ticker").first().reset_index().head(6)
    if bucket_key == "⚡ <30 DTE":
        moves = [0.03, 0.05, 0.08, 0.10]
    elif bucket_key == "🔄 30-90 DTE":
        moves = [0.05, 0.10, 0.15, 0.20]
    else:
        moves = [0.10, 0.20, 0.30, 0.50]

    scen = []
    for _, r in best_per_ticker.iterrows():
        for m in moves:
            new_spot = r["Spot"] * (1 + m)
            payout = max(new_spot - r["Strike"], 0)
            ret = (payout - r["Mid"]) / r["Mid"] if r["Mid"] > 0 else 0
            scen.append(
                {
                    "Ticker": r["Ticker"],
                    "Strike": r["Strike"],
                    "DTE": r["DTE"],
                    "Cost": f"${r['Mid']:,.2f}",
                    "Move": m,
                    "Return": ret,
                }
            )
    if scen:
        scen_df = pd.DataFrame(scen)
        piv = scen_df.pivot_table(
            index=["Ticker", "Strike", "DTE", "Cost"], columns="Move", values="Return"
        )
        piv.columns = [f"+{c:.0%}" for c in piv.columns]
        display(
            piv.style.format("{:+.0%}", na_rep="—")
            .background_gradient(cmap="RdYlGn", vmin=-0.5, vmax=3.0, axis=None)
            .set_caption(f"Return % if stock rallies — {bucket_key}")
        )

    all_picks.append(top)

# ══════════════════════════════════════════════════════════════════
# SUMMARY — One-page cheat sheet
# ══════════════════════════════════════════════════════════════════

display(Markdown("\n---\n## 🗒️ Cheat Sheet — Top Pick Per Bucket Per Ticker\n"))

summary_rows = []
for bucket_key, _, _ in buckets:
    sub = unified_df[unified_df["Bucket"] == bucket_key].copy()
    if sub.empty:
        continue
    best = (
        sub.sort_values("Combo Score", ascending=False)
        .groupby("Ticker")
        .first()
        .reset_index()
    )
    best["Bucket"] = bucket_key
    summary_rows.append(best)

if summary_rows:
    cheat = pd.concat(summary_rows, ignore_index=True)
    cheat = cheat.sort_values(["Ticker", "DTE"])

    cheat["Call"] = cheat.apply(
        lambda r: f"${r['Strike']:,.0f} {r['Expiry']} ({r['DTE']}d)", axis=1
    )
    cheat["Entry"] = cheat["Mid"].apply(lambda x: f"${x:,.2f}")
    cheat["B/E"] = cheat["Breakeven %"].apply(
        lambda x: f"{x:+.1%}" if not np.isnan(x) else "—"
    )

    summary_cols = [
        "Ticker",
        "Conviction",
        "Bucket",
        "Call",
        "Entry",
        "B/E",
        "Leverage",
        "P(Profit)",
        "Edge Score",
        "Bounce Score",
        "Combo Score",
    ]
    sa = [c for c in summary_cols if c in cheat.columns]

    display(
        cheat[sa]
        .style.format(
            {
                "Leverage": "{:.0f}x",
                "P(Profit)": "{:.0%}",
                "Edge Score": "{:.0f}",
                "Bounce Score": "{:.0f}",
                "Combo Score": "{:.0f}",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Combo Score"], cmap="RdYlGn", vmin=20, vmax=70)
        .set_caption("Best single call per ticker per time horizon")
    )

# ── Visual: Scatter of all top picks ──
if all_picks:
    all_top = pd.concat(all_picks, ignore_index=True)
    fig_final = px.scatter(
        all_top,
        x="DTE",
        y="Combo Score",
        text="Ticker",
        color="Bucket",
        size="Leverage",
        size_max=25,
        color_discrete_map={
            "⚡ <30 DTE": "#e74c3c",
            "🔄 30-90 DTE": "#f39c12",
            "🏗️ 300+ DTE": "#2ecc71",
        },
        title="Final Picks — Combo Score vs DTE (size = leverage)",
        labels={"Combo Score": "Combo Score (Edge + Bounce)"},
        log_x=True,
    )
    fig_final.update_traces(textposition="top center", textfont_size=9)
    fig_final.update_layout(height=500)
    fig_final.show()
# Out:
# ---
# # 🎯 Final Call Picks
# ### ⚡ Short-Term Swings — Momentum & Snap-Back Plays
# *Quick directional bets. High leverage, tight risk. Look for RSI reversals + momentum continuation.*
# <style type="text/css">
# #T_15387_row0_col13, #T_15387_row9_col13 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_15387_row0_col15, #T_15387_row1_col15 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_15387_row0_col16, #T_15387_row1_col16 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_15387_row1_col13 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_15387_row2_col13 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_15387_row2_col15, #T_15387_row3_col15 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_15387_row2_col16 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_15387_row3_col13, #T_15387_row5_col16 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_15387_row3_col16 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_15387_row4_col13 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_15387_row4_col15, #T_15387_row5_col15 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_15387_row4_col16, #T_15387_row8_col13 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_15387_row5_col13 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_15387_row6_col13, #T_15387_row7_col13 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_15387_row6_col15, #T_15387_row7_col15 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_15387_row6_col16, #T_15387_row7_col16 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_15387_row8_col15, #T_15387_row11_col15 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_15387_row8_col16, #T_15387_row14_col13 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_15387_row9_col15, #T_15387_row10_col15 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_15387_row9_col16 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_15387_row10_col13 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_15387_row10_col16, #T_15387_row13_col13 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_15387_row11_col13 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_15387_row11_col16 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_15387_row12_col13 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_15387_row12_col15, #T_15387_row13_col15, #T_15387_row14_col15 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_15387_row12_col16, #T_15387_row13_col16 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_15387_row14_col16 {
#   background-color: #feec9f;
#   color: #000000;
# }
# </style>
# <table id="T_15387">
#   <caption>Top picks — ⚡ <30 DTE | Sorted by Combo Score</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15387_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_15387_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_15387_level0_col2" class="col_heading level0 col2" >Bucket</th>
#       <th id="T_15387_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_15387_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_15387_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_15387_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_15387_level0_col7" class="col_heading level0 col7" >Spot</th>
#       <th id="T_15387_level0_col8" class="col_heading level0 col8" >Mid</th>
#       <th id="T_15387_level0_col9" class="col_heading level0 col9" >IV</th>
#       <th id="T_15387_level0_col10" class="col_heading level0 col10" >Breakeven %</th>
#       <th id="T_15387_level0_col11" class="col_heading level0 col11" >Leverage</th>
#       <th id="T_15387_level0_col12" class="col_heading level0 col12" >Cost/Contract</th>
#       <th id="T_15387_level0_col13" class="col_heading level0 col13" >P(Profit)</th>
#       <th id="T_15387_level0_col14" class="col_heading level0 col14" >Edge Score</th>
#       <th id="T_15387_level0_col15" class="col_heading level0 col15" >Bounce Score</th>
#       <th id="T_15387_level0_col16" class="col_heading level0 col16" >Combo Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15387_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15387_row0_col0" class="data row0 col0" >MSFT</td>
#       <td id="T_15387_row0_col1" class="data row0 col1" ></td>
#       <td id="T_15387_row0_col2" class="data row0 col2" >⚡ <30 DTE</td>
#       <td id="T_15387_row0_col3" class="data row0 col3" >2026-02-20</td>
#       <td id="T_15387_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_15387_row0_col5" class="data row0 col5" >$360</td>
#       <td id="T_15387_row0_col6" class="data row0 col6" >90%</td>
#       <td id="T_15387_row0_col7" class="data row0 col7" >$401.14</td>
#       <td id="T_15387_row0_col8" class="data row0 col8" >$42.45</td>
#       <td id="T_15387_row0_col9" class="data row0 col9" >51.5%</td>
#       <td id="T_15387_row0_col10" class="data row0 col10" >+0.3%</td>
#       <td id="T_15387_row0_col11" class="data row0 col11" >9x</td>
#       <td id="T_15387_row0_col12" class="data row0 col12" >$4,245</td>
#       <td id="T_15387_row0_col13" class="data row0 col13" >47%</td>
#       <td id="T_15387_row0_col14" class="data row0 col14" >49</td>
#       <td id="T_15387_row0_col15" class="data row0 col15" >67</td>
#       <td id="T_15387_row0_col16" class="data row0 col16" >57</td>
#     </tr>
#     <tr>
#       <th id="T_15387_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15387_row1_col0" class="data row1 col0" >MSFT</td>
#       <td id="T_15387_row1_col1" class="data row1 col1" ></td>
#       <td id="T_15387_row1_col2" class="data row1 col2" >⚡ <30 DTE</td>
#       <td id="T_15387_row1_col3" class="data row1 col3" >2026-02-20</td>
#       <td id="T_15387_row1_col4" class="data row1 col4" >12</td>
#       <td id="T_15387_row1_col5" class="data row1 col5" >$380</td>
#       <td id="T_15387_row1_col6" class="data row1 col6" >95%</td>
#       <td id="T_15387_row1_col7" class="data row1 col7" >$401.14</td>
#       <td id="T_15387_row1_col8" class="data row1 col8" >$23.90</td>
#       <td id="T_15387_row1_col9" class="data row1 col9" >36.3%</td>
#       <td id="T_15387_row1_col10" class="data row1 col10" >+0.7%</td>
#       <td id="T_15387_row1_col11" class="data row1 col11" >17x</td>
#       <td id="T_15387_row1_col12" class="data row1 col12" >$2,390</td>
#       <td id="T_15387_row1_col13" class="data row1 col13" >45%</td>
#       <td id="T_15387_row1_col14" class="data row1 col14" >49</td>
#       <td id="T_15387_row1_col15" class="data row1 col15" >67</td>
#       <td id="T_15387_row1_col16" class="data row1 col16" >57</td>
#     </tr>
#     <tr>
#       <th id="T_15387_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15387_row2_col0" class="data row2 col0" >AMZN</td>
#       <td id="T_15387_row2_col1" class="data row2 col1" ></td>
#       <td id="T_15387_row2_col2" class="data row2 col2" >⚡ <30 DTE</td>
#       <td id="T_15387_row2_col3" class="data row2 col3" >2026-02-20</td>
#       <td id="T_15387_row2_col4" class="data row2 col4" >12</td>
#       <td id="T_15387_row2_col5" class="data row2 col5" >$205</td>
#       <td id="T_15387_row2_col6" class="data row2 col6" >97%</td>
#       <td id="T_15387_row2_col7" class="data row2 col7" >$210.32</td>
#       <td id="T_15387_row2_col8" class="data row2 col8" >$8.55</td>
#       <td id="T_15387_row2_col9" class="data row2 col9" >36.1%</td>
#       <td id="T_15387_row2_col10" class="data row2 col10" >+1.5%</td>
#       <td id="T_15387_row2_col11" class="data row2 col11" >25x</td>
#       <td id="T_15387_row2_col12" class="data row2 col12" >$855</td>
#       <td id="T_15387_row2_col13" class="data row2 col13" >40%</td>
#       <td id="T_15387_row2_col14" class="data row2 col14" >47</td>
#       <td id="T_15387_row2_col15" class="data row2 col15" >63</td>
#       <td id="T_15387_row2_col16" class="data row2 col16" >54</td>
#     </tr>
#     <tr>
#       <th id="T_15387_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15387_row3_col0" class="data row3 col0" >AMZN</td>
#       <td id="T_15387_row3_col1" class="data row3 col1" ></td>
#       <td id="T_15387_row3_col2" class="data row3 col2" >⚡
# <style type="text/css">
# #T_2103b_row0_col0 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_2103b_row0_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_2103b_row0_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_2103b_row0_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_2103b_row1_col0 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_2103b_row1_col1 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_2103b_row1_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_2103b_row1_col3 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_2103b_row2_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_2103b_row2_col1 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_2103b_row2_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_2103b_row2_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_2103b_row3_col0 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_2103b_row3_col1, #T_2103b_row4_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_2103b_row3_col2, #T_2103b_row5_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_2103b_row3_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_2103b_row4_col0 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_2103b_row4_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_2103b_row4_col3 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_2103b_row5_col0 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_2103b_row5_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_2103b_row5_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# </style>
# <table id="T_2103b">
#   <caption>Return % if stock rallies — ⚡ <30 DTE</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2103b_level0_col0" class="col_heading level0 col0" >+3%</th>
#       <th id="T_2103b_level0_col1" class="col_heading level0 col1" >+5%</th>
#       <th id="T_2103b_level0_col2" class="col_heading level0 col2" >+8%</th>
#       <th id="T_2103b_level0_col3" class="col_heading level0 col3" >+10%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="index_name level1" >Strike</th>
#       <th class="index_name level2" >DTE</th>
#       <th class="index_name level3" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2103b_level0_row0" class="row_heading level0 row0" >AMAT</th>
#       <th id="T_2103b_level1_row0" class="row_heading level1 row0" >300.000000</th>
#       <th id="T_2103b_level2_row0" class="row_heading level2 row0" >12</th>
#       <th id="T_2103b_level3_row0" class="row_heading level3 row0" >$30.07</th>
#       <td id="T_2103b_row0_col0" class="data row0 col0" >+7%</td>
#       <td id="T_2103b_row0_col1" class="data row0 col1" >+28%</td>
#       <td id="T_2103b_row0_col2" class="data row0 col2" >+61%</td>
#       <td id="T_2103b_row0_col3" class="data row0 col3" >+82%</td>
#     </tr>
#     <tr>
#       <th id="T_2103b_level0_row1" class="row_heading level0 row1" >AMZN</th>
#       <th id="T_2103b_level1_row1" class="row_heading level1 row1" >205.000000</th>
#       <th id="T_2103b_level2_row1" class="row_heading level2 row1" >12</th>
#       <th id="T_2103b_level3_row1" class="row_heading level3 row1" >$8.55</th>
#       <td id="T_2103b_row1_col0" class="data row1 col0" >+36%</td>
#       <td id="T_2103b_row1_col1" class="data row1 col1" >+85%</td>
#       <td id="T_2103b_row1_col2" class="data row1 col2" >+159%</td>
#       <td id="T_2103b_row1_col3" class="data row1 col3" >+208%</td>
#     </tr>
#     <tr>
#       <th id="T_2103b_level0_row2" class="row_heading level0 row2" >ISRG</th>
#       <th id="T_2103b_level1_row2" class="row_heading level1 row2" >430.000000</th>
#       <th id="T_2103b_level2_row2" class="row_heading level2 row2" >12</th>
#       <th id="T_2103b_level3_row2" class="row_heading level3 row2" >$59.40</th>
#       <td id="T_2103b_row2_col0" class="data row2 col0" >+23%</td>
#       <td id="T_2103b_row2_col1" class="data row2 col1" >+39%</td>
#       <td id="T_2103b_row2_col2" class="data row2 col2" >+64%</td>
#       <td id="T_2103b_row2_col3" class="data row2 col3" >+80%</td>
#     </tr>
#     <tr>
#       <th id="T_2103b_level0_row3" class="row_heading level0 row3" >KLAC</th>
#       <th id="T_2103b_level1_row3" class="row_heading level1 row3" >1360.000000</th>
#       <th id="T_2103b_level2_row3" class="row_heading level2 row3" >12</th>
#       <th id="T_2103b_level3_row3" class="row_heading level3 row3" >$103.50</th>
#       <td id="T_2103b_row3_col0" class="data row3 col0" >+22%</td>
#       <td id="T_2103b_row3_col1" class="data row3 col1" >+50%</td>
#       <td id="T_2103b_row3_col2" class="data row3 col2" >+92%</td>
#       <td id="T_2103b_row3_col3" class="data row3 col3" >+120%</td>
#     </tr>
#     <tr>
#       <th id="T_2103b_level0_row4" class="row_heading level0 row4" >LRCX</th>
#       <th id="T_2103b_level1_row4" class="row_heading level1 row4" >220.000000</th>
#       <th id="T_2103b_level2_row4" class="row_heading level2 row4" >19</th>
#       <th id="T_2103b_level3_row4" class="row_heading level3 row4" >$19.60</th>
#       <td id="T_2103b_row4_col0" class="data row4 col0" >-8%</td>
#       <td id="T_2103b_row4_col1" class="data row4 col1" >+15%</td>
#       <td id="T_2103b_row4_col2" class="data row4 col2" >+50%</td>
#       <td id="T_2103b_row4_col3" class="data row4 col3" >+74%</td>
#     </tr>
#     <tr>
#       <th id="T_2103b_level0_row5" class="row_heading level0 row5" >MSFT</th>
#       <th id="T_2103b_level1_row5" class="row_heading level1 row5" >360.000000</th>
#       <th id="T_2103b_level2_row5" class="row_heading level2 row5" >12</th>
#       <th id="T_2103b_level3_row5" class="row_heading level3 row5" >$42.45</th>
#       <td id="T_2103b_row5_col0" class="data row5 col0" >+25%</td>
#       <td id="T_2103b_row5_col1" class="data row5 col1" >+44%</td>
#       <td id="T_2103b_row5_col2" class="data row5 col2" >+73%</td>
#       <td id="T_2103b_row5_col3" class="data row5 col3" >+91%</td>
#     </tr>
#   </tbody>
# </table>
# ### 🔄 Medium-Term — Bounce Recovery & Earnings Setups
# *Give oversold names 1-3 months to revert. Best risk/reward for bounce thesis.*
# <style type="text/css">
# #T_ea6d1_row0_col13, #T_ea6d1_row4_col16 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_ea6d1_row0_col15, #T_ea6d1_row1_col15 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_ea6d1_row0_col16 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_ea6d1_row1_col13 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_ea6d1_row1_col16 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_ea6d1_row2_col13 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_ea6d1_row2_col15, #T_ea6d1_row3_col15 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_ea6d1_row2_col16 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_ea6d1_row3_col13 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_ea6d1_row3_col16 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_ea6d1_row4_col13, #T_ea6d1_row10_col16 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_ea6d1_row4_col15, #T_ea6d1_row5_col15 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_ea6d1_row5_col13 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_ea6d1_row5_col16 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_ea6d1_row6_col13, #T_ea6d1_row7_col16 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_ea6d1_row6_col15, #T_ea6d1_row7_col15 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_ea6d1_row6_col16 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_ea6d1_row7_col13 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_ea6d1_row8_col13 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_ea6d1_row8_col15, #T_ea6d1_row9_col15 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_ea6d1_row8_col16 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_ea6d1_row9_col13, #T_ea6d1_row11_col13 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_ea6d1_row9_col16 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_ea6d1_row10_col13 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_ea6d1_row10_col15, #T_ea6d1_row11_col15 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_ea6d1_row11_col16 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_ea6d1_row12_col13 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_ea6d1_row12_col15, #T_ea6d1_row13_col15, #T_ea6d1_row14_col15 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ea6d1_row12_col16 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_ea6d1_row13_col13 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ea6d1_row13_col16 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_ea6d1_row14_col13 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_ea6d1_row14_col16 {
#   background-color: #fede89;
#   color: #000000;
# }
# </style>
# <table id="T_ea6d1">
#   <caption>Top picks — 🔄 30-90 DTE | Sorted by Combo Score</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea6d1_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_ea6d1_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_ea6d1_level0_col2" class="col_heading level0 col2" >Bucket</th>
#       <th id="T_ea6d1_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_ea6d1_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_ea6d1_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_ea6d1_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_ea6d1_level0_col7" class="col_heading level0 col7" >Spot</th>
#       <th id="T_ea6d1_level0_col8" class="col_heading level0 col8" >Mid</th>
#       <th id="T_ea6d1_level0_col9" class="col_heading level0 col9" >IV</th>
#       <th id="T_ea6d1_level0_col10" class="col_heading level0 col10" >Breakeven %</th>
#       <th id="T_ea6d1_level0_col11" class="col_heading level0 col11" >Leverage</th>
#       <th id="T_ea6d1_level0_col12" class="col_heading level0 col12" >Cost/Contract</th>
#       <th id="T_ea6d1_level0_col13" class="col_heading level0 col13" >P(Profit)</th>
#       <th id="T_ea6d1_level0_col14" class="col_heading level0 col14" >Edge Score</th>
#       <th id="T_ea6d1_level0_col15" class="col_heading level0 col15" >Bounce Score</th>
#       <th id="T_ea6d1_level0_col16" class="col_heading level0 col16" >Combo Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea6d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea6d1_row0_col0" class="data row0 col0" >MSFT</td>
#       <td id="T_ea6d1_row0_col1" class="data row0 col1" ></td>
#       <td id="T_ea6d1_row0_col2" class="data row0 col2" >🔄 30-90 DTE</td>
#       <td id="T_ea6d1_row0_col3" class="data row0 col3" >2026-03-20</td>
#       <td id="T_ea6d1_row0_col4" class="data row0 col4" >40</td>
#       <td id="T_ea6d1_row0_col5" class="data row0 col5" >$360</td>
#       <td id="T_ea6d1_row0_col6" class="data row0 col6" >90%</td>
#       <td id="T_ea6d1_row0_col7" class="data row0 col7" >$401.14</td>
#       <td id="T_ea6d1_row0_col8" class="data row0 col8" >$45.42</td>
#       <td id="T_ea6d1_row0_col9" class="data row0 col9" >38.1%</td>
#       <td id="T_ea6d1_row0_col10" class="data row0 col10" >+1.1%</td>
#       <td id="T_ea6d1_row0_col11" class="data row0 col11" >9x</td>
#       <td id="T_ea6d1_row0_col12" class="data row0 col12" >$4,542</td>
#       <td id="T_ea6d1_row0_col13" class="data row0 col13" >46%</td>
#       <td id="T_ea6d1_row0_col14" class="data row0 col14" >54</td>
#       <td id="T_ea6d1_row0_col15" class="data row0 col15" >67</td>
#       <td id="T_ea6d1_row0_col16" class="data row0 col16" >61</td>
#     </tr>
#     <tr>
#       <th id="T_ea6d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea6d1_row1_col0" class="data row1 col0" >MSFT</td>
#       <td id="T_ea6d1_row1_col1" class="data row1 col1" ></td>
#       <td id="T_ea6d1_row1_col2" class="data row1 col2" >🔄 30-90 DTE</td>
#       <td id="T_ea6d1_row1_col3" class="data row1 col3" >2026-03-20</td>
#       <td id="T_ea6d1_row1_col4" class="data row1 col4" >40</td>
#       <td id="T_ea6d1_row1_col5" class="data row1 col5" >$355</td>
#       <td id="T_ea6d1_row1_col6" class="data row1 col6" >88%</td>
#       <td id="T_ea6d1_row1_col7" class="data row1 col7" >$401.14</td>
#       <td id="T_ea6d1_row1_col8" class="data row1 col8" >$49.92</td>
#       <td id="T_ea6d1_row1_col9" class="data row1 col9" >39.7%</td>
#       <td id="T_ea6d1_row1_col10" class="data row1 col10" >+0.9%</td>
#       <td id="T_ea6d1_row1_col11" class="data row1 col11" >8x</td>
#       <td id="T_ea6d1_row1_col12" class="data row1 col12" >$4,992</td>
#       <td id="T_ea6d1_row1_col13" class="data row1 col13" >46%</td>
#       <td id="T_ea6d1_row1_col14" class="data row1 col14" >54</td>
#       <td id="T_ea6d1_row1_col15" class="data row1 col15" >67</td>
#       <td id="T_ea6d1_row1_col16" class="data row1 col16" >60</td>
#     </tr>
#     <tr>
#       <th id="T_ea6d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea6d1_row2_col0" class="data row2 col0" >AMZN</td>
#       <td id="T_ea6d1_row2_col1" class="data row2 col1" ></td>
#       <td id="T_ea6d1_row2_col2" class="data row2 col2" >🔄 30-90 DTE</td>
#       <td id="T_ea6d1_row2_col3" class="data row2 col3" >2026-03-20</td>
#       <td id="T_ea6d1_row2_col4" class="data row2 col4" >40</td>
#       <td id="T_ea6d1_row2_col5" class="data row2 col5" >$190</td>
#       <td id="T_ea6d1_row2_col6" class="data row2 col6" >90%</td>
#       <td id="T_ea6d1_row2_col7" class="data row2 col7" >$210.32</td>
#       <td id="T_ea6d1_row2_col8" class="data row2 col8" >$23.77</td>
#       <td id="T_ea6d1_row2_col9" class="data row2 col9" >40.6%</td>
#       <td id="T_ea6d1_row2_col10" class="data row2 col10" >+1.6%</td>
#       <td id="T_ea6d1_row2_col11" class="data row2 col11" >9x</td>
#       <td id="T_ea6d1_row2_col12" class="data row2 col12" >$2,378</td>
#       <td id="T_ea6d1_row2_col13" class="data row2 col13" >44%</td>
#       <td id="T_ea6d1_row2_col14" class="data row2 col14" >49</td>
#       <td id="T_ea6d1_row2_col15" class="data row2 col15" >63</td>
#       <td id="T_ea6d1_row2_col16" class="data row2 col16" >56</td>
#     </tr>
#     <tr>
# <style type="text/css">
# #T_d7bb5_row0_col0 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_d7bb5_row0_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_d7bb5_row0_col2, #T_d7bb5_row4_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_d7bb5_row0_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_d7bb5_row1_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_d7bb5_row1_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_d7bb5_row1_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_d7bb5_row1_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_d7bb5_row2_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_d7bb5_row2_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_d7bb5_row2_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_d7bb5_row2_col3 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_d7bb5_row3_col0 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_d7bb5_row3_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_d7bb5_row3_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_d7bb5_row3_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_d7bb5_row4_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_d7bb5_row4_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_d7bb5_row4_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_d7bb5_row5_col0 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_d7bb5_row5_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_d7bb5_row5_col2 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_d7bb5_row5_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# </style>
# <table id="T_d7bb5">
#   <caption>Return % if stock rallies — 🔄 30-90 DTE</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7bb5_level0_col0" class="col_heading level0 col0" >+5%</th>
#       <th id="T_d7bb5_level0_col1" class="col_heading level0 col1" >+10%</th>
#       <th id="T_d7bb5_level0_col2" class="col_heading level0 col2" >+15%</th>
#       <th id="T_d7bb5_level0_col3" class="col_heading level0 col3" >+20%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="index_name level1" >Strike</th>
#       <th class="index_name level2" >DTE</th>
#       <th class="index_name level3" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7bb5_level0_row0" class="row_heading level0 row0" >AMAT</th>
#       <th id="T_d7bb5_level1_row0" class="row_heading level1 row0" >290.000000</th>
#       <th id="T_d7bb5_level2_row0" class="row_heading level2 row0" >40</th>
#       <th id="T_d7bb5_level3_row0" class="row_heading level3 row0" >$44.77</th>
#       <td id="T_d7bb5_row0_col0" class="data row0 col0" >+9%</td>
#       <td id="T_d7bb5_row0_col1" class="data row0 col1" >+45%</td>
#       <td id="T_d7bb5_row0_col2" class="data row0 col2" >+81%</td>
#       <td id="T_d7bb5_row0_col3" class="data row0 col3" >+117%</td>
#     </tr>
#     <tr>
#       <th id="T_d7bb5_level0_row1" class="row_heading level0 row1" >AMZN</th>
#       <th id="T_d7bb5_level1_row1" class="row_heading level1 row1" >190.000000</th>
#       <th id="T_d7bb5_level2_row1" class="row_heading level2 row1" >40</th>
#       <th id="T_d7bb5_level3_row1" class="row_heading level3 row1" >$23.77</th>
#       <td id="T_d7bb5_row1_col0" class="data row1 col0" >+30%</td>
#       <td id="T_d7bb5_row1_col1" class="data row1 col1" >+74%</td>
#       <td id="T_d7bb5_row1_col2" class="data row1 col2" >+118%</td>
#       <td id="T_d7bb5_row1_col3" class="data row1 col3" >+162%</td>
#     </tr>
#     <tr>
#       <th id="T_d7bb5_level0_row2" class="row_heading level0 row2" >ISRG</th>
#       <th id="T_d7bb5_level1_row2" class="row_heading level1 row2" >430.000000</th>
#       <th id="T_d7bb5_level2_row2" class="row_heading level2 row2" >40</th>
#       <th id="T_d7bb5_level3_row2" class="row_heading level3 row2" >$63.90</th>
#       <td id="T_d7bb5_row2_col0" class="data row2 col0" >+29%</td>
#       <td id="T_d7bb5_row2_col1" class="data row2 col1" >+67%</td>
#       <td id="T_d7bb5_row2_col2" class="data row2 col2" >+106%</td>
#       <td id="T_d7bb5_row2_col3" class="data row2 col3" >+144%</td>
#     </tr>
#     <tr>
#       <th id="T_d7bb5_level0_row3" class="row_heading level0 row3" >KLAC</th>
#       <th id="T_d7bb5_level1_row3" class="row_heading level1 row3" >1280.000000</th>
#       <th id="T_d7bb5_level2_row3" class="row_heading level2 row3" >40</th>
#       <th id="T_d7bb5_level3_row3" class="row_heading level3 row3" >$201.75</th>
#       <td id="T_d7bb5_row3_col0" class="data row3 col0" >+17%</td>
#       <td id="T_d7bb5_row3_col1" class="data row3 col1" >+52%</td>
#       <td id="T_d7bb5_row3_col2" class="data row3 col2" >+88%</td>
#       <td id="T_d7bb5_row3_col3" class="data row3 col3" >+124%</td>
#     </tr>
#     <tr>
#       <th id="T_d7bb5_level0_row4" class="row_heading level0 row4" >LRCX</th>
#       <th id="T_d7bb5_level1_row4" class="row_heading level1 row4" >210.000000</th>
#       <th id="T_d7bb5_level2_row4" class="row_heading level2 row4" >40</th>
#       <th id="T_d7bb5_level3_row4" class="row_heading level3 row4" >$30.75</th>
#       <td id="T_d7bb5_row4_col0" class="data row4 col0" >+6%</td>
#       <td id="T_d7bb5_row4_col1" class="data row4 col1" >+43%</td>
#       <td id="T_d7bb5_row4_col2" class="data row4 col2" >+81%</td>
#       <td id="T_d7bb5_row4_col3" class="data row4 col3" >+119%</td>
#     </tr>
#     <tr>
#       <th id="T_d7bb5_level0_row5" class="row_heading level0 row5" >MSFT</th>
#       <th id="T_d7bb5_level1_row5" class="row_heading level1 row5" >360.000000</th>
#       <th id="T_d7bb5_level2_row5" class="row_heading level2 row5" >40</th>
#       <th id="T_d7bb5_level3_row5" class="row_heading level3 row5" >$45.42</th>
#       <td id="T_d7bb5_row5_col0" class="data row5 col0" >+35%</td>
#       <td id="T_d7bb5_row5_col1" class="data row5 col1" >+79%</td>
#       <td id="T_d7bb5_row5_col2" class="data row5 col2" >+123%</td>
#       <td id="T_d7bb5_row5_col3" class="data row5 col3" >+167%</td>
#     </tr>
#   </tbody>
# </table>
# ### 🏗️ LEAPS — Conviction Holds & Stock Replacement
# *Deep ITM for delta exposure, ATM for leverage. Long runway = time to be right.*
# <style type="text/css">
# #T_5ac4f_row0_col13 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5ac4f_row0_col15, #T_5ac4f_row3_col15 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_5ac4f_row0_col16 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_5ac4f_row1_col13 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_5ac4f_row1_col15, #T_5ac4f_row2_col15 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_5ac4f_row1_col16 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_5ac4f_row2_col13 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_5ac4f_row2_col16 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_5ac4f_row3_col13, #T_5ac4f_row11_col13 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_5ac4f_row3_col16 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_5ac4f_row4_col13 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_5ac4f_row4_col15, #T_5ac4f_row5_col15 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_5ac4f_row4_col16 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_5ac4f_row5_col13 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_5ac4f_row5_col16, #T_5ac4f_row6_col16 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_5ac4f_row6_col13 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_5ac4f_row6_col15, #T_5ac4f_row7_col15, #T_5ac4f_row10_col15, #T_5ac4f_row11_col15 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_5ac4f_row7_col13 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_5ac4f_row7_col16, #T_5ac4f_row8_col16 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_5ac4f_row8_col13 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_5ac4f_row8_col15, #T_5ac4f_row9_col15 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_5ac4f_row9_col13 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_5ac4f_row9_col16 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_5ac4f_row10_col13 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_5ac4f_row10_col16 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_5ac4f_row11_col16 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_5ac4f_row12_col13 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_5ac4f_row12_col15, #T_5ac4f_row13_col15 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_5ac4f_row12_col16 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_5ac4f_row13_col13 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_5ac4f_row13_col16 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_5ac4f_row14_col13 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_5ac4f_row14_col15 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5ac4f_row14_col16 {
#   background-color: #e0f295;
#   color: #000000;
# }
# </style>
# <table id="T_5ac4f">
#   <caption>Top picks — 🏗️ 300+ DTE | Sorted by Combo Score</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ac4f_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_5ac4f_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_5ac4f_level0_col2" class="col_heading level0 col2" >Bucket</th>
#       <th id="T_5ac4f_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_5ac4f_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_5ac4f_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_5ac4f_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_5ac4f_level0_col7" class="col_heading level0 col7" >Spot</th>
#       <th id="T_5ac4f_level0_col8" class="col_heading level0 col8" >Mid</th>
#       <th id="T_5ac4f_level0_col9" class="col_heading level0 col9" >IV</th>
#       <th id="T_5ac4f_level0_col10" class="col_heading level0 col10" >Breakeven %</th>
#       <th id="T_5ac4f_level0_col11" class="col_heading level0 col11" >Leverage</th>
#       <th id="T_5ac4f_level0_col12" class="col_heading level0 col12" >Cost/Contract</th>
#       <th id="T_5ac4f_level0_col13" class="col_heading level0 col13" >P(Profit)</th>
#       <th id="T_5ac4f_level0_col14" class="col_heading level0 col14" >Edge Score</th>
#       <th id="T_5ac4f_level0_col15" class="col_heading level0 col15" >Bounce Score</th>
#       <th id="T_5ac4f_level0_col16" class="col_heading level0 col16" >Combo Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ac4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ac4f_row0_col0" class="data row0 col0" >KLAC</td>
#       <td id="T_5ac4f_row0_col1" class="data row0 col1" ></td>
#       <td id="T_5ac4f_row0_col2" class="data row0 col2" >🏗️ 300+ DTE</td>
#       <td id="T_5ac4f_row0_col3" class="data row0 col3" >2026-09-18</td>
#       <td id="T_5ac4f_row0_col4" class="data row0 col4" >222</td>
#       <td id="T_5ac4f_row0_col5" class="data row0 col5" >$1,160</td>
#       <td id="T_5ac4f_row0_col6" class="data row0 col6" >80%</td>
#       <td id="T_5ac4f_row0_col7" class="data row0 col7" >$1,442.95</td>
#       <td id="T_5ac4f_row0_col8" class="data row0 col8" >$189.50</td>
#       <td id="T_5ac4f_row0_col9" class="data row0 col9" >0.0%</td>
#       <td id="T_5ac4f_row0_col10" class="data row0 col10" >-6.5%</td>
#       <td id="T_5ac4f_row0_col11" class="data row0 col11" >8x</td>
#       <td id="T_5ac4f_row0_col12" class="data row0 col12" >$18,950</td>
#       <td id="T_5ac4f_row0_col13" class="data row0 col13" >100%</td>
#       <td id="T_5ac4f_row0_col14" class="data row0 col14" >86</td>
#       <td id="T_5ac4f_row0_col15" class="data row0 col15" >27</td>
#       <td id="T_5ac4f_row0_col16" class="data row0 col16" >68</td>
#     </tr>
#     <tr>
#       <th id="T_5ac4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ac4f_row1_col0" class="data row1 col0" >MSFT</td>
#       <td id="T_5ac4f_row1_col1" class="data row1 col1" ></td>
#       <td id="T_5ac4f_row1_col2" class="data row1 col2" >🏗️ 300+ DTE</td>
#       <td id="T_5ac4f_row1_col3" class="data row1 col3" >2026-06-18</td>
#       <td id="T_5ac4f_row1_col4" class="data row1 col4" >130</td>
#       <td id="T_5ac4f_row1_col5" class="data row1 col5" >$350</td>
#       <td id="T_5ac4f_row1_col6" class="data row1 col6" >87%</td>
#       <td id="T_5ac4f_row1_col7" class="data row1 col7" >$401.14</td>
#       <td id="T_5ac4f_row1_col8" class="data row1 col8" >$64.72</td>
#       <td id="T_5ac4f_row1_col9" class="data row1 col9" >38.5%</td>
#       <td id="T_5ac4f_row1_col10" class="data row1 col10" >+3.4%</td>
#       <td id="T_5ac4f_row1_col11" class="data row1 col11" >6x</td>
#       <td id="T_5ac4f_row1_col12" class="data row1 col12" >$6,472</td>
#       <td id="T_5ac4f_row1_col13" class="data row1 col13" >42%</td>
#       <td id="T_5ac4f_row1_col14" class="data row1 col14" >55</td>
#       <td id="T_5ac4f_row1_col15" class="data row1 col15" >67</td>
#       <td id="T_5ac4f_row1_col16" class="data row1 col16" >58</td>
#     </tr>
#     <tr>
#       <th id="T_5ac4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ac4f_row2_col0" class="data row2 col0" >MSFT</td>
#       <td id="T_5ac4f_row2_col1" class="data row2 col1" ></td>
#       <td id="T_5ac4f_row2_col2" class="data row2 col2" >🏗️ 300+ DTE</td>
#       <td id="T_5ac4f_row2_col3" class="data row2 col3" >2026-05-15</td>
#       <td id="T_5ac4f_row2_col4" class="data row2 col4" >96</td>
#       <td id="T_5ac4f_row2_col5" class="data row2 col5" >$350</td>
#       <td id="T_5ac4f_row2_col6" class="data row2 col6" >87%</td>
#       <td id="T_5ac4f_row2_col7" class="data row2 col7" >$401.14</td>
#       <td id="T_5ac4f_row2_col8" class="data row2 col8" >$62.08</td>
#       <td id="T_5ac4f_row2_col9" class="data row2 col9" >40.4%</td>
#       <td id="T_5ac4f_row2_col10" class="data row2 col10" >+2.7%</td>
#       <td id="T_5ac4f_row2_col11" class="data row2 col11" >6x</td>
#       <td id="T_5ac4f_row2_col12" class="data row2 col12" >$6,208</td>
#       <td id="T_5ac4f_row2_col13" class="data row2 col13" >43%</td>
#       <td id="T_5ac4f_row2_col14" class="data row2 col14" >54</td>
#       <td id="T_5ac4f_row2_col15" class="data row2 col15" >67</td>
#       <td id="T_5ac4f_row2_col16
# <style type="text/css">
# #T_df14a_row0_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_df14a_row0_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_df14a_row0_col2, #T_df14a_row5_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_df14a_row0_col3 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_df14a_row1_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_df14a_row1_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_df14a_row1_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_df14a_row1_col3 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_df14a_row2_col0, #T_df14a_row5_col0 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_df14a_row2_col1 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_df14a_row2_col2 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_df14a_row2_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_df14a_row3_col0 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_df14a_row3_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_df14a_row3_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_df14a_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_df14a_row4_col0 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_df14a_row4_col1 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_df14a_row4_col2 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_df14a_row4_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_df14a_row5_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_df14a_row5_col3 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_df14a">
#   <caption>Return % if stock rallies — 🏗️ 300+ DTE</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df14a_level0_col0" class="col_heading level0 col0" >+10%</th>
#       <th id="T_df14a_level0_col1" class="col_heading level0 col1" >+20%</th>
#       <th id="T_df14a_level0_col2" class="col_heading level0 col2" >+30%</th>
#       <th id="T_df14a_level0_col3" class="col_heading level0 col3" >+50%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ticker</th>
#       <th class="index_name level1" >Strike</th>
#       <th class="index_name level2" >DTE</th>
#       <th class="index_name level3" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df14a_level0_row0" class="row_heading level0 row0" >AMAT</th>
#       <th id="T_df14a_level1_row0" class="row_heading level1 row0" >270.000000</th>
#       <th id="T_df14a_level2_row0" class="row_heading level2 row0" >130</th>
#       <th id="T_df14a_level3_row0" class="row_heading level3 row0" >$73.75</th>
#       <td id="T_df14a_row0_col0" class="data row0 col0" >+15%</td>
#       <td id="T_df14a_row0_col1" class="data row0 col1" >+59%</td>
#       <td id="T_df14a_row0_col2" class="data row0 col2" >+102%</td>
#       <td id="T_df14a_row0_col3" class="data row0 col3" >+190%</td>
#     </tr>
#     <tr>
#       <th id="T_df14a_level0_row1" class="row_heading level0 row1" >AMZN</th>
#       <th id="T_df14a_level1_row1" class="row_heading level1 row1" >175.000000</th>
#       <th id="T_df14a_level2_row1" class="row_heading level2 row1" >130</th>
#       <th id="T_df14a_level3_row1" class="row_heading level3 row1" >$43.15</th>
#       <td id="T_df14a_row1_col0" class="data row1 col0" >+31%</td>
#       <td id="T_df14a_row1_col1" class="data row1 col1" >+79%</td>
#       <td id="T_df14a_row1_col2" class="data row1 col2" >+128%</td>
#       <td id="T_df14a_row1_col3" class="data row1 col3" >+226%</td>
#     </tr>
#     <tr>
#       <th id="T_df14a_level0_row2" class="row_heading level0 row2" >CMI</th>
#       <th id="T_df14a_level1_row2" class="row_heading level1 row2" >480.000000</th>
#       <th id="T_df14a_level2_row2" class="row_heading level2 row2" >130</th>
#       <th id="T_df14a_level3_row2" class="row_heading level3 row2" >$110.75</th>
#       <td id="T_df14a_row2_col0" class="data row2 col0" >+40%</td>
#       <td id="T_df14a_row2_col1" class="data row2 col1" >+93%</td>
#       <td id="T_df14a_row2_col2" class="data row2 col2" >+145%</td>
#       <td id="T_df14a_row2_col3" class="data row2 col3" >+249%</td>
#     </tr>
#     <tr>
#       <th id="T_df14a_level0_row3" class="row_heading level0 row3" >KLAC</th>
#       <th id="T_df14a_level1_row3" class="row_heading level1 row3" >1160.000000</th>
#       <th id="T_df14a_level2_row3" class="row_heading level2 row3" >222</th>
#       <th id="T_df14a_level3_row3" class="row_heading level3 row3" >$189.50</th>
#       <td id="T_df14a_row3_col0" class="data row3 col0" >+125%</td>
#       <td id="T_df14a_row3_col1" class="data row3 col1" >+202%</td>
#       <td id="T_df14a_row3_col2" class="data row3 col2" >+278%</td>
#       <td id="T_df14a_row3_col3" class="data row3 col3" >+430%</td>
#     </tr>
#     <tr>
#       <th id="T_df14a_level0_row4" class="row_heading level0 row4" >LRCX</th>
#       <th id="T_df14a_level1_row4" class="row_heading level1 row4" >190.000000</th>
#       <th id="T_df14a_level2_row4" class="row_heading level2 row4" >130</th>
#       <th id="T_df14a_level3_row4" class="row_heading level3 row4" >$59.73</th>
#       <td id="T_df14a_row4_col0" class="data row4 col0" >+7%</td>
#       <td id="T_df14a_row4_col1" class="data row4 col1" >+46%</td>
#       <td id="T_df14a_row4_col2" class="data row4 col2" >+85%</td>
#       <td id="T_df14a_row4_col3" class="data row4 col3" >+162%</td>
#     </tr>
#     <tr>
#       <th id="T_df14a_level0_row5" class="row_heading level0 row5" >MSFT</th>
#       <th id="T_df14a_level1_row5" class="row_heading level1 row5" >350.000000</th>
#       <th id="T_df14a_level2_row5" class="row_heading level2 row5" >130</th>
#       <th id="T_df14a_level3_row5" class="row_heading level3 row5" >$64.72</th>
#       <td id="T_df14a_row5_col0" class="data row5 col0" >+41%</td>
#       <td id="T_df14a_row5_col1" class="data row5 col1" >+103%</td>
#       <td id="T_df14a_row5_col2" class="data row5 col2" >+165%</td>
#       <td id="T_df14a_row5_col3" class="data row5 col3" >+289%</td>
#     </tr>
#   </tbody>
# </table>
# ---
# ## 🗒️ Cheat Sheet — Top Pick Per Bucket Per Ticker
# <style type="text/css">
# #T_a4b84_row0_col10, #T_a4b84_row25_col10 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_a4b84_row1_col10 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_a4b84_row2_col10, #T_a4b84_row34_col10 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_a4b84_row3_col10 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_a4b84_row4_col10 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_a4b84_row5_col10 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_a4b84_row6_col10 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_a4b84_row7_col10, #T_a4b84_row13_col10 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_a4b84_row8_col10 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a4b84_row9_col10 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_a4b84_row10_col10 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a4b84_row11_col10 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_a4b84_row12_col10 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_a4b84_row14_col10 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a4b84_row15_col10, #T_a4b84_row28_col10, #T_a4b84_row40_col10 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_a4b84_row16_col10, #T_a4b84_row46_col10 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a4b84_row17_col10 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a4b84_row18_col10 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a4b84_row19_col10 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_a4b84_row20_col10 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_a4b84_row21_col10 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a4b84_row22_col10 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_a4b84_row23_col10 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_a4b84_row24_col10 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a4b84_row26_col10 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_a4b84_row27_col10 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_a4b84_row29_col10 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_a4b84_row30_col10 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_a4b84_row31_col10 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_a4b84_row32_col10 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_a4b84_row33_col10, #T_a4b84_row35_col10 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_a4b84_row36_col10 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_a4b84_row37_col10 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_a4b84_row38_col10 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_a4b84_row39_col10 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_a4b84_row41_col10 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_a4b84_row42_col10, #T_a4b84_row44_col10 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_a4b84_row43_col10 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_a4b84_row45_col10 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_a4b84_row47_col10 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# </style>
# <table id="T_a4b84">
#   <caption>Best single call per ticker per time horizon</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4b84_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_a4b84_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_a4b84_level0_col2" class="col_heading level0 col2" >Bucket</th>
#       <th id="T_a4b84_level0_col3" class="col_heading level0 col3" >Call</th>
#       <th id="T_a4b84_level0_col4" class="col_heading level0 col4" >Entry</th>
#       <th id="T_a4b84_level0_col5" class="col_heading level0 col5" >B/E</th>
#       <th id="T_a4b84_level0_col6" class="col_heading level0 col6" >Leverage</th>
#       <th id="T_a4b84_level0_col7" class="col_heading level0 col7" >P(Profit)</th>
#       <th id="T_a4b84_level0_col8" class="col_heading level0 col8" >Edge Score</th>
#       <th id="T_a4b84_level0_col9" class="col_heading level0 col9" >Bounce Score</th>
#       <th id="T_a4b84_level0_col10" class="col_heading level0 col10" >Combo Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4b84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4b84_row0_col0" class="data row0 col0" >AMAT</td>
#       <td id="T_a4b84_row0_col1" class="data row0 col1" >⭐</td>
#       <td id="T_a4b84_row0_col2" class="data row0 col2" >⚡ <30 DTE</td>
#       <td id="T_a4b84_row0_col3" class="data row0 col3" >$300 2026-02-20 (12d)</td>
#       <td id="T_a4b84_row0_col4" class="data row0 col4" >$30.07</td>
#       <td id="T_a4b84_row0_col5" class="data row0 col5" >+2.3%</td>
#       <td id="T_a4b84_row0_col6" class="data row0 col6" >11x</td>
#       <td id="T_a4b84_row0_col7" class="data row0 col7" >41%</td>
#       <td id="T_a4b84_row0_col8" class="data row0 col8" >63</td>
#       <td id="T_a4b84_row0_col9" class="data row0 col9" >17</td>
#       <td id="T_a4b84_row0_col10" class="data row0 col10" >42</td>
#     </tr>
#     <tr>
#       <th id="T_a4b84_level0_row1" class="row_heading level0 row1" >16</th>
#       <td id="T_a4b84_row1_col0" class="data row1 col0" >AMAT</td>
#       <td id="T_a4b84_row1_col1" class="data row1 col1" >⭐</td>
#       <td id="T_a4b84_row1_col2" class="data row1 col2" >🔄 30-90 DTE</td>
#       <td id="T_a4b84_row1_col3" class="data row1 col3" >$290 2026-03-20 (40d)</td>
#       <td id="T_a4b84_row1_col4" class="data row1 col4" >$44.77</td>
#       <td id="T_a4b84_row1_col5" class="data row1 col5" >+3.8%</td>
#       <td id="T_a4b84_row1_col6" class="data row1 col6" >7x</td>
#       <td id="T_a4b84_row1_col7" class="data row1 col7" >40%</td>
#       <td id="T_a4b84_row1_col8" class="data row1 col8" >64</td>
#       <td id="T_a4b84_row1_col9" class="data row1 col9" >17</td>
#       <td id="T_a4b84_row1_col10" class="data row1 col10" >40</td>
#     </tr>
#     <tr>
#       <th id="T_a4b84_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_a4b84_row2_col0" class="data row2 col0" >AMAT</td>
#       <td id="T_a4b84_row2_col1" class="data row2 col1" >⭐</td>
#       <td id="T_a4b84_row2_col2" class="data row2 col2" >🏗️ 300+ DTE</td>
#       <td id="T_a4b84_row2_col3" class="data row2 col3" >$270 2026-06-18 (130d)</td>
#       <td id="T_a4b84_row2_col4" class="data row2 col4" >$73.75</td>
#       <td id="T_a4b84_row2_col5" class="data row2 col5" >+6.6%</td>
#       <td id="T_a4b84_row2_col6" class="data row2 col6" >4x</td>
#       <td id="T_a4b84_row2_col7" class="data row2 col7" >38%</td>
#       <td id="T_a4b84_row2_col8" class="data row2 col8" >65</td>
#       <td id="T_a4b84_row2_col9" class="data row2 col9" >17</td>
#       <td id="T_a4b84_row2_col10" class="data row2 col10" >51</td>
#     </tr>
#     <tr>
#       <th id="T_a4b84_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_a4b84_row3_col0" class="data row3 col0" >AMZN</td>
#       <td id="T_a4b84_row3_col1" class="data row3 col1" ></td>
#       <td id="T_a4b84_row3_col2" class="data row3 col2" >⚡ <30 DTE</td>
#       <td id="T_a4b84_row3_col3" class="data row3 col3" >$205 2026-02-20 (12d)</td>
#       <td id="T_a4b84_row3_col4" class="data row3 col4" >$8.55</td>
#       <td id="T_a4b84_row3_col5" class="data row3 col5" >+1.5%</td>
#       <td id="T_a4b84_row3_col6" class="data row3 col6" >25x</td>
#       <td id="T_a4b84_row3_col7" class="data row3 col7" >40%</td>
#       <td id="T_a4b84_row3_col8" class="data row3 col8" >47</td>
#       <td id="T_a4b84_row3_col9" class="data row3 col9" >63</td>
#       <td id="T_a4b84_row3_col10" class="data row3 col10" >54</td>
#     </tr>
#     <tr>
#       <th id="T_a4b84_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_a4b84_row4_col0" class="data row4 col0" >AMZN</td>
#       <td id="T_a4b84_row4_col1" class="data row4 col1" ></td>
#       <td id="T_a4b84_row4_col2" class="data row4 col2" >🔄 30-90 DTE</td>
#       <td id="T_a4b84_row4_col3" class="data row4 col3" >$190 2026-03-20 (40d)</td>
#       <td id="T_a4b84_row4_col4" class="data row4 col4" >$23.77</td>
#       <
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b6223149-422d-48b5-92e2-0857c8a1291c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b6223149-422d-48b5-92e2-0857c8a1291c")) {                    Plotly.newPlot(                        "b6223149-422d-48b5-92e2-0857c8a1291c",                        [{"hovertemplate":"Bucket=\u26a1 \u003c30 DTE\u003cbr\u003eDTE=%{x}\u003cbr\u003eCombo Score (Edge + Bounce)=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u26a1 \u003c30 DTE","marker":{"color":"#e74c3c","size":{"dtype":"f8","bdata":"2mxn2T\u002fmIkBpQl7YusgwQF9AfwFNmThANcJyT4MQMUDt2LFjJ7UgQILUTUyIcilAovPVPRLiK0BFoZuSKm0pQKqqqqpNsStAY8Wjcp9vIEDH4hqL+9QhQLdt27aLvDdA1ofG+ouSJ0AV95eXmNIqQBIpRdlxciVA"},"sizemode":"area","sizeref":0.03935813002558479,"symbol":"circle"},"mode":"markers+text","name":"\u26a1 \u003c30 DTE","orientation":"v","showlegend":true,"text":["MSFT","MSFT","AMZN","AMZN","SNPS","SNPS","KLAC","KLAC","UBER","ISRG","ISRG","UBER","LRCX","LRCX","AMAT"],"x":{"dtype":"i1","bdata":"DAwMDAwMDAwMDAwMEwwM"},"xaxis":"x","y":{"dtype":"f8","bdata":"W36W9RihTED8L71vv49MQCSkQXL3\u002fEpAMICzmx7RSkBTM\u002fguZfVIQB5ER3o3fUhAb8HR1A8SR0CkhiXCUxFHQP3LsRxk40ZA8RqE+82PRkBWvPDL4wxGQCpg0grwr0VAbnHpNdZCRUAxUnBgA0FFQOKcT6LmBEVA"},"yaxis":"y","type":"scatter","textfont":{"size":9},"textposition":"top center"},{"hovertemplate":"Bucket=\ud83d\udd04 30-90 DTE\u003cbr\u003eDTE=%{x}\u003cbr\u003eCombo Score (Edge + Bounce)=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud83d\udd04 30-90 DTE","marker":{"color":"#f39c12","size":{"dtype":"f8","bdata":"OGsfSWGpIUBAWkAy2BEgQAdRxfVJsSFAxjuqWS9aJUCTOAFphiUbQB0W7QamxCFAOWuiANKbHEBldqMWK9ceQO7TkWyfjh5Ai2Mwgj2TIUCa7mC\u002fcQktQHqgcnYD2yFATSHQFNIMHkA9rLX3xc8cQHdnH5A+kR5A"},"sizemode":"area","sizeref":0.03935813002558479,"symbol":"circle"},"mode":"markers+text","name":"\ud83d\udd04 30-90 DTE","orientation":"v","showlegend":true,"text":["MSFT","MSFT","AMZN","AMZN","SNPS","SNPS","KLAC","KLAC","ISRG","ISRG","UBER","UBER","LRCX","AMAT","TSM"],"x":{"dtype":"i1","bdata":"KCgoKCgoKCgoKCgoKCgo"},"xaxis":"x","y":{"dtype":"f8","bdata":"Jjpny9hDTkAKA3OKHStOQPQXoa0vAExAxvCjJQxjS0BxpVpQtllJQNcF6M\u002fLSkhAMUMEYSsKSEBA1WWy\u002fEhHQEga8hv3F0dAamzSVNYER0BN0kP1V3VGQACzsSc4TUZAFm8u2MYIRUDW4uEpHjxEQKy+fRF680NA"},"yaxis":"y","type":"scatter","textfont":{"size":9},"textposition":"top center"},{"hovertemplate":"Bucket=\ud83c\udfd7\ufe0f 300+ DTE\u003cbr\u003eDTE=%{x}\u003cbr\u003eCombo Score (Edge + Bounce)=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud83c\udfd7\ufe0f 300+ DTE","marker":{"color":"#2ecc71","size":{"dtype":"f8","bdata":"QnpxiEJ1HkAGnTwXWcoYQLmtaYVG2RlApQsCSdC8EUBXZrnRI38TQPAQNgUYaBVA9uvOoXLxDkA3E3huKlYRQI1k1le43RRASHVOrplWGEByu5gw+H0RQBX\u002fpkbFfhJAyCR0EJ4jEEAN4zQI9GgOQOkVPoV5nA9A"},"sizemode":"area","sizeref":0.03935813002558479,"symbol":"circle"},"mode":"markers+text","name":"\ud83c\udfd7\ufe0f 300+ DTE","orientation":"v","showlegend":true,"text":["KLAC","MSFT","MSFT","KLAC","AMZN","AMZN","LRCX","LRCX","CMI","CMI","AMAT","AMAT","SNPS","SNPS","STX"],"x":{"dtype":"i2","bdata":"3gCCAGAAggCCAIIAggCCAIIAggCCAGAA3gDeAIIA"},"xaxis":"x","y":{"dtype":"f8","bdata":"coqX9K4LUUCeedLFNj1NQIYbUlhJ70xAa88exGKFS0BcrucP1RJKQHE7IVuB+klAkijbt0LySUAqpwXfo7dJQGsHks3BqklAO7hKoNJwSUBXLAv4XWdJQA2dpvJHS0lArD27EUr4SEAn7P6UQuNIQDdd6DsGiEhA"},"yaxis":"y","type":"scatter","textfont":{"size":9},"textposition":"top center"}],                        {"template":{"data":{"histogram2dcon ...

# %% [markdown]
# ---
#
# ## 🏆 Dynamic Pick Engine — Auto-Selects Best Calls
#
# Picks are chosen algorithmically — no hardcoded trades. Re-run any time for fresh results.
#
# ### Scoring Factors
#
# | Factor            | What It Measures                                            | Source                        |
# | ----------------- | ----------------------------------------------------------- | ----------------------------- |
# | **Sharpe Ratio**  | Stock's excess return / volatility (risk-adjusted quality)  | 6M daily returns vs risk-free |
# | **Sortino Ratio** | Excess return / target downside deviation (penalises drops) | 6M daily returns (proper TDD) |
# | **Calmar Ratio**  | Return / max drawdown (recovery ability)                    | 6M price history              |
# | **Win Rate**      | % of positive daily returns (consistency)                   | 6M daily returns              |
# | **Edge Score**    | P(Profit), IV vs HV, momentum, breakeven, style, liquidity  | BSM + technicals              |
# | **Bounce Score**  | RSI, Stochastic, Bollinger, MACD, support levels            | Technical indicators          |
# | **Risk/Reward**   | Expected return at +10% move vs max loss (premium)          | Scenario analysis             |
#
# ### Selection Rules per Bucket
#
# - **⚡ <30 DTE**: Top 3 by Final Score (Combo 40%, R/R 25%, Win Rate 20%, Sharpe 15%), max 1 per ticker
# - **🔄 30-90 DTE**: Top 3 by Final Score (Combo 35%, Sharpe 20%, Sortino 15%, R/R 15%, Win 15%), max 1 per ticker
# - **🏗️ 300+ DTE**: Top 3 by Final Score (Combo 30%, Sortino 20%, Calmar 15%, Sharpe 15%, R/R 10%, Win 10%), max 1 per ticker
#
# ### Methodology Notes & Caveats
#
# | Item               | Detail                                                                                                                            |
# | ------------------ | --------------------------------------------------------------------------------------------------------------------------------- |
# | **P(Profit)**      | Uses BSM risk-neutral probability (drift = r, not μ). Conservative — real-world probability is higher due to equity risk premium. |
# | **RSI**            | Wilder's exponential smoothing (EWM com=13), matching industry standard.                                                          |
# | **Sortino**        | Target downside deviation: √(mean(min(r − r_f, 0)²)) × √252. Includes zero contributions from up days.                            |
# | **IV vs HV**       | Compares option IV to 30-day realised vol. For LEAPS, long-term HV may differ from HV30 (vol term structure).                     |
# | **R/R**            | Intrinsic value at expiry only. For LEAPS, early-exit value would include time value → R/R is understated.                        |
# | **Annualisation**  | Sharpe/Calmar use arithmetic mean × 252. Geometric (CAGR) would be slightly lower for volatile stocks.                            |
# | **Risk-Free Rate** | 4.5% annualised (T-bill proxy), applied consistently to BSM, Sharpe, and Sortino.                                                 |

# %%
# ══════════════════════════════════════════════════════════════════
#  🏆  DYNAMIC PICK ENGINE — computes ratios, auto-selects best
# ══════════════════════════════════════════════════════════════════

PICKS_PER_BUCKET = 3

# ──────────────────────────────────────────────────────────────────
# 1.  Compute per-ticker ratios from daily returns (6-month window)
# ──────────────────────────────────────────────────────────────────
print("Computing Sharpe / Sortino / Calmar / Win Rate per ticker …\n")

ticker_ratios = {}
for ticker in ALL_TICKERS:
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        hist = t.history(period="6mo")
        if hist.empty or len(hist) < 60:
            continue
        closes = hist["Close"].dropna()
        daily_ret = closes.pct_change().dropna()

        # Annualised return & vol
        ann_ret = float(daily_ret.mean() * 252)
        ann_vol = float(daily_ret.std() * np.sqrt(252))

        # Sharpe
        sharpe = (ann_ret - RISK_FREE_RATE) / ann_vol if ann_vol > 0 else 0

        # Sortino (target downside deviation — proper formulation)
        daily_rf = RISK_FREE_RATE / 252
        diff_below = np.minimum(daily_ret - daily_rf, 0)
        down_vol = (
            float(np.sqrt(np.mean(diff_below**2)) * np.sqrt(252))
            if len(daily_ret) > 20
            else ann_vol
        )
        sortino = (ann_ret - RISK_FREE_RATE) / down_vol if down_vol > 0 else 0

        # Calmar (return / max drawdown)
        cum = (1 + daily_ret).cumprod()
        peak = cum.cummax()
        drawdown = (cum - peak) / peak
        max_dd = float(drawdown.min())  # negative
        calmar = ann_ret / abs(max_dd) if max_dd != 0 else 0

        # Win rate
        win_rate = float((daily_ret > 0).sum() / len(daily_ret))

        # Beta vs SPY proxy — use simple correlation of returns if we have it
        # (We don't fetch SPY here, so approximate beta from vol ratio)
        beta_approx = ann_vol / 0.16  # assume SPY ~16% vol

        ticker_ratios[ticker] = {
            "ann_ret": ann_ret,
            "ann_vol": ann_vol,
            "sharpe": sharpe,
            "sortino": sortino,
            "calmar": calmar,
            "max_dd": max_dd,
            "win_rate": win_rate,
            "beta": beta_approx,
        }
        flag = "🟢" if sharpe > 0.5 else "🟡" if sharpe > 0 else "🔴"
        print(
            f"  {flag} {ticker:5s}  Sharpe={sharpe:+.2f}  Sortino={sortino:+.2f}  "
            f"Calmar={calmar:+.2f}  MaxDD={max_dd:+.1%}  WinRate={win_rate:.0%}  "
            f"AnnRet={ann_ret:+.1%}  AnnVol={ann_vol:.1%}"
        )
    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

print(f"\n✅ Ratios computed for {len(ticker_ratios)} tickers")

# ──────────────────────────────────────────────────────────────────
# 2.  Enrich unified_df with ratios + risk/reward
# ──────────────────────────────────────────────────────────────────

# Merge ratios onto unified_df
ratio_df = (
    pd.DataFrame(ticker_ratios).T.reset_index().rename(columns={"index": "Ticker"})
)
ratio_df = ratio_df.rename(
    columns={
        "sharpe": "Sharpe",
        "sortino": "Sortino",
        "calmar": "Calmar",
        "max_dd": "Max DD",
        "win_rate": "Win Rate",
        "ann_ret": "Ann Ret",
        "ann_vol": "Ann Vol",
        "beta": "Beta",
    }
)

# Drop old ratio columns if re-running
for c in [
    "Sharpe",
    "Sortino",
    "Calmar",
    "Max DD",
    "Win Rate",
    "Ann Ret",
    "Ann Vol",
    "Beta",
    "R/R",
    "Final Score",
]:
    if c in unified_df.columns:
        unified_df = unified_df.drop(columns=[c])

unified_df = unified_df.merge(
    ratio_df[
        [
            "Ticker",
            "Sharpe",
            "Sortino",
            "Calmar",
            "Max DD",
            "Win Rate",
            "Ann Ret",
            "Ann Vol",
            "Beta",
        ]
    ],
    on="Ticker",
    how="left",
)


# Risk/Reward: expected return at +10% stock move vs max loss (premium)
def calc_rr(row):
    spot = row["Spot"]
    strike = row["Strike"]
    mid = row["Mid"]
    if mid <= 0 or spot <= 0:
        return np.nan
    upside_spot = spot * 1.10
    payout = max(upside_spot - strike, 0)
    gain = (payout - mid) / mid  # % return if stock +10%
    loss = -1.0  # max loss = 100% of premium
    return gain / abs(loss) if loss != 0 else gain  # reward-to-risk


unified_df["R/R"] = unified_df.apply(calc_rr, axis=1)

# ──────────────────────────────────────────────────────────────────
# 3.  Final Score — bucket-specific weighting
# ──────────────────────────────────────────────────────────────────


def final_score(row):
    combo = row["Combo Score"] if not np.isnan(row["Combo Score"]) else 0
    sharpe = row.get("Sharpe", 0) if not np.isnan(row.get("Sharpe", np.nan)) else 0
    sortino = row.get("Sortino", 0) if not np.isnan(row.get("Sortino", np.nan)) else 0
    rr = row.get("R/R", 0) if not np.isnan(row.get("R/R", np.nan)) else 0
    win = row.get("Win Rate", 0.5) if not np.isnan(row.get("Win Rate", np.nan)) else 0.5
    calmar = row.get("Calmar", 0) if not np.isnan(row.get("Calmar", np.nan)) else 0

    # Normalize ratios to ~0-100 scale
    sharpe_n = np.clip((sharpe + 1) * 33, 0, 100)  # -1→0, 0→33, 2→100
    sortino_n = np.clip((sortino + 1) * 25, 0, 100)  # wider range
    rr_n = np.clip(rr * 20, 0, 100)  # 0→0, 5→100
    win_n = np.clip(win * 100 - 20, 0, 100)  # 50%→30, 60%→40
    calmar_n = np.clip(calmar * 25, 0, 100)  # 0→0, 4→100

    bucket = row["Bucket"]
    if bucket == "⚡ <30 DTE":
        # Short-term: care about momentum (Combo), risk/reward, win rate
        return combo * 0.40 + rr_n * 0.25 + sharpe_n * 0.15 + win_n * 0.20
    elif bucket == "🔄 30-90 DTE":
        # Medium: balanced — sharpe + combo + sortino
        return (
            combo * 0.35
            + sharpe_n * 0.20
            + sortino_n * 0.15
            + rr_n * 0.15
            + win_n * 0.15
        )
    else:
        # LEAPS: quality matters most — sortino, calmar, combo
        return (
            combo * 0.30
            + sortino_n * 0.20
            + calmar_n * 0.15
            + sharpe_n * 0.15
            + rr_n * 0.10
            + win_n * 0.10
        )


unified_df["Final Score"] = unified_df.apply(final_score, axis=1)

# ──────────────────────────────────────────────────────────────────
# 4.  Auto-select picks per bucket
# ──────────────────────────────────────────────────────────────────

display(Markdown("---\n# 🏆 Auto-Selected Picks\n"))

bucket_configs = [
    (
        "⚡ <30 DTE",
        "⚡ Short-Term Swings",
        "Quick directional bets — high leverage, tight risk. Prioritises R/R asymmetry + win rate.",
    ),
    (
        "🔄 30-90 DTE",
        "🔄 Medium-Term Bounce & Recovery",
        "1-3 month horizon for oversold reversals. Sharpe & Sortino weigh quality of the underlying move.",
    ),
    (
        "🏗️ 300+ DTE",
        "🏗️ LEAPS — Conviction Holds",
        "Stock replacement & deep-ITM compounding. Sortino + Calmar reward consistent upside with limited drawdowns.",
    ),
]

all_auto_picks = []

for bucket_key, title, desc in bucket_configs:
    sub = unified_df[unified_df["Bucket"] == bucket_key].copy()
    if sub.empty:
        display(Markdown(f"\n### {title}\n*No options in this bucket.*"))
        continue

    # Pick best 1 per ticker, then top N
    top = (
        sub.sort_values("Final Score", ascending=False)
        .groupby("Ticker")
        .head(1)
        .sort_values("Final Score", ascending=False)
        .head(PICKS_PER_BUCKET)
        .reset_index(drop=True)
    )

    display(Markdown(f"\n### {title}"))
    display(Markdown(f"*{desc}*"))

    # Detailed card per pick
    for rank, (_, r) in enumerate(top.iterrows(), 1):
        pp_str = f"{r['P(Profit)']:.0%}" if not np.isnan(r["P(Profit)"]) else "—"
        be_str = f"{r['Breakeven %']:+.1%}" if not np.isnan(r["Breakeven %"]) else "—"
        sharpe_val = r.get("Sharpe", np.nan)
        sortino_val = r.get("Sortino", np.nan)
        calmar_val = r.get("Calmar", np.nan)
        maxdd_val = r.get("Max DD", np.nan)
        winr_val = r.get("Win Rate", np.nan)
        rr_val = r.get("R/R", np.nan)
        bounce_val = r.get("Bounce Score", 0)
        conv = "⭐ " if r["Ticker"] in CONVICTION else ""

        # Auto-generate thesis based on data
        reasons = []
        if not np.isnan(sharpe_val) and sharpe_val > 0.5:
            reasons.append(
                f"Strong Sharpe ({sharpe_val:+.2f}) — quality risk-adjusted returns"
            )
        elif not np.isnan(sharpe_val) and sharpe_val < -0.5:
            reasons.append(
                f"Negative Sharpe ({sharpe_val:+.2f}) — contrarian bounce play"
            )
        if not np.isnan(sortino_val) and sortino_val > 0.5:
            reasons.append(
                f"Sortino {sortino_val:+.2f} — upside moves dominate downside"
            )
        if not np.isnan(calmar_val) and calmar_val > 1.0:
            reasons.append(f"Calmar {calmar_val:.1f} — strong recovery from drawdowns")
        if not np.isnan(maxdd_val) and maxdd_val > -0.15:
            reasons.append(f"Shallow max drawdown ({maxdd_val:.0%})")
        if not np.isnan(winr_val) and winr_val > 0.53:
            reasons.append(f"Win rate {winr_val:.0%} — more up days than down")
        if bounce_val >= 50:
            reasons.append(
                f"Bounce Score {bounce_val:.0f} — multiple oversold indicators firing"
            )
        elif bounce_val >= 30:
            reasons.append(
                f"Bounce Score {bounce_val:.0f} — developing reversal signals"
            )
        if not np.isnan(rr_val) and rr_val > 2:
            reasons.append(f"R/R = {rr_val:.1f}x at +10% stock move")
        if r["Moneyness"] < 0.88:
            reasons.append(
                f"Deep ITM ({r['Moneyness']:.0%}) — high delta, stock replacement"
            )
        if not np.isnan(r.get("RSI", np.nan)) and r["RSI"] < 30:
            reasons.append(f"RSI {r['RSI']:.0f} — oversold")
        if r["Ticker"] in CONVICTION:
            reasons.append("Conviction name ⭐")

        why_text = (
            ". ".join(reasons) if reasons else "Scored highest in composite ranking."
        )

        # Risk auto-generated
        risks = []
        if r["DTE"] < 20:
            risks.append("Very short runway — needs quick catalyst")
        if not np.isnan(r.get("Ret 1M", np.nan)) and r["Ret 1M"] < -0.10:
            risks.append(f"Down {r['Ret 1M']:.0%} in last month — could keep falling")
        if not np.isnan(maxdd_val) and maxdd_val < -0.25:
            risks.append(f"Deep drawdown history ({maxdd_val:.0%})")
        if not np.isnan(r["IV"]) and r["IV"] > 0.50:
            risks.append(f"Elevated IV ({r['IV']:.0%}) — paying up for premium")
        if r.get("OI", 0) < 50:
            risks.append("Low open interest — wide spreads likely")
        risk_text = ". ".join(risks) if risks else "Standard directional risk."

        # Sizing logic
        if r["DTE"] < 30:
            sizing = "Small (1-2%)"
        elif r["DTE"] <= 90:
            sizing = "Medium (2-4%)"
        elif r["Moneyness"] < 0.85:
            sizing = "Large (5-8%) — stock replacement"
        else:
            sizing = "Medium (2-4%)"

        display(
            Markdown(
                f"#### #{rank} {conv}{r['Ticker']} — ${r['Strike']:,.0f} {r['Expiry']}  ({r['DTE']}d)\n"
                f"| Metric | Value | | Metric | Value |\n"
                f"|--------|-------|-|--------|-------|\n"
                f"| Entry | **${r['Mid']:,.2f}** (${r['Mid'] * 100:,.0f}/ct) | "
                f"| Sharpe | {sharpe_val:+.2f} |\n"
                f"| Breakeven | {be_str} from spot | "
                f"| Sortino | {sortino_val:+.2f} |\n"
                f"| Leverage | {r['Leverage']:.0f}x | "
                f"| Calmar | {calmar_val:+.2f} |\n"
                f"| P(Profit) | {pp_str} | "
                f"| Max DD | {maxdd_val:.0%} |\n"
                f"| R/R @+10% | {rr_val:.1f}x | "
                f"| Win Rate | {winr_val:.0%} |\n"
                f"| Edge / Bounce | {r['Edge Score']:.0f} / {bounce_val:.0f} | "
                f"| **Final Score** | **{r['Final Score']:.0f}** |\n"
                f"| Sizing | {sizing} | | | |\n\n"
                f"**Why:** {why_text}\n\n"
                f"**Risk:** {risk_text}"
            )
        )

    all_auto_picks.append(top)

# ══════════════════════════════════════════════════════════════════
# Summary table — all picks at a glance
# ══════════════════════════════════════════════════════════════════

display(Markdown("\n---\n### 📋 All Picks at a Glance\n"))

if all_auto_picks:
    summary = pd.concat(all_auto_picks, ignore_index=True)

    sum_cols = [
        "Bucket",
        "Ticker",
        "Conviction",
        "Expiry",
        "DTE",
        "Strike",
        "Moneyness",
        "Mid",
        "Breakeven %",
        "Leverage",
        "P(Profit)",
        "Sharpe",
        "Sortino",
        "Calmar",
        "Max DD",
        "Win Rate",
        "R/R",
        "Edge Score",
        "Bounce Score",
        "Final Score",
    ]
    sa = [c for c in sum_cols if c in summary.columns]

    display(
        summary[sa]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Mid": "${:,.2f}",
                "Moneyness": "{:.0%}",
                "Breakeven %": "{:+.1%}",
                "Leverage": "{:.0f}x",
                "P(Profit)": "{:.0%}",
                "Sharpe": "{:+.2f}",
                "Sortino": "{:+.2f}",
                "Calmar": "{:+.2f}",
                "Max DD": "{:.0%}",
                "Win Rate": "{:.0%}",
                "R/R": "{:.1f}x",
                "Edge Score": "{:.0f}",
                "Bounce Score": "{:.0f}",
                "Final Score": "{:.0f}",
            },
            na_rep="—",
        )
        .background_gradient(subset=["Final Score"], cmap="RdYlGn", vmin=30, vmax=65)
        .background_gradient(subset=["Sharpe"], cmap="RdYlGn", vmin=-1, vmax=2)
        .background_gradient(subset=["R/R"], cmap="Greens", vmin=0, vmax=5)
        .set_caption("Auto-selected picks — ranked by Final Score per bucket")
    )

# ══════════════════════════════════════════════════════════════════
# Scenario P&L for all auto-picks
# ══════════════════════════════════════════════════════════════════

display(Markdown("\n### 💰 Return Scenarios — All Picks\n"))

if all_auto_picks:
    scen_all = []
    for _, r in summary.iterrows():
        for m in [-0.05, 0.05, 0.10, 0.15, 0.25]:
            new_spot = r["Spot"] * (1 + m)
            payout = max(new_spot - r["Strike"], 0)
            ret = (payout - r["Mid"]) / r["Mid"] if r["Mid"] > 0 else 0
            scen_all.append(
                {
                    "Bucket": r["Bucket"],
                    "Ticker": r["Ticker"],
                    "Strike": f"${r['Strike']:,.0f}",
                    "DTE": int(r["DTE"]),
                    "Cost": f"${r['Mid']:,.2f}",
                    "Move": m,
                    "Return": ret,
                }
            )
    scen_all_df = pd.DataFrame(scen_all)
    piv = scen_all_df.pivot_table(
        index=["Bucket", "Ticker", "Strike", "DTE", "Cost"],
        columns="Move",
        values="Return",
    )
    piv.columns = [f"{c:+.0%}" for c in piv.columns]
    display(
        piv.style.format("{:+.0%}", na_rep="—")
        .background_gradient(cmap="RdYlGn", vmin=-1.0, vmax=3.0, axis=None)
        .set_caption("Return at expiry if stock moves — all auto-picks")
    )

# ══════════════════════════════════════════════════════════════════
# Ratio comparison chart
# ══════════════════════════════════════════════════════════════════

display(Markdown("\n### 📊 Ratio Dashboard — Picked Tickers\n"))

if all_auto_picks:
    picked_tickers = summary["Ticker"].unique().tolist()
    ratio_plot = ratio_df[ratio_df["Ticker"].isin(picked_tickers)].copy()

    fig_ratios = go.Figure()
    fig_ratios.add_trace(
        go.Bar(
            name="Sharpe",
            x=ratio_plot["Ticker"],
            y=ratio_plot["Sharpe"],
            marker_color="#3498db",
        )
    )
    fig_ratios.add_trace(
        go.Bar(
            name="Sortino",
            x=ratio_plot["Ticker"],
            y=ratio_plot["Sortino"],
            marker_color="#2ecc71",
        )
    )
    fig_ratios.add_trace(
        go.Bar(
            name="Calmar",
            x=ratio_plot["Ticker"],
            y=ratio_plot["Calmar"],
            marker_color="#e67e22",
        )
    )
    fig_ratios.update_layout(
        barmode="group",
        title="Risk-Adjusted Ratios — Picked Tickers",
        yaxis_title="Ratio Value",
        height=400,
    )
    fig_ratios.add_hline(y=0, line_dash="dot", line_color="gray")
    fig_ratios.show()

    # Scatter: Final Score vs Sharpe
    fig_fs = px.scatter(
        summary,
        x="Sharpe",
        y="Final Score",
        text="Ticker",
        color="Bucket",
        size="Leverage",
        size_max=25,
        color_discrete_map={
            "⚡ <30 DTE": "#e74c3c",
            "🔄 30-90 DTE": "#f39c12",
            "🏗️ 300+ DTE": "#2ecc71",
        },
        title="Final Score vs Sharpe Ratio (size = leverage)",
    )
    fig_fs.update_traces(textposition="top center")
    fig_fs.show()
# Out:
# Computing Sharpe / Sortino / Calmar / Win Rate per ticker …
#
#   🟢 WDC    Sharpe=+4.13  Sortino=+7.80  Calmar=+14.53  MaxDD=-20.1%  WinRate=62%  AnnRet=+292.2%  AnnVol=69.7%
#   🟢 GEV    Sharpe=+0.91  Sortino=+1.45  Calmar=+3.03  MaxDD=-16.6%  WinRate=48%  AnnRet=+50.3%  AnnVol=50.4%
#   🟢 STX    Sharpe=+3.34  Sortino=+6.39  Calmar=+12.40  MaxDD=-19.2%  WinRate=59%  AnnRet=+238.3%  AnnVol=69.9%
#   🟢 LRCX   Sharpe=+3.43  Sortino=+5.56  Calmar=+11.43  MaxDD=-16.1%  WinRate=63%  AnnRet=+184.0%  AnnVol=52.3%
#   🟢 AMAT   Sharpe=+2.55  Sortino=+3.75  Calmar=+7.17  MaxDD=-17.5%  WinRate=60%  AnnRet=+125.8%  AnnVol=47.6%
#   🟢 TSM    Sharpe=+2.20  Sortino=+3.55  Calmar=+7.62  MaxDD=-10.5%  WinRate=54%  AnnRet=+79.7%  AnnVol=34.2%
#   🟢 GE     Sharpe=+1.19  Sortino=+1.70  Calmar=+3.50  MaxDD=-10.7%  WinRate=57%  AnnRet=+37.5%  AnnVol=27.8%
#   🟢 CMI    Sharpe=+2.62  Sortino=+4.03  Calmar=+8.25  MaxDD=-10.7%  WinRate=58%  AnnRet=+88.5%  AnnVol=32.1%
#   🟢 KLAC   Sharpe=+2.04  Sortino=+2.90  Calmar=+4.68  MaxDD=-22.4%  WinRate=60%  AnnRet=+104.9%  AnnVol=49.1%
#   🔴 SNPS   Sharpe=-0.76  Sortino=-0.88  Calmar=-1.23  MaxDD=-38.7%  WinRate=50%  AnnRet=-47.4%  AnnVol=68.4%
#   🔴 META   Sharpe=-0.82  Sortino=-1.13  Calmar=-0.89  MaxDD=-25.4%  WinRate=48%  AnnRet=-22.5%  AnnVol=33.0%
#   🔴 UBER   Sharpe=-1.31  Sortino=-1.67  Calmar=-1.44  MaxDD=-26.2%  WinRate=48%  AnnRet=-37.7%  AnnVol=32.3%
#   🟡 ISRG   Sharpe=+0.25  Sortino=+0.44  Calmar=+0.66  MaxDD=-19.7%  WinRate=46%  AnnRet=+12.9%  AnnVol=32.9%
#   🔴 MSFT   Sharpe=-2.16  Sortino=-2.45  Calmar=-1.78  MaxDD=-27.2%  WinRate=51%  AnnRet=-48.4%  AnnVol=24.5%
#   🔴 AMZN   Sharpe=-0.37  Sortino=-0.53  Calmar=-0.41  MaxDD=-17.2%  WinRate=54%  AnnRet=-7.1%  AnnVol=31.1%
#   🟢 AVGO   Sharpe=+0.54  Sortino=+0.83  Calmar=+1.20  MaxDD=-25.3%  WinRate=54%  AnnRet=+30.3%  AnnVol=47.8%
#
# ✅ Ratios computed for 16 tickers
# ---
# # 🏆 Auto-Selected Picks
# ### ⚡ Short-Term Swings
# *Quick directional bets — high leverage, tight risk. Prioritises R/R asymmetry + win rate.*
# #### #1 CMI — $590 2026-02-20  (12d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$5.90** ($590/ct) | | Sharpe | +2.62 |
# | Breakeven | +3.1% from spot | | Sortino | +4.03 |
# | Leverage | 98x | | Calmar | +8.25 |
# | P(Profit) | 27% | | Max DD | -11% |
# | R/R @+10% | 6.7x | | Win Rate | 58% |
# | Edge / Bounce | 49 / 9 | | **Final Score** | **60** |
# | Sizing | Small (1-2%) | | | |
#
# **Why:** Strong Sharpe (+2.62) — quality risk-adjusted returns. Sortino +4.03 — upside moves dominate downside. Calmar 8.3 — strong recovery from drawdowns. Shallow max drawdown (-11%). Win rate 58% — more up days than down. R/R = 6.7x at +10% stock move
#
# **Risk:** Very short runway — needs quick catalyst
# #### #2 GE — $330 2026-02-20  (12d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$3.85** ($385/ct) | | Sharpe | +1.19 |
# | Breakeven | +4.0% from spot | | Sortino | +1.70 |
# | Leverage | 83x | | Calmar | +3.50 |
# | P(Profit) | 25% | | Max DD | -11% |
# | R/R @+10% | 5.0x | | Win Rate | 57% |
# | Edge / Bounce | 35 / 15 | | **Final Score** | **54** |
# | Sizing | Small (1-2%) | | | |
#
# **Why:** Strong Sharpe (+1.19) — quality risk-adjusted returns. Sortino +1.70 — upside moves dominate downside. Calmar 3.5 — strong recovery from drawdowns. Shallow max drawdown (-11%). Win rate 57% — more up days than down. R/R = 5.0x at +10% stock move
#
# **Risk:** Very short runway — needs quick catalyst
# #### #3 AMZN — $220 2026-02-20  (12d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$1.92** ($192/ct) | | Sharpe | -0.37 |
# | Breakeven | +5.5% from spot | | Sortino | -0.53 |
# | Leverage | 110x | | Calmar | -0.41 |
# | P(Profit) | 19% | | Max DD | -17% |
# | R/R @+10% | 4.9x | | Win Rate | 54% |
# | Edge / Bounce | 33 / 63 | | **Final Score** | **53** |
# | Sizing | Small (1-2%) | | | |
#
# **Why:** Win rate 54% — more up days than down. Bounce Score 63 — multiple oversold indicators firing. R/R = 4.9x at +10% stock move. RSI 29 — oversold
#
# **Risk:** Very short runway — needs quick catalyst. Down -15% in last month — could keep falling
# ### 🔄 Medium-Term Bounce & Recovery
# *1-3 month horizon for oversold reversals. Sharpe & Sortino weigh quality of the underlying move.*
# #### #1 KLAC — $1,280 2026-03-20  (40d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$201.75** ($20,175/ct) | | Sharpe | +2.04 |
# | Breakeven | +2.7% from spot | | Sortino | +2.90 |
# | Leverage | 7x | | Calmar | +4.68 |
# | P(Profit) | 42% | | Max DD | -22% |
# | R/R @+10% | 0.5x | | Win Rate | 60% |
# | Edge / Bounce | 69 / 27 | | **Final Score** | **59** |
# | Sizing | Medium (2-4%) | | | |
#
# **Why:** Strong Sharpe (+2.04) — quality risk-adjusted returns. Sortino +2.90 — upside moves dominate downside. Calmar 4.7 — strong recovery from drawdowns. Win rate 60% — more up days than down
#
# **Risk:** Elevated IV (55%) — paying up for premium
# #### #2 LRCX — $210 2026-03-20  (40d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$30.75** ($3,075/ct) | | Sharpe | +3.43 |
# | Breakeven | +4.2% from spot | | Sortino | +5.56 |
# | Leverage | 8x | | Calmar | +11.43 |
# | P(Profit) | 39% | | Max DD | -16% |
# | R/R @+10% | 0.4x | | Win Rate | 63% |
# | Edge / Bounce | 67 / 17 | | **Final Score** | **58** |
# | Sizing | Medium (2-4%) | | | |
#
# **Why:** Strong Sharpe (+3.43) — quality risk-adjusted returns. Sortino +5.56 — upside moves dominate downside. Calmar 11.4 — strong recovery from drawdowns. Win rate 63% — more up days than down
#
# **Risk:** Elevated IV (62%) — paying up for premium
# #### #3 CMI — $520 2026-03-20  (40d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$62.75** ($6,275/ct) | | Sharpe | +2.62 |
# | Breakeven | +0.9% from spot | | Sortino | +4.03 |
# | Leverage | 9x | | Calmar | +8.25 |
# | P(Profit) | 46% | | Max DD | -11% |
# | R/R @+10% | 0.8x | | Win Rate | 58% |
# | Edge / Bounce | 69 / 9 | | **Final Score** | **57** |
# | Sizing | Medium (2-4%) | | | |
#
# **Why:** Strong Sharpe (+2.62) — quality risk-adjusted returns. Sortino +4.03 — upside moves dominate downside. Calmar 8.3 — strong recovery from drawdowns. Shallow max drawdown (-11%). Win rate 58% — more up days than down
#
# **Risk:** Standard directional risk.
# ### 🏗️ LEAPS — Conviction Holds
# *Stock replacement & deep-ITM compounding. Sortino + Calmar reward consistent upside with limited drawdowns.*
# #### #1 KLAC — $1,160 2026-09-18  (222d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$189.50** ($18,950/ct) | | Sharpe | +2.04 |
# | Breakeven | -6.5% from spot | | Sortino | +2.90 |
# | Leverage | 8x | | Calmar | +4.68 |
# | P(Profit) | 100% | | Max DD | -22% |
# | R/R @+10% | 1.3x | | Win Rate | 60% |
# | Edge / Bounce | 86 / 27 | | **Final Score** | **76** |
# | Sizing | Large (5-8%) — stock replacement | | | |
#
# **Why:** Strong Sharpe (+2.04) — quality risk-adjusted returns. Sortino +2.90 — upside moves dominate downside. Calmar 4.7 — strong recovery from drawdowns. Win rate 60% — more up days than down. Deep ITM (80%) — high delta, stock replacement
#
# **Risk:** Low open interest — wide spreads likely
# #### #2 LRCX — $190 2026-06-18  (130d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$59.73** ($5,972/ct) | | Sharpe | +3.43 |
# | Breakeven | +8.1% from spot | | Sortino | +5.56 |
# | Leverage | 4x | | Calmar | +11.43 |
# | P(Profit) | 36% | | Max DD | -16% |
# | R/R @+10% | 0.1x | | Win Rate | 63% |
# | Edge / Bounce | 67 / 17 | | **Final Score** | **70** |
# | Sizing | Large (5-8%) — stock replacement | | | |
#
# **Why:** Strong Sharpe (+3.43) — quality risk-adjusted returns. Sortino +5.56 — upside moves dominate downside. Calmar 11.4 — strong recovery from drawdowns. Win rate 63% — more up days than down. Deep ITM (82%) — high delta, stock replacement
#
# **Risk:** Elevated IV (71%) — paying up for premium
# #### #3 CMI — $480 2026-06-18  (130d)
# | Metric | Value | | Metric | Value |
# |--------|-------|-|--------|-------|
# | Entry | **$110.75** ($11,075/ct) | | Sharpe | +2.62 |
# | Breakeven | +2.3% from spot | | Sortino | +4.03 |
# | Leverage | 5x | | Calmar | +8.25 |
# | P(Profit) | 44% | | Max DD | -11% |
# | R/R @+10% | 0.4x | | Win Rate | 58% |
# | Edge / Bounce | 69 / 9 | | **Final Score** | **70** |
# | Sizing | Large (5-8%) — stock replacement | | | |
#
# **Why:** Strong Sharpe (+2.62) — quality risk-adjusted returns. Sortino +4.03 — upside moves dominate downside. Calmar 8.3 — strong recovery from drawdowns. Shallow max drawdown (-11%). Win rate 58% — more up days than down. Deep ITM (83%) — high delta, stock replacement
#
# **Risk:** Low open interest — wide spreads likely
# ---
# ### 📋 All Picks at a Glance
# <style type="text/css">
# #T_358c0_row0_col11, #T_358c0_row3_col11, #T_358c0_row4_col11, #T_358c0_row5_col11, #T_358c0_row6_col11, #T_358c0_row6_col19, #T_358c0_row7_col11, #T_358c0_row7_col19, #T_358c0_row8_col11, #T_358c0_row8_col19 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_358c0_row0_col16, #T_358c0_row1_col16 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_358c0_row0_col19 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_358c0_row1_col11 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_358c0_row1_col19 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_358c0_row2_col11 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_358c0_row2_col16 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_358c0_row2_col19 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_358c0_row3_col16 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_358c0_row3_col19 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_358c0_row4_col16 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_358c0_row4_col19 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_358c0_row5_col16 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_358c0_row5_col19 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_358c0_row6_col16 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_358c0_row7_col16 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_358c0_row8_col16 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# </style>
# <table id="T_358c0">
#   <caption>Auto-selected picks — ranked by Final Score per bucket</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_358c0_level0_col0" class="col_heading level0 col0" >Bucket</th>
#       <th id="T_358c0_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_358c0_level0_col2" class="col_heading level0 col2" >Conviction</th>
#       <th id="T_358c0_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_358c0_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_358c0_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_358c0_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_358c0_level0_col7" class="col_heading level0 col7" >Mid</th>
#       <th id="T_358c0_level0_col8" class="col_heading level0 col8" >Breakeven %</th>
#       <th id="T_358c0_level0_col9" class="col_heading level0 col9" >Leverage</th>
#       <th id="T_358c0_level0_col10" class="col_heading level0 col10" >P(Profit)</th>
#       <th id="T_358c0_level0_col11" class="col_heading level0 col11" >Sharpe</th>
#       <th id="T_358c0_level0_col12" class="col_heading level0 col12" >Sortino</th>
#       <th id="T_358c0_level0_col13" class="col_heading level0 col13" >Calmar</th>
#       <th id="T_358c0_level0_col14" class="col_heading level0 col14" >Max DD</th>
#       <th id="T_358c0_level0_col15" class="col_heading level0 col15" >Win Rate</th>
#       <th id="T_358c0_level0_col16" class="col_heading level0 col16" >R/R</th>
#       <th id="T_358c0_level0_col17" class="col_heading level0 col17" >Edge Score</th>
#       <th id="T_358c0_level0_col18" class="col_heading level0 col18" >Bounce Score</th>
#       <th id="T_358c0_level0_col19" class="col_heading level0 col19" >Final Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_358c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_358c0_row0_col0" class="data row0 col0" >⚡ <30 DTE</td>
#       <td id="T_358c0_row0_col1" class="data row0 col1" >CMI</td>
#       <td id="T_358c0_row0_col2" class="data row0 col2" ></td>
#       <td id="T_358c0_row0_col3" class="data row0 col3" >2026-02-20</td>
#       <td id="T_358c0_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_358c0_row0_col5" class="data row0 col5" >$590</td>
#       <td id="T_358c0_row0_col6" class="data row0 col6" >102%</td>
#       <td id="T_358c0_row0_col7" class="data row0 col7" >$5.90</td>
#       <td id="T_358c0_row0_col8" class="data row0 col8" >+3.1%</td>
#       <td id="T_358c0_row0_col9" class="data row0 col9" >98x</td>
#       <td id="T_358c0_row0_col10" class="data row0 col10" >27%</td>
#       <td id="T_358c0_row0_col11" class="data row0 col11" >+2.62</td>
#       <td id="T_358c0_row0_col12" class="data row0 col12" >+4.03</td>
#       <td id="T_358c0_row0_col13" class="data row0 col13" >+8.25</td>
#       <td id="T_358c0_row0_col14" class="data row0 col14" >-11%</td>
#       <td id="T_358c0_row0_col15" class="data row0 col15" >58%</td>
#       <td id="T_358c0_row0_col16" class="data row0 col16" >6.7x</td>
#       <td id="T_358c0_row0_col17" class="data row0 col17" >49</td>
#       <td id="T_358c0_row0_col18" class="data row0 col18" >9</td>
#       <td id="T_358c0_row0_col19" class="data row0 col19" >60</td>
#     </tr>
#     <tr>
#       <th id="T_358c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_358c0_row1_col0" class="data row1 col0" >⚡ <30 DTE</td>
#       <td id="T_358c0_row1_col1" class="data row1 col1" >GE</td>
#       <td id="T_358c0_row1_col2" class="data row1 col2" ></td>
#       <td id="T_358c0_row1_col3" class="data row1 col3" >2026-02-20</td>
#       <td id="T_358c0_row1_col4" class="data row1 col4" >12</td>
#       <td id="T_358c0_row1_col5" class="data row1 col5" >$330</td>
#       <td id="T_358c0_row1_col6" class="data row1 col6" >103%</td>
#       <td id="T_358c0_row1_col7" class="data row1 col7" >$3.85</td>
#       <td id="T_358c0_row1_col8" class="data row1 col8" >+4.0%</td>
#       <td id="T_358c0_row1_col9" class="data row1 col9" >83x</td>
#       <td id="T_358c0_row1_col10" class="data row1 col10" >25%</td>
#       <td id="T_358c0_row1_col11" class="data row1 col11" >+1.19</td>
#       <td id="T_358c0_row1_col12" class="data row1 col12" >+1.70</td>
#       <td id="T_358c0_row1_col13" class="data row1 col13" >+3.50</td>
#       <td id="T_358c0_row1_col14" class="data row1 col14" >-11%</td>
#       <td id="T_358c0_row1_col15" class="data row1 col15" >57%</td>
#       <td id="T_358c0_row1_col16" class="data row1 col16" >5.0x</td>
#       <td id="T_358c0_row1_col17" class="data row1 col17" >35</td>
#       <td id="T_358c0_row1_col18" class="data row1 col18" >15</td>
#       <td id="T_358c0_row1_col19" class="data row1 col19" >54</td>
#     </tr>
#     <tr>
#       <th id="T_358c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_358c0_row2_col0" class="data row2 col0" >⚡ <30 DTE</td>
#       <td id="T_358c0_row2_col1" class="data row2 col1" >AMZN</td>
#       <td id="T_358c0_row2_col2" class="data row2 col2" ></td>
#       <td id="T_358c0_row2_col3" class="data row2 col3" >2026-02-20</td>
#       <td id="T_358c0_row2_col4" class="data row2 col4" >12</td>
#       <td id="T_358c0_row2_col5" class="data row2 col5" >$220</td>
#       <td id="T_358c0_row2_col6" class="data row2 col6" >105%</td>
#       <td id="T_358c0_row2_col7" class="data row2 col7" >$1.92</td>
#       <td id="T_358c0_row2_col8" class="data row2 col8" >+5.5%</td>
#       <td id="T_358c0_row2_col9" class="data row2 col9" >110x</td>
#       <td id="T_358c0_row2_col10" class="data row2 col10" >19%</td>
#       <td id="T_358c0_row2_col11" class="data row2 col11" >-0.37</td>
#       <td id="T_358c0_row2_col12" class="data row2 col12" >-0.53</td>
#       <td id="T_358c0_row2_col13" class="data row2 col13" >-0.41</td>
#       <td id="T_358c0_row2_col14" class="data row2 col14" >-17%</td>
#       <td id="T_358c0_row2_col15" class="data row2 col15" >54%</td>
#       <td id="T_358c0_row2_col16" class="data row2 col16" >4.9x</td>
#       <td id="T_358c0_row2_col17" class="data row2 col17" >33</td>
#       <td id="T_358c0_row2_col18" class="data row2 col18" >63</td>
#       <td id="T_358c0_row2_col19" class="data row2 col19" >53</td>
#     </tr>
#     <tr>
#       <th id="T_358c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_358c0_row3_col0" class="data row3 col0" >🔄 30-90 DTE</td>
#       <td id="T_358c0_row3_col1" class="data row3 col1" >KLAC</td>
#       <td id="T_358c0_row3_col2" class="data row3 col2" ></td>
#       <td id="T_358c0_row3_col3" class="data row3 col3" >2026-0
# ### 💰 Return Scenarios — All Picks
# <style type="text/css">
# #T_a226a_row0_col0, #T_a226a_row1_col0, #T_a226a_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a226a_row0_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_a226a_row0_col2, #T_a226a_row0_col3, #T_a226a_row0_col4, #T_a226a_row1_col2, #T_a226a_row1_col3, #T_a226a_row1_col4, #T_a226a_row2_col2, #T_a226a_row2_col3, #T_a226a_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a226a_row1_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_a226a_row2_col1, #T_a226a_row6_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_a226a_row3_col0 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_a226a_row3_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_a226a_row3_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_a226a_row3_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_a226a_row3_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a226a_row4_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_a226a_row4_col1 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a226a_row4_col2 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_a226a_row4_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_a226a_row4_col4 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_a226a_row5_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_a226a_row5_col1 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_a226a_row5_col2 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_a226a_row5_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_a226a_row5_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_a226a_row6_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_a226a_row6_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_a226a_row6_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_a226a_row6_col4 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_a226a_row7_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a226a_row7_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a226a_row7_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_a226a_row7_col3 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_a226a_row7_col4 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_a226a_row8_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_a226a_row8_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_a226a_row8_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_a226a_row8_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a226a_row8_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# </style>
# <table id="T_a226a">
#   <caption>Return at expiry if stock moves — all auto-picks</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a226a_level0_col0" class="col_heading level0 col0" >-5%</th>
#       <th id="T_a226a_level0_col1" class="col_heading level0 col1" >+5%</th>
#       <th id="T_a226a_level0_col2" class="col_heading level0 col2" >+10%</th>
#       <th id="T_a226a_level0_col3" class="col_heading level0 col3" >+15%</th>
#       <th id="T_a226a_level0_col4" class="col_heading level0 col4" >+25%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th class="index_name level1" >Ticker</th>
#       <th class="index_name level2" >Strike</th>
#       <th class="index_name level3" >DTE</th>
#       <th class="index_name level4" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a226a_level0_row0" class="row_heading level0 row0" rowspan="3">⚡ <30 DTE</th>
#       <th id="T_a226a_level1_row0" class="row_heading level1 row0" >AMZN</th>
#       <th id="T_a226a_level2_row0" class="row_heading level2 row0" >$220</th>
#       <th id="T_a226a_level3_row0" class="row_heading level3 row0" >12</th>
#       <th id="T_a226a_level4_row0" class="row_heading level4 row0" >$1.92</th>
#       <td id="T_a226a_row0_col0" class="data row0 col0" >-100%</td>
#       <td id="T_a226a_row0_col1" class="data row0 col1" >-56%</td>
#       <td id="T_a226a_row0_col2" class="data row0 col2" >+491%</td>
#       <td id="T_a226a_row0_col3" class="data row0 col3" >+1039%</td>
#       <td id="T_a226a_row0_col4" class="data row0 col4" >+2134%</td>
#     </tr>
#     <tr>
#       <th id="T_a226a_level1_row1" class="row_heading level1 row1" >CMI</th>
#       <th id="T_a226a_level2_row1" class="row_heading level2 row1" >$590</th>
#       <th id="T_a226a_level3_row1" class="row_heading level3 row1" >12</th>
#       <th id="T_a226a_level4_row1" class="row_heading level4 row1" >$5.90</th>
#       <td id="T_a226a_row1_col0" class="data row1 col0" >-100%</td>
#       <td id="T_a226a_row1_col1" class="data row1 col1" >+182%</td>
#       <td id="T_a226a_row1_col2" class="data row1 col2" >+671%</td>
#       <td id="T_a226a_row1_col3" class="data row1 col3" >+1161%</td>
#       <td id="T_a226a_row1_col4" class="data row1 col4" >+2140%</td>
#     </tr>
#     <tr>
#       <th id="T_a226a_level1_row2" class="row_heading level1 row2" >GE</th>
#       <th id="T_a226a_level2_row2" class="row_heading level2 row2" >$330</th>
#       <th id="T_a226a_level3_row2" class="row_heading level3 row2" >12</th>
#       <th id="T_a226a_level4_row2" class="row_heading level4 row2" >$3.85</th>
#       <td id="T_a226a_row2_col0" class="data row2 col0" >-100%</td>
#       <td id="T_a226a_row2_col1" class="data row2 col1" >+83%</td>
#       <td id="T_a226a_row2_col2" class="data row2 col2" >+500%</td>
#       <td id="T_a226a_row2_col3" class="data row2 col3" >+917%</td>
#       <td id="T_a226a_row2_col4" class="data row2 col4" >+1751%</td>
#     </tr>
#     <tr>
#       <th id="T_a226a_level0_row3" class="row_heading level0 row3" rowspan="3">🏗️ 300+ DTE</th>
#       <th id="T_a226a_level1_row3" class="row_heading level1 row3" >CMI</th>
#       <th id="T_a226a_level2_row3" class="row_heading level2 row3" >$480</th>
#       <th id="T_a226a_level3_row3" class="row_heading level3 row3" >130</th>
#       <th id="T_a226a_level4_row3" class="row_heading level4 row3" >$110.75</th>
#       <td id="T_a226a_row3_col0" class="data row3 col0" >-38%</td>
#       <td id="T_a226a_row3_col1" class="data row3 col1" >+14%</td>
#       <td id="T_a226a_row3_col2" class="data row3 col2" >+40%</td>
#       <td id="T_a226a_row3_col3" class="data row3 col3" >+66%</td>
#       <td id="T_a226a_row3_col4" class="data row3 col4" >+119%</td>
#     </tr>
#     <tr>
#       <th id="T_a226a_level1_row4" class="row_heading level1 row4" >KLAC</th>
#       <th id="T_a226a_level2_row4" class="row_heading level2 row4" >$1,160</th>
#       <th id="T_a226a_level3_row4" class="row_heading level3 row4" >222</th>
#       <th id="T_a226a_level4_row4" class="row_heading level4 row4" >$189.50</th>
#       <td id="T_a226a_row4_col0" class="data row4 col0" >+11%</td>
#       <td id="T_a226a_row4_col1" class="data row4 col1" >+87%</td>
#       <td id="T_a226a_row4_col2" class="data row4 col2" >+125%</td>
#       <td id="T_a226a_row4_col3" class="data row4 col3" >+164%</td>
#       <td id="T_a226a_row4_col4" class="data row4 col4" >+240%</td>
#     </tr>
#     <tr>
#       <th id="T_a226a_level1_row5" class="row_heading level1 row5" >LRCX</th>
#       <th id="T_a226a_level2_row5" class="row_heading level2 row5" >$190</th>
#       <th id="T_a226a_level3_row5" class="row_heading level3 row5" >130</th>
#       <th id="T_a226a_level4_row5" class="row_heading level4 row5" >$59.73</th>
#       <td id="T_a226a_row5_col0" class="data row5 col0" >-51%</td>
#       <td id="T_a226a_row5_col1" class="data row5 col1" >-12%</td>
#       <td id="T_a226a_row5_col2" class="data row5 col2" >+7%</td>
#       <td id="T_a226a_row5_col3" class="data row5 col3" >+27%</td>
#       <td id="T_a226a_row5_col4" class="data ro
# ### 📊 Ratio Dashboard — Picked Tickers
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e8895bb4-de40-4473-b18e-dd3ef3894c71" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8895bb4-de40-4473-b18e-dd3ef3894c71")) {                    Plotly.newPlot(                        "e8895bb4-de40-4473-b18e-dd3ef3894c71",                        [{"marker":{"color":"#3498db"},"name":"Sharpe","x":["LRCX","GE","CMI","KLAC","AMZN"],"y":{"dtype":"f8","bdata":"hhwoj9RwC0DXllOHT\u002fjyP6V5dl3C8QRAtAi3naFZAEB2gX4fyMPXvw=="},"type":"bar"},{"marker":{"color":"#2ecc71"},"name":"Sortino","x":["LRCX","GE","CMI","KLAC","AMZN"],"y":{"dtype":"f8","bdata":"1MaxBJM7FkB0IchwXTP7P6Rr9MPWHhBAgc+45psvB0DGG\u002f9YeRjhvw=="},"type":"bar"},{"marker":{"color":"#e67e22"},"name":"Calmar","x":["LRCX","GE","CMI","KLAC","AMZN"],"y":{"dtype":"f8","bdata":"NRAIb4HdJkC4hqRz7f8LQBnu7NVfgSBAWHr1Vji6EkATe6mQGj7avw=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"mark ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="73903cd3-12e2-49c9-87a6-415144c7a81a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73903cd3-12e2-49c9-87a6-415144c7a81a")) {                    Plotly.newPlot(                        "73903cd3-12e2-49c9-87a6-415144c7a81a",                        [{"hovertemplate":"Bucket=\u26a1 \u003c30 DTE\u003cbr\u003eSharpe=%{x}\u003cbr\u003eFinal Score=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u26a1 \u003c30 DTE","marker":{"color":"#e74c3c","size":{"dtype":"f8","bdata":"Sd2Xx+Z6WEBrYO+YGthUQKuqqrqqYltA"},"sizemode":"area","sizeref":0.1752666727701823,"symbol":"circle"},"mode":"markers+text","name":"\u26a1 \u003c30 DTE","orientation":"v","showlegend":true,"text":["CMI","GE","AMZN"],"x":{"dtype":"f8","bdata":"pXl2XcLxBEDXllOHT\u002fjyP3aBfh\u002fIw9e\u002f"},"xaxis":"x","y":{"dtype":"f8","bdata":"qKRee8D9TUAmn0n8G9dKQJLJuBiLhUpA"},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Bucket=\ud83d\udd04 30-90 DTE\u003cbr\u003eSharpe=%{x}\u003cbr\u003eFinal Score=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud83d\udd04 30-90 DTE","marker":{"color":"#f39c12","size":{"dtype":"f8","bdata":"OWuiANKbHEBNIdAU0gweQLuLtYroaSJA"},"sizemode":"area","sizeref":0.1752666727701823,"symbol":"circle"},"mode":"markers+text","name":"\ud83d\udd04 30-90 DTE","orientation":"v","showlegend":true,"text":["KLAC","LRCX","CMI"],"x":{"dtype":"f8","bdata":"tAi3naFZAECGHCiP1HALQKV5dl3C8QRA"},"xaxis":"x","y":{"dtype":"f8","bdata":"SNARmgGITUD3IIKnkcZMQC1RlTEfc0xA"},"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Bucket=\ud83c\udfd7\ufe0f 300+ DTE\u003cbr\u003eSharpe=%{x}\u003cbr\u003eFinal Score=%{y}\u003cbr\u003eLeverage=%{marker.size}\u003cbr\u003eTicker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud83c\udfd7\ufe0f 300+ DTE","marker":{"color":"#2ecc71","size":{"dtype":"f8","bdata":"QnpxiEJ1HkD2686hcvEOQI1k1le43RRA"},"sizemode":"area","sizeref":0.1752666727701823,"symbol":"circle"},"mode":"markers+text","name":"\ud83c\udfd7\ufe0f 300+ DTE","orientation":"v","showlegend":true,"text":["KLAC","LRCX","CMI"],"x":{"dtype":"f8","bdata":"tAi3naFZAECGHCiP1HALQKV5dl3C8QRA"},"xaxis":"x","y":{"dtype":"f8","bdata":"KkGAzSkfU0BxZzySFoRRQL3QLHghgFFA"},"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %% [markdown]
# ---
#
# ## 💼 Portfolio Construction Engine — $15k Starting Balance
#
# Builds an optimal, diversified portfolio of call options across tickers and time horizons.
#
# ### How It Works
#
# 1. **Fetch fundamentals** — Forward P/E, PEG, FCF yield, market cap via `yfinance .info`. Compute a Valuation Score (0–100) rewarding cheap + growing names.
# 2. **Correlation matrix** — 6-month daily returns across all tickers. Used to penalise stacking correlated positions (e.g. LRCX + AMAT).
# 3. **Portfolio Score** — Extends Final Score with valuation quality + diversification benefit.
# 4. **Fractional Kelly sizing** — `f* = (p·b − q) / b` capped at 25% Kelly, max 12% of portfolio per position. Converts to real dollar allocations.
# 5. **Greedy builder** — Iteratively selects highest Portfolio Score option that fits remaining balance, enforcing:
#    - Max ~20% of total capital per single ticker (across all buckets)
#    - Target bucket split: ~15–20% short / ~25–30% medium / ~50–60% LEAPS
#    - Correlation penalty: score reduced if ρ > 0.65 with an already-held name
#    - Whole-contract constraint (options = 100 shares, can't buy fractional)
# 6. **Dashboard** — Allocation charts, risk summary, scenario P&L at portfolio level, correlation heatmap.

# %%
# ══════════════════════════════════════════════════════════════════
#  💼  PORTFOLIO CONSTRUCTION ENGINE
# ══════════════════════════════════════════════════════════════════

STARTING_BALANCE = 15_000
MAX_TICKER_PCT = 0.25  # max 25% of capital in any one ticker
MAX_SINGLE_POS_PCT = 0.20  # max 20% per single option position
FRACTIONAL_KELLY = 0.25  # use 25% of full Kelly (conservative)
KELLY_CAP = 0.20  # hard cap Kelly fraction (higher for small accounts)
EDGE_HAIRCUT = 0.90  # haircut BSM P(Profit) by 10% for conservatism
CORRELATION_PENALTY_THRESH = 0.65  # penalise if ρ > this with existing position
MIN_POSITION_COST = 100  # don't bother with positions under $100

# Target bucket allocation (soft targets — greedy builder aims for these)
BUCKET_TARGET = {
    "⚡ <30 DTE": 0.15,  # 15% short-term
    "🔄 30-90 DTE": 0.30,  # 30% medium-term
    "🏗️ 300+ DTE": 0.55,  # 55% LEAPS
}

# ──────────────────────────────────────────────────────────────────
# 1.  FETCH FUNDAMENTALS — valuation data from yfinance .info
# ──────────────────────────────────────────────────────────────────
print("Fetching fundamentals (P/E, PEG, FCF, market cap)…\n")

fundamentals = {}
for ticker in ALL_TICKERS:
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        info = t.info or {}

        fwd_pe = info.get("forwardPE") or info.get("forwardPe")
        trail_pe = info.get("trailingPE") or info.get("trailingPe")
        peg = info.get("pegRatio") or info.get("trailingPegRatio")
        mcap = info.get("marketCap", 0)
        fcf = info.get("freeCashflow", 0)
        ev = info.get("enterpriseValue", 0)
        rev_growth = info.get("revenueGrowth")
        profit_margin = info.get("profitMargins")
        roe = info.get("returnOnEquity")

        # FCF yield = FCF / Market Cap
        fcf_yield = (fcf / mcap * 100) if (mcap and fcf) else None

        fundamentals[ticker] = {
            "fwd_pe": fwd_pe,
            "trail_pe": trail_pe,
            "peg": peg,
            "mcap": mcap,
            "fcf_yield": fcf_yield,
            "rev_growth": rev_growth,
            "profit_margin": profit_margin,
            "roe": roe,
        }

        pe_str = f"FwdPE={fwd_pe:.1f}" if fwd_pe else "FwdPE=—"
        peg_str = f"PEG={peg:.2f}" if peg else "PEG=—"
        fcf_str = f"FCFy={fcf_yield:.1f}%" if fcf_yield else "FCFy=—"
        mcap_str = f"MCap=${mcap / 1e9:.0f}B" if mcap else "MCap=—"
        print(f"  {ticker:5s}  {pe_str:14s}  {peg_str:10s}  {fcf_str:10s}  {mcap_str}")
    except Exception as e:
        print(f"  ⚠ {ticker}: {e}")

print(f"\n✅ Fundamentals for {len(fundamentals)} tickers")


# ──────────────────────────────────────────────────────────────────
# 2.  VALUATION SCORE (0–100)
# ──────────────────────────────────────────────────────────────────


def valuation_score(ticker):
    """Score 0-100: higher = more attractively valued."""
    f = fundamentals.get(ticker, {})
    if not f:
        return 50  # neutral default

    score = 0
    n = 0

    # Forward P/E — lower is better for value, but not too low (value trap)
    fwd_pe = f.get("fwd_pe")
    if fwd_pe and fwd_pe > 0:
        if fwd_pe < 12:
            score += 85
        elif fwd_pe < 18:
            score += 75
        elif fwd_pe < 25:
            score += 60
        elif fwd_pe < 35:
            score += 40
        elif fwd_pe < 50:
            score += 25
        else:
            score += 10
        n += 1

    # PEG ratio — <1 is ideal (cheap relative to growth)
    peg = f.get("peg")
    if peg and peg > 0:
        if peg < 0.8:
            score += 90
        elif peg < 1.2:
            score += 75
        elif peg < 2.0:
            score += 50
        elif peg < 3.0:
            score += 30
        else:
            score += 10
        n += 1

    # FCF yield — higher is better (cash generation)
    fcf_y = f.get("fcf_yield")
    if fcf_y is not None:
        if fcf_y > 6:
            score += 90
        elif fcf_y > 4:
            score += 75
        elif fcf_y > 2:
            score += 55
        elif fcf_y > 0:
            score += 35
        else:
            score += 10  # negative FCF
        n += 1

    # Revenue growth — bonus for growing companies
    rg = f.get("rev_growth")
    if rg is not None:
        if rg > 0.20:
            score += 85
        elif rg > 0.10:
            score += 65
        elif rg > 0.05:
            score += 50
        elif rg > 0:
            score += 35
        else:
            score += 15
        n += 1

    # Profit margin — quality indicator
    pm = f.get("profit_margin")
    if pm is not None:
        if pm > 0.30:
            score += 85
        elif pm > 0.20:
            score += 70
        elif pm > 0.10:
            score += 50
        elif pm > 0:
            score += 30
        else:
            score += 10
        n += 1

    return score / n if n > 0 else 50


val_scores = {t: valuation_score(t) for t in ALL_TICKERS}
val_df = pd.DataFrame(
    [
        {
            "Ticker": t,
            "Val Score": s,
            "Fwd PE": fundamentals.get(t, {}).get("fwd_pe"),
            "PEG": fundamentals.get(t, {}).get("peg"),
            "FCF Yield": fundamentals.get(t, {}).get("fcf_yield"),
            "Rev Growth": fundamentals.get(t, {}).get("rev_growth"),
            "Profit Margin": fundamentals.get(t, {}).get("profit_margin"),
        }
        for t, s in val_scores.items()
    ]
).sort_values("Val Score", ascending=False)

display(Markdown("### 📊 Valuation Scores"))
display(
    val_df.style.format(
        {
            "Val Score": "{:.0f}",
            "Fwd PE": "{:.1f}",
            "PEG": "{:.2f}",
            "FCF Yield": "{:.1f}%",
            "Rev Growth": "{:.1%}",
            "Profit Margin": "{:.1%}",
        },
        na_rep="—",
    )
    .background_gradient(subset=["Val Score"], cmap="RdYlGn", vmin=30, vmax=80)
    .set_caption("Higher = more attractively valued")
)


# ──────────────────────────────────────────────────────────────────
# 3.  CORRELATION MATRIX — 6-month daily returns
# ──────────────────────────────────────────────────────────────────
print("\nBuilding correlation matrix…")

returns_dict = {}
for ticker in ALL_TICKERS:
    try:
        t = yf.Ticker(ticker)
        time.sleep(RATE_LIMIT_SLEEP)
        hist = t.history(period="6mo")
        if not hist.empty and len(hist) > 30:
            returns_dict[ticker] = hist["Close"].pct_change().dropna()
    except Exception:
        pass

returns_matrix = pd.DataFrame(returns_dict)
corr_matrix = returns_matrix.corr()
print(f"✅ Correlation matrix: {corr_matrix.shape[0]}×{corr_matrix.shape[1]}")


# ──────────────────────────────────────────────────────────────────
# 4.  PORTFOLIO SCORE — Final Score + Valuation + Diversification
# ──────────────────────────────────────────────────────────────────

# Merge valuation scores onto unified_df
unified_df["Val Score"] = unified_df["Ticker"].map(val_scores).fillna(50)


def portfolio_score(row):
    """Extend Final Score with valuation quality."""
    fs = row.get("Final Score", 0)
    if np.isnan(fs):
        fs = 0
    vs = row.get("Val Score", 50)

    bucket = row["Bucket"]
    if bucket == "⚡ <30 DTE":
        # Short-term: valuation matters less, momentum matters more
        return fs * 0.85 + vs * 0.15
    elif bucket == "🔄 30-90 DTE":
        # Medium: valuation starts to matter
        return fs * 0.80 + vs * 0.20
    else:
        # LEAPS: valuation matters most — you're a long-term holder
        return fs * 0.70 + vs * 0.30


unified_df["Portfolio Score"] = unified_df.apply(portfolio_score, axis=1)


# ──────────────────────────────────────────────────────────────────
# 5.  FRACTIONAL KELLY SIZING
# ──────────────────────────────────────────────────────────────────


def kelly_fraction(p_profit, rr):
    """Fractional Kelly criterion for position sizing.

    f* = (p*b - q) / b   where p=P(win), q=1-p, b=win/loss ratio
    Then multiply by FRACTIONAL_KELLY for conservatism.
    """
    if np.isnan(p_profit) or np.isnan(rr) or rr <= 0:
        return 0.01  # minimum 1% if we can't compute

    p = min(p_profit * EDGE_HAIRCUT, 0.95)  # haircut + cap
    q = 1 - p
    b = rr  # reward-to-risk ratio

    full_kelly = (p * b - q) / b if b > 0 else 0

    if full_kelly <= 0:
        return 0.005  # tiny allocation for negative-edge (included for diversification)

    frac = full_kelly * FRACTIONAL_KELLY
    return min(frac, KELLY_CAP)


def max_contracts(kelly_frac, balance, cost_per_contract):
    """How many whole contracts can we buy given Kelly fraction and balance."""
    if cost_per_contract <= 0:
        return 0
    dollar_alloc = balance * kelly_frac
    return max(0, int(dollar_alloc // cost_per_contract))


# ──────────────────────────────────────────────────────────────────
# 6.  ROUND-ROBIN PORTFOLIO BUILDER — fills buckets proportionally
# ──────────────────────────────────────────────────────────────────
print("\n" + "═" * 60)
print("  💼  BUILDING PORTFOLIO — Round-Robin Bucket Builder")
print("═" * 60)
print(f"  Starting balance: ${STARTING_BALANCE:,.0f}")
print(f"  Kelly fraction:   {FRACTIONAL_KELLY:.0%} of full Kelly")
print(f"  Edge haircut:     {EDGE_HAIRCUT:.0%} of BSM P(Profit)")
print(f"  Max per ticker:   {MAX_TICKER_PCT:.0%}")
print(f"  Max per position: {MAX_SINGLE_POS_PCT:.0%}")
print(
    f"  Bucket targets:   LEAPS {BUCKET_TARGET['🏗️ 300+ DTE']:.0%} / "
    f"Med {BUCKET_TARGET['🔄 30-90 DTE']:.0%} / "
    f"Short {BUCKET_TARGET['⚡ <30 DTE']:.0%}\n"
)

# Pre-compute Kelly fractions for all candidates
candidates = unified_df.copy()
candidates["Kelly Frac"] = candidates.apply(
    lambda r: kelly_fraction(r.get("P(Profit)", np.nan), r.get("R/R", np.nan)),
    axis=1,
)

# Filter: must have valid cost/score, and at least 1 contract affordable
candidates = candidates[
    (candidates["Cost/Contract"] > 0)
    & (candidates["Portfolio Score"] > 0)
    & (candidates["Cost/Contract"] <= STARTING_BALANCE)
].copy()

# Track state
remaining = STARTING_BALANCE
ticker_allocated = {}  # ticker → total $ allocated
bucket_allocated = {}  # bucket → total $ allocated
selected_tickers = set()  # for correlation penalty
selected_options = set()  # (ticker, strike, expiry) to avoid duplicates
portfolio_rows = []

# Bucket dollar targets
bucket_targets = {b: STARTING_BALANCE * pct for b, pct in BUCKET_TARGET.items()}

# Build candidate pools per bucket, sorted by Portfolio Score
bucket_order = ["🏗️ 300+ DTE", "🔄 30-90 DTE", "⚡ <30 DTE"]  # LEAPS first
bucket_pools = {}
for b in bucket_order:
    pool = candidates[candidates["Bucket"] == b].sort_values(
        "Portfolio Score", ascending=False
    )
    bucket_pools[b] = pool.iterrows()


def try_add_position(
    row,
    remaining,
    ticker_allocated,
    bucket_allocated,
    selected_tickers,
    selected_options,
    portfolio_rows,
):
    """Try to add a single position. Returns (remaining, success)."""
    ticker = row["Ticker"]
    bucket = row["Bucket"]
    cost = row["Cost/Contract"]
    opt_key = (ticker, row["Strike"], row["Expiry"])

    if opt_key in selected_options:
        return remaining, False
    if cost > remaining:
        return remaining, False

    # Ticker concentration
    ticker_total = ticker_allocated.get(ticker, 0)
    if ticker_total >= STARTING_BALANCE * MAX_TICKER_PCT:
        return remaining, False

    # Correlation penalty
    corr_penalty = 1.0
    for held_ticker in selected_tickers:
        if held_ticker in corr_matrix.columns and ticker in corr_matrix.columns:
            rho = corr_matrix.loc[ticker, held_ticker]
            if rho > CORRELATION_PENALTY_THRESH:
                corr_penalty = min(
                    corr_penalty, 1.0 - (rho - CORRELATION_PENALTY_THRESH) * 1.5
                )

    effective_score = row["Portfolio Score"] * max(corr_penalty, 0.3)
    if effective_score < 20:
        return remaining, False

    # Position size
    kelly_f = row["Kelly Frac"]
    min_alloc = min(cost, STARTING_BALANCE * 0.05)
    ticker_room = STARTING_BALANCE * MAX_TICKER_PCT - ticker_total

    dollar_alloc = min(
        remaining,
        max(STARTING_BALANCE * kelly_f, min_alloc),
        STARTING_BALANCE * MAX_SINGLE_POS_PCT,
        ticker_room,
    )

    n_contracts = int(dollar_alloc // cost)
    if n_contracts < 1:
        # Try to squeeze in 1 contract if affordable
        if cost <= remaining and cost <= ticker_room:
            n_contracts = 1
        else:
            return remaining, False

    total_cost = n_contracts * cost
    if total_cost > remaining:
        n_contracts = int(remaining // cost)
        if n_contracts < 1:
            return remaining, False
        total_cost = n_contracts * cost

    # Record
    remaining -= total_cost
    ticker_allocated[ticker] = ticker_allocated.get(ticker, 0) + total_cost
    bucket_allocated[bucket] = bucket_allocated.get(bucket, 0) + total_cost
    selected_tickers.add(ticker)
    selected_options.add(opt_key)

    portfolio_rows.append(
        {
            "Ticker": ticker,
            "Conviction": row.get("Conviction", ""),
            "Bucket": bucket,
            "Expiry": row["Expiry"],
            "DTE": row["DTE"],
            "Strike": row["Strike"],
            "Moneyness": row["Moneyness"],
            "Spot": row["Spot"],
            "Mid": row["Mid"],
            "Contracts": n_contracts,
            "Total Cost": total_cost,
            "% of Portfolio": total_cost / STARTING_BALANCE,
            "Kelly Frac": kelly_f,
            "P(Profit)": row.get("P(Profit)", np.nan),
            "R/R": row.get("R/R", np.nan),
            "Leverage": row["Leverage"],
            "IV": row.get("IV", np.nan),
            "Sharpe": row.get("Sharpe", np.nan),
            "Sortino": row.get("Sortino", np.nan),
            "Val Score": row.get("Val Score", 50),
            "Edge Score": row.get("Edge Score", np.nan),
            "Bounce Score": row.get("Bounce Score", 0),
            "Final Score": row.get("Final Score", np.nan),
            "Portfolio Score": row["Portfolio Score"],
            "Eff. Score": effective_score,
            "Corr Penalty": corr_penalty,
            "Breakeven %": row.get("Breakeven %", np.nan),
            "Max DD": row.get("Max DD", np.nan),
        }
    )

    conv = "⭐" if ticker in CONVICTION else "  "
    bucket_emoji = bucket.split(" ")[0]
    print(
        f"  {conv} {bucket_emoji} {ticker:5s}  ${row['Strike']:,.0f} {row['Expiry']} ({row['DTE']}d)  "
        f"×{n_contracts} = ${total_cost:,.0f}  "
        f"({total_cost / STARTING_BALANCE:.0%} of port)  "
        f"Kelly={kelly_f:.1%}  PScore={effective_score:.0f}"
    )
    return remaining, True


# ── Round-robin allocation: fill each bucket toward its target ──
MAX_ROUNDS = 6  # prevent infinite loops
for round_num in range(MAX_ROUNDS):
    if remaining < 100:
        break

    made_progress = False

    for bucket in bucket_order:
        target = bucket_targets.get(bucket, 0)
        current = bucket_allocated.get(bucket, 0)

        # Skip if bucket is already at/above target (with 20% tolerance)
        if current >= target * 1.2 and round_num < MAX_ROUNDS - 1:
            continue

        # Try adding the next best candidate from this bucket's pool
        pool_iter = bucket_pools[bucket]
        tries = 0
        while tries < 50:  # don't burn through entire pool in one pass
            tries += 1
            try:
                _, row = next(pool_iter)
            except StopIteration:
                break

            remaining, added = try_add_position(
                row,
                remaining,
                ticker_allocated,
                bucket_allocated,
                selected_tickers,
                selected_options,
                portfolio_rows,
            )
            if added:
                made_progress = True
                break

    if not made_progress:
        # Last resort: try any remaining candidate regardless of bucket
        if round_num == MAX_ROUNDS - 1:
            break

        # Re-sort all remaining candidates and try
        all_remaining = candidates[
            ~candidates.apply(
                lambda r: (r["Ticker"], r["Strike"], r["Expiry"]) in selected_options,
                axis=1,
            )
        ].sort_values("Portfolio Score", ascending=False)

        for _, row in all_remaining.head(20).iterrows():
            if remaining < 100:
                break
            remaining, added = try_add_position(
                row,
                remaining,
                ticker_allocated,
                bucket_allocated,
                selected_tickers,
                selected_options,
                portfolio_rows,
            )
            if added:
                made_progress = True

        if not made_progress:
            break

portfolio_df = pd.DataFrame(portfolio_rows)
cash_remaining = remaining

print(f"\n{'─' * 60}")
print(f"  Positions:  {len(portfolio_df)}")
print(
    f"  Tickers:    {portfolio_df['Ticker'].nunique() if not portfolio_df.empty else 0}"
)
print(
    f"  Invested:   ${STARTING_BALANCE - cash_remaining:,.0f} ({(STARTING_BALANCE - cash_remaining) / STARTING_BALANCE:.0%})"
)
print(f"  Cash:       ${cash_remaining:,.0f} ({cash_remaining / STARTING_BALANCE:.0%})")
for b in bucket_order:
    ba = bucket_allocated.get(b, 0)
    bt = bucket_targets.get(b, 0)
    print(
        f"    {b}: ${ba:,.0f} (target ${bt:,.0f}, {'✅' if ba >= bt * 0.7 else '⚠️ under'})"
    )
print(f"{'═' * 60}")


# ══════════════════════════════════════════════════════════════════
# 7.  PORTFOLIO DASHBOARD
# ══════════════════════════════════════════════════════════════════

display(Markdown("---\n# 💼 Portfolio — $15k Call Options Book\n"))

if portfolio_df.empty:
    display(Markdown("❌ No positions could be constructed. Check balance or scoring."))
else:
    # ── Holdings Table ──
    display(Markdown("### 📋 Holdings"))

    hold_cols = [
        "Ticker",
        "Conviction",
        "Bucket",
        "Expiry",
        "DTE",
        "Strike",
        "Moneyness",
        "Mid",
        "Contracts",
        "Total Cost",
        "% of Portfolio",
        "P(Profit)",
        "R/R",
        "Val Score",
        "Portfolio Score",
    ]
    ha = [c for c in hold_cols if c in portfolio_df.columns]

    display(
        portfolio_df[ha]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Mid": "${:,.2f}",
                "Moneyness": "{:.0%}",
                "Total Cost": "${:,.0f}",
                "% of Portfolio": "{:.1%}",
                "P(Profit)": "{:.0%}",
                "R/R": "{:.1f}x",
                "Val Score": "{:.0f}",
                "Portfolio Score": "{:.0f}",
            },
            na_rep="—",
        )
        .background_gradient(
            subset=["Portfolio Score"], cmap="RdYlGn", vmin=30, vmax=75
        )
        .background_gradient(subset=["% of Portfolio"], cmap="Blues", vmin=0, vmax=0.15)
        .set_caption(
            f"Portfolio holdings — ${STARTING_BALANCE - cash_remaining:,.0f} invested, ${cash_remaining:,.0f} cash"
        )
    )

    # ── Risk Summary Card ──
    display(Markdown("### 📊 Risk Summary"))

    total_invested = STARTING_BALANCE - cash_remaining
    max_loss = total_invested  # all options go to zero
    weighted_pp = (
        (
            (portfolio_df["P(Profit)"].fillna(0) * portfolio_df["Total Cost"]).sum()
            / total_invested
        )
        if total_invested > 0
        else 0
    )
    weighted_rr = (
        (
            (portfolio_df["R/R"].fillna(0) * portfolio_df["Total Cost"]).sum()
            / total_invested
        )
        if total_invested > 0
        else 0
    )
    avg_dte = (
        ((portfolio_df["DTE"] * portfolio_df["Total Cost"]).sum() / total_invested)
        if total_invested > 0
        else 0
    )
    n_tickers = portfolio_df["Ticker"].nunique()
    n_positions = len(portfolio_df)
    avg_leverage = (
        ((portfolio_df["Leverage"] * portfolio_df["Total Cost"]).sum() / total_invested)
        if total_invested > 0
        else 0
    )

    # Herfindahl index for concentration
    weights = portfolio_df["Total Cost"] / total_invested
    hhi = (weights**2).sum()
    effective_positions = 1 / hhi if hhi > 0 else 0

    risk_data = {
        "Metric": [
            "Starting Balance",
            "Total Invested",
            "Cash Reserve",
            "Max Loss (all expire worthless)",
            "Positions / Tickers",
            "Weighted P(Profit)",
            "Weighted R/R @+10%",
            "Weighted Avg DTE",
            "Weighted Avg Leverage",
            "Concentration (HHI)",
            "Effective # Positions",
        ],
        "Value": [
            f"${STARTING_BALANCE:,.0f}",
            f"${total_invested:,.0f} ({total_invested / STARTING_BALANCE:.0%})",
            f"${cash_remaining:,.0f} ({cash_remaining / STARTING_BALANCE:.0%})",
            f"${max_loss:,.0f} ({max_loss / STARTING_BALANCE:.0%})",
            f"{n_positions} positions across {n_tickers} tickers",
            f"{weighted_pp:.0%}",
            f"{weighted_rr:.1f}x",
            f"{avg_dte:.0f} days",
            f"{avg_leverage:.0f}x",
            f"{hhi:.2f} (1.0 = all in one, lower = diversified)",
            f"{effective_positions:.1f}",
        ],
    }
    display(
        pd.DataFrame(risk_data)
        .style.hide(axis="index")
        .set_caption("Portfolio risk metrics")
    )

    # ── Allocation by Bucket — Pie Chart ──
    display(Markdown("### 🥧 Allocation Breakdown"))

    bucket_alloc = portfolio_df.groupby("Bucket")["Total Cost"].sum().reset_index()
    bucket_alloc["Pct"] = bucket_alloc["Total Cost"] / total_invested
    # Add cash
    bucket_alloc = pd.concat(
        [
            bucket_alloc,
            pd.DataFrame(
                [
                    {
                        "Bucket": "💵 Cash",
                        "Total Cost": cash_remaining,
                        "Pct": cash_remaining / STARTING_BALANCE,
                    }
                ]
            ),
        ],
        ignore_index=True,
    )

    fig_pie_bucket = px.pie(
        bucket_alloc,
        values="Total Cost",
        names="Bucket",
        title="Allocation by Time Horizon",
        color="Bucket",
        color_discrete_map={
            "⚡ <30 DTE": "#e74c3c",
            "🔄 30-90 DTE": "#f39c12",
            "🏗️ 300+ DTE": "#2ecc71",
            "💵 Cash": "#95a5a6",
        },
        hole=0.35,
    )
    fig_pie_bucket.update_traces(textinfo="label+percent", textposition="outside")
    fig_pie_bucket.show()

    # Allocation by Ticker
    ticker_alloc = portfolio_df.groupby("Ticker")["Total Cost"].sum().reset_index()
    ticker_alloc = pd.concat(
        [
            ticker_alloc,
            pd.DataFrame([{"Ticker": "Cash", "Total Cost": cash_remaining}]),
        ],
        ignore_index=True,
    )

    fig_pie_ticker = px.pie(
        ticker_alloc,
        values="Total Cost",
        names="Ticker",
        title="Allocation by Ticker",
        hole=0.35,
    )
    fig_pie_ticker.update_traces(textinfo="label+percent", textposition="outside")
    fig_pie_ticker.show()

    # ── Scenario P&L — Portfolio Level ──
    display(Markdown("### 💰 Scenario P&L — Portfolio Level"))
    display(Markdown("*What happens to the whole book if the market moves uniformly.*"))

    scenarios = [-0.15, -0.10, -0.05, 0.0, 0.05, 0.10, 0.15, 0.20, 0.30]
    scen_rows = []

    for move in scenarios:
        total_payout = 0
        for _, pos in portfolio_df.iterrows():
            new_spot = pos["Spot"] * (1 + move)
            intrinsic = max(new_spot - pos["Strike"], 0)
            payout = intrinsic * 100 * pos["Contracts"]
            total_payout += payout

        total_cost = total_invested
        pnl = total_payout - total_cost
        pnl_pct = pnl / STARTING_BALANCE  # P&L as % of full balance

        scen_rows.append(
            {
                "Market Move": f"{move:+.0%}",
                "Portfolio Value": total_payout,
                "P&L ($)": pnl,
                "P&L (% of Balance)": pnl_pct,
                "Total Return": (total_payout + cash_remaining) / STARTING_BALANCE - 1,
            }
        )

    scen_pnl = pd.DataFrame(scen_rows)
    display(
        scen_pnl.style.format(
            {
                "Portfolio Value": "${:,.0f}",
                "P&L ($)": "${:+,.0f}",
                "P&L (% of Balance)": "{:+.1%}",
                "Total Return": "{:+.1%}",
            }
        )
        .background_gradient(
            subset=["P&L ($)"],
            cmap="RdYlGn",
            vmin=-total_invested,
            vmax=total_invested * 2,
        )
        .hide(axis="index")
        .set_caption(
            f"At-expiry intrinsic value — starting balance ${STARTING_BALANCE:,.0f}"
        )
    )

    # ── P&L waterfall chart ──
    fig_pnl = go.Figure()
    fig_pnl.add_trace(
        go.Bar(
            x=scen_pnl["Market Move"],
            y=scen_pnl["P&L ($)"],
            marker_color=[
                "#e74c3c" if v < 0 else "#2ecc71" for v in scen_pnl["P&L ($)"]
            ],
            text=[f"${v:+,.0f}" for v in scen_pnl["P&L ($)"]],
            textposition="outside",
        )
    )
    fig_pnl.update_layout(
        title="Portfolio P&L by Market Move (at expiry)",
        xaxis_title="Uniform Market Move",
        yaxis_title="P&L ($)",
        height=400,
        showlegend=False,
    )
    fig_pnl.add_hline(y=0, line_dash="dot", line_color="gray")
    fig_pnl.show()

    # ── Per-Position Scenario Detail ──
    display(Markdown("### 📊 Per-Position Return Scenarios"))

    pos_scen_rows = []
    for _, pos in portfolio_df.iterrows():
        for move in [-0.05, 0.05, 0.10, 0.20]:
            new_spot = pos["Spot"] * (1 + move)
            intrinsic = max(new_spot - pos["Strike"], 0)
            pos_pnl = (intrinsic - pos["Mid"]) * 100 * pos["Contracts"]
            pos_ret = (intrinsic - pos["Mid"]) / pos["Mid"] if pos["Mid"] > 0 else 0
            pos_scen_rows.append(
                {
                    "Ticker": pos["Ticker"],
                    "Bucket": pos["Bucket"],
                    "Strike": f"${pos['Strike']:,.0f}",
                    "Cost": f"${pos['Total Cost']:,.0f}",
                    "Move": move,
                    "Return": pos_ret,
                }
            )

    pos_scen_df = pd.DataFrame(pos_scen_rows)
    if not pos_scen_df.empty:
        pos_piv = pos_scen_df.pivot_table(
            index=["Bucket", "Ticker", "Strike", "Cost"],
            columns="Move",
            values="Return",
        )
        pos_piv.columns = [f"{c:+.0%}" for c in pos_piv.columns]
        display(
            pos_piv.style.format("{:+.0%}", na_rep="—")
            .background_gradient(cmap="RdYlGn", vmin=-1.0, vmax=3.0, axis=None)
            .set_caption("Per-position return at expiry")
        )

    # ── Correlation Heatmap of Selected Positions ──
    display(Markdown("### 🔗 Correlation — Selected Tickers"))

    port_tickers = sorted(portfolio_df["Ticker"].unique().tolist())
    port_tickers_in_corr = [t for t in port_tickers if t in corr_matrix.columns]

    if len(port_tickers_in_corr) > 1:
        sub_corr = corr_matrix.loc[port_tickers_in_corr, port_tickers_in_corr]

        fig_corr = go.Figure(
            data=go.Heatmap(
                z=sub_corr.values,
                x=sub_corr.columns.tolist(),
                y=sub_corr.index.tolist(),
                colorscale="RdYlGn_r",
                zmin=-0.2,
                zmax=1.0,
                text=np.round(sub_corr.values, 2),
                texttemplate="%{text}",
                textfont={"size": 12},
            )
        )
        fig_corr.update_layout(
            title="Pairwise Correlation — Portfolio Tickers (6M daily returns)",
            height=400,
            width=500,
        )
        fig_corr.show()

        # Flag highly correlated pairs
        high_corr_pairs = []
        for i, t1 in enumerate(port_tickers_in_corr):
            for j, t2 in enumerate(port_tickers_in_corr):
                if i < j and sub_corr.loc[t1, t2] > 0.65:
                    high_corr_pairs.append((t1, t2, sub_corr.loc[t1, t2]))

        if high_corr_pairs:
            display(Markdown("**⚠️ Correlated pairs in portfolio:**"))
            for t1, t2, rho in sorted(high_corr_pairs, key=lambda x: -x[2]):
                display(
                    Markdown(
                        f"- {t1} ↔ {t2}: ρ = {rho:.2f} — consider these as overlapping exposure"
                    )
                )
        else:
            display(
                Markdown(
                    "✅ No highly correlated pairs (ρ > 0.65) — good diversification."
                )
            )

    # ── Position Sizing Breakdown ──
    display(Markdown("### 🎯 Sizing Logic Breakdown"))

    sizing_cols = [
        "Ticker",
        "Bucket",
        "Strike",
        "DTE",
        "Kelly Frac",
        "Contracts",
        "Total Cost",
        "% of Portfolio",
        "P(Profit)",
        "R/R",
        "Corr Penalty",
        "Portfolio Score",
    ]
    sa = [c for c in sizing_cols if c in portfolio_df.columns]
    display(
        portfolio_df[sa]
        .style.format(
            {
                "Strike": "${:,.0f}",
                "Kelly Frac": "{:.1%}",
                "Total Cost": "${:,.0f}",
                "% of Portfolio": "{:.1%}",
                "P(Profit)": "{:.0%}",
                "R/R": "{:.1f}x",
                "Corr Penalty": "{:.2f}",
                "Portfolio Score": "{:.0f}",
            },
            na_rep="—",
        )
        .set_caption(
            "How each position was sized — Kelly fraction × balance constraints"
        )
    )

    # ── Final Summary ──
    display(Markdown("---"))
    display(
        Markdown(
            f"### ✅ Portfolio Complete\n\n"
            f"- **{n_positions} positions** across **{n_tickers} tickers** and "
            f"**{portfolio_df['Bucket'].nunique()} time horizons**\n"
            f"- **${total_invested:,.0f} deployed** ({total_invested / STARTING_BALANCE:.0%}) "
            f"with **${cash_remaining:,.0f} cash reserve** ({cash_remaining / STARTING_BALANCE:.0%})\n"
            f"- Weighted P(Profit): **{weighted_pp:.0%}** | Weighted R/R: **{weighted_rr:.1f}x** "
            f"| Avg DTE: **{avg_dte:.0f}d**\n"
            f"- Effective positions: **{effective_positions:.1f}** (HHI = {hhi:.2f})\n\n"
            f"**Portfolio is max-loss capped at ${max_loss:,.0f}** (options expire worthless). "
            f"Cash reserve provides dry powder for dips or rolling positions.\n\n"
            f"*Rebalance triggers:* Roll LEAPS when DTE < 90. "
            f"Take profit on swings at 2× entry. "
            f"Re-run this notebook weekly for updated scores."
        )
    )
# Out:
# Fetching fundamentals (P/E, PEG, FCF, market cap)…
#
#   WDC    FwdPE=21.6      PEG=0.88    FCFy=4.0%   MCap=$97B
#   GEV    FwdPE=35.1      PEG=3.17    FCFy=2.5%   MCap=$211B
#   STX    FwdPE=22.2      PEG=0.92    FCFy=1.2%   MCap=$94B
#   LRCX   FwdPE=34.0      PEG=2.16    FCFy=1.7%   MCap=$290B
#   AMAT   FwdPE=26.5      PEG=2.72    FCFy=1.4%   MCap=$256B
#   TSM    FwdPE=19.4      PEG=1.23    FCFy=34.2%  MCap=$1809B
#   GE     FwdPE=37.8      PEG=5.55    FCFy=1.5%   MCap=$339B
#   CMI    FwdPE=18.4      PEG=2.39    FCFy=1.7%   MCap=$80B
#   KLAC   FwdPE=31.6      PEG=2.26    FCFy=1.7%   MCap=$190B
#   SNPS   FwdPE=25.3      PEG=2.68    FCFy=2.7%   MCap=$82B
#   META   FwdPE=18.7      PEG=1.19    FCFy=1.4%   MCap=$1673B
#   UBER   FwdPE=17.5      PEG=7.74    FCFy=4.2%   MCap=$156B
#   ISRG   FwdPE=42.7      PEG=2.55    FCFy=1.3%   MCap=$173B
#   MSFT   FwdPE=21.3      PEG=1.53    FCFy=1.8%   MCap=$2981B
#   AMZN   FwdPE=22.7      PEG=1.59    FCFy=1.1%   MCap=$2258B
#   AVGO   FwdPE=23.2      PEG=0.93    FCFy=1.6%   MCap=$1578B
#
# ✅ Fundamentals for 16 tickers
# ### 📊 Valuation Scores
# <style type="text/css">
# #T_b1b22_row0_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_b1b22_row1_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_b1b22_row2_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_b1b22_row3_col1 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_b1b22_row4_col1 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_b1b22_row5_col1, #T_b1b22_row6_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_b1b22_row7_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_b1b22_row8_col1, #T_b1b22_row9_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_b1b22_row10_col1 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_b1b22_row11_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_b1b22_row12_col1, #T_b1b22_row13_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_b1b22_row14_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_b1b22_row15_col1 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1b22">
#   <caption>Higher = more attractively valued</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1b22_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_b1b22_level0_col1" class="col_heading level0 col1" >Val Score</th>
#       <th id="T_b1b22_level0_col2" class="col_heading level0 col2" >Fwd PE</th>
#       <th id="T_b1b22_level0_col3" class="col_heading level0 col3" >PEG</th>
#       <th id="T_b1b22_level0_col4" class="col_heading level0 col4" >FCF Yield</th>
#       <th id="T_b1b22_level0_col5" class="col_heading level0 col5" >Rev Growth</th>
#       <th id="T_b1b22_level0_col6" class="col_heading level0 col6" >Profit Margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1b22_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_b1b22_row0_col0" class="data row0 col0" >TSM</td>
#       <td id="T_b1b22_row0_col1" class="data row0 col1" >74</td>
#       <td id="T_b1b22_row0_col2" class="data row0 col2" >19.4</td>
#       <td id="T_b1b22_row0_col3" class="data row0 col3" >1.23</td>
#       <td id="T_b1b22_row0_col4" class="data row0 col4" >34.2%</td>
#       <td id="T_b1b22_row0_col5" class="data row0 col5" >20.5%</td>
#       <td id="T_b1b22_row0_col6" class="data row0 col6" >45.1%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_b1b22_row1_col0" class="data row1 col0" >WDC</td>
#       <td id="T_b1b22_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_b1b22_row1_col2" class="data row1 col2" >21.6</td>
#       <td id="T_b1b22_row1_col3" class="data row1 col3" >0.88</td>
#       <td id="T_b1b22_row1_col4" class="data row1 col4" >4.0%</td>
#       <td id="T_b1b22_row1_col5" class="data row1 col5" >—</td>
#       <td id="T_b1b22_row1_col6" class="data row1 col6" >35.6%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_b1b22_row2_col0" class="data row2 col0" >META</td>
#       <td id="T_b1b22_row2_col1" class="data row2 col1" >68</td>
#       <td id="T_b1b22_row2_col2" class="data row2 col2" >18.7</td>
#       <td id="T_b1b22_row2_col3" class="data row2 col3" >1.19</td>
#       <td id="T_b1b22_row2_col4" class="data row2 col4" >1.4%</td>
#       <td id="T_b1b22_row2_col5" class="data row2 col5" >23.8%</td>
#       <td id="T_b1b22_row2_col6" class="data row2 col6" >30.1%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_b1b22_row3_col0" class="data row3 col0" >AVGO</td>
#       <td id="T_b1b22_row3_col1" class="data row3 col1" >64</td>
#       <td id="T_b1b22_row3_col2" class="data row3 col2" >23.2</td>
#       <td id="T_b1b22_row3_col3" class="data row3 col3" >0.93</td>
#       <td id="T_b1b22_row3_col4" class="data row3 col4" >1.6%</td>
#       <td id="T_b1b22_row3_col5" class="data row3 col5" >16.4%</td>
#       <td id="T_b1b22_row3_col6" class="data row3 col6" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_b1b22_row4_col0" class="data row4 col0" >STX</td>
#       <td id="T_b1b22_row4_col1" class="data row4 col1" >61</td>
#       <td id="T_b1b22_row4_col2" class="data row4 col2" >22.2</td>
#       <td id="T_b1b22_row4_col3" class="data row4 col3" >0.92</td>
#       <td id="T_b1b22_row4_col4" class="data row4 col4" >1.2%</td>
#       <td id="T_b1b22_row4_col5" class="data row4 col5" >21.5%</td>
#       <td id="T_b1b22_row4_col6" class="data row4 col6" >19.6%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_b1b22_row5_col0" class="data row5 col0" >MSFT</td>
#       <td id="T_b1b22_row5_col1" class="data row5 col1" >59</td>
#       <td id="T_b1b22_row5_col2" class="data row5 col2" >21.3</td>
#       <td id="T_b1b22_row5_col3" class="data row5 col3" >1.53</td>
#       <td id="T_b1b22_row5_col4" class="data row5 col4" >1.8%</td>
#       <td id="T_b1b22_row5_col5" class="data row5 col5" >16.7%</td>
#       <td id="T_b1b22_row5_col6" class="data row5 col6" >39.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_b1b22_row6_col0" class="data row6 col0" >UBER</td>
#       <td id="T_b1b22_row6_col1" class="data row6 col1" >59</td>
#       <td id="T_b1b22_row6_col2" class="data row6 col2" >17.5</td>
#       <td id="T_b1b22_row6_col3" class="data row6 col3" >7.74</td>
#       <td id="T_b1b22_row6_col4" class="data row6 col4" >4.2%</td>
#       <td id="T_b1b22_row6_col5" class="data row6 col5" >20.1%</td>
#       <td id="T_b1b22_row6_col6" class="data row6 col6" >19.3%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_b1b22_row7_col0" class="data row7 col0" >LRCX</td>
#       <td id="T_b1b22_row7_col1" class="data row7 col1" >55</td>
#       <td id="T_b1b22_row7_col2" class="data row7 col2" >34.0</td>
#       <td id="T_b1b22_row7_col3" class="data row7 col3" >2.16</td>
#       <td id="T_b1b22_row7_col4" class="data row7 col4" >1.7%</td>
#       <td id="T_b1b22_row7_col5" class="data row7 col5" >22.1%</td>
#       <td id="T_b1b22_row7_col6" class="data row7 col6" >30.2%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row8" class="row_heading level0 row8" >14</th>
#       <td id="T_b1b22_row8_col0" class="data row8 col0" >AMZN</td>
#       <td id="T_b1b22_row8_col1" class="data row8 col1" >52</td>
#       <td id="T_b1b22_row8_col2" class="data row8 col2" >22.7</td>
#       <td id="T_b1b22_row8_col3" class="data row8 col3" >1.59</td>
#       <td id="T_b1b22_row8_col4" class="data row8 col4" >1.1%</td>
#       <td id="T_b1b22_row8_col5" class="data row8 col5" >13.6%</td>
#       <td id="T_b1b22_row8_col6" class="data row8 col6" >10.8%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1b22_row9_col0" class="data row9 col0" >SNPS</td>
#       <td id="T_b1b22_row9_col1" class="data row9 col1" >52</td>
#       <td id="T_b1b22_row9_col2" class="data row9 col2" >25.3</td>
#       <td id="T_b1b22_row9_col3" class="data row9 col3" >2.68</td>
#       <td id="T_b1b22_row9_col4" class="data row9 col4" >2.7%</td>
#       <td id="T_b1b22_row9_col5" class="data row9 col5" >37.8%</td>
#       <td id="T_b1b22_row9_col6" class="data row9 col6" >18.9%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_row10" class="row_heading level0 row10" >8</th>
#       <td id="T_b1b22_row10_col0" class="data row10 col0" >KLAC</td>
#       <td id="T_b1b22_row10_col1" class="data row10 col1" >48</td>
#       <td id="T_b1b22_row10_col2" class="data row10 col2" >31.6</td>
#       <td id="T_b1b22_row10_col3" class="data row10 col3" >2.26</td>
#       <td id="T_b1b22_row10_col4" class="data row10 col4" >1.7%</td>
#       <td id="T_b1b22_row10_col5" class="data row10 col5" >7.2%</td>
#       <td id="T_b1b22_row10_col6" class="data row10 col6" >35.8%</td>
#     </tr>
#     <tr>
#       <th id="T_b1b22_level0_ro
# Building correlation matrix…
# ✅ Correlation matrix: 16×16
#
# ════════════════════════════════════════════════════════════
#   💼  BUILDING PORTFOLIO — Round-Robin Bucket Builder
# ════════════════════════════════════════════════════════════
#   Starting balance: $15,000
#   Kelly fraction:   25% of full Kelly
#   Edge haircut:     90% of BSM P(Profit)
#   Max per ticker:   25%
#   Max per position: 20%
#   Bucket targets:   LEAPS 55% / Med 30% / Short 15%
#
#      🏗️ TSM    $340 2026-05-15 (96d)  ×1 = $3,572  (24% of port)  Kelly=0.5%  PScore=68
#      🔄 LRCX   $210 2026-03-20 (40d)  ×1 = $3,075  (20% of port)  Kelly=0.5%  PScore=55
#      ⚡ CMI    $590 2026-02-20 (12d)  ×1 = $590  (4% of port)  Kelly=3.4%  PScore=57
#      🔄 WDC    $270 2026-03-13 (33d)  ×1 = $3,575  (24% of port)  Kelly=0.5%  PScore=57
#      ⚡ CMI    $580 2026-02-20 (12d)  ×1 = $1,070  (7% of port)  Kelly=3.5%  PScore=26
#      ⚡ AMZN   $220 2026-02-20 (12d)  ×1 = $192  (1% of port)  Kelly=0.0%  PScore=53
#      🏗️ GE     $310 2026-05-15 (96d)  ×1 = $2,855  (19% of port)  Kelly=0.5%  PScore=49
#
# ────────────────────────────────────────────────────────────
#   Positions:  7
#   Tickers:    6
#   Invested:   $14,930 (100%)
#   Cash:       $70 (0%)
#     🏗️ 300+ DTE: $6,428 (target $8,250, ✅)
#     🔄 30-90 DTE: $6,650 (target $4,500, ✅)
#     ⚡ <30 DTE: $1,852 (target $2,250, ✅)
# ════════════════════════════════════════════════════════════
# ---
# # 💼 Portfolio — $15k Call Options Book
# ### 📋 Holdings
# <style type="text/css">
# #T_25099_row0_col10, #T_25099_row1_col10, #T_25099_row3_col10, #T_25099_row6_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_25099_row0_col14 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_25099_row1_col14, #T_25099_row3_col14 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_25099_row2_col10 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_25099_row2_col14 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_25099_row4_col10 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_25099_row4_col14 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_25099_row5_col10 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_25099_row5_col14 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_25099_row6_col14 {
#   background-color: #fee695;
#   color: #000000;
# }
# </style>
# <table id="T_25099">
#   <caption>Portfolio holdings — $14,930 invested, $70 cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25099_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_25099_level0_col1" class="col_heading level0 col1" >Conviction</th>
#       <th id="T_25099_level0_col2" class="col_heading level0 col2" >Bucket</th>
#       <th id="T_25099_level0_col3" class="col_heading level0 col3" >Expiry</th>
#       <th id="T_25099_level0_col4" class="col_heading level0 col4" >DTE</th>
#       <th id="T_25099_level0_col5" class="col_heading level0 col5" >Strike</th>
#       <th id="T_25099_level0_col6" class="col_heading level0 col6" >Moneyness</th>
#       <th id="T_25099_level0_col7" class="col_heading level0 col7" >Mid</th>
#       <th id="T_25099_level0_col8" class="col_heading level0 col8" >Contracts</th>
#       <th id="T_25099_level0_col9" class="col_heading level0 col9" >Total Cost</th>
#       <th id="T_25099_level0_col10" class="col_heading level0 col10" >% of Portfolio</th>
#       <th id="T_25099_level0_col11" class="col_heading level0 col11" >P(Profit)</th>
#       <th id="T_25099_level0_col12" class="col_heading level0 col12" >R/R</th>
#       <th id="T_25099_level0_col13" class="col_heading level0 col13" >Val Score</th>
#       <th id="T_25099_level0_col14" class="col_heading level0 col14" >Portfolio Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25099_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25099_row0_col0" class="data row0 col0" >TSM</td>
#       <td id="T_25099_row0_col1" class="data row0 col1" ></td>
#       <td id="T_25099_row0_col2" class="data row0 col2" >🏗️ 300+ DTE</td>
#       <td id="T_25099_row0_col3" class="data row0 col3" >2026-05-15</td>
#       <td id="T_25099_row0_col4" class="data row0 col4" >96</td>
#       <td id="T_25099_row0_col5" class="data row0 col5" >$340</td>
#       <td id="T_25099_row0_col6" class="data row0 col6" >97%</td>
#       <td id="T_25099_row0_col7" class="data row0 col7" >$35.73</td>
#       <td id="T_25099_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_25099_row0_col9" class="data row0 col9" >$3,572</td>
#       <td id="T_25099_row0_col10" class="data row0 col10" >23.8%</td>
#       <td id="T_25099_row0_col11" class="data row0 col11" >35%</td>
#       <td id="T_25099_row0_col12" class="data row0 col12" >0.2x</td>
#       <td id="T_25099_row0_col13" class="data row0 col13" >74</td>
#       <td id="T_25099_row0_col14" class="data row0 col14" >68</td>
#     </tr>
#     <tr>
#       <th id="T_25099_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25099_row1_col0" class="data row1 col0" >LRCX</td>
#       <td id="T_25099_row1_col1" class="data row1 col1" ></td>
#       <td id="T_25099_row1_col2" class="data row1 col2" >🔄 30-90 DTE</td>
#       <td id="T_25099_row1_col3" class="data row1 col3" >2026-03-20</td>
#       <td id="T_25099_row1_col4" class="data row1 col4" >40</td>
#       <td id="T_25099_row1_col5" class="data row1 col5" >$210</td>
#       <td id="T_25099_row1_col6" class="data row1 col6" >91%</td>
#       <td id="T_25099_row1_col7" class="data row1 col7" >$30.75</td>
#       <td id="T_25099_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_25099_row1_col9" class="data row1 col9" >$3,075</td>
#       <td id="T_25099_row1_col10" class="data row1 col10" >20.5%</td>
#       <td id="T_25099_row1_col11" class="data row1 col11" >39%</td>
#       <td id="T_25099_row1_col12" class="data row1 col12" >0.4x</td>
#       <td id="T_25099_row1_col13" class="data row1 col13" >55</td>
#       <td id="T_25099_row1_col14" class="data row1 col14" >57</td>
#     </tr>
#     <tr>
#       <th id="T_25099_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25099_row2_col0" class="data row2 col0" >CMI</td>
#       <td id="T_25099_row2_col1" class="data row2 col1" ></td>
#       <td id="T_25099_row2_col2" class="data row2 col2" >⚡ <30 DTE</td>
#       <td id="T_25099_row2_col3" class="data row2 col3" >2026-02-20</td>
#       <td id="T_25099_row2_col4" class="data row2 col4" >12</td>
#       <td id="T_25099_row2_col5" class="data row2 col5" >$590</td>
#       <td id="T_25099_row2_col6" class="data row2 col6" >102%</td>
#       <td id="T_25099_row2_col7" class="data row2 col7" >$5.90</td>
#       <td id="T_25099_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_25099_row2_col9" class="data row2 col9" >$590</td>
#       <td id="T_25099_row2_col10" class="data row2 col10" >3.9%</td>
#       <td id="T_25099_row2_col11" class="data row2 col11" >27%</td>
#       <td id="T_25099_row2_col12" class="data row2 col12" >6.7x</td>
#       <td id="T_25099_row2_col13" class="data row2 col13" >38</td>
#       <td id="T_25099_row2_col14" class="data row2 col14" >57</td>
#     </tr>
#     <tr>
#       <th id="T_25099_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25099_row3_col0" class="data row3 col0" >WDC</td>
#       <td id="T_25099_row3_col1" class="data row3 col1" ></td>
#       <td id="T_25099_row3_col2" class="data row3 col2" >🔄 30-90 DTE</td>
#       <td id="T_25099_row3_col3" class="data row3 col3" >2026-03-13</td>
#       <td id="T_25099_row3_col4" class="data row3 col4" >33</td>
#       <td id="T_25099_row3_col5" class="data row3 col5" >$270</td>
#       <td id="T_25099_row3_col6" class="data row3 col6" >96%</td>
#       <td id="T_25099_row3_col7" class="data row3 col7" >$35.75</td>
#       <td id="T_25099_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_25099_row3_col9" class="data row3 col9" >$3,575</td>
#       <td id="T_25099_row3_col10" class="data row3 col10" >23.8%</td>
#       <td id="T_25099_row3_col11" class="data row3 col11" >34%</td>
#       <td id="T_25099_row3_col12" class="data row3 col12" >0.1x</td>
#       <td id="T_25099_row3_col13" class="data row3 col13" >74</td>
#       <td id="T_25099_row3_col14" class="data row3 col14" >57</td>
#     </tr>
#     <tr>
#       <th id="T_25099_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25099_row4_col0" class="data row4 col0" >CMI</td>
#       <td id="T_25099_row4_col1" class="data row4 col1" ></td>
#       <td id="T_25099_row4_col2" class="data row4 col2" >⚡ <30 DTE</td>
#       <td id="T_25099_row4_col3" class="data row4 col3" >2026-02-20</td>
#       <td id="T_25099_row4_col4" class="data row4 col4" >12</td>
#       <td id="T_25099_row4_col5" class="data row4 col5" >$580</td>
#       <td id="T_25099_row4_col6" class="data row4 col6" >100%</td>
#       <td id="T_25099_row4_col7" class="data row4 col7" >$10.70</td>
#       <td id="T_25099_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_25099_row4_col9" class="data row4 col9" >$1,070</td>
#       <td id="T_25099_row4_col10" class="data row4 col10" >7.1%</td>
#       <td id="T_25099_row4_col11" class="data row4 col11" >34%</td>
#       <td id="T_25099_row4_col12" class="data row4 col12" >4.2x</td>
#       <td id="T_25099_row4_col13" class="data row4 col13" >38</td>
#       <td id="T_25099_row4_col14" class="data row4 col14" >54</td>
#     </tr>
#     <tr>
#       <th id="T_25099_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25099_row5_col0" class="data row5 col0" >AMZN</td>
#       <td id="T_25099_row5_col1" class="data row5 c
# ### 📊 Risk Summary
# <style type="text/css">
# </style>
# <table id="T_f9290">
#   <caption>Portfolio risk metrics</caption>
#   <thead>
#     <tr>
#       <th id="T_f9290_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_f9290_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f9290_row0_col0" class="data row0 col0" >Starting Balance</td>
#       <td id="T_f9290_row0_col1" class="data row0 col1" >$15,000</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row1_col0" class="data row1 col0" >Total Invested</td>
#       <td id="T_f9290_row1_col1" class="data row1 col1" >$14,930 (100%)</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row2_col0" class="data row2 col0" >Cash Reserve</td>
#       <td id="T_f9290_row2_col1" class="data row2 col1" >$70 (0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row3_col0" class="data row3 col0" >Max Loss (all expire worthless)</td>
#       <td id="T_f9290_row3_col1" class="data row3 col1" >$14,930 (100%)</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row4_col0" class="data row4 col0" >Positions / Tickers</td>
#       <td id="T_f9290_row4_col1" class="data row4 col1" >7 positions across 6 tickers</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row5_col0" class="data row5 col0" >Weighted P(Profit)</td>
#       <td id="T_f9290_row5_col1" class="data row5 col1" >35%</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row6_col0" class="data row6 col0" >Weighted R/R @+10%</td>
#       <td id="T_f9290_row6_col1" class="data row6 col1" >0.9x</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row7_col0" class="data row7 col0" >Weighted Avg DTE</td>
#       <td id="T_f9290_row7_col1" class="data row7 col1" >59 days</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row8_col0" class="data row8 col0" >Weighted Avg Leverage</td>
#       <td id="T_f9290_row8_col1" class="data row8 col1" >17x</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row9_col0" class="data row9 col0" >Concentration (HHI)</td>
#       <td id="T_f9290_row9_col1" class="data row9 col1" >0.20 (1.0 = all in one, lower = diversified)</td>
#     </tr>
#     <tr>
#       <td id="T_f9290_row10_col0" class="data row10 col0" >Effective # Positions</td>
#       <td id="T_f9290_row10_col1" class="data row10 col1" >5.0</td>
#     </tr>
#   </tbody>
# </table>
# ### 🥧 Allocation Breakdown
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cbc1e330-3730-4408-83a0-5dadfd524d8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cbc1e330-3730-4408-83a0-5dadfd524d8b")) {                    Plotly.newPlot(                        "cbc1e330-3730-4408-83a0-5dadfd524d8b",                        [{"customdata":[["\u26a1 \u003c30 DTE"],["\ud83c\udfd7\ufe0f 300+ DTE"],["\ud83d\udd04 30-90 DTE"],["\ud83d\udcb5 Cash"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.35,"hovertemplate":"Bucket=%{customdata[0]}\u003cbr\u003eTotal Cost=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u26a1 \u003c30 DTE","\ud83c\udfd7\ufe0f 300+ DTE","\ud83d\udd04 30-90 DTE","\ud83d\udcb5 Cash"],"legendgroup":"","marker":{"colors":["#e74c3c","#2ecc71","#f39c12","#95a5a6"]},"name":"","showlegend":true,"values":{"dtype":"f8","bdata":"AAAAAADwnEAAAAAAgBu5QAAAAAAA+rlAAAAAAACgUUA="},"type":"pie","textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"sca ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="858b407e-f680-479d-95cc-96bd4c570faf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("858b407e-f680-479d-95cc-96bd4c570faf")) {                    Plotly.newPlot(                        "858b407e-f680-479d-95cc-96bd4c570faf",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.35,"hovertemplate":"Ticker=%{label}\u003cbr\u003eTotal Cost=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["AMZN","CMI","GE","LRCX","TSM","WDC","Cash"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"f8","bdata":"AAAAAAAAaEAAAAAAAPCZQAAAAAAATqZAAAAAAAAGqEAAAAAAAOmrQAAAAAAA7qtAAAAAAACgUUA="},"type":"pie","textinfo":"label+percent","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker": ...
# ### 💰 Scenario P&L — Portfolio Level
# *What happens to the whole book if the market moves uniformly.*
# <style type="text/css">
# #T_694bb_row0_col2, #T_694bb_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_694bb_row2_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_694bb_row3_col2 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_694bb_row4_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_694bb_row5_col2 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_694bb_row6_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_694bb_row7_col2, #T_694bb_row8_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_694bb">
#   <caption>At-expiry intrinsic value — starting balance $15,000</caption>
#   <thead>
#     <tr>
#       <th id="T_694bb_level0_col0" class="col_heading level0 col0" >Market Move</th>
#       <th id="T_694bb_level0_col1" class="col_heading level0 col1" >Portfolio Value</th>
#       <th id="T_694bb_level0_col2" class="col_heading level0 col2" >P&L ($)</th>
#       <th id="T_694bb_level0_col3" class="col_heading level0 col3" >P&L (% of Balance)</th>
#       <th id="T_694bb_level0_col4" class="col_heading level0 col4" >Total Return</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_694bb_row0_col0" class="data row0 col0" >-15%</td>
#       <td id="T_694bb_row0_col1" class="data row0 col1" >$0</td>
#       <td id="T_694bb_row0_col2" class="data row0 col2" >$-14,930</td>
#       <td id="T_694bb_row0_col3" class="data row0 col3" >-99.5%</td>
#       <td id="T_694bb_row0_col4" class="data row0 col4" >-99.5%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row1_col0" class="data row1 col0" >-10%</td>
#       <td id="T_694bb_row1_col1" class="data row1 col1" >$0</td>
#       <td id="T_694bb_row1_col2" class="data row1 col2" >$-14,930</td>
#       <td id="T_694bb_row1_col3" class="data row1 col3" >-99.5%</td>
#       <td id="T_694bb_row1_col4" class="data row1 col4" >-99.5%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row2_col0" class="data row2 col0" >-5%</td>
#       <td id="T_694bb_row2_col1" class="data row2 col1" >$946</td>
#       <td id="T_694bb_row2_col2" class="data row2 col2" >$-13,984</td>
#       <td id="T_694bb_row2_col3" class="data row2 col3" >-93.2%</td>
#       <td id="T_694bb_row2_col4" class="data row2 col4" >-93.2%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row3_col0" class="data row3 col0" >+0%</td>
#       <td id="T_694bb_row3_col1" class="data row3 col1" >$5,344</td>
#       <td id="T_694bb_row3_col2" class="data row3 col2" >$-9,586</td>
#       <td id="T_694bb_row3_col3" class="data row3 col3" >-63.9%</td>
#       <td id="T_694bb_row3_col4" class="data row3 col4" >-63.9%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row4_col0" class="data row4 col0" >+5%</td>
#       <td id="T_694bb_row4_col1" class="data row4 col1" >$15,668</td>
#       <td id="T_694bb_row4_col2" class="data row4 col2" >$+739</td>
#       <td id="T_694bb_row4_col3" class="data row4 col3" >+4.9%</td>
#       <td id="T_694bb_row4_col4" class="data row4 col4" >+4.9%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row5_col0" class="data row5 col0" >+10%</td>
#       <td id="T_694bb_row5_col1" class="data row5 col1" >$28,414</td>
#       <td id="T_694bb_row5_col2" class="data row5 col2" >$+13,485</td>
#       <td id="T_694bb_row5_col3" class="data row5 col3" >+89.9%</td>
#       <td id="T_694bb_row5_col4" class="data row5 col4" >+89.9%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row6_col0" class="data row6 col0" >+15%</td>
#       <td id="T_694bb_row6_col1" class="data row6 col1" >$41,160</td>
#       <td id="T_694bb_row6_col2" class="data row6 col2" >$+26,231</td>
#       <td id="T_694bb_row6_col3" class="data row6 col3" >+174.9%</td>
#       <td id="T_694bb_row6_col4" class="data row6 col4" >+174.9%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row7_col0" class="data row7 col0" >+20%</td>
#       <td id="T_694bb_row7_col1" class="data row7 col1" >$53,906</td>
#       <td id="T_694bb_row7_col2" class="data row7 col2" >$+38,977</td>
#       <td id="T_694bb_row7_col3" class="data row7 col3" >+259.8%</td>
#       <td id="T_694bb_row7_col4" class="data row7 col4" >+259.8%</td>
#     </tr>
#     <tr>
#       <td id="T_694bb_row8_col0" class="data row8 col0" >+30%</td>
#       <td id="T_694bb_row8_col1" class="data row8 col1" >$79,399</td>
#       <td id="T_694bb_row8_col2" class="data row8 col2" >$+64,469</td>
#       <td id="T_694bb_row8_col3" class="data row8 col3" >+429.8%</td>
#       <td id="T_694bb_row8_col4" class="data row8 col4" >+429.8%</td>
#     </tr>
#   </tbody>
# </table>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f6a3a8bc-a08c-4bc1-a8af-c33bf3e1b288" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f6a3a8bc-a08c-4bc1-a8af-c33bf3e1b288")) {                    Plotly.newPlot(                        "f6a3a8bc-a08c-4bc1-a8af-c33bf3e1b288",                        [{"marker":{"color":["#e74c3c","#e74c3c","#e74c3c","#e74c3c","#2ecc71","#2ecc71","#2ecc71","#2ecc71","#2ecc71"]},"text":["$-14,930","$-14,930","$-13,984","$-9,586","$+739","$+13,485","$+26,231","$+38,977","$+64,469"],"textposition":"outside","x":["-15%","-10%","-5%","+0%","+5%","+10%","+15%","+20%","+30%"],"y":{"dtype":"f8","bdata":"AAAAAMAozcAAAAAAwCjNwAEAgHfGT8vAAAAAKsC4wsBAAAA4wxSHQAwAAPlYVspA\u002fP8\u002f37Kd2UAAAAChHAjjQAAAwAOjeu9A"},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type": ...
# ### 📊 Per-Position Return Scenarios
# <style type="text/css">
# #T_ae6f9_row0_col0, #T_ae6f9_row1_col0, #T_ae6f9_row2_col0, #T_ae6f9_row3_col0, #T_ae6f9_row4_col0, #T_ae6f9_row6_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ae6f9_row0_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_ae6f9_row0_col2, #T_ae6f9_row0_col3, #T_ae6f9_row1_col2, #T_ae6f9_row1_col3, #T_ae6f9_row2_col2, #T_ae6f9_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ae6f9_row1_col1 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_ae6f9_row2_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_ae6f9_row3_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_ae6f9_row3_col2 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_ae6f9_row3_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_ae6f9_row4_col1, #T_ae6f9_row6_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_ae6f9_row4_col2 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_ae6f9_row4_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_ae6f9_row5_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_ae6f9_row5_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_ae6f9_row5_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_ae6f9_row5_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_ae6f9_row6_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_ae6f9_row6_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# </style>
# <table id="T_ae6f9">
#   <caption>Per-position return at expiry</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae6f9_level0_col0" class="col_heading level0 col0" >-5%</th>
#       <th id="T_ae6f9_level0_col1" class="col_heading level0 col1" >+5%</th>
#       <th id="T_ae6f9_level0_col2" class="col_heading level0 col2" >+10%</th>
#       <th id="T_ae6f9_level0_col3" class="col_heading level0 col3" >+20%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bucket</th>
#       <th class="index_name level1" >Ticker</th>
#       <th class="index_name level2" >Strike</th>
#       <th class="index_name level3" >Cost</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae6f9_level0_row0" class="row_heading level0 row0" rowspan="3">⚡ <30 DTE</th>
#       <th id="T_ae6f9_level1_row0" class="row_heading level1 row0" >AMZN</th>
#       <th id="T_ae6f9_level2_row0" class="row_heading level2 row0" >$220</th>
#       <th id="T_ae6f9_level3_row0" class="row_heading level3 row0" >$192</th>
#       <td id="T_ae6f9_row0_col0" class="data row0 col0" >-100%</td>
#       <td id="T_ae6f9_row0_col1" class="data row0 col1" >-56%</td>
#       <td id="T_ae6f9_row0_col2" class="data row0 col2" >+491%</td>
#       <td id="T_ae6f9_row0_col3" class="data row0 col3" >+1587%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level1_row1" class="row_heading level1 row1" rowspan="2">CMI</th>
#       <th id="T_ae6f9_level2_row1" class="row_heading level2 row1" >$580</th>
#       <th id="T_ae6f9_level3_row1" class="row_heading level3 row1" >$1,070</th>
#       <td id="T_ae6f9_row1_col0" class="data row1 col0" >-100%</td>
#       <td id="T_ae6f9_row1_col1" class="data row1 col1" >+149%</td>
#       <td id="T_ae6f9_row1_col2" class="data row1 col2" >+419%</td>
#       <td id="T_ae6f9_row1_col3" class="data row1 col3" >+959%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level2_row2" class="row_heading level2 row2" >$590</th>
#       <th id="T_ae6f9_level3_row2" class="row_heading level3 row2" >$590</th>
#       <td id="T_ae6f9_row2_col0" class="data row2 col0" >-100%</td>
#       <td id="T_ae6f9_row2_col1" class="data row2 col1" >+182%</td>
#       <td id="T_ae6f9_row2_col2" class="data row2 col2" >+671%</td>
#       <td id="T_ae6f9_row2_col3" class="data row2 col3" >+1650%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level0_row3" class="row_heading level0 row3" rowspan="2">🏗️ 300+ DTE</th>
#       <th id="T_ae6f9_level1_row3" class="row_heading level1 row3" >GE</th>
#       <th id="T_ae6f9_level2_row3" class="row_heading level2 row3" >$310</th>
#       <th id="T_ae6f9_level3_row3" class="row_heading level3 row3" >$2,855</th>
#       <td id="T_ae6f9_row3_col0" class="data row3 col0" >-100%</td>
#       <td id="T_ae6f9_row3_col1" class="data row3 col1" >-5%</td>
#       <td id="T_ae6f9_row3_col2" class="data row3 col2" >+51%</td>
#       <td id="T_ae6f9_row3_col3" class="data row3 col3" >+163%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level1_row4" class="row_heading level1 row4" >TSM</th>
#       <th id="T_ae6f9_level2_row4" class="row_heading level2 row4" >$340</th>
#       <th id="T_ae6f9_level3_row4" class="row_heading level3 row4" >$3,572</th>
#       <td id="T_ae6f9_row4_col0" class="data row4 col0" >-100%</td>
#       <td id="T_ae6f9_row4_col1" class="data row4 col1" >-26%</td>
#       <td id="T_ae6f9_row4_col2" class="data row4 col2" >+22%</td>
#       <td id="T_ae6f9_row4_col3" class="data row4 col3" >+120%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level0_row5" class="row_heading level0 row5" rowspan="2">🔄 30-90 DTE</th>
#       <th id="T_ae6f9_level1_row5" class="row_heading level1 row5" >LRCX</th>
#       <th id="T_ae6f9_level2_row5" class="row_heading level2 row5" >$210</th>
#       <th id="T_ae6f9_level3_row5" class="row_heading level3 row5" >$3,075</th>
#       <td id="T_ae6f9_row5_col0" class="data row5 col0" >-69%</td>
#       <td id="T_ae6f9_row5_col1" class="data row5 col1" >+6%</td>
#       <td id="T_ae6f9_row5_col2" class="data row5 col2" >+43%</td>
#       <td id="T_ae6f9_row5_col3" class="data row5 col3" >+119%</td>
#     </tr>
#     <tr>
#       <th id="T_ae6f9_level1_row6" class="row_heading level1 row6" >WDC</th>
#       <th id="T_ae6f9_level2_row6" class="row_heading level2 row6" >$270</th>
#       <th id="T_ae6f9_level3_row6" class="row_heading level3 row6" >$3,575</th>
#       <td id="T_ae6f9_row6_col0" class="data row6 col0" >-100%</td>
#       <td id="T_ae6f9_row6_col1" class="data row6 col1" >-25%</td>
#       <td id="T_ae6f9_row6_col2" class="data row6 col2" >+14%</td>
#       <td id="T_ae6f9_row6_col3" class="data row6 col3" >+93%</td>
#     </tr>
#   </tbody>
# </table>
# ### 🔗 Correlation — Selected Tickers
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="0b044ba3-f7a6-473e-9c1c-683805cdeb1e" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0b044ba3-f7a6-473e-9c1c-683805cdeb1e")) {                    Plotly.newPlot(                        "0b044ba3-f7a6-473e-9c1c-683805cdeb1e",                        [{"colorscale":[[0.0,"rgb(0,104,55)"],[0.1,"rgb(26,152,80)"],[0.2,"rgb(102,189,99)"],[0.3,"rgb(166,217,106)"],[0.4,"rgb(217,239,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(254,224,139)"],[0.7,"rgb(253,174,97)"],[0.8,"rgb(244,109,67)"],[0.9,"rgb(215,48,39)"],[1.0,"rgb(165,0,38)"]],"text":{"dtype":"f8","bdata":"AAAAAAAA8D\u002fhehSuR+HKP3sUrkfherQ\u002fSOF6FK5H0T8AAAAAAADQP8P1KFyPwtU\u002f4XoUrkfhyj8AAAAAAADwP65H4XoUrtc\u002fuB6F61G43j+uR+F6FK7XP1yPwvUoXN8\u002fexSuR+F6tD+uR+F6FK7XPwAAAAAAAPA\u002fcT0K16Nw3T+amZmZmZnZP0jhehSuR9E\u002fSOF6FK5H0T+4HoXrUbjeP3E9CtejcN0\u002fAAAAAAAA8D9xPQrXo3DlPzMzMzMzM+M\u002fAAAAAAAA0D+uR+F6FK7XP5qZmZmZmdk\u002fcT0K16Nw5T8AAAAAAADwP1yPwvUoXN8\u002fw\u002fUoXI\u002fC1T9cj8L1KFzfP0jhehSuR9E\u002fMzMzMzMz4z9cj8L1KFzfPwAAAAAAAPA\u002f","shape":"6, 6"},"textfont":{"size":12},"texttemplate":"%{text}","x":["AMZN","CMI","GE","LRCX","TSM","WDC"],"y":["AMZN","CMI","GE","LRCX","TSM","WDC"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D8WTBJ2NIzKP5sfNx0rpLQ\u002f1SgOzwV20T\u002f+LC6vCwzQP\u002fHaNNpq6dU\u002fFkwSdjSMyj8AAAAAAADwP0vFYhyD39c\u002fsueQ52N+3j8X5lgM\u002fePXP3kZfjjaT98\u002fmx83HSuktD9LxWIcg9\u002fXPwAAAAAAAPA\u002fuEufVF4y3T9DbW3zXK\u002fZP\u002fkleS8EX9E\u002f1SgOzwV20T+y55DnY37eP7hLn1ReMt0\u002fAAAAAAAA8D+O3ZD+s4PlP+lDQWyiEOM\u002f\u002fiwurwsM0D8X5lgM\u002fePXP0NtbfNcr9k\u002fjt2Q\u002frOD5T8AAAAAAADwPxM1K8NdN98\u002f8do02mrp1T95GX442k\u002ffP\u002fkleS8EX9E\u002f6UNBbKIQ4z8TNSvDXTffPwAAAAAAAPA\u002f","shape":"6, 6"},"zmax":1.0,"zmin":-0.2,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"], ...
# **⚠️ Correlated pairs in portfolio:**
# - LRCX ↔ TSM: ρ = 0.67 — consider these as overlapping exposure
# ### 🎯 Sizing Logic Breakdown
# <style type="text/css">
# </style>
# <table id="T_306fa">
#   <caption>How each position was sized — Kelly fraction × balance constraints</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_306fa_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_306fa_level0_col1" class="col_heading level0 col1" >Bucket</th>
#       <th id="T_306fa_level0_col2" class="col_heading level0 col2" >Strike</th>
#       <th id="T_306fa_level0_col3" class="col_heading level0 col3" >DTE</th>
#       <th id="T_306fa_level0_col4" class="col_heading level0 col4" >Kelly Frac</th>
#       <th id="T_306fa_level0_col5" class="col_heading level0 col5" >Contracts</th>
#       <th id="T_306fa_level0_col6" class="col_heading level0 col6" >Total Cost</th>
#       <th id="T_306fa_level0_col7" class="col_heading level0 col7" >% of Portfolio</th>
#       <th id="T_306fa_level0_col8" class="col_heading level0 col8" >P(Profit)</th>
#       <th id="T_306fa_level0_col9" class="col_heading level0 col9" >R/R</th>
#       <th id="T_306fa_level0_col10" class="col_heading level0 col10" >Corr Penalty</th>
#       <th id="T_306fa_level0_col11" class="col_heading level0 col11" >Portfolio Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_306fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_306fa_row0_col0" class="data row0 col0" >TSM</td>
#       <td id="T_306fa_row0_col1" class="data row0 col1" >🏗️ 300+ DTE</td>
#       <td id="T_306fa_row0_col2" class="data row0 col2" >$340</td>
#       <td id="T_306fa_row0_col3" class="data row0 col3" >96</td>
#       <td id="T_306fa_row0_col4" class="data row0 col4" >0.5%</td>
#       <td id="T_306fa_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_306fa_row0_col6" class="data row0 col6" >$3,572</td>
#       <td id="T_306fa_row0_col7" class="data row0 col7" >23.8%</td>
#       <td id="T_306fa_row0_col8" class="data row0 col8" >35%</td>
#       <td id="T_306fa_row0_col9" class="data row0 col9" >0.2x</td>
#       <td id="T_306fa_row0_col10" class="data row0 col10" >1.00</td>
#       <td id="T_306fa_row0_col11" class="data row0 col11" >68</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_306fa_row1_col0" class="data row1 col0" >LRCX</td>
#       <td id="T_306fa_row1_col1" class="data row1 col1" >🔄 30-90 DTE</td>
#       <td id="T_306fa_row1_col2" class="data row1 col2" >$210</td>
#       <td id="T_306fa_row1_col3" class="data row1 col3" >40</td>
#       <td id="T_306fa_row1_col4" class="data row1 col4" >0.5%</td>
#       <td id="T_306fa_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_306fa_row1_col6" class="data row1 col6" >$3,075</td>
#       <td id="T_306fa_row1_col7" class="data row1 col7" >20.5%</td>
#       <td id="T_306fa_row1_col8" class="data row1 col8" >39%</td>
#       <td id="T_306fa_row1_col9" class="data row1 col9" >0.4x</td>
#       <td id="T_306fa_row1_col10" class="data row1 col10" >0.97</td>
#       <td id="T_306fa_row1_col11" class="data row1 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_306fa_row2_col0" class="data row2 col0" >CMI</td>
#       <td id="T_306fa_row2_col1" class="data row2 col1" >⚡ <30 DTE</td>
#       <td id="T_306fa_row2_col2" class="data row2 col2" >$590</td>
#       <td id="T_306fa_row2_col3" class="data row2 col3" >12</td>
#       <td id="T_306fa_row2_col4" class="data row2 col4" >3.4%</td>
#       <td id="T_306fa_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_306fa_row2_col6" class="data row2 col6" >$590</td>
#       <td id="T_306fa_row2_col7" class="data row2 col7" >3.9%</td>
#       <td id="T_306fa_row2_col8" class="data row2 col8" >27%</td>
#       <td id="T_306fa_row2_col9" class="data row2 col9" >6.7x</td>
#       <td id="T_306fa_row2_col10" class="data row2 col10" >1.00</td>
#       <td id="T_306fa_row2_col11" class="data row2 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_306fa_row3_col0" class="data row3 col0" >WDC</td>
#       <td id="T_306fa_row3_col1" class="data row3 col1" >🔄 30-90 DTE</td>
#       <td id="T_306fa_row3_col2" class="data row3 col2" >$270</td>
#       <td id="T_306fa_row3_col3" class="data row3 col3" >33</td>
#       <td id="T_306fa_row3_col4" class="data row3 col4" >0.5%</td>
#       <td id="T_306fa_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_306fa_row3_col6" class="data row3 col6" >$3,575</td>
#       <td id="T_306fa_row3_col7" class="data row3 col7" >23.8%</td>
#       <td id="T_306fa_row3_col8" class="data row3 col8" >34%</td>
#       <td id="T_306fa_row3_col9" class="data row3 col9" >0.1x</td>
#       <td id="T_306fa_row3_col10" class="data row3 col10" >1.00</td>
#       <td id="T_306fa_row3_col11" class="data row3 col11" >57</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_306fa_row4_col0" class="data row4 col0" >CMI</td>
#       <td id="T_306fa_row4_col1" class="data row4 col1" >⚡ <30 DTE</td>
#       <td id="T_306fa_row4_col2" class="data row4 col2" >$580</td>
#       <td id="T_306fa_row4_col3" class="data row4 col3" >12</td>
#       <td id="T_306fa_row4_col4" class="data row4 col4" >3.5%</td>
#       <td id="T_306fa_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_306fa_row4_col6" class="data row4 col6" >$1,070</td>
#       <td id="T_306fa_row4_col7" class="data row4 col7" >7.1%</td>
#       <td id="T_306fa_row4_col8" class="data row4 col8" >34%</td>
#       <td id="T_306fa_row4_col9" class="data row4 col9" >4.2x</td>
#       <td id="T_306fa_row4_col10" class="data row4 col10" >0.48</td>
#       <td id="T_306fa_row4_col11" class="data row4 col11" >54</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_306fa_row5_col0" class="data row5 col0" >AMZN</td>
#       <td id="T_306fa_row5_col1" class="data row5 col1" >⚡ <30 DTE</td>
#       <td id="T_306fa_row5_col2" class="data row5 col2" >$220</td>
#       <td id="T_306fa_row5_col3" class="data row5 col3" >12</td>
#       <td id="T_306fa_row5_col4" class="data row5 col4" >0.0%</td>
#       <td id="T_306fa_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_306fa_row5_col6" class="data row5 col6" >$192</td>
#       <td id="T_306fa_row5_col7" class="data row5 col7" >1.3%</td>
#       <td id="T_306fa_row5_col8" class="data row5 col8" >19%</td>
#       <td id="T_306fa_row5_col9" class="data row5 col9" >4.9x</td>
#       <td id="T_306fa_row5_col10" class="data row5 col10" >1.00</td>
#       <td id="T_306fa_row5_col11" class="data row5 col11" >53</td>
#     </tr>
#     <tr>
#       <th id="T_306fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_306fa_row6_col0" class="data row6 col0" >GE</td>
#       <td id="T_306fa_row6_col1" class="data row6 col1" >🏗️ 300+ DTE</td>
#       <td id="T_306fa_row6_col2" class="data row6 col2" >$310</td>
#       <td id="T_306fa_row6_col3" class="data row6 col3" >96</td>
#       <td id="T_306fa_row6_col4" class="data row6 col4" >0.5%</td>
#       <td id="T_306fa_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_306fa_row6_col6" class="data row6 col6" >$2,855</td>
#       <td id="T_306fa_row6_col7" class="data row6 col7" >19.0%</td>
#       <td id="T_306fa_row6_col8" class="data row6 col8" >38%</td>
#       <td id="T_306fa_row6_col9" class="data row6 col9" >0.5x</td>
#       <td id="T_306fa_row6_col10" class="data row6 col10" >1.00</td>
#       <td id="T_306fa_row6_col11" class="data row6 col11" >49</td>
#     </tr>
#   </tbody>
# </table>
# ---
# ### ✅ Portfolio Complete
#
# - **7 positions** across **6 tickers** and **3 time horizons**
# - **$14,930 deployed** (100%) with **$70 cash reserve** (0%)
# - Weighted P(Profit): **35%** | Weighted R/R: **0.9x** | Avg DTE: **59d**
# - Effective positions: **5.0** (HHI = 0.20)
#
# **Portfolio is max-loss capped at $14,930** (options expire worthless). Cash reserve provides dry powder for dips or rolling positions.
#
# *Rebalance triggers:* Roll LEAPS when DTE < 90. Take profit on swings at 2× entry. Re-run this notebook weekly for updated scores.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
